# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 페이지 리스트에서 타이틀, 링크 크롤링

# %%
start = time.time()

path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)

title = []
link = []

for page in range(1,17):
    url='http://www.marieclairekorea.com/page/'+str(page)+'/?s=%EC%A0%9C%EB%8B%88'
    driver.get(url)
    
    contElements = driver.find_elements_by_css_selector('article')

    for cont in contElements:
        # 타이틀 가져오기
        title.append(cont.find_element_by_tag_name('h2').text)
        

        # 링크 가져오기
        link.append(cont.find_element_by_tag_name('a').get_attribute('href'))
        
        time.sleep(1)
print(title)
print(len(title), len(link))


print(time.time() - start)
# Out:
# ['지금 당장 ‘손민수’하고 싶은 드라마 속 메이크업 룩', 'BEAUTIFUL MIND', 'One Moment More', '부담스럽지 않아, 볼드한 주얼리.', '낭만의 시대', '스타들이 선택한 데일리백은?', '돌고 돌아 다시 유행하는 타이다이', '묶고 묶고 또 묶고', '제니도 도전한 블리치 헤어', '매일매일 입고 싶은 티셔츠', '집콕 아트를 실현하는 사람들', 'VERSACE', '장기용의 여름 날', '요즘 대세! 하이라이트 염색', '더울 땐 올림머리', 'TOM FORD', 'REJINA PYO', '꽃으로 전하는 위로', '도전 더위사냥! 스타들의 반다나 헤어 활용법', 'ADVANCED ENSEMBLE', '마리&메종 쇼퍼북 뷰티 #스킨케어', '두 사람만을 위한 어느 뷰티 데이', 'HOME, SWEET JENTLE HOME – Video', '제니, 젠틀홈 패키지 언박싱', '제니의 젠틀홈 투어', '2020 F/W 패션위크 다이어리 – 뉴욕', '책상, 봄', '제니와 젠틀몬스터가 함께 꾸민 공간', '나, 수지', '다시 만난 패션', '허니문 스냅에 대한 모든 것 – 제주도', 'DAY DREAM', 'VERSACE', '눈가에 스며든 파스텔 컬러', '11월 마지막주 #영화 추천', '미래의 라이프스타일을 경험하다 LIFEPLUS 컨퍼런스 2019', '11월 넷째주 #영화 #드라마 추천', '얼굴에 바르는 유산균', '#마리이벤트 – 허슬러', '내추럴 스모키 메이크업 ①', '2020 S/S 패션위크다이어리 #밀란', '11월 신상 뷰티템 #메이크업', 'EDITOR’S REVIEW, 2020 루이비통 크루즈', '2019 BIFF 아시아 스타 어워즈 수상자', '2019 BIFF 아시아 스타 어워즈', '피부를 지켜줄 슈퍼 세럼 9', '메이크업 텍스처 플레이 #립스틱', '피부 보약 환절기 에센스', '아시아 스타 어워즈 2019', '올가을 위시리스트 #데님룩', '요즘 머리', '9월 셋째주 #드라마 추천',
# ...

# %%
marie_jenny= pd.DataFrame({
    'title':title,
    'link':link
})
marie_jenny
# Out:
#                              title  \
# 0    지금 당장 ‘손민수’하고 싶은 드라마 속 메이크업 룩
# 1                   BEAUTIFUL MIND
# 2                  One Moment More
# 3               부담스럽지 않아, 볼드한 주얼리.
# 4                           낭만의 시대
# ..                             ...
# 146                  사랑을 부르는 오감 뷰티
# 147                      야해서 웃긴 광고
# 148                 Remind Wedding
# 149                     카메라 밖의 구하라
# 150                   김혜성, 다시 시작한다
#
#                                                   link
# 0    http://www.marieclairekorea.com/beauty/2020/12...
# 1    http://www.marieclairekorea.com/celebrity/2020...
# 2    http://www.marieclairekorea.com/celebrity/2020...
# 3    http://www.marieclairekorea.com/fashion/2020/0...
# 4    http://www.marieclairekorea.com/fashion/2020/0...
# ..                                                 ...
# 146  http://www.marieclairekorea.com/beauty/2016/02...
# 147  http://www.marieclairekorea.com/lifestyle/2016...
# ...

# %%
start = time.time()

path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)

title = []
link = []

for page in range(1,64):
    url='http://www.marieclairekorea.com/page/'+str(page)+'/?s=%EC%A7%80%EC%88%98'
    driver.get(url)
    
    contElements = driver.find_elements_by_css_selector('article')

    for cont in contElements:
        # 타이틀 가져오기
        title.append(cont.find_element_by_tag_name('h2').text)
        

        # 링크 가져오기
        link.append(cont.find_element_by_tag_name('a').get_attribute('href'))
        
        time.sleep(1)
print(title)
print(len(title), len(link))


print(time.time() - start)
# Out:
# ['올겨울 코트 스타일', '따뜻하고 스타일리시한 패딩', '내 입술을 따뜻한 커피처럼', '2020 STRANGER AWARDS', '반클리프 아펠의 우아한 세계', '가을 베이식 아이템으로 옷입기', '2021 S/S 뉴욕 패션 위크 리포트', '보습의 정석', 'MASCULINE SCENE', '마린 세르 신드롬', '니트의 계절', '요즘 어떤 운동화가 핫해?', '키치의 세계', '새 시대, 세 디자이너', '가죽의 힘', 'Unforgettable', '낭만의 시대', '점만 잘 찍어도!', 'BEST VEST', '디지털 나라의 런웨이', '보이지 않을 수 없는 여성이 될 때까지', 'THE CODE', '느리게 가는 큐이', 'CALM And GRACE', '디올 뷰티의 뮤즈, 지수와 함께한 뷰티 필름', '8월 셋째주 #신작 추천', 'BEAUTY BEHIND', '마리끌레르 9월호 커버 주인공, 지수', '지수다운 순간', '꿉꿉한 여름엔 바디 미스트', '혼수 공예품', '패션 에디터들이 입어본 스커트', '코로나 시대의 웨딩', '장마철 불쾌지수를 낮추는 방법', '새로워진 동네 자양동 ②', '새로워진 동네 자양동 ①', '포스트 코로나 시대 뷰티 트렌드', 'MZ세대가 사는 세상', 'ON EARTH', '어떤 자외선도 철저히 차단한다 헤라 선메이트', '원 샷 원 킬', '신비한 나라의 허자보이', '넷플릭스 영화 <365일>에 관한 궁금증', '슬기로운 향기 생활', '여름을 위한 향', '쌓이고 쌓이는', '태양을 피하는 방법', '즐겁고, 건강하게! ②', '올여름 꼭 구매하고 싶은 일곱 개의 아이템!', '생생한 제품 평가', 'SNS로 체감하는 뷰티 스토리', '나는 박주현', '골프 하기 좋은 날', '흔들림 없이 맑게 차오르는 피부, 아모레퍼시픽 빈티지 싱글 익스트렉트 에센스', '도시 뷰티 백서', '갱년기 여성 건강을 위한 프리미엄 앰플 바이탈뷰티 자음보액', '아이스크림 주세요!', 'LOEWE', 'A.W.A.
# ...

# %%
marie_jisu= pd.DataFrame({
    'title':title,
    'link':link
})
marie_jisu
# Out:
#                          title  \
# 0                   올겨울 코트 스타일
# 1               따뜻하고 스타일리시한 패딩
# 2               내 입술을 따뜻한 커피처럼
# 3         2020 STRANGER AWARDS
# 4              반클리프 아펠의 우아한 세계
# ..                         ...
# 619  사랑스러운 파스텔 컬러 메이크업을 한 러블리즈
# 620                     심쿵 주의보
# 621                사표 내기 10초 전
# 622                The Journey
# 623                    박서준의 확신
#
#                                                   link
# 0    http://www.marieclairekorea.com/fashion/2020/1...
# 1    http://www.marieclairekorea.com/fashion/2020/1...
# 2    http://www.marieclairekorea.com/%ed%96%a5%ec%9...
# 3    http://www.marieclairekorea.com/lifestyle/2020...
# 4    http://www.marieclairekorea.com/fashion/2020/1...
# ..                                                 ...
# 619  http://www.marieclairekorea.com/celebrity/2016...
# 620  http://www.marieclairekorea.com/lifestyle/2016...
# 621  http://www.marieclairekorea.com/lifestyle/2016...
# ...

# %%
start = time.time()

path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)

title = []
link = []

for page in range(1,9):
    url='http://www.marieclairekorea.com/page/'+str(page)+'/?s=%EB%A1%9C%EC%A0%9C'
    driver.get(url)
    
    contElements = driver.find_elements_by_css_selector('article')

    for cont in contElements:
        # 타이틀 가져오기
        title.append(cont.find_element_by_tag_name('h2').text)
        

        # 링크 가져오기
        link.append(cont.find_element_by_tag_name('a').get_attribute('href'))
        
        time.sleep(1)
print(title)
print(len(title), len(link))


print(time.time() - start)
# Out:
# ['연말에 어울리는 술', '패셔니스타들이 레오퍼드 스커트를 입는 방법', '집에서도 할 수 있다 부기 빼기!', '넥스트 K- 뷰티', '그들이 입은 여름, 슬리브리스', '브루어리 여행 ② 대전 여행 스팟', '홈 술과 홈 밥', '마리&메종 쇼퍼북 패션 #쥬얼리', '마리&메종 쇼퍼북 뷰티 #메이크업', '럭셔리한 포인트 가구', '샤넬과 아카데미 시상식', 'S/S 키 룩 따라입기 ⑤', 'PYER MOSS', '후암동 골목길 ②', '가을 원석 주얼리', '남프랑스의 휴양지, 코트다쥐르', '빈티지 마스터', '정확한 도달', '한국에서 빚은 와인', '내추럴 와인과 치즈', '아이린 뷰티 TIP', '8월 신상 뷰티템 #향수', '7월 마지막주 염소자리 별자리 운세', '7월 신상 뷰티템 #향수', '5월 뷰티 신상 #향수', '봄 스타일링 포인트로 제격! 스타일별 주얼리 추천', '워크웨어 스타일링 가이드 #모던', '사랑의 고전', '액세서리로 스타일링 끝!', '스타일링의 마무리는 진주 액세서리로', '패션의 완성은 액세서리', '와인의 시간', '연말, 파티 퀸 스타일링 #반짝반짝 화려한 룩', '2018 마지막 뷰티 신상 #메이크업제품', '동화속 공주님처럼', 'LATE VACANCE', '헬로키티 101', 'SLOK의 내추럴 와인', '봄의 향기', '와인 보다 맛있는 와인 가이드', '#가성비 좋은 신상 봄 향수', 'Boogie Night Movie', '신부를 위한 장미꽃향기', 'Blooming Scene', '겨울 쿠션', '달콤한 선물', '요즘 홈 클래스', 'Brilliant Moments', '대구 골목의 발견 ②', '낮술 한잔', '샴페인 마시기 좋은 날', '피노 누아에 바치는 헌사', 'Love Fully', '오승훈의 출발', '예쁘고 맛있는 선물', '인투 더 포레스트', '밸런타인 선물 가이드 ② 뷰티 아이템', '마음을 담은 기프트 박스', '해운대 EAT, PLAY, LOVE! ②', 'LOVE! C
# ...

# %%
marie_rose= pd.DataFrame({
    'title':title,
    'link':link
})
marie_rose
# Out:
#                       title                                               link
# 0                연말에 어울리는 술  http://www.marieclairekorea.com/lifestyle/2020...
# 1   패셔니스타들이 레오퍼드 스커트를 입는 방법  http://www.marieclairekorea.com/fashion/2020/0...
# 2        집에서도 할 수 있다 부기 빼기!  http://www.marieclairekorea.com/beauty/2020/07...
# 3                 넥스트 K- 뷰티  http://www.marieclairekorea.com/beauty/2020/07...
# 4          그들이 입은 여름, 슬리브리스  http://www.marieclairekorea.com/fashion/2020/0...
# ..                      ...                                                ...
# 72            영화인들이 사랑하는 영화  http://www.marieclairekorea.com/lifestyle/2016...
# 73                떠나고 싶은 영화  http://www.marieclairekorea.com/lifestyle/2015...
# 74      미러 선글라스를 위한 메이크업 키트  http://www.marieclairekorea.com/beauty/2015/07...
# 75             Fresh Moment  http://www.marieclairekorea.com/celebrity/2015...
# 76              Pretty Girl  http://www.marieclairekorea.com/celebrity/2015...
#
# [77 rows x 2 columns]

# %%
start = time.time()

path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)

title = []
link = []

for page in range(1,15):
    url='http://www.marieclairekorea.com/page/'+str(page)+'/?s=%EB%A6%AC%EC%82%AC'
    driver.get(url)
    
    contElements = driver.find_elements_by_css_selector('article')

    for cont in contElements:
        # 타이틀 가져오기
        title.append(cont.find_element_by_tag_name('h2').text)
        

        # 링크 가져오기
        link.append(cont.find_element_by_tag_name('a').get_attribute('href'))
        
        time.sleep(1)
print(title)
print(len(title), len(link))


print(time.time() - start)
# Out:
# ['남자의 피부를 위한 완벽 솔루션', '지금은 아이 메이크업을 할때', '소셜 벤처, 제가 합니다', '스포츠 브랜드의 바람막이', '지수다운 순간', '시원하고 간편하게 트랙 쇼츠', '운동화나 사볼까?', '포스트 코로나 시대 뷰티 트렌드', '주식 초보를 위한 유튜브와 책', '브루어리 여행 ④ 광주 여행 스팟', '우산보다 버킷 햇', '곰손도 그릴 수 있다, 완벽한 눈썹!', 'SIES MARJAN', 'MICHAEL KORS', 'PRADA', 'VICTORIA BECKHAM', '이토록 예쁜 수영복', '2020 섹스 라이프', '그와 계속 자도 괜찮을까?', '나우, 서울', 'Rise And Shine', '2020 F/W 패션위크 다이어리 – 뉴욕', '트레쉬 버스터즈', '2020 F/W 패션위크 다이어리 – 파리', '뭐 이런 걸 다', '오픈톨드를 만나다', '다시 만난 패션', '2월 넷째주 #신작 추천', '2월 둘째주 #신작 추천', 'PYRAMID OF GIFTS', '유랑하는 삶', '스키복의 숨겨진 세상', 'Winter Acc Idea: 가죽 장갑', '독도 여행', '참외로 차린 한 상', '이 땅에서 나는 밀', 'TIMELESS', '나의 시골살이', '양파와 마늘로 차린 밥상', '구리빛 피부를 위한 태닝 숍 리스트', 'NEW 뷰티 브랜드 소식', '운동은 장비빨 #하이킹&트레킹', '초여름 더위를 잊게 할 #스릴러 5편', '스타들의 휴가룩', '참 쉬운 다이어트', '테라스가 있는 작은 실험실', '#라이프레시피 한우샤브샤브, 관계의 법칙', '플라스틱을 대하는 우리의 자세 ②', '#마리이벤트 – 킹아더', '지구를 지키는 패션 히어로', '어글리 슈즈의 시대는 계속된다', 'WHEN I GROW UP', '인재 예측 보고서 #건축&영화&요리', 'Halpern', '새해 첫 술', 'Michael Kors', 'SEED TO TABLE', '특별한 크래프트 숍 ②', '목수의 상상은 현실이 된다', '구
# ...

# %%
marie_lisa= pd.DataFrame({
    'title':title,
    'link':link
})
marie_lisa
# Out:
#                           title  \
# 0             남자의 피부를 위한 완벽 솔루션
# 1               지금은 아이 메이크업을 할때
# 2                 소셜 벤처, 제가 합니다
# 3                 스포츠 브랜드의 바람막이
# 4                       지수다운 순간
# ..                          ...
# 127  Turn Up The Music(Bagagee)
# 128                      소울의 계절
# 129                   각질은 내게 맡겨
# 130     내 남자친구 이야기 With 인피니트 성종
# 131                  이직을 위한 자격증
#
#                                                   link
# 0    http://www.marieclairekorea.com/%ed%96%a5%ec%9...
# 1    http://www.marieclairekorea.com/beauty/2020/11...
# 2    http://www.marieclairekorea.com/%ed%96%a5%ec%9...
# 3    http://www.marieclairekorea.com/video/fashion-...
# 4    http://www.marieclairekorea.com/celebrity/2020...
# ..                                                 ...
# 127  http://www.marieclairekorea.com/lifestyle/2015...
# 128  http://www.marieclairekorea.com/lifestyle/2015...
# 129  http://www.marieclairekorea.com/beauty/2015/10...
# ...

# %%
def get_date(df):
    df['year'] = df['link'].str.split('/').str[4]
    df['mon'] = df['link'].str.split('/').str[5]
    df['date'] = df['year'].astype(str)+'-'+df['mon'].astype(str)
    display(df)

# %%
marie_bp = [marie_jenny, marie_jisu, marie_rose, marie_lisa]

# %%
for bp in marie_bp:
    get_date(bp)
# Out:
#                              title  \
# 0    지금 당장 ‘손민수’하고 싶은 드라마 속 메이크업 룩
# 1                   BEAUTIFUL MIND
# 2                  One Moment More
# 3               부담스럽지 않아, 볼드한 주얼리.
# 4                           낭만의 시대
# ..                             ...
# 146                  사랑을 부르는 오감 뷰티
# 147                      야해서 웃긴 광고
# 148                 Remind Wedding
# 149                     카메라 밖의 구하라
# 150                   김혜성, 다시 시작한다
#
#                                                   link  year mon     date
# 0    http://www.marieclairekorea.com/beauty/2020/12...  2020  12  2020-12
# 1    http://www.marieclairekorea.com/celebrity/2020...  2020  11  2020-11
# 2    http://www.marieclairekorea.com/celebrity/2020...  2020  10  2020-10
# 3    http://www.marieclairekorea.com/fashion/2020/0...  2020  09  2020-09
# 4    http://www.marieclairekorea.com/fashion/2020/0...  2020  09  2020-09
# ..                                                 ...   ...  ..      ...
# ...

# %% [markdown]
# ### 본문 크롤링

# %%
path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)
driver

# content_list = []

for i in range(5, len(marie_jenny)):
    url = marie_jenny['link'][i]
    driver.get(url)
    
    print(i, driver.current_url)
    
    para = []
    
    contents = driver.find_element_by_css_selector('div.post-content')
    
    p_contents = contents.find_elements_by_css_selector('p')
    
    for content in p_contents:
        para.append(content.text)
        
    content_list.append(para)
    
    time.sleep(2)

    

print(len(marie_jenny))
print(len(content_list))
# Out:
# 5 http://www.marieclairekorea.com/fashion/2020/08/%ec%8a%a4%ed%83%80%eb%93%a4%ec%9d%b4-%ec%84%a0%ed%83%9d%ed%95%9c-%eb%8d%b0%ec%9d%bc%eb%a6%ac%eb%b0%b1%ec%9d%80/
# 6 http://www.marieclairekorea.com/fashion/2020/08/%eb%8f%8c%ea%b3%a0-%eb%8f%8c%ec%95%84-%eb%8b%a4%ec%8b%9c-%ec%9c%a0%ed%96%89%ed%95%98%eb%8a%94-%ed%83%80%ec%9d%b4%eb%8b%a4%ec%9d%b4/
# 7 http://www.marieclairekorea.com/fashion/2020/08/%eb%ac%b6%ea%b3%a0-%eb%ac%b6%ea%b3%a0-%eb%98%90-%eb%ac%b6%ea%b3%a0/
# 8 http://www.marieclairekorea.com/beauty/2020/08/%ec%a0%9c%eb%8b%88%eb%8f%84-%eb%8f%84%ec%a0%84%ed%95%9c-%eb%b8%94%eb%a6%ac%ec%b9%98-%ed%97%a4%ec%96%b4/
# 9 http://www.marieclairekorea.com/fashion/2020/07/%eb%a7%a4%ec%9d%bc%eb%a7%a4%ec%9d%bc-%ec%9e%85%ea%b3%a0-%ec%8b%b6%ec%9d%80-%ed%8b%b0%ec%85%94%ec%b8%a0/
# 10 http://www.marieclairekorea.com/%ed%96%a5%ec%9e%a5/2020/07/%ec%a7%91%ec%bd%95-%ec%95%84%ed%8a%b8%eb%a5%bc-%ec%8b%a4%ed%98%84%ed%95%98%eb%8a%94-%ec%82%ac%eb%9e%8c%eb%93%a4/
# ...

# %%
len(content_list)
# Out:
# 151

# %%
len(marie_jenny)
# Out:
# 151

# %%
marie_jenny['contents'] = content_list

# %%
path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)
driver

content_list = []

for i in range(len(marie_rose)):
    url = marie_rose['link'][i]
    driver.get(url)
    
    print(i, driver.current_url)
    
    para = []
    
    contents = driver.find_element_by_css_selector('div.post-content')
    
    p_contents = contents.find_elements_by_css_selector('p')
    
    for content in p_contents:
        para.append(content.text)
        
    content_list.append(para)
    
    time.sleep(2)
    

print(len(marie_rose))
print(len(content_list))
# Out:
# 0 http://www.marieclairekorea.com/lifestyle/2020/12/holiday-drink/
# 1 http://www.marieclairekorea.com/fashion/2020/08/%ed%8c%a8%ec%85%94%eb%8b%88%ec%8a%a4%ed%83%80%eb%93%a4%ec%9d%b4-%eb%a0%88%ec%98%a4%ed%8d%bc%eb%93%9c-%ec%8a%a4%ec%bb%a4%ed%8a%b8%eb%a5%bc-%ec%9e%85%eb%8a%94-%eb%b0%a9%eb%b2%95/
# 2 http://www.marieclairekorea.com/beauty/2020/07/%ec%a7%91%ec%97%90%ec%84%9c%eb%8f%84-%ed%95%a0-%ec%88%98-%ec%9e%88%eb%8b%a4-%eb%b6%80%ea%b8%b0-%eb%b9%bc%ea%b8%b0/
# 3 http://www.marieclairekorea.com/beauty/2020/07/%eb%84%a5%ec%8a%a4%ed%8a%b8-k-%eb%b7%b0%ed%8b%b0/
# 4 http://www.marieclairekorea.com/fashion/2020/07/%ea%b7%b8%eb%93%a4%ec%9d%b4-%ec%9e%85%ec%9d%80-%ec%97%ac%eb%a6%84-%ec%8a%ac%eb%a6%ac%eb%b8%8c%eb%a6%ac%ec%8a%a4/
# 5 http://www.marieclairekorea.com/lifestyle/2020/06/%eb%b8%8c%eb%a3%a8%ec%96%b4%eb%a6%ac-%ec%97%ac%ed%96%89-%e2%91%a1-%eb%8c%80%ec%a0%84-%ec%97%ac%ed%96%89-%ec%8a%a4%ed%8c%9f/
# ...

# %%
marie_rose['contents'] = content_list

# %%
path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)
driver

# content_list = []

for i in range(608, len(marie_jisu)):
    url = marie_jisu['link'][i]
    driver.get(url)
    
    print(i, driver.current_url)
    
    para = []
    
    contents = driver.find_element_by_css_selector('div.post-content')
    
    p_contents = contents.find_elements_by_css_selector('p')
    
    for content in p_contents:
        para.append(content.text)
        
    content_list.append(para)
    
    time.sleep(1)
    

print(len(marie_jisu))
print(len(content_list))
# Out:
# 608 http://www.marieclairekorea.com/lifestyle/2016/06/%eb%8b%a5%ed%84%b0%ec%8a%a4/
# 609 http://www.marieclairekorea.com/lifestyle/2016/06/%ec%97%ac%ed%96%89%ec%9d%84-%eb%96%a0%eb%82%98%ea%b3%a0-%ec%8b%b6%ec%9d%80-%eb%8f%84%ec%8b%9c/
# 610 http://www.marieclairekorea.com/celebrity/2016/06/%ea%bf%88%ea%be%b8%eb%8a%94-%eb%b0%b0%ec%9a%b0%eb%93%a4-%ec%9e%84%ec%84%b8%eb%af%b8%ec%9d%98-%ec%8b%9c%ec%9e%91%eb%90%9c-%ec%97%ac%ec%a0%95/
# 611 http://www.marieclairekorea.com/lifestyle/2016/05/%ec%97%84%eb%a7%88%ec%99%80-%eb%94%b8/
# 612 http://www.marieclairekorea.com/fashion/2016/05/%ec%97%ac%eb%a6%84-%ec%8b%a0%ec%83%81-%ec%84%a0%ea%b8%80%eb%9d%bc%ec%8a%a4/
# 613 http://www.marieclairekorea.com/runway/2016/05/gucci-2/
# 614 http://www.marieclairekorea.com/beauty/2016/05/%eb%82%b4%ec%9d%bc-%eb%84%a4%ec%9d%bc/
# 615 http://www.marieclairekorea.com/beauty/2016/05/%ec%98%a8%ec%b2%9c%ec%88%98-%eb%af%b8%ec%8a%a4%ed%8a%b8/
# ...

# %%
len(content_list)
# Out:
# 624

# %%
marie_jisu['contents'] = content_list

# %%
path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)
driver

content_list = []

for i in range(len(marie_lisa)):
    url = marie_lisa['link'][i]
    driver.get(url)
    
    print(i, driver.current_url)
    
    para = []
    
    contents = driver.find_element_by_css_selector('div.post-content')
    
    p_contents = contents.find_elements_by_css_selector('p')
    
    for content in p_contents:
        para.append(content.text)
        
    content_list.append(para)
    
    time.sleep(1)
    

print(len(marie_lisa))
print(len(content_list))
# Out:
# 0 http://www.marieclairekorea.com/%ed%96%a5%ec%9e%a5/2020/12/men-skincare/
# 1 http://www.marieclairekorea.com/beauty/2020/11/catch-your-eyes/
# 2 http://www.marieclairekorea.com/%ed%96%a5%ec%9e%a5/2020/10/%ec%86%8c%ec%85%9c-%eb%b2%a4%ec%b2%98-%ec%a0%9c%ea%b0%80-%ed%95%a9%eb%8b%88%eb%8b%a4/
# 3 http://www.marieclairekorea.com/video/fashion-video/2020/09/%ec%8a%a4%ed%8f%ac%ec%b8%a0-%eb%b8%8c%eb%9e%9c%eb%93%9c%ec%9d%98-%eb%b0%94%eb%9e%8c%eb%a7%89%ec%9d%b4/
# 4 http://www.marieclairekorea.com/celebrity/2020/08/%ec%a7%80%ec%88%98%eb%8b%a4%ec%9a%b4-%ec%88%9c%ea%b0%84/
# 5 http://www.marieclairekorea.com/fashion/2020/08/%ec%8b%9c%ec%9b%90%ed%95%98%ea%b3%a0-%ea%b0%84%ed%8e%b8%ed%95%98%ea%b2%8c-%ed%8a%b8%eb%9e%99-%ec%87%bc%ec%b8%a0/
# 6 http://www.marieclairekorea.com/fashion/2020/08/%ec%9a%b4%eb%8f%99%ed%99%94%eb%82%98-%ec%82%ac%eb%b3%bc%ea%b9%8c/
# ...

# %%
marie_lisa['contents'] = content_list

# %%
marie_jenny.head()
# Out:
#                            title  \
# 0  지금 당장 ‘손민수’하고 싶은 드라마 속 메이크업 룩
# 1                 BEAUTIFUL MIND
# 2                One Moment More
# 3             부담스럽지 않아, 볼드한 주얼리.
# 4                         낭만의 시대
#
#                                                 link  year mon     date  \
# 0  http://www.marieclairekorea.com/beauty/2020/12...  2020  12  2020-12
# 1  http://www.marieclairekorea.com/celebrity/2020...  2020  11  2020-11
# 2  http://www.marieclairekorea.com/celebrity/2020...  2020  10  2020-10
# 3  http://www.marieclairekorea.com/fashion/2020/0...  2020  09  2020-09
# 4  http://www.marieclairekorea.com/fashion/2020/0...  2020  09  2020-09
#
#                                             contents
# 0  [최근 생긴 신조어 ‘손민수’하다 라는 말을 들어보았는지?\n몇 년 전, 화제가 되...
# 1  [, 에스티 로더의 베스트셀링 파운데이션,\n더블웨어 스테이-인-플레이스 메이크업\...
# 2                                            [, ,  ]
# 3  [볼드한 주얼리에 눈길이 가는 계절이다.\n두꺼운 체인, 화려한 보석, 주렁주렁한 ...
# 4  [매 시즌 유혹의 손길을 내미는 수많은 패션 아이템 중 원피스가 다수의 국내 여성복...

# %%
marie_jisu.head()
# Out:
#                   title                                               link  \
# 0            올겨울 코트 스타일  http://www.marieclairekorea.com/fashion/2020/1...
# 1        따뜻하고 스타일리시한 패딩  http://www.marieclairekorea.com/fashion/2020/1...
# 2        내 입술을 따뜻한 커피처럼  http://www.marieclairekorea.com/%ed%96%a5%ec%9...
# 3  2020 STRANGER AWARDS  http://www.marieclairekorea.com/lifestyle/2020...
# 4       반클리프 아펠의 우아한 세계  http://www.marieclairekorea.com/fashion/2020/1...
#
#    year mon     date                                           contents
# 0  2020  12  2020-12  [Tip! 길이가 짧은 퍼 재킷은 사랑스러운 무드를 살리는 게 핵심이다. 리본이나 ...
# 1  2020  12  2020-12  [Tip! 같은 퍼퍼 재킷이라도 뉴트럴 컬러가 더해지면 스타일리시한 느낌이 배가된다...
# 2  2020  12  2020-12  [ , 겨울철 입술이 유독 갈라지고 건조한 이유는 무엇일까? 입술은 눈가와 마찬가지...
# 3  2020  12  2020-12  [복길(칼럼니스트)\n올해 방송인 박세리를 처음 만났고 김민경을 다시 보았고, 이효...
# 4  2020  11  2020-11  [이번 전시에 대해 소개해주기 바란다., 리즈 맥도널드(이하 리즈) 2021년 6월...

# %%
marie_rose.head()
# Out:
#                      title                                               link  \
# 0               연말에 어울리는 술  http://www.marieclairekorea.com/lifestyle/2020...
# 1  패셔니스타들이 레오퍼드 스커트를 입는 방법  http://www.marieclairekorea.com/fashion/2020/0...
# 2       집에서도 할 수 있다 부기 빼기!  http://www.marieclairekorea.com/beauty/2020/07...
# 3                넥스트 K- 뷰티  http://www.marieclairekorea.com/beauty/2020/07...
# 4         그들이 입은 여름, 슬리브리스  http://www.marieclairekorea.com/fashion/2020/0...
#
#    year mon     date                                           contents
# 0  2020  12  2020-12  [케이스에 원하는 문구를 새길 수 있는 리미티드 에디션.\n사과와 감귤 등 과일 향...
# 1  2020  08  2020-08  [레오퍼드 패턴이라 하면 ‘센’ 이미지가 강했는데,\n그랬던 ‘레오퍼드’가\n어느새...
# 2  2020  07  2020-07  [더운 날씨 때문에 밤마다 잠을 설치고,\n그로 인해 얼굴이 자꾸만 붓는것 같은 건...
# 3  2020  07  2020-07                              [ ,  ,  ,  ,  ,  ,  ]
# 4  2020  07  2020-07  [여름이 되면\n한 번쯤 입고 싶어지는 슬리브리스., 어떤 스타일을 어떻게 입을지\...

# %%
marie_lisa.head()
# Out:
#                title                                               link  \
# 0  남자의 피부를 위한 완벽 솔루션  http://www.marieclairekorea.com/%ed%96%a5%ec%9...
# 1    지금은 아이 메이크업을 할때  http://www.marieclairekorea.com/beauty/2020/11...
# 2      소셜 벤처, 제가 합니다  http://www.marieclairekorea.com/%ed%96%a5%ec%9...
# 3      스포츠 브랜드의 바람막이  http://www.marieclairekorea.com/video/fashion-...
# 4            지수다운 순간  http://www.marieclairekorea.com/celebrity/2020...
#
#             year   mon                date  \
# 0           2020    12             2020-12
# 1           2020    11             2020-11
# 2           2020    10             2020-10
# 3  fashion-video  2020  fashion-video-2020
# 4           2020    08             2020-08
#
#                                             contents
# 0  [ ,  , 헤라 옴므 블랙 퍼펙트 스킨 바이오 포리사카라이드\n장수유전자, SIR...
# 1  [ , 이번 시즌에는 창의적인 아이라인이 대거 등장했다. 랙 앤 본은 뉴욕의 스카이...
# 2  [핸드스피크를 창업하게 된 계기가 있나요? 2010년, 제가 일하는 공연 기획사에 ...
# 3  [ , , 요즘처럼 아침 저녁으로 쌀쌀한 간절기에\n가볍게 툭 걸치기 좋은 바람 막...
# ...

# %%
marie_jenny.to_csv('marie_jenny.csv', sep = '|', encoding = 'utf-8', index = 'False')
marie_jisu.to_csv('marie_jisu.csv', sep = '|', encoding = 'utf-8', index = 'False')
marie_rose.to_csv('marie_rose.csv', sep = '|', encoding = 'utf-8', index = 'False')
marie_lisa.to_csv('marie_lisa.csv', sep = '|', encoding = 'utf-8', index = 'False')

# %% [markdown]
# # 카테고리 가져오기

# %% [markdown]
# ## 데이터 가져오기

# %%
marie_chanel = pd.read_csv('marie_chanel.csv', sep = '|', encoding = 'utf-8')
marie_dior = pd.read_csv('marie_dior.csv', sep = '|', encoding = 'utf-8')
marie_ysl = pd.read_csv('marie_ysl.csv', sep = '|', encoding = 'utf-8')
marie_celine = pd.read_csv('marie_celine.csv', sep = '|', encoding = 'utf-8')

# %% [markdown]
# ## 본문에 브랜드 없는 것 check 컬럼에 2 부여

# %%
marie_celine.head()
# Out:
#                                 title  \
# 0                     MASCULINE SCENE
# 1  2020 F/W BEAUTY TREND FORECAST – 2
# 2                              낭만의 시대
# 3                              DOUBLE
# 4                 2020 F/W 뷰티 트렌드 프리뷰
#
#                                                 link     date  self  \
# 0  http://www.marieclairekorea.com/fashion/2020/1...  2020-10     0
# 1  http://www.marieclairekorea.com/beauty/2020/10...  2020-10     0
# 2  http://www.marieclairekorea.com/fashion/2020/0...  2020-09     0
# 3  http://www.marieclairekorea.com/fashion/2020/0...  2020-09     0
# 4  http://www.marieclairekorea.com/%ed%96%a5%ec%9...  2020-09     0
#
#                                              content  check  why
# 0                                           ['', '']      0  NaN
# 1  ['올가을에는 짙은 레드 립스틱 대신 마치 뱀파이어 영화 속 흡혈귀같은 다크 립스틱...      0  NaN
# 2  ['매 시즌 유혹의 손길을 내미는 수많은 패션 아이템 중 원피스가 다수의 국내 여성...      0  NaN
# ...

# %%
def get_check_2(df, kw):
    for i in range(len(df)):
        if df['title_brand'][i] == 0:
            if not kw in df['content'][i]:
                df['check'][i] = 2

# %%
marie_ysl['title_brand'] = 0
marie_ysl['check'] = 0
marie_ysl['why']=''

# %%
marie_celine.columns = ['title', 'link', 'date', 'title_brand', 'content', 'check', 'why']

# %%
get_check_2(marie_chanel, '샤넬')
get_check_2(marie_dior, '디올')
get_check_2(marie_ysl, '로랑')
get_check_2(marie_celine, '셀린느')
# Out:
# C:\Users\wnsgo\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# ## 카테고리 가져오기

# %%
def get_cat(df):
    df['category'] = df['link'].str.split('/').str[3]

# %%
get_cat(marie_chanel)
get_cat(marie_dior)
get_cat(marie_ysl)
get_cat(marie_celine)

# %% [markdown]
# ## 카테고리 뷰티인 것은 check 컬럼에 2부여

# %%
print('chanel')
marie_chanel['category'].value_counts()
# Out:
# chanel
# fashion        311
# beauty         251
# video           24
# celebrity       22
# ad-campaign     15
# lifestyle       12
# 향장               3
# runway           2
# mc-likes         1
# shopperbook      1
# Name: category, dtype: int64

# %%
marie_chanel.loc[marie_chanel['category'] == '%ed%96%a5%ec%9e%a5', 'category'] ='향장'

# %%
marie_chanel[(marie_chanel['category'] =='celebrity')]
# Out:
#                              title  \
# 17                      KEEP GOING
# 119                        꽃처럼, 민아
# 154                아시아 스타 어워즈 2019
# 174                ONCE IN MY LIFE
# 177         FUSED WITH IRENE – 아이린
# 226               YOU LOOK SO COOL
# 247             몰디브에서 보낸 기은세의 홀리데이
# 267                         김고은의 봄
# 346  ASIA STAR AWARDS 2018 WINNERS
# 349     BIFF ASIA STAR AWARDS 2018
# 351                       HER TIME
# 362          #BIFF 아시아 스타 어워즈 2018
# 365                        다미를 보세요
# 369                       Who Am I
# 466                 Blooming Scene
# 505             Emma Stone In Hope
# 507           BIFF 아시아 스타 어워즈 2017
# 553                 박신혜의 밤, 그리고 파리
# 576                  한예슬의 달콤한 뷰티 신
# 583                  Miss Scarlett
# 603                우주소녀의 달콤한 크리스마스
# 612   아시아 스타 어워즈 With BIFF #올해의배우들
#
#                                                   link     date  title_brand  \
# ...

# %%
print('dior')
marie_dior['category'].value_counts()
# Out:
# dior
# fashion        255
# beauty         242
# celebrity       52
# video           24
# lifestyle        6
# ad-campaign      4
# runway           2
# 향장               2
# mc-likes         1
# shopperbook      1
# Name: category, dtype: int64

# %%
marie_dior.loc[marie_dior['category'] == '%ed%96%a5%ec%9e%a5', 'category'] = '향장'

# %%
print('ysl')
marie_ysl['category'].value_counts()
# Out:
# ysl
# fashion        145
# beauty         101
# celebrity       18
# lifestyle        8
# runway           6
# video            4
# ad-campaign      2
# film             1
# shopperbook      1
# Name: category, dtype: int64

# %%
print('celine')
marie_celine['category'].value_counts()
# Out:
# celine
# fashion        143
# celebrity       15
# beauty           8
# ad-campaign      4
# 향장               2
# lifestyle        1
# runway           1
# film             1
# Name: category, dtype: int64

# %%
get_date(marie_ysl)
# Out:
#                     title                                               link  \
# 0              코트 속 러플 셔츠  http://www.marieclairekorea.com/fashion/2020/1...
# 1    THINGS WE SAID TODAY  http://www.marieclairekorea.com/celebrity/2020...
# 2      THE SENSUAL THINGS  http://www.marieclairekorea.com/fashion/2020/1...
# 3            가을 아우터 코드 #2  http://www.marieclairekorea.com/fashion/2020/1...
# 4        BACK TO THE 90’S  http://www.marieclairekorea.com/beauty/2020/10...
# ..                    ...                                                ...
# 386          할머니 옷장을 뒤져라!  http://www.marieclairekorea.com/fashion/2015/0...
# 387                페이의 욕심  http://www.marieclairekorea.com/celebrity/2015...
# 388                이게 나예요  http://www.marieclairekorea.com/celebrity/2015...
# 389               박서준의 확신  http://www.marieclairekorea.com/celebrity/2014...
# 390         참 괜찮은 뮤지션 박재범  http://www.marieclairekorea.com/celebrity/2013...
#
# ...

# %%
marie_ysl['date'].unique()
# Out:
# array(['2020-11', '2020-10', '2020-09', '2020-08', '2020-07', '2020-06',
#        '2020-05', '2020-04', '2020-03', '2020-02', '2020-01', '2019-12',
#        '2019-11', '2019-10', '2019-09', '2019-08', '2019-07', '2019-06',
#        '2019-05', '2019-04', '2019-03', '2019-02', '2019-01', '2018-12',
#        '2018-11', nan, '2018-10', '2018-09', '2018-08', '2018-07',
#        '2018-06', '2018-05', '2018-04', '2018-03', '2018-02', '2018-01',
#        '2017-12', '2017-11', '2017-10', '2017-09', '2017-08', '2017-07',
#        '2017-06', '2017-05', '2017-04', '2017-03', '2017-02', '2017-01',
#        '2016-12', '2016-11', '2016-10', '2016-09', '2016-08', '2016-07',
#        '2016-06', '2016-05', '2016-04', '2016-03', '2016-02', '2016-01',
#        '2015-12', '2015-11', '2015-10', '2015-09', '2015-07', '2015-03',
#        '2014-07', '2013-05'], dtype=object)

# %%
marie_ysl[marie_ysl['date'].isnull()]
# Out:
#                       title  \
# 134  #마리이벤트 – 다이빙 : 그녀에 빠지다
#
#                                                   link  \
# 134  http://www.marieclairekorea.com/%eb%a7%88%eb%a...
#
#                                                content  title_brand  check  \
# 134  ['감성 멜로 드라마 <다이빙: 그녀에 빠지다> 예매권 이벤트!\n뜨거웠던 사랑 후...            0      0
#
#     why                                           category year  mon date
# 134      %eb%a7%88%eb%a6%ac%ec%9d%b4%eb%b2%a4%ed%8a%b8-...       NaN  NaN

# %%
marie_ysl = marie_ysl.dropna(axis=0)

# %%
drop_year(marie_ysl)
# Out:
# C:\Users\wnsgo\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# C:\Users\wnsgo\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\wnsgo\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
marie_dior[marie_dior['title'] == '디올의 여름']
# Out:
#       title                                               link     date  \
# 181  디올의 여름  http://www.marieclairekorea.com/fashion/2019/0...  2019-06
#
#      title_brand                                            content  check  \
# 181            1  ['디올의 수장, 마리아 그라치아 치우리가\n러시아 발레단, ‘발레 뤼스(Ballt...      0
#
#      why category
# 181  NaN  fashion

# %% [markdown]
# ## 뷰티 찾기

# %%
def find_beauty(df):
    df.loc[df['category'] == 'beauty', 'check'] = 2
    display(df[df['category'] == 'beauty'])

# %%
find_beauty(marie_chanel)
find_beauty(marie_dior)
find_beauty(marie_ysl)
find_beauty(marie_celine)
# Out:
#                         title  \
# 1    연말 파티 메이크업은 펑크 메이크업이 대세!
# 2        HAPPY EARLY HOLIDAY!
# 3                      보습의 정석
# 6            MY SCENT JOURNEY
# 8                KISS MY LIPS
# ..                        ...
# 622           가을을 위한 메이크업 팁 3
# 631            쉽게 따라 하는 입체 화장
# 632           신혼여행을 위한 트래블 키트
# 637          고가 VS 저가 #네일 에나멜
# 638                  귀부인의 인생템
#
#                                                   link     date  title_brand  \
# 1    http://www.marieclairekorea.com/beauty/2020/11...  2020-11            0
# 2    http://www.marieclairekorea.com/beauty/2020/11...  2020-11            0
# 3    http://www.marieclairekorea.com/beauty/2020/10...  2020-10            0
# 6    http://www.marieclairekorea.com/beauty/2020/10...  2020-10            0
# 8    http://www.marieclairekorea.com/beauty/2020/10...  2020-10            0
# ..                                                 ...      ...          ...
# ...

# %%
marie_chanel.to_csv('marie_chanel.csv', sep='|', encoding='utf-8', index = False)
marie_dior.to_csv('marie_dior.csv', sep='|', encoding='utf-8', index = False)
marie_ysl.to_csv('marie_ysl.csv', sep='|', encoding='utf-8', index = False)
marie_celine.to_csv('marie_celine.csv', sep='|', encoding='utf-8', index = False)

# %%
marie_chanel = pd.read_csv('marie_chanel.csv', sep='|', encoding='utf-8')
marie_dior = pd.read_csv('marie_dior.csv', sep='|', encoding='utf-8')
marie_ysl = pd.read_csv('marie_ysl.csv', sep='|', encoding='utf-8')
marie_celine = pd.read_csv('marie_celine.csv', sep='|', encoding='utf-8')

# %%
marie_chanel['brand'] = 'Ch'

# %%
marie_dior['brand'] = 'D'

# %%
marie_ysl['brand'] = 'YSL'

# %%
marie_celine['brand'] = 'Ce'

# %%
marie_chanel.to_csv('marie_chanel.csv', sep='|', encoding='utf-8', index = False)
marie_dior.to_csv('marie_dior.csv', sep='|', encoding='utf-8', index = False)
marie_ysl.to_csv('marie_ysl.csv', sep='|', encoding='utf-8', index = False)
marie_celine.to_csv('marie_celine.csv', sep='|', encoding='utf-8', index = False)

# %% [markdown]
# # 셀린 다시 크롤링

# %%
start = time.time()

path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)

title = []
link = []

for page in range(1,23):
    url='http://www.marieclairekorea.com/page/'+str(page)+'/?s=%EC%85%80%EB%A6%B0'
    driver.get(url)
    
    print(driver.current_url)
    
    contElements = driver.find_elements_by_css_selector('article')

    for cont in contElements:
        # 타이틀 가져오기
        title.append(cont.find_element_by_tag_name('h2').text)
        

        # 링크 가져오기
        link.append(cont.find_element_by_tag_name('a').get_attribute('href'))
        
        time.sleep(2)

print(len(title), len(link))


print(time.time() - start)
# Out:
# http://www.marieclairekorea.com/page/1/?s=%EC%85%80%EB%A6%B0
# http://www.marieclairekorea.com/page/2/?s=%EC%85%80%EB%A6%B0
# http://www.marieclairekorea.com/page/3/?s=%EC%85%80%EB%A6%B0
# http://www.marieclairekorea.com/page/4/?s=%EC%85%80%EB%A6%B0
# http://www.marieclairekorea.com/page/5/?s=%EC%85%80%EB%A6%B0
# http://www.marieclairekorea.com/page/6/?s=%EC%85%80%EB%A6%B0
# http://www.marieclairekorea.com/page/7/?s=%EC%85%80%EB%A6%B0
# http://www.marieclairekorea.com/page/8/?s=%EC%85%80%EB%A6%B0
# http://www.marieclairekorea.com/page/9/?s=%EC%85%80%EB%A6%B0
# http://www.marieclairekorea.com/page/10/?s=%EC%85%80%EB%A6%B0
# http://www.marieclairekorea.com/page/11/?s=%EC%85%80%EB%A6%B0
# http://www.marieclairekorea.com/page/12/?s=%EC%85%80%EB%A6%B0
# http://www.marieclairekorea.com/page/13/?s=%EC%85%80%EB%A6%B0
# http://www.marieclairekorea.com/page/14/?s=%EC%85%80%EB%A6%B0
# http://www.marieclairekorea.com/page/15/?s=%EC%85%80%EB%A6%B0
# ...

# %%
marie_celine = pd.DataFrame({
    'title':title,
    'link':link
})

# %%
marie_celine.head()
# Out:
#                                 title  \
# 0                             Look At
# 1             10월 넷째주, 11월 첫째주 #신작 추천
# 2                         오직, 여자의 이야기
# 3                     MASCULINE SCENE
# 4  2020 F/W BEAUTY TREND FORECAST – 2
#
#                                                 link
# 0  http://www.marieclairekorea.com/celebrity/2020...
# 1  http://www.marieclairekorea.com/lifestyle/2020...
# 2  http://www.marieclairekorea.com/lifestyle/2020...
# 3  http://www.marieclairekorea.com/fashion/2020/1...
# 4  http://www.marieclairekorea.com/beauty/2020/10...

# %%
path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)
driver

content_list = []

for link in marie_celine['link']:
    url = link
    driver.get(url)
    
    print(driver.current_url)
    
    para = []
    
    contents = driver.find_element_by_css_selector('div.post-content')
    
    p_contents = contents.find_elements_by_css_selector('p')
    
    for content in p_contents:
        para.append(content.text)
        
    content_list.append(para)
    
    time.sleep(1)

    

print(len(marie_celine))
print(len(content_list))
# Out:
# http://www.marieclairekorea.com/celebrity/2020/11/look-at/
# http://www.marieclairekorea.com/lifestyle/2020/11/10%ec%9b%94-%eb%84%b7%ec%a7%b8%ec%a3%bc-11%ec%9b%94-%ec%b2%ab%ec%a7%b8%ec%a3%bc-%ec%8b%a0%ec%9e%91-%ec%b6%94%ec%b2%9c/
# http://www.marieclairekorea.com/lifestyle/2020/11/women-movie/
# http://www.marieclairekorea.com/fashion/2020/10/masculine-scene/
# http://www.marieclairekorea.com/beauty/2020/10/2020-f-w-beauty-trend-forecast-2/
# http://www.marieclairekorea.com/fashion/2020/09/%eb%82%ad%eb%a7%8c%ec%9d%98-%ec%8b%9c%eb%8c%80/
# http://www.marieclairekorea.com/fashion/2020/09/double-2/
# http://www.marieclairekorea.com/%ed%96%a5%ec%9e%a5/2020/09/2020-f-w-%eb%b7%b0%ed%8b%b0-%ed%8a%b8%eb%a0%8c%eb%93%9c-%ed%94%84%eb%a6%ac%eb%b7%b0/
# http://www.marieclairekorea.com/%ed%96%a5%ec%9e%a5/2020/09/%ed%8c%a8%ec%85%94%eb%84%88%eb%b8%94%ed%95%9c-%ed%96%a5%ec%88%98-2/
# http://www.marieclairekorea.com/celebrity/2020/08/%ec%b2%98%ec%9d%8c-%eb%b3%b4%eb%8a%94-%ec%95%88%ec%86%8c%ed%9d%ac/
# ...

# %%
marie_celine['content'] = content_list

# %%
marie_celine['date'] = marie_celine['link'].str.split('/').str[4]+'-'+marie_celine['link'].str.split('/').str[5]

# %%
marie_celine['category'] = marie_celine['link'].str.split('/').str[3]

# %%
get_self(marie_celine, '셀린')
# Out:
#                                title  \
# 52               꼭 기억해야할 스타일링 공식 #셀린
# 84            #OLDCELINE ‘올드 셀린느’의 힘
# 189  #마리패션위크 2017 SS 발렌시아가, 셀린느, 지방시
# 205                      셀린느의 뉴 피비니즘
#
#                                                   link  \
# 52   http://www.marieclairekorea.com/fashion/2019/0...
# 84   http://www.marieclairekorea.com/fashion/2018/1...
# 189  http://www.marieclairekorea.com/fashion/2016/1...
# 205  http://www.marieclairekorea.com/fashion/2016/0...
#
#                                                content     date category  \
# 52   [레트로 트렌드는 이번 시즌에도 이어진다. 셀린느 컬렉션처럼 브라운 톤 체크 팬츠에...  2019-08  fashion
# 84   [, 지난해 12월, LVMH는 10년동안 셀린느(CÉLine)의 수장이었던 피비 ...  2018-11  fashion
# 189  [ , BALENCIAGA, 역시 패션계의 대세 아이콘, 뎀나입니다! 그만의 관능적...  2016-10  fashion
# 205                                                 []  2016-08  fashion
#
#      title_brand  brand
# 52             1    1.0
# 84             1    1.0
# 189            1    1.0
# 205            1    1.0

# %%
marie_celine['check'] = 0
marie_celine['why']=''

# %%
for i in range(len(marie_celine)):
    if not '셀린' in marie_celine['content'][i]:
        marie_celine.loc[i, 'check'] = 2

# %%
marie_celine.head()
# Out:
#                                 title  \
# 0                             Look At
# 1             10월 넷째주, 11월 첫째주 #신작 추천
# 2                         오직, 여자의 이야기
# 3                     MASCULINE SCENE
# 4  2020 F/W BEAUTY TREND FORECAST – 2
#
#                                                 link  \
# 0  http://www.marieclairekorea.com/celebrity/2020...
# 1  http://www.marieclairekorea.com/lifestyle/2020...
# 2  http://www.marieclairekorea.com/lifestyle/2020...
# 3  http://www.marieclairekorea.com/fashion/2020/1...
# 4  http://www.marieclairekorea.com/beauty/2020/10...
#
#                                              content     date   category  \
# 0  [,  , 화보 촬영을 즐기는 편인가? 노출도 약간 있었고, 무용 동작을 요구하기도...  2020-11  celebrity
# 1  [10월 마지막주와 11월 첫째주,\n새롭게 만나볼 수 있는\n신작 12편을 모았다...  2020-11  lifestyle
# 2  [<워터 릴리스><톰보이>에 이은 셀린 시아마 감독의 성장 영화. 엄마를 대신해 동...  2020-11  lifestyle
# 3                                               [, ]  2020-10    fashion
# ...

# %%
marie_celine.to_csv('marie_celine.csv', encoding = 'utf-8', index = False, sep='|')

# %%
pd.read_csv('marie_celine.csv', sep='|', encoding = 'utf-8')
# Out:
#                                   title  \
# 0                               Look At
# 1               10월 넷째주, 11월 첫째주 #신작 추천
# 2                           오직, 여자의 이야기
# 3                       MASCULINE SCENE
# 4    2020 F/W BEAUTY TREND FORECAST – 2
# ..                                  ...
# 208                     과일처럼 상큼발랄한 뷰티 신
# 209                       Woman In Gold
# 210                        디자이너들의 리얼 룩!
# 211                              유정의 여정
# 212               가늘고 길게, 새로운 감성의 미니멀 룩
#
#                                                   link  \
# 0    http://www.marieclairekorea.com/celebrity/2020...
# 1    http://www.marieclairekorea.com/lifestyle/2020...
# 2    http://www.marieclairekorea.com/lifestyle/2020...
# 3    http://www.marieclairekorea.com/fashion/2020/1...
# 4    http://www.marieclairekorea.com/beauty/2020/10...
# ..                                                 ...
# 208  http://www.marieclairekorea.com/beauty/2016/07...
# ...

# %%
marie_ysl.head()
# Out:
#                 title                                               link  \
# 0          코트 속 러플 셔츠  http://www.marieclairekorea.com/fashion/2020/1...
# 1        가을 아우터 코드 #2  http://www.marieclairekorea.com/fashion/2020/1...
# 2    BACK TO THE 90’S  http://www.marieclairekorea.com/beauty/2020/10...
# 3  AUTUMN VELVET LIPS  http://www.marieclairekorea.com/beauty/2020/10...
# 4  부담스럽지 않아, 볼드한 주얼리.  http://www.marieclairekorea.com/fashion/2020/0...
#
#       date  self                                            content
# 0  2020-11     0  [ , 올 가을 꼭 가져야할 아이템을 꼽으라면 러플 셔츠를 추천하고 싶다.\n손쉽게...
# 1  2020-10     0  [ ,  ,  ,  ,  ,  ,  ,  ,  ,  ,  ,  ,  ,  ,  , ...
# 2  2020-10     0  [1990년대 대한민국 아이돌 스타들의 공통점은? 블루와 실버 계열 컬러로 눈두덩 ...
# 3  2020-10     0  [, 1 디올 루즈 디올 울트라 케어 리퀴드. #635 엑스테이즈, 6ml, 4만5...
# 4  2020-09     0  [볼드한 주얼리에 눈길이 가는 계절이다.\n두꺼운 체인, 화려한 보석, 주렁주렁한 ...

# %%
marie_ysl['content'] = content_list

# %%
path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)
driver

content_list = []

for i in range(len(marie_chanel)):
    url = marie_chanel['link'][i]
    driver.get(url)
    
    print(i, driver.current_url)
    
    para = []
    
    contents = driver.find_element_by_css_selector('div.post-content')
    
    p_contents = contents.find_elements_by_css_selector('p')
    
    for content in p_contents:
        para.append(content.text)
        
    content_list.append(para)
marie_chanel['content'] = content_list

    
print('-'*50)
print(len(marie_chanel))
print(len(content_list))
# Out:
# 0 http://www.marieclairekorea.com/fashion/2020/11/scenery-of-autumn/
# 1 http://www.marieclairekorea.com/beauty/2020/11/holiday-punk/
# 2 http://www.marieclairekorea.com/beauty/2020/11/happy-early-holiday/
# 3 http://www.marieclairekorea.com/beauty/2020/10/%eb%b3%b4%ec%8a%b5%ec%9d%98-%ec%a0%95%ec%84%9d/
# 4 http://www.marieclairekorea.com/fashion/2020/10/2021-s-s-fashion-week-review-paris/
# 5 http://www.marieclairekorea.com/fashion/2020/10/the-sensual-things/
# 6 http://www.marieclairekorea.com/beauty/2020/10/my-scent-journey/
# 7 http://www.marieclairekorea.com/fashion/2020/10/%ec%83%a4%eb%84%ac%ec%9d%98-%ec%98%81%ed%99%94%ec%a0%81-%eb%aa%a8%eb%a8%bc%ed%8a%b8/
# 8 http://www.marieclairekorea.com/beauty/2020/10/kiss-my-lips/
# 9 http://www.marieclairekorea.com/beauty/2020/10/2020-f-w-beauty-trend-forecast-1/
# 10 http://www.marieclairekorea.com/fashion/2020/10/for-fall/
# ...

# %%
print('-'*50)
print(len(marie_chanel))
print(len(content_list))
# Out:
# --------------------------------------------------
# 642
# 107

# %%
marie_chanel.loc[107, 'link']
# Out:
# 'http://www.marieclairekorea.com/beauty/2020/02/%eb%b3%bc%eb%b9%a8%ea%b0%84-%eb%a9%94%ec%9d%b4%ed%81%ac%ec%97%85/'

# %% [markdown]
# ### check 확인

# %%
marie_ce['check'].value_counts()
# Out:
# 2    213
# Name: check, dtype: int64

# %%
marie_ce['check'] = 0

# %%
for i in range(len(marie_ce)):
    if marie_ce['title_brand'][i] == 0:
        if not ('셀린' or '셀린느') in marie_ce['contents'][i]:
            marie_ce['check'][i] = 2
# Out:
# C:\Users\wnsgo\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
marie_ce['check'].value_counts()
# Out:
# 0    122
# 2     91
# Name: check, dtype: int64

# %%
marie_ce.head()
# Out:
#   magazine brand   category                               title  \
# 0        M    Ce  celebrity                             Look At
# 1        M    Ce  lifestyle             10월 넷째주, 11월 첫째주 #신작 추천
# 2        M    Ce  lifestyle                         오직, 여자의 이야기
# 3        M    Ce    fashion                     MASCULINE SCENE
# 4        M    Ce     beauty  2020 F/W BEAUTY TREND FORECAST – 2
#
#                                                 link     date  \
# 0  http://www.marieclairekorea.com/celebrity/2020...  2020-11
# 1  http://www.marieclairekorea.com/lifestyle/2020...  2020-11
# 2  http://www.marieclairekorea.com/lifestyle/2020...  2020-11
# 3  http://www.marieclairekorea.com/fashion/2020/1...  2020-10
# 4  http://www.marieclairekorea.com/beauty/2020/10...  2020-10
#
#                                             contents  title_brand  check  why
# 0  ['', ' ', '화보 촬영을 즐기는 편인가? 노출도 약간 있었고, 무용 동작을 ...            0      2  NaN
# ...

# %%
marie_ce.to_csv('./magazine/marie_ce.csv', sep = '|', encoding = 'utf-8', index = False)

# %%
marie_ce['category'].value_counts()
# Out:
# fashion        145
# beauty          20
# celebrity       18
# runway          16
# lifestyle        6
# ad-campaign      4
# 향장               3
# film             1
# Name: category, dtype: int64

# %%
marie_ce.loc[marie_ce['category'] == '%ed%96%a5%ec%9e%a5', 'category'] = '향장'

# %%
marie_ce.loc[7, 'link']
# Out:
# 'http://www.marieclairekorea.com/%ed%96%a5%ec%9e%a5/2020/09/2020-f-w-%eb%b7%b0%ed%8b%b0-%ed%8a%b8%eb%a0%8c%eb%93%9c-%ed%94%84%eb%a6%ac%eb%b7%b0/'
