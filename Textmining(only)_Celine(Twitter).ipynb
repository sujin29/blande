# %%
import pandas as pd
import numpy as np

# %%
from collections import Counter

# %%
a_ce_dw = pd.read_csv('./magazine/final/a_ce_dw.csv', sep = '|', encoding = 'utf-8')
b_ce_dw = pd.read_csv('./magazine/final/b_ce_dw.csv', sep = '|', encoding = 'utf-8')
c_ce_dw = pd.read_csv('./magazine/final/c_ce_dw.csv', sep = '|', encoding = 'utf-8')
e_ce_dw = pd.read_csv('./magazine/final/e_ce_dw.csv', sep = '|', encoding = 'utf-8')
fb_ce_dw = pd.read_csv('./magazine/final/fb_ce_dw.csv', sep = '|', encoding = 'utf-8')
fn_ce_dw = pd.read_csv('./magazine/final/fn_ce_dw.csv', sep = '|', encoding = 'utf-8')
m_ce_dw = pd.read_csv('./magazine/final/m_ce_dw.csv', sep = '|', encoding = 'utf-8')
v_ce_dw = pd.read_csv('./magazine/final/v_ce_dw.csv', sep = '|', encoding = 'utf-8')
w_ce_dw = pd.read_csv('./magazine/final/w_ce_dw.csv', sep = '|', encoding = 'utf-8')

# %% [markdown]
# ## list(article_list) 생성 후 append

# %%
contents_list = []

# %%
magazines_ce_dw = [a_ce_dw, b_ce_dw, c_ce_dw, e_ce_dw, fb_ce_dw, fn_ce_dw, m_ce_dw, v_ce_dw, w_ce_dw]

# %%
a_ce_dw
# Out:
#    magazine brand   category  \
# 0         A    Ce    FASHION
# 1         A    Ce    FASHION
# 2         A    Ce    FASHION
# 3         A    Ce  CELEBRITY
# 4         A    Ce  CELEBRITY
# 5         A    Ce    FASHION
# 6         A    Ce    FASHION
# 7         A    Ce    FASHION
# 8         A    Ce    FASHION
# 9         A    Ce    FASHION
# 10        A    Ce    FASHION
# 11        A    Ce    FASHION
# 12        A    Ce    FASHION
# 13        A    Ce    FASHION
# 14        A    Ce    FASHION
# 15        A    Ce    FASHION
# 16        A    Ce  CELEBRITY
# 17        A    Ce    FEATURE
# 18        A    Ce  CELEBRITY
# 19        A    Ce    FASHION
# 20        A    Ce    FASHION
# 21        A    Ce    FASHION
# 22        A    Ce    FASHION
# 23        A    Ce    FASHION
# 24        A    Ce    FASHION
# 25        A    Ce    FASHION
# 26        A    Ce    FASHION
# 27        A    Ce    FASHION
# 28        A    Ce    FEATURE
# 29        A    Ce    FASHION
# ..      ...   ...        ...
# 59        A    Ce    FASHION
# 60        A    Ce    FASHION
# 61        A    Ce    FASHION
# 62        A    Ce    FASHION
# 63        A    Ce    FASHION
# 64        A    Ce    FASHION
# 65        A    Ce    FASHION
# 66        A    Ce    FASHION
# 67        A    Ce    FASHION
# 68        A    Ce    FASHION
# 69        A    Ce    FASHION
# 70        A    Ce    FASHION
# 71        A    Ce    FASHION
# 72        A    Ce    FASHION
# 73        A    Ce    FASHION
# 74        A    Ce    FASHION
# 75        A    Ce    FASHION
# 76        A    Ce    FASHION
# 77        A    Ce    FASHION
# 78        A    Ce    FASHION
# 79        A    Ce    FASHION
# 80        A    Ce    FEATURE
# 81        A    Ce    FEATURE
# 82        A    Ce    FASHION
# 83        A    Ce    FEATURE
# 84        A    Ce    FASHION
# 85        A    Ce    FEATURE
# 86        A    Ce    FASHION
# 87        A    Ce    FASHION
# 88        A    Ce    FEATURE
#
#                                                 title  \
# 0                                               코트 체크
# 1                                           데님이여 영원하라
# 2                                       남자 백’까지 갖고 싶어
# 3                                               예림-예리
# 4                                       GOOD TIME, 헨리
# 5         차정원부터 아이린까지. 옷 잘입는 셀럽들의 사복 패션에 등장한 뉴 백은 무엇?
# 6                         주식을 시작한 패션 에디터의 이야기, 나는 주주다
# 7                              가을의 그림자만큼 길어진 롱부츠 12가지
# 8                             가을의 정석, 트렌치 코트 입는 법 8가지
# 9                             하나만 걸쳐도 남달라! 후디 입는 법 12
# 10          로퍼의 정체성은 발등의 장식에 따라 달라진다! 신고 싶게 잘생긴 로퍼 19
# 11  ESFP에게 어울리는 운동화는? MBTI 성향 별 어울리는 백과 슈즈 추천 리스트 [3]
# 12  ESFP에게 어울리는 운동화는? MBTI 성향 별 어울리는 백과 슈즈 추천 리스트 [1]
# 13                     1940년대가 돌아온다! 올해는 동전지갑을 주목할 것!
# 14                         가을에 어울리는 색을 딱 하나 고르면? 카멜색!
# 15                       미리 보는 2020 가을 겨울 패션 트렌드! [2]
# 16                                      웃음 뒤의 웃음, 남윤수
# 17                                           다이어트의 마음
# 18                          DON’T CATEGORIZE ME / 유태오
# 19                            당장 따라하고 싶은 다채로운 데님 스타일링
# 20                                   청량한 컬러의 틴티드 선글라스
# 21                                        2020년식 아나바다
# 22             네? 명품 브랜드의 마스크라고요? 코로나19가 바꾼 전 세계 패션 신
# 23                          로고 플레이로 포인트를 더한 각양각색의 티셔츠
# 24                         올봄 다방면으로 활용할 수 있는 베스트 스타일링
# 25                                       봄맞이 원피스 스타일링
# 26                                       나만 알고 싶은 브랜드
# 27                                   스타일을 완성하는 탐나는 벨트
# 28                             쇼핑 좀 해본 패션 고수들의 쇼핑 노하우
# 29                                스타일에 보온성을 위한 한 끗 차이
# ..                                                ...
# 59                                          패션 컬트의 시대
# 60                                거, 트렌치코트 입기 좋은 날씨구만
# 61                                   패션에도 컬러 테라피가 필요해
# 62                              이 럭셔리 브랜드의 로고가 바뀌었다고?
# 63                                       내 사진은 셀피가 최고
# 64                                오 마이 백! 이렇게 예쁠 일이니?
# 65                         헐리우드의 영앤리치 스타들은 어떤 옷을 입을까?
# 66                               눈알가리개 아니고 사이파이 선글라스!
# 67                                모델 김설희, 서울 탈출을 꿈꾸다?
# 68                      트렌치코트, 아노락, 재킷 중 지금 내게 필요한 건?
# 69                                        WARM BREEZE
# 70                                        네 엄마 모델이었냥.
# 71                                            봄철 옷장정리
# 72                                         BE SIMPLE!
# 73                                       MY OWN STAGE
# 74                                        THE PASTELS
# 75                                     LOOK AT THESE!
# 76                                    내 가방을 닦으면 생기는 일
# 77                            인플루언서의 여행지 스타일링 노하우 <1>
# 78                                           어느게 팔이게?
# 79                                           흰색은 다 옳다
# 80                                         사랑을 쓴다 <1>
# 81                                       건축물의 유기적 변신들
# 82                                  머리부터 발끝까지 가죽 레이어링
# 83                                     미니 보습 크림 성분 사전
# 84                                          BEAUTIFUL
# 85                                      ANNE HATHAWAY
# 86                             트렌치 코트, 어디까지 입어봤니? <2>
# 12  ['나에게 어울리는 백과 슈즈는 무엇일까? 2020 가을/겨울 시즌, MBTI 성향...            0      0   -
# 13  ['1970년대의 화려함, 90년대의 익숙함을 지나 40년대의 고풍스러움에 안착했다...            0      0   -
# 14  ['가을을 기다리게 하는 색. 캐멀빛의 다채로운 모습.', '  1990’S CLE...            0      0   -
# 15  ['가을을 오매불망 애타게 기다리는 이들을 위한 가을/겨울 트렌드 키워드 미리보기....            0      0   -
# 16  ['남윤수의 말간 미소 뒤에는 전혀 낯선 얼굴이 있다.', '  이제 확실히 ‘배우...            0      0   -
# 17  ['마를 만큼 말랐음에도 더 마르고 싶은 마음. 마른 몸은 과연 나를 행복의 나라로...            0      0   -
# 18  ['“Don’t Categorize Me.” 그가 말했다. 배우 유태오는 더없이 자...            0      0   -
# 19  ['다채로운 모습의 분방한 데님을 즐길 때. 언제나 그렇듯 믿음직스럽게.', '  ...            0      0   -
# 20  ['맑고 밝은 봄여름의 선글라스라면 청량한 컬러에 햇빛은 제대로 막아주는 틴티드 선...            0      0   -
# 21  ['요즘 애들은 이렇게 사고, 저렇게 팝니다. 디지털 환경 속에서 실현하는 2020...            0      0   -
# 22  ['코로나19가 바꾼 전 세계 패션 신의 풍경. 부디 ‘그땐 그랬지’ 하며 이때를 ...            0      0   -
# 23  ['하나만으로도 스타일링에 힘을 실어줄 티셔츠를 꺼내야 할 때다. 로고 플레이로 포...            0      0   -
# 24  ['올봄 다방면으로 활용할 수 있는 베스트 스타일링, 아우터와 이너웨어 그 사이에서...            0      0   -
# 25  ['봄이 오기 전 필요한 원피스 스타일링. 미니멀부터 캐주얼 스타일까지.', '  ...            0      0   -
# 26  ['오늘도 목마른 쇼퍼들을 위해 골랐다. 나만 알고 싶은 에디터의 사적인 브랜드 리...            0      0   -
# 27  ['벨트는 스타일의 완성도를 높여주는 작지만 강한 병기다. 어디에, 어느 것을 두르...            0      0   -
# 28  ['새해부터는 계획적인 쇼핑을 하리라 결심했지만 날로 높아지는 세일의 할인율에 또 ...            0      0   -
# 29  ['스타일에 보온성을 위한 한 끗 차이. 숨은그림찾기로 겨울철 숨은 아이템을 찾아볼...            0      0   -
# ..                                                ...          ...    ...  ..
# 59  ['패션과 스타일을 숭배하는 여자들의 ‘성경’이나 다름없던 피비 파일로의 셀린느 시...            0      0   -
# 60  ['가을 필수템인 트렌치코트, 누구나 트렌치코트에 얽힌 사연 하나쯤 가지고 있다.'...            0      0   -
# 61  ['피치 핑크, 퍼플, 레드, 그레이 패션에서 인기 만점인 컬러들만 모았다.', '...            0      0   -
# 62  ['에디 슬리먼의 셀린느, 리카르도 티시의 버버리가 간결한 로고 디자인으로 변신했다...            0      0   -
# 63  ['자신의 매력을 제대로 보여주고 싶다면 셀피하라! 찍고 공유하라! 너의 진짜 매력...            0      0   -
# 64  ['작은 벨트백부터 거대한 빅 백까지. 마음을 끄는 새로운 가방들.', '원피스로도...            0      0   -
# 65  ['자유롭고 편안한 데이 룩부터 머리부터 발끝까지 풀 세팅한 나이트 룩까지, 영 앤...            0      0   -
# 66  ['다채로운 컬러의 선글라스 무지개가 떴다. 색도 모양도 각기 다르지만, 모두 뜨거...            0      0   -
# 67  ['비로소 떠나야 알 수 있는 현실의 소중함. 지금 당장 떠나자.', '품이 큰 재...            0      0   -
# 68  ['일교차 심한 요즘 딱 입기 좋은 아우터 셋.', '  TRENCH COAT', ...            0      0   -
# 69  ['잠이 쏟아진다. 따뜻한 봄바람에. 보드라운 옷깃에.', '실크 소재의 잔잔한 꽃...            0      0   -
# 70  ['예쁜 댕댕이들의 엄마를 만났다. 모델들의 강아지를 만났다. 댕댕이들의 포즈실력은...            0      0   -
# 71  ['더 이상 추운 겨울은 없어. 따뜻한 봄이 코끝에 닿기 전, 내게도 정리가 필요해...            0      0   -
# 72  ['옷도 생각도 단순하게. 그 바다에 서서.', '아라(오른쪽 모델)가 입은 하얀색...            0      0   -
# 73  ['나를 위한, 나에 의한, 오로지 나만의 무대가 되어주는 피팅룸. 패턴 플레이에 ...            0      0   -
# 74  ['파스텔 컬러는 형태 없는 꽃이다. 향기이고, 달콤함이다. 샤넬, 니나 리치, 보...            0      0   -
# 75  ['전위적인 사이파이 선글라스부터 화려한 나비 모티브 선글라스까지. 과연 나에게 어...            0      0   -
# 76  ['깨끗한 줄 알았던 내 가방을 닦아보았다.\n  (credit – giphy)\n...            0      0   -
# 77  ['설렘과 낭만이 가득한 여행지에서도 스타일은 중요하다. 여행을 사랑하고 자신만의 ...            0      0   -
# 78  ['자세히 봐야 예쁜 슬리브. 이것은 차라리 마법에 가깝다. 위트 있는 스타일링과 ...            0      0   -
# 79  ['이번 봄/여름 시즌, 검정과 흰색 중에 하나를 선택해야 한다면 당연히 흰색이다....            0      0   -
# 80  ['노래는 사랑의 기승전결을 말한다. 사랑의 감정은 보편적일지라도, 그 안에는 서로...            0      0   -
# 81  ['거대한 고가도로와 철로, 버려진 원자력 발전소가 공원으로, 테마파크로 변했다. ...            0      0   -
# 82  ['가을/겨울이면 언제나처럼 사랑받았던 가죽 아이템. 하지만 이번 시즌 가죽은 더 ...            0      0   -
# 83  ['전문가들은 보습 제품만은 반드시 성분을 확인해야 한다고 강조한다. 내 보습 크림...            0      0   -
# 84  ['창문을 비집고 들어오는 3월의 햇살처럼. 예쁘다. 그저 그대로 너의 모습.', ...            0      0   -
# 85  ['뉴욕의 어느 카페에서 만난 앤 해서웨이. 그녀만큼 팬과 안티팬을 두루 거느리고 ...            0      0   -
# 86  ['봄/가을이면 으레 꺼내 입는 트렌치 코트. 클래식 아이템의 정수로 손꼽히는 트렌...            0      0   -
# 87  ['길바닥을 순식간에 런웨이로 만들어버리는 특별한 아이템이 있다. 섹슈얼리티와 스포...            0      0   -
# 88  ['컴퓨터 툴을 브러시로, 인스타그램을 캔버스로 활용하는 아티스트들이 있다. 인스타...            0      0   -
#
#                                           word_celine
# 0   ['골드 잠금 장식으로 포인트를 준 케이프 체크 코트는 1백9만원, 산드로(Sand...
# 1    ['  빈티지한 주름과 워싱이 특징인 데님 팬츠는 가격미정, 셀린느(Celine).']
# 2       ['  1970년대 에스닉한 분위기가 물씬 풍기는 셀린느의 방패 모양 숄더백.']
# 3   ['재킷, 셔츠, 슈즈는 셀린느(Celine), 블랙 스커트는 렉토, 이어링은 스타...
# 4   ['재킷, 셔츠, 네크리스는 모두 셀린느(Celine), 팬츠는 다잉브리드, 슈즈는...
# 5                               ['셀린느, 나노 벨트백 1백만원대']
# 6   ['  요즘 들어 주식은 친구들과의 대화에서 빼놓을 수 없는 주제가 되었다. 코로나...
# 7   ['  컬러블록이 조화로운 부츠는 가격미정, 샤넬(Chanel). 와인색 니하이 부...
# 8   ['격자무늬 트렌치코트는 4백26만5천원, 와이드 팬츠는 가격미정, 지방시. 밤색 ...
# 9   ['민트색 후드 톱은 가격미정, 크롬하츠(Chrome Hearts). 안경은 52만...
# 10  ['  프린지 장식위에 메탈 소재의 트라이엄프를 장식한 로퍼는 가격미정, 셀린느(C...
# 11  ['다정 다감한 성격 때문에 ENFJ 주변엔 언제나 사람이 많아요. 모임을 좋아하는...
# 12  ['논리적이고 책임감 있는 성격이라 질서를 중시하는 조직에서 일할 확률이 높은 IS...
# 13  ['  히피 룩과 펑크, 글램 룩으로 새로운 바람을 불게 했던 1970년대와 세기말...
# 14  ['빈티지한 체크무늬 재킷은 가격미정, 셀린느(Celine). 비비드한 핑크 컬러 ...
# 15  ['격자무늬는 단순하지만 가장 다양한 모습으로 변주하는 복합적 패턴이기도 하다. 이...
# 16  ['화이트 슬리브리스, 스트라이프 오버올 팬츠는 모두 셀린느(Celine).', '...
# 17  ['나는 쉬지 않고 다이어트를 한다. 평생을 장거리 수영선수 같은 몸을 가지고 싶었...
# 18  ['화이트 슈트 재킷과 블랙 플립플랍은 스타일리스트 소장품. 이너 슬리브리스 톱은 ...
# 19  ['보타이, 오버올 슈트, 버뮤다 쇼츠 등 이번 시즌 데님에도 여지없이 레트로 무드...
# 20  ['파란색 뿔테 틴티드 선글라스는 57만원, 셀린느 바이 베디베로(Celine by...
# 21  ['  빈티지에 대한 나의 첫 기억은 종로5가 광장시장 안에서의 쿰쿰한 냄새와 함께...
# 22  ['‘사회적 거리 두기’가 장기화되며 집에서도 스타일을 유지하고자 하는 이들의 니즈...
# 23  ['  정갈한 고딕체 로고 티셔츠는 가격미정, 셀린느 바이 에디 슬리먼(Celine...
# 24  ['언제든 잘 갖춰 입은 듯한 룩이 필요할 땐 테일러드 스타일의 베스트를 활용해보자...
# 25  ['체인 프린트가 있는 주름 장식 원피스, 벨트와 사이하이 부츠는 모두 가격미정, ...
# 26  ['피터 두는 일상적인 워킹 우먼의 룩을 만드는 뉴욕 브랜드다. 간결하지만 독특한 ...
# 27  ['6 홀스빗 장식의 레더 벨트는 가격미정, 셀린느 바이 에디 슬리먼(Celine ...
# 28  ['2 가장 후회 없는 쇼핑 경험이 있다면? 피비 파일로의 셀린느 피스들. 그녀가 ...
# 29  ['베이지색 케이프 코트, 터틀넥 니트,데님 팬츠, 벨트는 가격미정, 모두 셀린느 ...
# ..                                                ...
# 59  ["['패션과 스타일을 숭배하는 여자들의 ‘성경’이나 다름없던 피비 파일로의 셀린느...
# 60  ['나는 친정으로 가는 KTX 안에서 엄마의 젊은 시절을 끄집어냈다. 버버리 트렌치...
# 61  ['1 셀린느. 2 보테가 베네타. 3 모이나. 4 샤넬. 5 비비안 웨스트우드. ...
# 62  ["['에디 슬리먼의 셀린느, 리카르도 티시의 버버리가 간결한 로고 디자인으로 변신...
# 63  ['패치워크 스타일의 가죽 재킷과 팬츠, 긴 셔츠는 모두 셀린느(Celine). 앞...
# 64  ['  격자무늬 팬츠와 오렌지색 양말은 모두 미우미우(MiuMiu). 메탈 잠금장치...
# 65                             ['진주 귀고리는 가격미정, 셀린느.']
# 66              ['3 빨간색 프레임의 캣아이 선글라스는 셀린느(Celine).']
# 67  ['품이 큰 재킷과 브라톱, 주름 장식 치마는 모두 셀린느(Celine). 격자무늬...
# 68  ['3 싱글 디자인의 회색 트렌치코트에 같은 색상 계열의 이너를 매치해 도시적인 분...
# 69  ["실크 스카프를 덧댄 듯한 니트 톱은 셀린느(Celine). 새틴 스커트는 로우 ...
# 70  ['  실크 프린트 블라우스와 플리츠 스커트는 모두 셀린느(Celine). 진주 귀...
# 71  ['벌룬 소매 원피스는 듀이듀이, 선글라스는 셀린느, 비닐 속에 있는 드레스는 펜디...
# 72  ['아라(오른쪽 모델)가 입은 하얀색 슬립 드레스는 로우클래식(Low Classic...
# 73  ['  시퀸 소재의 튜브톱 드레스는 셀린느 바이 에디 슬리먼(Celine by He...
# 74  ['전체 라인업에서 파스텔 컬러를 포인트로 사용한 컬렉션의 묘미도 놓칠 수 없다. ...
# 75  ['커프스가 긴 화이트 셔츠는 40만원대, 준지(Juun.J). 펑크한 분위기의 스...
# 76  ["['깨끗한 줄 알았던 내 가방을 닦아보았다.\\n  (credit – giphy...
# 77  ['    티셔츠는 세인트 제임스. 팬츠는 유니클로 U(Uniqlo U). 샌들은 ...
# 78  ['처음 보았을 땐 우스꽝스러웠고, 두 번째 보았을 땐 호기심이 생겼다. 세 번째 ...
# 79  ['셔츠를 디자인하는 나에게 화이트 컬러는 완벽한 색이다. 이번 시즌에는 셀린느, ...
# 80  ['(+)사랑에 빠진 사람을 위한 플레이리스트 영화 <미드나잇 인 파리>와 <카페 ...
# 81  ['파리 12구역의 버려진 고가철로 위에 지어진 공원, 프롬나드 플랑테(Promen...
# 82  ['그렇다면 리얼 웨이에서 가죽 레이어드를 얼마큼 활용할 수 있을까? 런웨이와 스트...
# 83  ["['전문가들은 보습 제품만은 반드시 성분을 확인해야 한다고 강조한다. 내 보습 ...
# 84  ['하얀색 톱은 살바토레 페라가모(Salvatore Ferragamo). 하얀 끈 ...
# 85  ['드레스는 라코스테(Lacoste). 스카프는 록킨스. 귀고리는 셀린느.', '재...
# 86  ['셀린느 넓은 칼라와 가슴 덮개를 대신하는 포켓 장식이 동시대적인 멋스러움을 주는...
# 87  ["['길바닥을 순식간에 런웨이로 만들어버리는 특별한 아이템이 있다. 섹슈얼리티와 ...
# 88  ['로고 뒤에 여리 여리한 다리만 보면 고상하고 우아한 샤넬 캠페인? 금발 소년의 ...
#
# [89 rows x 11 columns]

# %%
magazine_list = []
article_list = []
for magazine in magazines_ce_dw:
    articles = magazine['word_celine']
    for article in articles:
        article_list.append(article)

# %%
len(article_list)
# Out:
# 826

# %% [markdown]
# ## 트위터 패키지 안에 konlpy 모듈 호출

# %%
from konlpy.tag import Twitter

# %%
twitter = Twitter()
# Out:
# C:\Users\i\Anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %% [markdown]
# ### 각 문장별로 형태소 구분하기

# %%
sentences_tag = []

for sentence in article_list:
    morph = twitter.pos(sentence)
    sentences_tag.append(morph)
    
    

print(len(sentences_tag))
# Out:
# 826

# %%
sentences_tag[0]
# Out:
# [("['", 'Punctuation'),
#  ('골드', 'Noun'),
#  ('잠금', 'Verb'),
#  ('장식', 'Noun'),
#  ('으로', 'Josa'),
#  ('포인트', 'Noun'),
#  ('를', 'Josa'),
#  ('준', 'Noun'),
#  ('케이프', 'Noun'),
#  ('체크', 'Noun'),
#  ('코트', 'Noun'),
#  ('는', 'Josa'),
#  ('1', 'Number'),
#  ('백', 'Noun'),
#  ('9만원', 'Number'),
#  (',', 'Punctuation'),
#  ('산드로', 'Noun'),
#  ('(', 'Punctuation'),
#  ('Sandro', 'Alpha'),
#  (').', 'Punctuation'),
#  ('데님', 'Noun'),
#  ('팬츠', 'Noun'),
#  ('는', 'Josa'),
#  ('가격', 'Noun'),
#  ('미정', 'Noun'),
#  (',', 'Punctuation'),
#  ('리바이스', 'Noun'),
#  ('(', 'Punctuation'),
#  ('Levi', 'Alpha'),
#  ('’', 'Punctuation'),
#  ('s', 'Alpha'),
#  (').', 'Punctuation'),
#  ('그레이', 'Noun'),
#  ('컬러', 'Noun'),
#  ('니트', 'Noun'),
#  ('톱', 'Noun'),
#  ('은', 'Josa'),
#  ('13만', 'Number'),
#  ('2천원', 'Number'),
#  (',', 'Punctuation'),
#  ('르누이', 'Noun'),
#  ('(', 'Punctuation'),
#  ('Le', 'Alpha'),
#  ('Nuee', 'Alpha'),
#  (').', 'Punctuation'),
#  ('라이딩', 'Noun'),
#  ('부츠', 'Noun'),
#  ('는', 'Josa'),
#  ('2', 'Number'),
#  ('백', 'Noun'),
#  ('26만원', 'Number'),
#  (',', 'Punctuation'),
#  ('발렌티노', 'Noun'),
#  ('가라', 'Noun'),
#  ('바니', 'Noun'),
#  ('.', 'Punctuation'),
#  ('줄무늬', 'Noun'),
#  ('포인트', 'Noun'),
#  ('비니', 'Noun'),
#  ('는', 'Josa'),
#  ('8만', 'Number'),
#  ('5천원', 'Number'),
#  (',', 'Punctuation'),
#  ('프레드', 'Noun'),
#  ('페리', 'Noun'),
#  ('(', 'Punctuation'),
#  ('Fred', 'Alpha'),
#  ('Perry', 'Alpha'),
#  (').', 'Punctuation'),
#  ('로고', 'Noun'),
#  ('패턴', 'Noun'),
#  ('백', 'Noun'),
#  ('은', 'Josa'),
#  ('가격', 'Noun'),
#  ('미정', 'Noun'),
#  (',', 'Punctuation'),
#  ('셀린느', 'Noun'),
#  (".',", 'Punctuation'),
#  ("'", 'Punctuation'),
#  ('벨벳', 'Noun'),
#  ('소재', 'Noun'),
#  ('의', 'Josa'),
#  ('후드', 'Noun'),
#  ('코트', 'Noun'),
#  (',', 'Punctuation'),
#  ('레이스', 'Noun'),
#  ('아플리', 'Adjective'),
#  ('케', 'Noun'),
#  ('디테일', 'Noun'),
#  ('톱', 'Noun'),
#  (',', 'Punctuation'),
#  ('자', 'Noun'),
#  ('카드', 'Noun'),
#  ('소재', 'Noun'),
#  ('스커트', 'Noun'),
#  (',', 'Punctuation'),
#  ('원', 'Modifier'),
#  ('석', 'Noun'),
#  ('네', 'Determiner'),
#  ('크리스', 'Noun'),
#  ('는', 'Josa'),
#  ('모두', 'Noun'),
#  ('가격', 'Noun'),
#  ('미정', 'Noun'),
#  (',', 'Punctuation'),
#  ('셀린느', 'Noun'),
#  ('(', 'Punctuation'),
#  ('Celine', 'Alpha'),
#  (').', 'Punctuation'),
#  ('반', 'Modifier'),
#  ('무테', 'Noun'),
#  ('안경', 'Noun'),
#  ('은', 'Josa'),
#  ('33만원', 'Number'),
#  (',', 'Punctuation'),
#  ('젠틀', 'Noun'),
#  ('몬스터', 'Noun'),
#  ('(', 'Punctuation'),
#  ('Gentle', 'Alpha'),
#  ('Monster', 'Alpha'),
#  (').', 'Punctuation'),
#  ('앵', 'Adverb'),
#  ('클', 'Verb'),
#  ('부츠', 'Noun'),
#  ('는', 'Josa'),
#  ('가격', 'Noun'),
#  ('미정', 'Noun'),
#  (',', 'Punctuation'),
#  ('폴로', 'Noun'),
#  ('랄프', 'Noun'),
#  ('로렌', 'Noun'),
#  ('(', 'Punctuation'),
#  ('Polo', 'Alpha'),
#  ('Ralph', 'Alpha'),
#  ('Lauren', 'Alpha'),
#  (").']", 'Punctuation')]

# %% [markdown]
# ### 1. 명사 혹은 형용사인 품사만 선별해 리스트에 담기

# %%
noun_adj_list= []
for sentence1 in sentences_tag:
    for word, tag in sentence1:
        if tag in ['Noun', 'Adjective']:
            noun_adj_list.append(word)

# %%
len(noun_adj_list)
# Out:
# 68493

# %%
noun_adj_list[:20]
# Out:
# ['골드',
#  '장식',
#  '포인트',
#  '준',
#  '케이프',
#  '체크',
#  '코트',
#  '백',
#  '산드로',
#  '데님',
#  '팬츠',
#  '가격',
#  '미정',
#  '리바이스',
#  '그레이',
#  '컬러',
#  '니트',
#  '톱',
#  '르누이',
#  '라이딩']

# %%
noun_adj_list[:10]
# Out:
# ['골드', '장식', '포인트', '준', '케이프', '체크', '코트', '백', '산드로', '데님']

# %% [markdown]
# ### 선별된 품사별 빈도수 계산 & 상위 빈도 10위까지 출력

# %%
word = Counter(noun_adj_list)
print(word.most_common(200))
# Out:
# [('셀린느', 1157), ('것', 750), ('에디', 560), ('그', 471), ('셀린', 471), ('컬렉션', 465), ('브랜드', 450), ('수', 419), ('있다', 365), ('등', 359), ('패션', 353), ('이', 318), ('있는', 316), ('디자이너', 302), ('룩', 300), ('시즌', 289), ('피비', 283), ('이번', 276), ('백', 263), ('의', 263), ('남성', 254), ('스타일', 244), ('컬러', 230), ('여성', 215), ('디자인', 212), ('팬츠', 204), ('지난', 203), ('디렉터', 202), ('슬리', 200), ('슬리먼', 198), ('드레스', 196), ('쇼', 196), ('말', 186), ('재킷', 184), ('가격', 180), ('더', 179), ('장식', 176), ('새로운', 176), ('파리', 174), ('가장', 171), ('때', 168), ('복', 165), ('생', 161), ('아이템', 156), ('로랑', 153), ('미정', 147), ('옷', 147), ('같은', 146), ('위', 146), ('코트', 144), ('매치', 143), ('를', 140), ('사진', 139), ('일', 137), ('첫', 137), ('크리에이티브', 137), ('그녀', 135), ('로', 134), ('자신', 133), ('가죽', 133), ('로고', 128), ('등장', 126), ('필로', 126), ('역시', 124), ('모델', 123), ('소재', 122), ('디올', 122), ('영국', 121), ('위해', 119), ('블랙', 118), ('스타', 118), ('봄', 118), ('모두', 117), ('셔츠', 116), ('나', 116), ('전', 115), ('듯', 115), ('파일', 115), ('시작', 112), ('버버리', 112), ('스커트', 111), ('실루엣', 107), ('부츠', 105), ('때문', 105), ('럭셔리', 104), ('런웨이', 104), ('여름', 102), ('시대', 101), ('가방', 100), ('연출', 100), ('클래식', 97), ('다양한', 96), ('제품', 96), ('매장', 95), ('하나', 94), ('매력', 94), ('트렌드', 94), ('그룹', 93), ('데님', 92), ('통해', 92), ('화이트', 91), ('샤넬', 90), ('대한', 89), ('라인', 89), ('드', 89), ('구찌', 87), ('주목', 87), ('눈', 87), ('입', 87), ('건', 86), ('바이', 86), ('슬', 86), ('다른', 85), ('내', 85), ('리먼', 85), ('또', 84), ('변화', 83), ('발렌시아', 83), ('모든', 83), ('링', 82), ('사람', 82), ('세계', 81), ('중', 81), ('지방시', 80), ('패션계', 80), ('스', 79), ('최근', 79), ('패션쇼', 79), ('데뷔', 78), ('지금', 77), ('우리', 77), ('프린트', 77), ('패턴', 76), ('슈즈', 76), ('완성', 76), ('영감', 76), ('무드', 76), ('성복', 76), ('생각', 75), ('슈트', 75), ('속', 75), ('세', 75), ('액세서리', 75), ('재', 74), ('캠페인', 74), ('없는', 72), ('정도', 72), ('후', 72), ('일링', 72), ('이미지', 72), ('많은', 72), ('패션위크', 71), ('옴므', 70), ('두', 69), ('피부', 69), ('또한', 68), ('바로', 68), ('하우스', 68), ('사이즈', 67), ('가을', 67), ('미니', 67), ('프랑스', 67), ('시간', 66), ('데', 66), ('사실', 66), ('티', 66), ('수트', 66), ('매출', 66), ('분위기', 65), ('선글라스', 65), ('런던', 65), ('빈티', 64), ('겨울', 64), ('선택', 64), ('안', 63), ('시절', 63), ('느낌', 62), ('감', 62), ('동시', 62), ('가지', 61), ('고', 60), ('광고', 59), ('현재', 59), ('포인트', 58), ('사랑', 58), ('뒤', 58), ('대표', 58), ('케이프', 57), ('스트리트', 57), ('아니라', 57), ('존재', 56), ('리', 56), ('은', 56), ('향수', 56), ('어떤', 55), ('점', 54), ('베스트', 54), ('스니커즈', 54), ('니트', 53), ('세대', 53)]

# %%
# 한 글자인 단어는 제외

for i, v in enumerate(noun_adj_list):
    if len(v)<2:
        noun_adj_list.pop(i)

# %%
count = Counter(noun_adj_list)

# %%
word_list = count.most_common(200)
for v in word_list:
    print(v)
# Out:
# ('셀린느', 1157)
# ('에디', 560)
# ('셀린', 471)
# ('컬렉션', 465)
# ('브랜드', 450)
# ('있다', 365)
# ('패션', 353)
# ('있는', 316)
# ('디자이너', 302)
# ('시즌', 289)
# ('피비', 283)
# ('이번', 276)
# ('남성', 254)
# ('스타일', 244)
# ('컬러', 230)
# ('여성', 215)
# ('디자인', 212)
# ('영화', 51)
# ('다시', 51)
# ('처음', 51)
# ('한편', 51)
# ('진행', 51)
# ('골드', 50)
# ('대해', 50)
# ('명품', 50)
# ('더욱', 50)
# ('오버', 50)
# ('뉴욕', 50)
# ('이후', 50)
# ('없다', 49)
# ('효과', 49)
# ('발표', 49)
# ('이름', 48)
# ('웨어', 48)
# ('당시', 47)
# ('더', 47)
# ('방식', 47)
# ('체크', 46)
# ('에디터', 46)
# ('메종', 46)
# ('테일러', 46)
# ('있을', 46)
# ('지난해', 46)
# ('무늬', 45)
# ('인스타그램', 45)
# ('블라우스', 45)
# ('말', 45)
# ('시도', 45)
# ('아티스', 45)
# ('펜디', 44)
# ('길이', 44)
# ('시크', 44)

# %% [markdown]
# ### 2. 명사만 선별해 리스트에 담기

# %%
noun= []
for sentence1 in sentences_tag:
    for word, tag in sentence1:
        if tag in ['Noun']:
            noun.append(word)

# %%
for i, v in enumerate(noun):
    if len(v)<2:
        noun.pop(i)

# %%
counts = Counter(noun)

# %% [markdown]
# ### 3. 명사만 선별해 아티클 별로 리스트에 담기

# %%
noun_article= []
for sentence1 in sentences_tag:
    art_noun = []
    for word, tag in sentence1:
        if tag in ['Noun']:
            art_noun.append(word)
    noun_article.append(art_noun)

print(len(noun_article))
# Out:
# 826

# %%
len(article_list)
# Out:
# 826

# %%
noun_df = pd.DataFrame({
    'article':article_list,
    'noun':noun_article
})

# %%
w_list = noun_df['noun']

# %%
for i in range(len(w_list)):
    for idx, v in enumerate(w_list[i]):
        if len(v)<2:
            w_list[i].pop(idx)

# %%
w_list[0]
# Out:
# ['골드',
#  '장식',
#  '포인트',
#  '케이프',
#  '체크',
#  '코트',
#  '산드로',
#  '데님',
#  '팬츠',
#  '가격',
#  '미정',
#  '리바이스',
#  '그레이',
#  '컬러',
#  '니트',
#  '르누이',
#  '라이딩',
#  '부츠',
#  '발렌티노',
#  '가라',
#  '바니',
#  '줄무늬',
#  '포인트',
#  '비니',
#  '프레드',
#  '페리',
#  '로고',
#  '패턴',
#  '가격',
#  '미정',
#  '셀린느',
#  '벨벳',
#  '소재',
#  '후드',
#  '코트',
#  '레이스',
#  '디테일',
#  '자',
#  '카드',
#  '소재',
#  '스커트',
#  '크리스',
#  '모두',
#  '가격',
#  '미정',
#  '셀린느',
#  '무테',
#  '안경',
#  '젠틀',
#  '몬스터',
#  '부츠',
#  '가격',
#  '미정',
#  '폴로',
#  '랄프',
#  '로렌']

# %%
noun_df.to_csv('noun_celine.csv', sep = '|', index = False, encoding = 'utf-8')

# %%
noun_df['noun']
# Out:
# 0      [골드, 장식, 포인트, 케이프, 체크, 코트, 산드로, 데님, 팬츠, 가격, 미정...
# 1                  [빈티, 주름, 워싱, 특징, 데님, 팬츠, 가격, 미정, 셀린느]
# 2                        [에스, 분위기, 물씬, 셀린느, 방패, 모양, 숄더백]
# 3      [재킷, 셔츠, 슈즈, 셀린느, 블랙, 스커트, 렉토, 이어링, 스타일, 리스트, ...
# 4            [재킷, 셔츠, 크리스, 모두, 셀린느, 팬츠, 다잉브, 리드, 슈즈, 던힐]
# 5                                     [셀린느, 나노, 벨트, 백만원]
# 6      [요즘, 주식, 친구, 대화, 주제가, 코로나, 불안감, 지금, 시기, 기회, 수도...
# 7      [컬러, 블록, 부츠, 가격, 미정, 샤넬, 와인, 하이, 부츠, 가격, 미정, 셀...
# 8      [격자, 무늬, 트렌치코트, 와이드, 팬츠, 가격, 미정, 지방시, 밤색, 터틀넥,...
# 9      [민트, 후드, 가격, 미정, 크롬, 하츠, 안경, 셀린느, 바이, 플라워, 프린트...
# 10         [프린지, 장식, 메탈, 소재, 트라이엄프, 장식, 로퍼, 가격, 미정, 셀린느]
# 11     [다정, 성격, 때문, 주변, 사람, 모임, 사회, 운동, 가형, 사교, 모임, 장...
# 12     [논리, 책임감, 성격, 질서, 중시, 조직, 확률, 컬러, 디자인, 클래식, 보수...
# 13     [히피, 펑크, 글램, 바람, 세기말, 절제, 디자인, 추구, 미니멀리즘, 테크노,...
# 14     [빈티, 체크, 무늬, 재킷, 가격, 미정, 셀린느, 비비드, 핑크, 컬러, 셔츠,...
# 15     [격자, 무늬, 가장, 모습, 변주, 복합, 패턴, 이번, 시즌, 셀린느, 케이프,...
# 16     [화이트, 슬리브, 리스, 스트라이프, 오버, 팬츠, 모두, 셀린느, 화이트, 블루...
# 17     [쉬, 다이어트, 평생, 장거리, 수영, 선수, 가지, 시시, 부터, 예약, 신의,...
# 18     [화이트, 슈트, 재킷, 블랙, 플립플랍, 스타일, 리스트, 소장품, 슬리브, 리스...
# 19     [보타이, 오버, 슈트, 버뮤다, 쇼츠, 이번, 시즌, 데님, 여지, 레트로, 존재...
# 20     [파란색, 뿔테, 틴티드, 선글라스, 셀린느, 바이, 분홍색, 트렌치코트, 메종, ...
# 21     [빈티, 대한, 첫, 기억, 종로, 광장시장, 냄새, 비지, 고등학생, 브랜드, 구...
# 22     [사회, 거리, 두기, 장기, 스타일, 유지, 를, 만족, 홈웨어, 인기, 슬리브,...
# 23               [고딕체, 로고, 티셔츠, 가격, 미정, 셀린느, 바이, 에디, 리먼]
# 24     [언제, 룩, 테일러, 스타일, 베스트, 활용, 무채색, 베스트, 매일, 재킷, 대...
# 25     [체인, 프린트, 주름, 장식, 원피스, 벨트, 하이, 부츠, 모두, 가격, 미정,...
# 26     [피터, 일상, 워킹, 우먼, 뉴욕, 브랜드, 커팅, 모던, 컬러, 매치, 무장, ...
# 27            [홀스빗, 장식, 레더, 벨트, 가격, 미정, 셀린느, 바이, 에디, 리먼]
# 28     [가장, 후회, 쇼핑, 경험, 피비, 파일, 셀린느, 피스, 그녀, 브랜드, 당시,...
# 29     [베이지색, 케이프, 코트, 터틀넥, 니트, 데님, 팬츠, 벨트, 가격, 미정, 모...
#                              ...
# 796    [세계, 명품, 시장, 절반, 이상, 차지, 프랑스, 그룹, 루이, 비통, 셀린, ...
# 797                               [보디, 실루엣, 셀린, 실크, 원피스]
# 798    [순백, 변신, 무죄, 화이트, 독보, 한여름, 밤, 컬러, 일렁일, 가장, 여름,...
# 799                                                   []
# 800                                                   []
# 801                                                   []
# 802                                                   []
# 803    [셀린, 공식, 인스타그램, 사다리, 강아지, 사진, 업로드, 매장, 오픈, 뷰티,...
# 804                                                   []
# 805                                                   []
# 806    [내내, 런웨이, 의상, 모조리, 옷장, 정도, 셀린, 컬렉션, 유난, 피비, 파일...
# 807                  [셀린느, 청담, 플래그, 스토어, 서울시, 강남구, 압구정로]
# 808                                                   []
# 809    [모든, 의문, 이번, 시즌, 프라다, 로부터, 시작, 프라다, 여사, 깃털, 장식...
# 810    [셀린, 아티스, 동시, 대적, 감각, 영감, 때론, 열정, 때론, 지적, 때론, ...
# 811    [셀린, 아티스, 동시, 대적, 감각, 영감, 때론, 열정, 때론, 지적, 때론, ...
# 812    [셀린, 아티스, 동시, 대적, 감각, 영감, 때론, 열정, 때론, 지적, 때론, ...
# 813    [셀린, 아티스, 동시, 대적, 감각, 영감, 순간, 명의, 한국, 사진가, 포착,...
# 814    [백, 시즌, 전만, 해도, 오버, 사이즈, 세상, 모든, 근심, 지고, 사람, 이...
# 815    [플라워, 시스루, 드레스, 셀린, 스프링, 컬렉션, 룩북, 마주, 무늬, 드레스,...
# 816    [사옥, 오픈, 외국, 디자이너, 그, 브랜드, 콘셉트, 공존, 스토어, 재미, 정...
# 817                                                   []
# 818                                                   []
# 819    [극적, 볼륨, 부피, 줄, 미니, 방식, 실루엣, 연출, 케이프, 셀린, 코트, ...
# 820    [노멀, 시티, 최근, 리조트, 컬렉션, 여름, 가을, 겨울, 레디, 웨어, 컬렉션...
# 821    [마야, 리아, 셀린, 패스, 모델, 워킹, 복판, 보고, 여자, 로망, 셀린, 곳...
# 822    [코리아, 파워, 지난해, 파리, 데뷔, 한국, 디자이너, 황록, 정보, 마틴, 마...
# 823    [패션, 에디터, 김신, 가을, 괜스레, 감상, 정제, 보헤미안, 감성, 국적, 무...
# 824                                                   []
# 825    [허리, 가방, 주머니, 듯, 벨트, 듯, 허리, 가방, 생명, 불어, 셀린, 피비...
# Name: noun, Length: 826, dtype: object

# %%
noun_df.loc[860:865]
# Out:
# Empty DataFrame
# Columns: [article, noun]
# Index: []

# %% [markdown]
# ### 명사빈도 카운트

# %%
noun_list = counts.most_common(200)
for v in noun_list:
    print(v)
# Out:
# ('셀린느', 1157)
# ('에디', 560)
# ('셀린', 471)
# ('컬렉션', 465)
# ('브랜드', 450)
# ('패션', 353)
# ('디자이너', 302)
# ('시즌', 289)
# ('피비', 283)
# ('이번', 276)
# ('남성', 254)
# ('스타일', 244)
# ('컬러', 230)
# ('여성', 215)
# ('디자인', 212)
# ('팬츠', 204)
# ('지난', 203)
# ('디렉터', 202)
# ('슬리', 200)
# ('슬리먼', 198)
# ('드레스', 196)
# ('재킷', 184)
# ('가격', 180)
# ('장식', 176)
# ('파리', 174)
# ('가장', 171)
# ('아이템', 156)
# ('로랑', 153)
# ('미정', 147)
# ('코트', 144)
# ('매치', 143)
# ('것', 142)
# ('사진', 139)
# ('크리에이티브', 137)
# ('그녀', 135)
# ('자신', 133)
# ('가죽', 133)
# ('로고', 128)
# ('등장', 126)
# ('필로', 126)
# ('역시', 124)
# ('모델', 123)
# ('소재', 122)
# ('디올', 122)
# ('영국', 121)
# ('위해', 119)
# ('블랙', 118)
# ('스타', 118)
# ('모두', 117)
# ('셔츠', 116)
# ('파일', 115)
# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 패키지 설치 및 폰트 어쩌구

# %%
import matplotlib.font_manager as fm

# 이용 가능한 폰트 중 '고딕'만 선별
for font in fm.fontManager.ttflist:
    if 'Gothic' in font.name:
        print(font.name, font.fname)
# Out:
# Copperplate Gothic Bold C:\Windows\Fonts\COPRGTB.TTF
# Showcard Gothic C:\Windows\Fonts\SHOWG.TTF
# Century Gothic c:\windows\fonts\gothicb.ttf
# Franklin Gothic Medium C:\Windows\Fonts\framd.ttf
# Franklin Gothic Demi c:\windows\fonts\fradm.ttf
# Franklin Gothic Book c:\windows\fonts\frabkit.ttf
# Franklin Gothic Demi C:\Windows\Fonts\FRADMIT.TTF
# Century Gothic c:\windows\fonts\gothic.ttf
# Franklin Gothic Book C:\Windows\Fonts\FRABKIT.TTF
# Century Gothic c:\windows\fonts\gothicbi.ttf
# Franklin Gothic Medium C:\Windows\Fonts\framdit.ttf
# Franklin Gothic Demi C:\Windows\Fonts\FRADM.TTF
# HYGothic-Extra c:\windows\fonts\h2gtre.ttf
# Franklin Gothic Heavy c:\windows\fonts\frahvit.ttf
# Franklin Gothic Demi Cond c:\windows\fonts\fradmcn.ttf
# Malgun Gothic c:\windows\fonts\malgunbd.ttf
# Showcard Gothic c:\windows\fonts\showg.ttf
# Franklin Gothic Medium Cond c:\windows\fonts\framdcn.ttf
# Franklin Gothic Heavy C:\Windows\Fonts\FRAHV.TTF
# Malgun Gothic c:\windows\fonts\malgun.ttf
# Century Gothic c:\windows\fonts\gothici.ttf
# Century Gothic C:\Windows\Fonts\GOTHICBI.TTF
# HYGothic-Medium c:\windows\fonts\h2gtrm.ttf
# Franklin Gothic Demi Cond C:\Windows\Fonts\FRADMCN.TTF
# HYGothic-Extra C:\Windows\Fonts\H2GTRE.TTF
# Copperplate Gothic Light C:\Windows\Fonts\COPRGTL.TTF
# Copperplate Gothic Light c:\windows\fonts\coprgtl.ttf
# Malgun Gothic C:\Windows\Fonts\malgunsl.ttf
# HYGothic-Medium C:\Windows\Fonts\H2GTRM.TTF
# Franklin Gothic Book C:\Windows\Fonts\FRABK.TTF
# Copperplate Gothic Bold c:\windows\fonts\coprgtb.ttf
# Franklin Gothic Heavy c:\windows\fonts\frahv.ttf
# Franklin Gothic Book c:\windows\fonts\frabk.ttf
# Franklin Gothic Demi c:\windows\fonts\fradmit.ttf
# Century Gothic C:\Windows\Fonts\GOTHIC.TTF
# Century Gothic C:\Windows\Fonts\GOTHICI.TTF
# Century Gothic C:\Windows\Fonts\GOTHICB.TTF
# Franklin Gothic Medium Cond C:\Windows\Fonts\FRAMDCN.TTF
# Franklin Gothic Heavy C:\Windows\Fonts\FRAHVIT.TTF

# %%
font_path = 'C:\WINDOWS\Fonts\malgun.ttf'

# %% [markdown]
# ### wordcloud 그리기

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud(font_path=font_path, background_color="white", width=600, height=400)

# %%
wc.generate_from_frequencies(dict(word_list))

plt.imshow(wc) 
plt.axis('off') 
plt.show()


wc.to_file('twitter_adj_noun_celine.png')

# %%
wc.generate_from_frequencies(dict(noun_list))
wc.to_file('twitter_noun_celine.png')
