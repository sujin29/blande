# %%
import pandas as pd
import numpy as np

# %%
from collections import Counter

# %%
tot_l = pd.read_csv('./magazine/final/video_lisa_adfn_2.csv', sep='|', encoding = 'utf-8')

# %%
tot_l
# Out:
#     magazine    brand                                              title  \
# 0    YOUTUBE  YOUTUBE  BLACKPINK - 'How You Like That' LISA Concept T...
# 1    YOUTUBE  YOUTUBE  BLACKPINK - 'KILL THIS LOVE' LISA TEASER VIDEO...
# 2    YOUTUBE  YOUTUBE  BLACKPINK - 'SQUARE UP' LISA MOVING POSTER_kor...
# 3    YOUTUBE  YOUTUBE  BLACKPINK - 'THE ALBUM' LISA Concept Teaser Vi...
# 4    YOUTUBE  YOUTUBE  BLACKPINK - LISA 'Forever Young' FOCUSED CAMER...
# ..       ...      ...                                                ...
# 192        W        L                                         밀라노로 떠난 리사
# 193        W        L                                         리사의 새로운 행보
# 194        W        L                           블랙핑크X세레나 고메즈 영상통화, 협업 티징
# 195        W        L                            블랙핑크가 아이스크림 셀카를 올린 이유는?
# 196        W        L                               블랙핑크 컴백! 남다른 패션 스타일링
#
#                                              word_lisa  \
# ...

# %%
for word in tot_l['word_lisa']:
    if '움' in word:
        print(word)
        print('-'*50)
# Out:
# ['우리가 봐도 이렇게 멋있는데 태국 사람들은 얼마나 멋있다  자랑스러울까 국뽕오지게맞을듯', '리사 진짜 보석임ㅠ.. 진짜 엄청난 보석.. 솔로 나와라 제발.. 해외진출도 하고..', '나는 리사가 한말이 안 잊혀져 태국은 내나라 한국은 우리나라...그대여 세계를 품을 수 있는 여자 그 이름 리사', '한국인 댓글을 찾을 수 없는 BLACKPINK 영상들....한국인들 모이세요 ,,, 한국블링크의 화력을 보여줘 !!!!!!!!!!!', '리사 한국말 너무 잘해 ㅋㅋㅋㅋㅋㅋㅋㅋ 잘하는 수준이 아니라 그냥 한국인', '언니 그렇게 멋지게 웃으면 나 주거... 존나  예쁘다  쉬발,,,역시 내 최애..격하게 사랑해.,..저평가 되는 것 같아서 아쉽다 ㅠㅠ 최근에 사람들이 칭찬 많이 해주긴 하는데 그것도 아직 모자라..더 하란 말이야 내 기준 아이돌 능력치 갑', '난 가끔 리사가 한국인이라고 착각할때가 많다 ...', '진짜 한국말 잘한다.. 저렇게 말하기까지 얼마나 노력했을까 ㅠㅠ  첨엔 걍 이국적이게 생긴 한국인인줄 알았는디', '리사 한국인 다 됐어ㅋㅋㅋㅋㅋㅋ 사랑의 불시착도 보는 구나...', '1:53 그립감이라는 단어랑 발음이 완전 한국인...', '리사 처음 대뷔때 우리 나라사람 아님 혼혈인둘 알았는데ㅠㅠㅠㅠㅠ 한국말 너뮤 잘해서 진짜 진짜 한귝사람이야', '리사 흑발까지도 잘 어울려버리네...♡ 어깨라인이 진짜 멋있다  부럽다♡', '리사가 진짜 사기캐인게 영어 태국어 한국어 일어까지 가능함. 일어는 조금 할 줄 안다치는데 모국어 제외하고 2개는 수준급으로 구사함...외모? 키랑 비율은 말하자면 입 아프고 진짜 스타일리쉬함. 다 비슷비슷한 케이팝 아이돌멤버 스타일이 아님 보면 잊혀지지가 않음. 솔로데뷔가 진짜 시급함...', '한국어 진짜 많이 늘었다 얼굴도 가면 갈수록 리즈 찍고', '리사...얼굴도 너모 작고 비율 미쳤고 랩도 잘해 춤 겁나 잘춰 한국어도 잘해 성격 너모 기여운데 중국프듀에서 영어와 중국어를 자유자제로 사용하며 단발이 클레오 
# ...

# %%
tot_l['ADFN_2'][0][0]
# Out:
# '['

# %%
for word in tot_l['ADFN_2']:
    if "원" in word:
        print(word)
        print('-'*50)
# Out:
# ['바비', '같습니다', '리사', '사랑', '불공평하다', '회원', '리사', '제외', '아름다운', '의상', '입는다', '부드러운', '춤', '증오', '듣지', '마십시오', '좋아하고', '새로운', '팬', '리사', '넌', '예쁘다', '아름다운', '춤', '한국어', '찾으셨습니다', '리사', '딥', '쉬', '형광', '예쁘네', '생일', '리사', '장수', '건강하고', '귀엽다', '깜박임', '생일', '리사', '자형', '자물쇠', '살', '찌워', '주', 'O', 'M', 'G', '리사', '최고', '리사', '🥰', '사랑', '파이팅']
# --------------------------------------------------
# ['Congratulate', 'on', '리사', 'So', 'uploaded', 'beatboxing', 'remix', '뚜두뚜두', 'for', 'Hope', 'like', 'it', 'We', 'love', '´∇｀', '않았어', '리사', '훌륭', '메인', '댄서', '자격', '잡았', '기', '해커', '아닙니다', '비율', '보소', '와우', '🤩', '공주', '사랑', '말랐네', '안녕', '노래', '노래', 'sds', '노래', '🥺', '사랑', '동의', '리사', '한국', '산업', '적응하기가', '힘들지만', '관리', '춤', '천재', '리사', '죽어', '어머', '리사', '사랑', '소원', '제나', '끔찍한', '리사', '바비인형', '리사', '미친', '허리', '실화', '스타', '모스트', '리사', '리사', '얼굴', '소멸하기', '전이네', '비율', '믿겠네', '마네킹', '몸매', '존해', '신기해', '오진다', '오져', '리사', '️️️️️️️️', '사랑']
# --------------------------------------------------
# ...

# %%
# 걸크러시
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'걸', '크러시", "걸크러시")
# 걸크러쉬
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'걸', '크러쉬'", "걸크러시")
# 걸크
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'걸', '크'", "걸크러시")

# 걸그룹
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'걸', '그룹'", "걸그룹")

# %%
# 글로우
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'글', '로우'", "글로우")

# %%
# 아우터
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'아우', '터'", "아우터")

# %%
# 데일리
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'데', '일리'", "데일리")

# %%
# 볼륨감
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'볼륨', '감'", "볼륨감")
# 존재감
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'존재', '감'", "존재감")
# 통일감
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'통일', '감'", "통일감")

# %%
# 스타일링
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'스타', '일링'", "스타일링")

# %%
# 캐주얼
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'캐', '주얼'", "캐주얼")

# 비쥬얼
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'비쥬', '얼'", "비주얼")

# %%
# FW / SS
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'F', 'W'", "FW")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'S', 'S'", "SS")

# %%
# 스포티
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'스포', '티'", "스포티")
# 프리티
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'프리', '티'", "프리티")

# %%
# 테일러 / 레이어
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'테일러', '드'", "테일러드")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'레이어', '드'", "레이어드")

# %%
# 하이틴
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'하이', '틴'", "하이틴")

# %%
# 눈정화 / 눈호강
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'눈', '호강'", "눈호강")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'눈', '정화'", "눈정화")

# %%
# 제만
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'제만'", "로제")
# 제씨
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'제씨'", "로제")

tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("朴彩英哭戏", "로제")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("朴彩瑛", "로제")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("PARKCHAEYOUNG", "로제")

# %%
# 뚜두뚜두 
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'뚜', '두', '뚜', '두'", "뚜두뚜두")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'뚜', '두', '뚜'", "뚜두뚜두")

# %%
# 진짜
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'진', '짜'", "진짜")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("♡", "")

# 퀸
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'QUINN'", "퀸")
# 퀸
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'QUEEN'", "퀸")

# 최고
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'BEST'", "최고")
# 최고
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'최고다'", "최고")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'원', '탑'", "원탑")


# 디자인
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'DESIGN'", "디자인")
# 이모지
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'♡'", "")
# 인플루언서
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'INFLUENCER'", "인플루언서")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'CREATIVE'", "크리에이티브")

# 드
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'데이즈', '드'", "데이즈드")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'레이어', '드'", "레이어드")

# 새롭
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'새롭'", "새로운")

# %%
# 원석
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'원', '석'", "원석")
# 원탑
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'원', '탑'", "원탑")

# %%
# 원석
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'love'", "사랑")

# %%
# 비주얼
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'비주'", "비주얼")

# %%
# 귀엽다
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'귀엽'", "귀엽다")
# 귀엽다
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'귀여운'", "귀엽다")


tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("elegance", "우아")

# %%
# 비주얼
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'비주'", "비주얼")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'visual'", "비주얼")

tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'아름다'", "아름다운")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'아름답습니다'", "아름다운")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'아름답고'", "아름다운")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'아름답게'", "아름다운")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'아름다워진다'", "아름다운")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'아름다워'", "아름다운")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'아름답습니다'", "아름다운")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'아름답다'", "아름다운")

# %%
# 좋겠어요
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("좋겠어요", "좋겠다")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("좋은", "좋아")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("좋고", "좋아")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("좋아하는", "좋아")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("좋은데", "좋아")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("좋음", "좋아")

# %%
# 로랑
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'YSL'", "LAURENT")

# %%
# 인간
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("HUMAN", "인간")
# 생로랑
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("MISSSAINTLAURENT", "'인간', 'LAURENT'")

# %%
# 사랑스러워
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'사랑스러워'", "사랑스럽다")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'사랑스러운'", "사랑스럽다")

# %%
# 우아
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'우아한'", "우아")
# 우아
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'우아하게'", "우아")
# 우아
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'우아함'", "우아")
# 우아
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'우아하다'", "우아")

# %%
# 귀엽다
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'귀엽'", "귀엽다")
# 귀엽다
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'귀여운'", "귀엽다")


# 예쁘네
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'예쁘네'", "예쁘다")

tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("elegance", "우아")

# %%
# 쩐다
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'쩐다'", "최고")
# 대박
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'대박'", "최고")

# %%
# 개멋
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'개멋'", "멋있다")
# 미친
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'미친'", "미쳤다")

# %%
tot_l
# Out:
#     magazine    brand                                              title  \
# 0    YOUTUBE  YOUTUBE  BLACKPINK - 'How You Like That' LISA Concept T...
# 1    YOUTUBE  YOUTUBE  BLACKPINK - 'KILL THIS LOVE' LISA TEASER VIDEO...
# 2    YOUTUBE  YOUTUBE  BLACKPINK - 'SQUARE UP' LISA MOVING POSTER_kor...
# 3    YOUTUBE  YOUTUBE  BLACKPINK - 'THE ALBUM' LISA Concept Teaser Vi...
# 4    YOUTUBE  YOUTUBE  BLACKPINK - LISA 'Forever Young' FOCUSED CAMER...
# ..       ...      ...                                                ...
# 192        W        L                                         밀라노로 떠난 리사
# 193        W        L                                         리사의 새로운 행보
# 194        W        L                           블랙핑크X세레나 고메즈 영상통화, 협업 티징
# 195        W        L                            블랙핑크가 아이스크림 셀카를 올린 이유는?
# 196        W        L                               블랙핑크 컴백! 남다른 패션 스타일링
#
#                                              word_lisa  \
# ...

# %% [markdown]
# ### stopword 추가

# %%
sw_df = pd.read_csv('stopwords.csv', header=None)

# %%
sw_df.columns = ['stopword']

# %%
stop_words = []
for sw in sw_df['stopword']:
    stop_words.append(sw)

# %%
print(len(stop_words))
print(type(stop_words))
# Out:
# 675
# <class 'list'>

# %%
stop_words[-10:]
# Out:
# ['둘', '셋', '넷', '다섯', '여섯', '일곱', '여덟', '아홉', '령', '영']

# %%
add_0 = ['진짜', '존나', '보고', '그냥', '카이', '이광수', '광수', '런닝맨', '❤️', '없는', '유재석', '❤', '♥', '♡', '♡','♡',
         '있고', '거', 
         '내', '더', '개', '사람', '영상', '광고', '언니', '말', '뭐', '수', '생각', '아는', 
        '있는', '정말', '같은', '같음', '듯', '♡', '완전', '같아', '정도', '지금', '역시', '뭔가', '입니다', '때문', '아니라',
         '함', '같은데', '해', '하는', '할', '넘', '한', '안', '했다', '보면', '데', '하고', '하면', '게', '해서', '봐도', 
         '한다', '된', '건', '요', '움', '임', '애', '하는거', '해도', '보는', '이제', '했는데', '하는데', '하는게', '같아요', 
         '합니다', '하지', '하게', '되는', 'I', '는', '난', '서', '도', '줄', '위', '분', '알', '은', '두', '번', '뒤',
         '이건', '없다', '있어요', '아니고', '있어', 
        '계속', '원래', '뭘', '못', '후', '이름', '속', '욕', '옆', '하네', '아님', '그런', '된다', '있음',
        '같', '돼', 'you', '제품', '표현', 'n', '봤는데', '건가', '나오는', '가지', '저런', '보이', '고',
        '중', '사진', '댓글', '부분', '진심', '그녀', '보', '날', '겁나', '요즘', '앞', '워', '이유', '솔직히', '하며', '통해',
        '모든', '항상', '전', '기자', '다시', '오늘', '↑', '이자', '대해',
        '링', '한편', '️⃣',
        '람쥐', '아닌가', '도민준', '없네', '이수근', '아이유', 'our', '젠', '였다면', '올해', '미우', 'The', 'my', '이란',
        '그게', '같고', '아니다', '아닌데', '있지',  '만큼', '백예린', '같네', 'we', '있게', '덕분', '있어서', '든', '썸넬',
        '라서', '여서', '라면', '인지', 'a','와중', '하자', '이후', '해야', '예전', '막',
        '없어', '왜케', 'You', 'THE', 'your', 'u', 'AN', '수가',
        'MUCH', 'FORTIFFANYANDCO', 'TIFFANYANDCO', 'ahh', 'her', 'knew', '않고', '보니', '처음',  '가사', '누나', '없음', 'if',
        '아아', '헐','', '걸', '처음', '머리', '헤어', '고민', '뿐','진짜', '존나', '보고', '그냥', '카이', '이광수', '광수', '런닝맨', '❤️', '없는', '유재석', '❤', '♥', '♡', '♡','♡',
         '있고', '거', 
         '내', '더', '개', '사람', '영상', '광고', '언니', '말', '뭐', '수', '생각', '아는', 
        '있는', '정말', '같은', '같음', '듯', '♡', '완전', '같아', '정도', '지금', '역시', '뭔가', '입니다', '때문', '아니라',
         '함', '같은데', '해', '하는', '할', '넘', '한', '안', '했다', '보면', '데', '하고', '하면', '게', '해서', '봐도', 
         '한다', '된', '건', '요', '움', '임', '애', '하는거', '해도', '보는', '이제', '했는데', '하는데', '하는게', '같아요', 
         '합니다', '하지', '하게', '되는', 'I', '는', '난', '서', '도', '줄', '위', '분', '알', '은', '두', '번', '뒤',
         '이건', '없다', '있어요', '아니고', '있어', 
        '계속', '원래', '뭘', '못', '후', '이름', '속', '욕', '옆', '하네', '아님', '그런', '된다', '있음',
        '같', '돼', 'you', '제품', '표현', 'n', '봤는데', '건가', '나오는', '가지', '저런', '보이', '고',
        '중', '사진', '댓글', '부분', '진심', '그녀', '보', '날', '겁나', '요즘', '앞', '워', '이유', '솔직히', '하며', '통해',
        '모든', '항상', '전', '기자', '다시', '오늘', '↑', '이자', '대해',
        '링', '한편', '️⃣',
        '람쥐', '아닌가', '도민준', '없네', '이수근', '아이유', 'our', '젠', '였다면', '올해', '미우', 'The', 'my', '이란',
        '그게', '같고', '아니다', '아닌데', '있지',  '만큼', '백예린', '같네', 'we', '있게', '덕분', '있어서', '든', '썸넬',
        '라서', '여서', '라면', '인지', 'a','와중', '하자', '이후', '해야', '예전', '막',
        '없어', '왜케', 'You', 'THE', 'your', 'u', 'AN', '수가',
        'MUCH', 'FORTIFFANYANDCO', 'TIFFANYANDCO', 'ahh', 'her', 'knew', '않고', '보니', '처음',  '가사', '누나', '없음', 'if',
        '아아', '헐','', '시작', '고민', '않는', '했습니다', '손흥민', 
        '했던', '절대', '하세요', '않은', '했을', '있나요', '제대로', '보세요', '런가', '비해', '있다는', 
         '없어서', '그거', '있다면', '보일', 'T', '그거', '걸', '처음', '머리', '헤어', '고민', '뿐',
        '헤어', '패턴', '가족', '달곰', '봄', '존재', '평소', '뿐', '늘', '그대로', '팝', '긴', '성',
        '자막', '장면', '트', '입고', '가진', '직접', '기억', '선', '땐', '돈', '목', 'ELLE', '대표',  
         '달', '널', '유', '비', '식', '풀',
        '오빠', '양', '수도',  '헬륨가스', '평가', '에스', '주는', '호', '바', 
         '로서', '까르띠', '수지', '아빠', '밤', '뷰', '무드', '체크','점점', '받는', '캐', '순', 
         '대신', '발라', '받은', '올', '당시', '단', '진짜', '존나', '보고', '그냥', '카이', '이광수', '광수', '런닝맨', '❤️', '없는', '유재석', '❤', '♥', '있고', '거', 
         '내', '더', '개', '사람', '영상', '광고', '언니', '말', '뭐', '수', '생각',
        '있는', '정말', '같은', '같음', '듯', '♡', '완전', '같아', '정도', '지금', '역시', '뭔가', '입니다', '때문', '아니라',
         '함', '같은데', '해', '하는', '할', '넘', '한', '안', '했다', '보면', '데', '하고', '하면', '게', '해서', '봐도', 
         '한다', '된', '건', '요', '움', '임', '애', '하는거', '해도', '보는', '이제', '했는데', '하는데', '하는게', '같아요', 
         '합니다', '하지', '하게', '되는', 'I', '는', '난', '서', '도', '줄', '위', '분', '알', '은', '두', '번', '뒤',
         '이건', '없다', '있어요', '아니고', '있어',
        '계속', '원래', '뭘', '못', '후', '이름', '속', '욕', '옆', '하네', '아님', '그런', '된다', '있음',
        '같', '돼', 'you', '제품', '표현', 'n', '봤는데', '건가', '나오는', '가지', '저런', '보이', '고',
        '중', '사진', '댓글', '부분', '진심', '그녀', '보', '날', '겁나', '요즘', '앞', '워', '이유', '솔직히', '하며', '통해',
        '모든', '항상', '전', '기자', '다시', '오늘', '걸', '처음', '머리', '헤어', '고민', '뿐', '',
        '잘', '눈', '자체', '제일', '나도', '대', 'YG', '제발', '한번', '가장', '누가', '보러',
         '울', '입고', 'u', '트와이스', '입', '큰', '어쩜', '까', '끝', '사실', '썸넬', '젤', '기여', '미',
         '회수', '순간', '시작', '볼때',
        '패턴', '비', '제목', '막', '있는데', '수가', '헐', '없어', '해주세요', '트', '알았는데', '해야',
         '보이는', '보니', '만', '자꾸', '길이', '됨', '실제', '아주', '척', '땐', '머', 'lo', '유튜브',
        '왜케', '논란', '한편', '아닌데', '호', '얘', '몇번', '첫', '보임', '보면서', '짧은', '얼', 'xa', '남', 
         '감', '웃겨', '니', '될', '보게', '앤', '나오면', '보다가', '않고', '아닌', '위해', '무', '듣고', '싶다', '와중', '없음',
        '연습생', '쌤', '선생님', '반', '넼', '쟤', '이어', '보는데', '있네', '두두', '자리', '이민지', 'of', '씨',
         '아니냐', '없고', '둘다', '하니까', '배쌤', '싸', '김영철', '따', 'so','is', '인','곤','하다','보기', '아는', '형님',
        '돌려', '누', '맛', '볼', '서로', '싶어요']
for w in add_0:
    stop_words.append(w)

# %%
add_1 = ['BLACKPINK', '로제', '지수', '제니']
for w in add_1:
    stop_words.append(w)

# %%
len(stop_words)
# Out:
# 1475

# %%
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace('[', '').str.replace(']', '').str.replace('"', '').str.replace("'", "").str.split(', ')

# %%
a = []
for i in range(len(tot_l)):
    b = []
    for word in tot_l.loc[i, 'ADFN_2']:
        if not word in stop_words:
            b.append(word)
    a.append(b)

# %%
len(a)
# Out:
# 197

# %%
tot_l['ADFN_2'] = a

# %%
noun_adj_list = []
for i in range(len(tot_l)):
    for word in tot_l.loc[i, 'ADFN_2']:
        if word not in stop_words:
            noun_adj_list.append(word)

# %%
# # 유튜브만
# noun_adj_list = []
# for i in range(len(tot_je)):
#     if tot_je.loc[i, 'magazine'] == 'YOUTUBE':
#         for word in tot_je.loc[i, 'ADFN_2']:
#             if word not in stop_words:
#                 noun_adj_list.append(word)

# %%
# # 잡지만
# noun_adj_list = []
# for i in range(len(tot_je)):
#     if tot_je.loc[i, 'magazine'] != 'YOUTUBE':
#         for word in tot_je.loc[i, 'ADFN_2']:
#             if word not in stop_words:
#                 noun_adj_list.append(word)

# %%
noun_adj_list
# Out:
# ['Yorumlada',
#  'turk',
#  'cok',
#  'g',
#  'ö',
#  'rdum',
#  've',
#  'selamlar',
#  'ver',
#  'ı',
#  'yorum',
#  '한국어',
#  '깜박임',
#  '멋있당',
#  '리사',
#  '닺내애',
#  '휸',
#  '잳재넬',
#  '래댇',
#  '댜',
#  '종',
#  '댲',
#  '지',
#  '√®',
#  'ü',
#  'm',
#  'Turk',
#  'ı',
#  'sh',
#  'bl',
#  'ı',
#  'nk',
#  'lovesickgirl',
#  'aks',
#  'ı',
#  'yar',
#  'ışı',
#  'kazanmal',
#  'ı',
#  'y',
#  'ı',
#  'zzz',
#  '터키어',
#  '깜박임',
#  '사랑',
#  '말랐네',
#  '갈비뼈',
#  '채널',
#  '구독',
#  '등록',
#  '하신',
#  '어머니',
#  '달러',
#  '벌고',
#  '평생',
#  '행복하길',
#  '바랍니다',
#  'ILOVE',
#  'YOU',
#  '리사',
#  '멋있다',
#  '매력',
#  '넘치는',
#  '리사',
#  '예쁘다',
#  '🤩',
#  '와우',
#  '리사',
#  '완벽한',
#  '브라보',
#  'Wawww',
#  'cloths',
#  '리사',
#  '사랑',
#  '하나님',
#  '달콤하고',
#  '사랑',
#  '깜빡',
#  '아니며',
#  '사랑',
#  '와우',
#  '리사',
#  '멋있다',
#  '아름다운',
#  '미쳤지',
#  '사랑',
#  '됩니다',
#  '아닙니다',
#  '인생',
#  '세상',
#  '소녀',
#  '사랑',
#  '햇살',
#  '굉장하다',
#  '사랑',
#  '사는',
#  '감사합니다',
#  '유일한',
#  '리자',
#  '사랑',
#  '와칸',
#  '포에버',
# ...

# %%
word = Counter(noun_adj_list)
print(word.most_common(200))
# Out:
# [('리사', 3570), ('예쁘다', 699), ('귀엽다', 568), ('춤', 478), ('사랑', 341), ('랩', 275), ('한국', 255), ('영어', 247), ('멋있다', 243), ('노래', 223), ('얼굴', 195), ('무대', 192), ('최고', 187), ('아이돌', 178), ('매력', 172), ('태국', 170), ('한국어', 155), ('중국', 153), ('한국인', 145), ('패션', 139), ('표정', 132), ('비율', 131), ('실력', 124), ('느낌', 123), ('외국인', 117), ('팬', 107), ('여자', 100), ('블랙', 98), ('미쳤다', 90), ('컬러', 84), ('예능', 79), ('인기', 78), ('스타일', 76), ('룩', 75), ('프로', 71), ('다리', 71), ('단발', 67), ('걸그룹', 67), ('태국인', 67), ('컬렉션', 67), ('외국', 66), ('CELINE', 65), ('인형', 64), ('그룹', 64), ('브랜드', 64), ('모델', 61), ('좋다', 61), ('노력', 60), ('카리스마', 60), ('짱', 60), ('한국말', 58), ('사랑스럽다', 57), ('간지', 56), ('스타', 55), ('참석', 55), ('우리나라', 53), ('세계', 53), ('컴백', 53), ('해외', 52), ('프라다', 52), ('좋아요', 51), ('포인트', 51), ('매치', 51), ('연습', 50), ('아름다운', 49), ('옷', 49), ('성격', 48), ('목소리', 48), ('좋겠다', 48), ('콘서트', 48), ('춤선', 47), ('화보', 47), ('분위기', 46), ('재킷', 46), ('음악', 45), ('메인', 45), ('일본', 45), ('나라', 44), ('태국어
# ...

# %%
count = Counter(noun_adj_list)

# %%
word_list = count.most_common(500)
for v in word_list:
    print(v)
# Out:
# ('리사', 3570)
# ('예쁘다', 699)
# ('귀엽다', 568)
# ('춤', 478)
# ('사랑', 341)
# ('랩', 275)
# ('한국', 255)
# ('영어', 247)
# ('멋있다', 243)
# ('노래', 223)
# ('얼굴', 195)
# ('무대', 192)
# ('최고', 187)
# ('아이돌', 178)
# ('매력', 172)
# ('태국', 170)
# ('한국어', 155)
# ('중국', 153)
# ('한국인', 145)
# ('패션', 139)
# ('표정', 132)
# ('비율', 131)
# ('실력', 124)
# ('느낌', 123)
# ('외국인', 117)
# ('팬', 107)
# ('여자', 100)
# ('블랙', 98)
# ('미쳤다', 90)
# ('컬러', 84)
# ('예능', 79)
# ('인기', 78)
# ('스타일', 76)
# ('룩', 75)
# ('프로', 71)
# ('다리', 71)
# ('단발', 67)
# ('걸그룹', 67)
# ('태국인', 67)
# ('컬렉션', 67)
# ('외국', 66)
# ('CELINE', 65)
# ('인형', 64)
# ('그룹', 64)
# ('브랜드', 64)
# ('모델', 61)
# ('좋다', 61)
# ('노력', 60)
# ('카리스마', 60)
# ('짱', 60)
# ('한국말', 58)
# ('사랑스럽다', 57)
# ('간지', 56)
# ('스타', 55)
# ('참석', 55)
# ('우리나라', 53)
# ('세계', 53)
# ('컴백', 53)
# ('해외', 52)
# ('프라다', 52)
# ('좋아요', 51)
# ('포인트', 51)
# ('매치', 51)
# ('연습', 50)
# ('아름다운', 49)
# ('옷', 49)
# ('성격', 48)
# ('목소리', 48)
# ('좋겠다', 48)
# ('콘서트', 48)
# ('춤선', 47)
# ('화보', 47)
# ...

# %%
top500 = pd.DataFrame(word_list)

# %%
top500.columns = ['word', 'count']

# %%
top500
# Out:
#     word  count
# 0     리사   3570
# 1    예쁘다    699
# 2    귀엽다    568
# 3      춤    478
# 4     사랑    341
# ..   ...    ...
# 495   존멋     13
# 496   안보     13
# 497   타팬     13
# 498   싶은     13
# 499   매일     13
#
# [500 rows x 2 columns]

# %%
top500.to_csv('./tot_lisa_top500.csv', sep='|', encoding = 'utf-8', index = False)

# %% [markdown]
# ## 워드클라우드 만들기

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.font_manager as fm

# 이용 가능한 폰트 중 '고딕'만 선별
for font in fm.fontManager.ttflist:
    if 'Gothic' in font.name:
        print(font.name, font.fname)
# Out:
# Malgun Gothic C:\WINDOWS\Fonts\malgun.ttf
# Yu Gothic C:\WINDOWS\Fonts\YuGothB.ttc
# HYGothic-Extra C:\WINDOWS\Fonts\H2GTRE.TTF
# Franklin Gothic Medium C:\WINDOWS\Fonts\framdit.ttf
# Malgun Gothic C:\Windows\Fonts\malgunbd.ttf
# Yu Gothic C:\Windows\Fonts\YuGothL.ttc
# Century Gothic C:\Windows\Fonts\GOTHIC.TTF
# Yu Gothic C:\Windows\Fonts\YuGothM.ttc
# Yu Gothic C:\WINDOWS\Fonts\YuGothR.ttc
# MS Gothic C:\WINDOWS\Fonts\msgothic.ttc
# HYGothic-Medium C:\WINDOWS\Fonts\H2GTRM.TTF
# Malgun Gothic C:\WINDOWS\Fonts\malgunsl.ttf
# Century Gothic C:\Windows\Fonts\GOTHICI.TTF
# Century Gothic C:\WINDOWS\Fonts\GOTHICBI.TTF
# Century Gothic C:\Windows\Fonts\GOTHICB.TTF
# Franklin Gothic Medium C:\WINDOWS\Fonts\framd.ttf

# %%
font_path = 'C:\WINDOWS\Fonts\malgun.ttf'

# %% [markdown]
# ### 워드클라우드 그리기

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud(font_path=font_path, background_color= '#272727', width=600, height=400, colormap = 'RdPu')

# %%
wc.generate_from_frequencies(dict(word_list[:50]))

plt.imshow(wc) 
plt.axis('off') 

# plt.savefig('./final_img/rose_total50.png', bbox_inches = 'tight')
plt.show()


wc.to_file('./final_img/lisa_total50.png')

# %%
tot_l.to_csv('./magazine/final/video_lisa_adfn_2.csv', sep='|', encoding = 'utf-8', index = False)
