# %%
import pandas as pd
import numpy as np

# %%
magazine_ch = pd.read_csv('./magazine/final/ch_tag_Twitter.csv', sep = '|', encoding = 'utf-8')

# %%
# Out:
#      magazine brand          category                        title  \
# 0           A    Ch           FASHION        가을 트렌드 컬러, 위대한 블랙의 위로
# 1           A    Ch           FASHION                   빈티지 쇼핑의 시대
# 2           A    Ch           FASHION          올가을 시즌의 주인공, 체인의 활약
# 3           A    Ch           FASHION  주식을 시작한 패션 에디터의 이야기, 나는 주주다
# 4           A    Ch           FASHION       가을의 그림자만큼 길어진 롱부츠 12가지
# ...       ...   ...               ...                          ...
# 1445        W    Ch  FASHION, 뉴스, 트렌드                   이토록 빛나는 밀밭
# 1446        W    Ch  FASHION, 쇼핑, 트렌드                          피어나
# 1447        W    Ch      FASHION, 트렌드                         체키라웃
# 1448        W    Ch  FASHION, 쇼핑, 트렌드                      가을의 하이킹
# 1449        W    Ch      FASHION, 트렌드                    너도 나도 베트멍
#
#                                                    link        date  \
# 0     http://www.allurekorea.com/2020/11/15/%ea%b0%8...  2020-11-15
# ...
