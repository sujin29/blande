# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time

# %%
import pandas as pd
import numpy as np

# %%
from selenium.common.exceptions import NoSuchElementException

# %%
print(len(cosmo_jenny))
print(len(content_list))
# Out:
# 97
# 97

# %%
cosmo_jenny['content']=content_list

# %% [markdown]
# ### 엘르 한번에 저장

# %%
elle_jenny.to_csv('elle_jenny.csv', encoding = 'utf-8', index = False, sep='|')
elle_jisu.to_csv('elle_jisu.csv', encoding = 'utf-8', index = False, sep='|')
elle_rose.to_csv('elle_rose.csv', encoding = 'utf-8', index = False, sep='|')
elle_lisa.to_csv('elle_lisa.csv', encoding = 'utf-8', index = False, sep='|')

# %% [markdown]
# ### 코스모 한 번에 저장

# %%
cosmo_jenny.to_csv('cosmo_jenny.csv', encoding = 'utf-8', index = False, sep='|')
cosmo_jisu.to_csv('cosmo_jisu.csv', encoding = 'utf-8', index = False, sep='|')
cosmo_rose.to_csv('cosmo_rose.csv', encoding = 'utf-8', index = False, sep='|')
cosmo_lisa.to_csv('cosmo_lisa.csv', encoding = 'utf-8', index = False, sep='|')

# %%
elle_jenny = pd.read_csv('./blackpink/elle_jenny.csv', sep='|', encoding = 'utf-8')
elle_jisu = pd.read_csv('./blackpink/elle_jisu.csv', sep='|', encoding = 'utf-8')
elle_rose = pd.read_csv('./blackpink/elle_rose.csv', sep='|', encoding = 'utf-8')
elle_lisa = pd.read_csv('./blackpink/elle_lisa.csv', sep='|', encoding = 'utf-8')

# %%
cosmo_jenny = pd.read_csv('./blackpink/cosmo_jenny.csv', sep='|', encoding = 'utf-8')
cosmo_jisu = pd.read_csv('./blackpink/cosmo_jisu.csv', sep='|', encoding = 'utf-8')
cosmo_rose = pd.read_csv('./blackpink/cosmo_rose.csv', sep='|', encoding = 'utf-8')
cosmo_lisa = pd.read_csv('./blackpink/cosmo_lisa.csv', sep='|', encoding = 'utf-8')

# %% [markdown]
# ## 엘르 - 카테고리 가져오기

# %%
path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)

category = []


for i in range(len(elle_jenny)) :
    url = elle_jenny['elle_link'][i]
    driver.get(url)
    
    print(i, driver.current_url)
    
    driver.get(url)
    
    try:
        category.append(driver.find_element_by_css_selector('#contents > div > div.article_head > div').find_element_by_tag_name('span').text)
        
    except NoSuchElementException as nse :
        category.append(0)
    
    time.sleep(1)
    
    
print('-'*50)
print(len(category))
# Out:
# 0 https://www.elle.co.kr/article/50267
# 1 https://www.elle.co.kr/article/49683
# 2 https://www.elle.co.kr/article/50047
# 3 https://www.elle.co.kr/article/50580
# 4 https://www.elle.co.kr/article/49773
# 5 https://www.elle.co.kr/article/49396
# 6 https://www.elle.co.kr/article/47790
# 7 https://www.elle.co.kr/article/48448
# 8 https://www.elle.co.kr/article/50348
# 9 https://www.elle.co.kr/article/50141
# 10 https://www.elle.co.kr/article/47768
# 11 https://www.elle.co.kr/article/48413
# 12 https://www.elle.co.kr/article/50025
# 13 https://www.elle.co.kr/article/50147
# 14 https://www.elle.co.kr/article/48519
# 15 https://www.elle.co.kr/article/46829
# 16 https://www.elle.co.kr/article/47953
# 17 https://www.elle.co.kr/article/49962
# 18 https://www.elle.co.kr/article/46016
# 19 https://www.elle.co.kr/article/49858
# 20 https://www.elle.co.kr/article/42174
# 21 https://www.elle.co.kr/article/42586
# 22 https://www.elle.co.kr/article/43700
# 23 https://www.elle.co.kr/article/49749
# ...

# %%
elle_jenny['category'] = category

# %%
path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)

category = []


for i in range(len(elle_rose)) :
    url = elle_rose['elle_link'][i]
    driver.get(url)
    
    print(i, driver.current_url)
    
    driver.get(url)
    
    try:
        category.append(driver.find_element_by_css_selector('#contents > div > div.article_head > div').find_element_by_tag_name('span').text)
        
    except NoSuchElementException as nse :
        category.append(0)
    
    time.sleep(1)
    
    
print('-'*50)
print(len(category))
# Out:
# 0 https://www.elle.co.kr/article/49675
# 1 https://www.elle.co.kr/article/48555
# 2 https://www.elle.co.kr/article/50417
# 3 https://www.elle.co.kr/article/47015
# 4 https://www.elle.co.kr/article/47410
# 5 https://www.elle.co.kr/article/49914
# 6 https://www.elle.co.kr/article/44139
# 7 https://www.elle.co.kr/article/44127
# 8 https://www.elle.co.kr/article/48635
# 9 https://www.elle.co.kr/article/48513
# 10 https://www.elle.co.kr/article/48533
# 11 https://www.elle.co.kr/article/47768
# 12 https://www.elle.co.kr/article/47402
# 13 https://www.elle.co.kr/article/47524
# 14 https://www.elle.co.kr/article/47648
# 15 https://www.elle.co.kr/article/47329
# 16 https://www.elle.co.kr/article/45130
# 17 https://www.elle.co.kr/article/46518
# 18 https://www.elle.co.kr/article/45123
# 19 https://www.elle.co.kr/article/46583
# 20 https://www.elle.co.kr/article/45743
# 21 https://www.elle.co.kr/article/45308
# 22 https://www.elle.co.kr/article/43844
# 23 https://www.elle.co.kr/article/45957
# ...

# %%
elle_rose['category'] = category

# %%
elle_lisa = pd.read_csv('./blackpink/elle_lisa.csv', sep='|', encoding = 'utf-8')

# %%
path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)

category = []


for i in range(len(elle_lisa)) :
    url = elle_lisa['elle_link'][i]
    driver.get(url)
    
    print(i, driver.current_url)
    
    driver.get(url)
    
    try:
        category.append(driver.find_element_by_css_selector('#contents > div > div.article_head > div').find_element_by_tag_name('span').text)
        
    except NoSuchElementException as nse :
        category.append(0)
    
    time.sleep(1)
    
    
print('-'*50)
print(len(category))
# Out:
# 0 https://www.elle.co.kr/article/49661
# 1 https://www.elle.co.kr/article/50533
# 2 https://www.elle.co.kr/article/48533
# 3 https://www.elle.co.kr/article/45776
# 4 https://www.elle.co.kr/article/44180
# 5 https://www.elle.co.kr/article/44417
# 6 https://www.elle.co.kr/article/44288
# 7 https://www.elle.co.kr/article/49646
# 8 https://www.elle.co.kr/article/44127
# 9 https://www.elle.co.kr/article/22749
# 10 https://www.elle.co.kr/article/48666
# 11 https://www.elle.co.kr/article/44424
# 12 https://www.elle.co.kr/article/48703
# 13 https://www.elle.co.kr/article/48513
# 14 https://www.elle.co.kr/article/47768
# 15 https://www.elle.co.kr/article/18847
# 16 https://www.elle.co.kr/article/48049
# 17 https://www.elle.co.kr/article/47329
# 18 https://www.elle.co.kr/article/46687
# 19 https://www.elle.co.kr/article/45015
# 20 https://www.elle.co.kr/article/45130
# 21 https://www.elle.co.kr/article/46520
# 22 https://www.elle.co.kr/article/44354
# 23 https://www.elle.co.kr/article/43932
# ...

# %%
elle_lisa['category'] = category

# %%
path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)

category = []


for i in range(len(elle_jisu)) :
    url = elle_jisu['elle_link'][i]
    driver.get(url)
    
    print(i, driver.current_url)
    
    driver.get(url)
    
    try:
        category.append(driver.find_element_by_css_selector('#contents > div > div.article_head > div').find_element_by_tag_name('span').text)
        
    except NoSuchElementException as nse :
        category.append(0)
    
    time.sleep(1)
    
    
print('-'*50)
print(len(category))
# Out:
# 0 https://www.elle.co.kr/article/50348
# 1 https://www.elle.co.kr/article/48988
# 2 https://www.elle.co.kr/article/50554
# 3 https://www.elle.co.kr/article/49409
# 4 https://www.elle.co.kr/article/49823
# 5 https://www.elle.co.kr/article/48272
# 6 https://www.elle.co.kr/article/50516
# 7 https://www.elle.co.kr/shop/article/622
# 8 https://www.elle.co.kr/shop/article/619
# 9 https://www.elle.co.kr/article/48866
# 10 https://www.elle.co.kr/article/47317
# 11 https://www.elle.co.kr/article/47215
# 12 https://www.elle.co.kr/article/50267
# 13 https://www.elle.co.kr/article/47453
# 14 https://www.elle.co.kr/article/50135
# 15 https://www.elle.co.kr/shop/article/551
# 16 https://www.elle.co.kr/article/43183
# 17 https://www.elle.co.kr/article/49842
# 18 https://www.elle.co.kr/article/43313
# 19 https://www.elle.co.kr/shop/article/519
# 20 https://news.joins.com/article/23653194
# 21 https://www.elle.co.kr/article/47339
# 22 https://www.elle.co.kr/article/49095
# ...

# %%
elle_jisu['category'] = category

# %% [markdown]
# ## 코스모 - 카테고리

# %%
path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)

category = []


for i in range(len(cosmo_jenny)) :
    url = cosmo_jenny['cosmo_link'][i]
    driver.get(url)
    
    print(i, driver.current_url)
    
    driver.get(url)
    
    try:
        category.append(driver.find_element_by_css_selector('#contents > div > div.article_head > div').find_element_by_tag_name('span').text)
        
    except NoSuchElementException as nse :
        category.append(0)
    
    time.sleep(1)
    
    
print('-'*50)
print(len(category))
# Out:
# 0 https://www.cosmopolitan.co.kr/article/49623
# 1 https://www.cosmopolitan.co.kr/article/50292
# 2 https://www.cosmopolitan.co.kr/article/47370
# 3 https://www.cosmopolitan.co.kr/article/49434
# 4 https://www.cosmopolitan.co.kr/article/49632
# 5 https://www.cosmopolitan.co.kr/article/45097
# 6 https://www.cosmopolitan.co.kr/article/49452
# 7 https://www.cosmopolitan.co.kr/article/33658
# 8 https://www.cosmopolitan.co.kr/article/49226
# 9 https://www.cosmopolitan.co.kr/article/48903
# 10 https://www.cosmopolitan.co.kr/article/49102
# 11 https://www.cosmopolitan.co.kr/article/48986
# 12 https://www.cosmopolitan.co.kr/article/48707
# 13 https://www.cosmopolitan.co.kr/article/32737
# 14 https://www.cosmopolitan.co.kr/article/49351
# 15 https://www.cosmopolitan.co.kr/article/47840
# 16 https://www.cosmopolitan.co.kr/article/48009
# 17 https://www.cosmopolitan.co.kr/article/47833
# 18 https://www.cosmopolitan.co.kr/article/48103
# 19 https://www.cosmopolitan.co.kr/article/47318
# ...

# %%
cosmo_jenny['category'] = category

# %%
path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)

category = []


for i in range(len(cosmo_jisu)) :
    url = cosmo_jisu['cosmo_link'][i]
    driver.get(url)
    
    print(i, driver.current_url)
    
    driver.get(url)
    
    try:
        category.append(driver.find_element_by_css_selector('#contents > div > div.article_head > div').find_element_by_tag_name('span').text)
        
    except NoSuchElementException as nse :
        category.append(0)
    
    time.sleep(1)
    
    
print('-'*50)
print(len(category))
# Out:
# 0 https://www.cosmopolitan.co.kr/article/49105
# 1 https://www.cosmopolitan.co.kr/article/49434
# 2 https://www.cosmopolitan.co.kr/article/49649
# 3 https://www.cosmopolitan.co.kr/article/49364
# 4 https://www.cosmopolitan.co.kr/article/49185
# 5 https://www.cosmopolitan.co.kr/article/49452
# 6 https://www.cosmopolitan.co.kr/article/49593
# 7 https://www.cosmopolitan.co.kr/article/49403
# 8 https://www.cosmopolitan.co.kr/article/49103
# 9 https://www.cosmopolitan.co.kr/article/48903
# 10 https://www.cosmopolitan.co.kr/article/46557
# 11 https://www.cosmopolitan.co.kr/article/48683
# 12 https://www.cosmopolitan.co.kr/article/48961
# 13 https://www.cosmopolitan.co.kr/article/28648
# 14 https://www.cosmopolitan.co.kr/article/33385
# 15 https://www.cosmopolitan.co.kr/article/48841
# 16 https://www.cosmopolitan.co.kr/article/29723
# 17 https://www.cosmopolitan.co.kr/article/48225
# 18 https://www.cosmopolitan.co.kr/article/47743
# 19 https://www.cosmopolitan.co.kr/article/48163
# ...

# %%
cosmo_jisu['category'] = category

# %%
path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)

category = []


for i in range(len(cosmo_rose)) :
    url = cosmo_rose['cosmo_link'][i]
    driver.get(url)
    
    print(i, driver.current_url)
    
    driver.get(url)
    
    try:
        category.append(driver.find_element_by_css_selector('#contents > div > div.article_head > div').find_element_by_tag_name('span').text)
        
    except NoSuchElementException as nse :
        category.append(0)
    
    time.sleep(1)
    
    
print('-'*50)
print(len(category))
# Out:
# 0 https://www.cosmopolitan.co.kr/article/50134
# 1 https://www.cosmopolitan.co.kr/article/50052
# 2 https://www.cosmopolitan.co.kr/article/50043
# 3 https://www.cosmopolitan.co.kr/article/49434
# 4 https://www.cosmopolitan.co.kr/article/49452
# 5 https://www.cosmopolitan.co.kr/article/49214
# 6 https://www.cosmopolitan.co.kr/article/49099
# 7 https://www.cosmopolitan.co.kr/article/48903
# 8 https://www.cosmopolitan.co.kr/article/48822
# 9 https://www.cosmopolitan.co.kr/article/48568
# 10 https://www.cosmopolitan.co.kr/article/48572
# 11 https://www.cosmopolitan.co.kr/article/47400
# 12 https://www.cosmopolitan.co.kr/article/47627
# 13 https://www.cosmopolitan.co.kr/article/45664
# 14 https://www.cosmopolitan.co.kr/article/46465
# 15 https://www.cosmopolitan.co.kr/article/46297
# 16 https://www.cosmopolitan.co.kr/article/46658
# 17 https://www.cosmopolitan.co.kr/article/46378
# 18 https://www.cosmopolitan.co.kr/article/42377
# 19 https://www.cosmopolitan.co.kr/article/45563
# ...

# %%
cosmo_rose['category'] = category

# %%
path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)

category = []


for i in range(len(cosmo_lisa)) :
    url = cosmo_lisa['cosmo_link'][i]
    driver.get(url)
    
    print(i, driver.current_url)
    
    driver.get(url)
    
    try:
        category.append(driver.find_element_by_css_selector('#contents > div > div.article_head > div').find_element_by_tag_name('span').text)
        
    except NoSuchElementException as nse :
        category.append(0)
    
    time.sleep(1)
    
    
print('-'*50)
print(len(category))
# Out:
# 0 https://www.cosmopolitan.co.kr/article/50201
# 1 https://www.cosmopolitan.co.kr/article/49434
# 2 https://www.cosmopolitan.co.kr/article/49452
# 3 https://www.cosmopolitan.co.kr/article/48716
# 4 https://www.cosmopolitan.co.kr/article/32022
# 5 https://www.cosmopolitan.co.kr/article/48568
# 6 https://www.cosmopolitan.co.kr/article/48081
# 7 https://www.cosmopolitan.co.kr/article/46971
# 8 https://www.cosmopolitan.co.kr/article/47627
# 9 https://www.cosmopolitan.co.kr/article/45626
# 10 https://www.cosmopolitan.co.kr/article/45664
# 11 https://www.cosmopolitan.co.kr/article/45133
# 12 https://www.cosmopolitan.co.kr/article/46473
# 13 https://www.cosmopolitan.co.kr/article/43419
# 14 https://www.cosmopolitan.co.kr/article/44038
# 15 https://www.cosmopolitan.co.kr/article/45669
# 16 https://www.cosmopolitan.co.kr/article/44412
# 17 https://www.cosmopolitan.co.kr/article/43531
# 18 https://www.cosmopolitan.co.kr/article/33695
# 19 https://www.cosmopolitan.co.kr/article/40384
# ...

# %%
cosmo_lisa['category'] = category

# %%
elle_jenny.to_csv('./blackpink/elle_jenny.csv', sep='|', encoding = 'utf-8', index = False)
elle_jisu.to_csv('./blackpink/elle_jisu.csv', sep='|', encoding = 'utf-8', index = False)
elle_rose.to_csv('./blackpink/elle_rose.csv', sep='|', encoding = 'utf-8', index = False)
elle_lisa.to_csv('./blackpink/elle_lisa.csv', sep='|', encoding = 'utf-8', index = False)

# %%
cosmo_jenny.to_csv('./blackpink/cosmo_jenny.csv', sep='|', encoding = 'utf-8', index = False)
cosmo_jisu.to_csv('./blackpink/cosmo_jisu.csv', sep='|', encoding = 'utf-8', index = False)
cosmo_rose.to_csv('./blackpink/cosmo_rose.csv', sep='|', encoding = 'utf-8', index = False)
cosmo_lisa.to_csv('./blackpink/cosmo_lisa.csv', sep='|', encoding = 'utf-8', index = False)

# %%
elle_jisu = pd.read_csv('./blackpink/elle_jisu.csv', sep='|', encoding = 'utf-8')

# %% [markdown]
# ### 날짜로 sort

# %%
def sort_date(df):
    df.sort_values(by = 'date', ascending=False, inplace=True)
    df.reset_index(drop='True', inplace=True)

# %%
elle_bp = [elle_jenny, elle_jisu, elle_rose, elle_lisa]

# %%
cosmo_bp = [cosmo_jenny, cosmo_jisu, cosmo_rose, cosmo_lisa]

# %%
for e_bp in elle_bp:
    sort_date(e_bp)

# %%
for c_bp in cosmo_bp:
    sort_date(c_bp)

# %%
sort_date(elle_jisu)

# %%
elle_jenny['date'].unique()
# Out:
# array(['2020.12.08', '2020.11.26', '2020.11.23', '2020.11.17',
#        '2020.11.12', '2020.11.11', '2020.11.07', '2020.11.03',
#        '2020.10.29', '2020.10.28', '2020.10.25', '2020.10.13',
#        '2020.10.12', '2020.09.23', '2020.09.14', '2020.09.08',
#        '2020.09.04', '2020.09.03', '2020.08.31', '2020.08.29',
#        '2020.08.28', '2020.08.26', '2020.08.24', '2020.08.21',
#        '2020.08.14', '2020.08.12', '2020.08.03', '2020.07.30',
#        '2020.07.24', '2020.07.21', '2020.07.20', '2020.07.19',
#        '2020.07.16', '2020.06.26', '2020.05.31', '2020.05.26',
#        '2020.04.28', '2020.04.17', '2020.04.16', '2020.03.20',
#        '2020.03.17', '2020.03.16', '2020.03.05', '2020.02.18',
#        '2020.02.12', '2020.01.24', '2020.01.11', '2020.01.03',
#        '2020.01.01', '2019.12.23', '2019.12.15', '2019.12.10',
#        '2019.12.09', '2019.12.05', '2019.12.02', '2019.11.24',
#        '2019.11.22', '2019.11.20', '2019.11.16', '2019.11.09',
# ...

# %%
elle_jenny.loc[elle_jenny['date']=='6시간전 | 엘르 ', 'date'] = '2020.12.08'

# %% [markdown]
# ### title_name

# %%
elle_jenny['title_name']=0
elle_jisu['title_name']=0
elle_rose['title_name']=0
elle_lisa['title_name']=0

# %%
cosmo_jenny['title_name']=0
cosmo_jisu['title_name']=0
cosmo_rose['title_name']=0
cosmo_lisa['title_name']=0

# %%
for e_bp in elle_bp:
    print(e_bp.columns)
    print('-'*50)
# Out:
# Index(['title', 'link', 'date', 'elle_link', 'contents', 'category',
#        'title_name', 'check'],
#       dtype='object')
# --------------------------------------------------
# Index(['title', 'link', 'date', 'elle_link', 'contents', 'category',
#        'title_name'],
#       dtype='object')
# --------------------------------------------------
# Index(['title', 'link', 'date', 'elle_link', 'contents', 'category',
#        'title_name'],
#       dtype='object')
# --------------------------------------------------
# Index(['title', 'link', 'date', 'elle_link', 'contents', 'category',
#        'title_name'],
#       dtype='object')
# --------------------------------------------------

# %%
for c_bp in cosmo_bp:
    print(c_bp.columns)
    print('-'*50)
# Out:
# Index(['title', 'link', 'date', 'cosmo_link', 'contents', 'category',
#        'title_name'],
#       dtype='object')
# --------------------------------------------------
# Index(['title', 'link', 'date', 'cosmo_link', 'contents', 'category',
#        'title_name'],
#       dtype='object')
# --------------------------------------------------
# Index(['title', 'link', 'date', 'cosmo_link', 'contents', 'category',
#        'title_name'],
#       dtype='object')
# --------------------------------------------------
# Index(['title', 'link', 'date', 'cosmo_link', 'contents', 'category',
#        'title_name'],
#       dtype='object')
# --------------------------------------------------

# %% [markdown]
# ### 타이틀 확인

# %%
def get_title(df, kw):
    for i in range(len(df)):
        if kw in df.loc[i, 'title']:
            df.loc[i, 'title_name'] = 1

# %%
get_title(elle_jenny, '제니')
get_title(elle_jisu, '지수')
get_title(elle_lisa, '리사')
get_title(elle_rose, '로제')

# %%
get_title(cosmo_jenny, '제니')
get_title(cosmo_jisu, '지수')
get_title(cosmo_lisa, '리사')
get_title(cosmo_rose, '로제')

# %% [markdown]
# ### 키워드 확인

# %%
elle_jenny['check'] = 0
for i in range(len(elle_jenny)):
    if elle_jenny.loc[i, 'title_name'] == 0:
        if '제니' not in elle_jenny.loc[i, 'contents']:
            elle_jenny.loc[i, 'check'] = 2

# %%
def get_check(df, kw):
    df['check']=0
    for i in range(len(df)):
        if df.loc[i, 'title_name'] == 0:
            if kw not in df.loc[i, 'contents']:
                df.loc[i, 'check']=2

# %%
get_check(elle_jenny, '제니')
get_check(elle_jisu, '지수')
get_check(elle_rose, '로제')
get_check(elle_lisa, '리사')

# %%
get_check(elle_jisu, '지수')

# %%
get_check(cosmo_jenny, '제니')
get_check(cosmo_jisu, '지수')
get_check(cosmo_rose, '로제')
get_check(cosmo_lisa, '리사')

# %%
elle_jenny.to_csv('./blackpink/elle_jenny.csv', sep='|', encoding = 'utf-8', index = False)
elle_jisu.to_csv('./blackpink/elle_jisu.csv', sep='|', encoding = 'utf-8', index = False)
elle_rose.to_csv('./blackpink/elle_rose.csv', sep='|', encoding = 'utf-8', index = False)
elle_lisa.to_csv('./blackpink/elle_lisa.csv', sep='|', encoding = 'utf-8', index = False)
cosmo_jenny.to_csv('./blackpink/cosmo_jenny.csv', sep='|', encoding = 'utf-8', index = False)
cosmo_jisu.to_csv('./blackpink/cosmo_jisu.csv', sep='|', encoding = 'utf-8', index = False)
cosmo_rose.to_csv('./blackpink/cosmo_rose.csv', sep='|', encoding = 'utf-8', index = False)
cosmo_lisa.to_csv('./blackpink/cosmo_lisa.csv', sep='|', encoding = 'utf-8', index = False)

# %% [markdown]
# ## 콘텐츠 확인 - 멤버 아닌거 제거

# %% [markdown]
# ### 제니

# %%
# 제니퍼 삭제
for word in elle_jenny['contents']:
    if '제니' in word:
        print(word)
        print('-'*50)
# Out:
# [[], ['', '쇄골 라인에 걸리는 진주 목걸이의 클래식한 매력을 캐치한 제니. 화이트 셔츠와 블랙 컬러의 테일러드 재킷에 진주 목걸이를 매치해 세련되게 연출했습니다. 진주 주얼리에 도전해보고 싶다면 어떤 룩에든 자연스럽게 어울리는 간결한 진주 목걸이부터 시작해보세요.', '', '김나영은 캐주얼한 프린트 티셔츠와 데님 팬츠에 허리 라인까지 내려오는 긴 진주 목걸이를 매치했어요. 이런 스타일은 쇄골 라인에 걸쳐지는 짧은 목걸이보다 더 화려하고 성숙한 느낌을 줄 수 있죠. 목에 두 번 감아 짧게 연출할 수도 있으니 일석이조!', '', '진주 주얼리가 얌전하다는 고정관념은 이제 버리셔도 좋습니다. 볼륨감 있는 진주 주얼리는 섹시하고 대담한 이미지를 줄 수 있거든요. 진주 목걸이를 목에 딱 맞는 초커 스타일로 레이어드하고 귀여운 꽃 모티프의 펜던트가 잘 보이게 아래로 늘어뜨려 화려하게 연출한 전소미의 스타일을 참고하세요.', '', '지수의 언밸런스한 이어링에 주목해보세요. 한쪽 귀엔 작고 심플한 진주 이어링을, 다른 쪽 귀엔 진주를 체인으로 연결한 드롭 이어링을 선택했습니다. 이렇게 각기 다른 스타일의 진주 이어링을 믹스하면 통일감은 유지하면서 센스 넘치는 연출을 할 수 있어요.', '', '다라는 핸드폰을 액세서리처럼 적극 활용하고 있어요. 진주와 체인이 믹스된 크로스 보디 형태의 핸드폰 스트랩을 연결하고 화려한 패턴의 케이스를 장착해 진주의 무궁무진한 활용법을 제시합니다.', '', '예리는 진주 목걸이 대신 헤어 밴드를 선택했어요. 단정하게 정리한 긴 생머리에 촘촘하게 꿴 진주 헤어 밴드를 더해 클래식한 매력을 극대화했죠. 골드 버튼 포인트의 니트 원피스와 군더더기 없는 사각 백으로 우아하게 연출한 오늘의 룩과도 잘 어울리네요.', '* 잔나비, 사이먼도미닉, 이성경, 이제훈, 박정민, 코드 쿤스트가 함께한 뮤직 프로젝트 보기']]
# --------------------------------------------------
# ...

# %%
elle_jenny['no'] = 0

# %%
elle_jenny.loc[elle_jenny['contents'].str.contains('제니 홀저'), 'no'] = np.NaN

# %%
elle_jenny.loc[elle_jenny['contents'].str.contains('NOW제니?'), 'no'] = np.NaN

# %%
elle_jenny.loc[elle_jenny['contents'].str.contains('미국인 제니 한의'), 'no'] = np.NaN

# %%
elle_jenny.loc[elle_jenny['contents'].str.contains('제니 게이지 감독은'), 'no'] = np.NaN

# %%
elle_jenny.loc[elle_jenny['contents'].str.contains('감독 제니 게이지와'), 'no'] = np.NaN

# %%
elle_jenny.loc[elle_jenny['contents'].str.contains('제니 오델'), 'no'] = np.NaN

# %%
elle_jenny.loc[elle_jenny['contents'].str.contains('작가 제니 루니는'), 'no'] = np.NaN

# %%
elle_jenny.loc[elle_jenny['contents'].str.contains('제니팩햄 원피스를'), 'no'] = np.NaN

# %%
elle_jenny.loc[elle_jenny['contents'].str.contains('앨리슨 제니의'), 'no'] = np.NaN

# %%
elle_jenny.loc[elle_jenny['contents'].str.contains('레클레어 드 제니'), 'no'] = np.NaN

# %%
elle_jenny.loc[elle_jenny['contents'].str.contains('제니 리베라가'), 'no'] = np.NaN

# %%
elle_jenny.loc[elle_jenny['contents'].str.contains('제니 권 디자인'), 'no'] = np.NaN

# %%
elle_jenny.loc[elle_jenny['contents'].str.contains('제니 시미즈'), 'no'] = np.NaN

# %%
elle_jenny.dropna(inplace=True)

# %%
elle_jenny.isnull().sum()
# Out:
# title         0
# link          0
# date          0
# elle_link     0
# contents      0
# category      0
# title_name    0
# check         0
# no            0
# dtype: int64

# %%
elle_jenny.reset_index(drop=True, inplace =True)

# %%
elle_jenny
# Out:
#                                  title  \
# 0            김나영부터 지수까지! 진주 주얼리를 한 스타들
# 1             공효진부터 제니까지! 스타들의 #니트 활용법
# 2             '핑크색 입으면 기분이 조크든요' 핑크 홀릭
# 3         제니부터 조이까지! 스타들이 선택한 #리본헤어스타일
# 4   저장각! 겨울 필수템 머플러, 스타들의 연출법과 추천템 리스트
# ..                                 ...
# 78                           활짝 핀 블랙핑크
# 79                           봄에 피어난 제니
# 80         엘르 최초 K팝 그룹 단체 커버의 주인공 블랙핑크
# 81                          제니의 패션 놀이터
# 82                        그 입술 '공답'되나요
#
#                                            link        date  \
# 0   http://v.media.daum.net/v/20201126070033106  2020.11.26
# 1   http://v.media.daum.net/v/20201123070034440  2020.11.23
# 2   http://v.media.daum.net/v/20201117115642590  2020.11.17
# 3   http://v.media.daum.net/v/20201112070037606  2020.11.12
# 4   http://v.media.daum.net/v/20201111070112614  2020.11.11
# ..                                          ...         ...
# 78  http://v.media.daum.net/v/20180404142840507  2018.04.04
# ...

# %% [markdown]
# ### 리사

# %%
# 요리사 삭제
for word in elle_lisa['contents']:
    if '리사' in word:
        print(word)
        print('-'*50)
# Out:
# [[], ['', '겨울에 더 사랑받는 패턴이 있습니다. 바로 마름모꼴이 연속적으로 배치된 아가일 패턴인데요, 주로 니트나 울, 캐시미어 등 포근한 소재들로 만들어 따뜻하고 클래식한 매력으로 꾸준히 사랑받고 있어요. 특히 이번 시즌에는 다양한 브랜드에서 아가 일 패턴의 제품을 만나볼 수 있을 만큼 그 활약이 두드러집니다.', '', '', '', '', '버버리에서는 스웨터와 스커트, 핸드백까지 아가일 패턴으로 통일한 스타일링을 제안했는데요, 아가일 패턴의 니트 셋업룩 에컬리한 디테일이 돋보이는 양털 코트와 미니멀한 디자인의 앵클 부츠로 레트로한 무드를 한층 세련되게 완성했어요. 클래식한 이미지의 아가일 패턴을 성근 짜임과 디스트로이드 디테일로 그런지하게 해석한 아크네 스튜디오의 오버사이즈 스웨터와 두 가지 컬러만으로 구성된 아가일 패턴의 카디건으로 웨어러블한 데일리 룩을 연출한 아미 파리스, 출시되자마자 품절 사태를 일으키며 국내 패피들의높은 관심을받는 더 오픈 프로덕트의 아가일 패턴 머플러까지 선택지는 다양합니다. 대 유행을 예감하는 아가일 패턴의 활약상은 스타들의 룩에서도 찾아볼 수 있습니다.', '', '넉넉한 크기의 아가일 패턴 스웨터에 샤스커트를 매치하고 모자, 장갑 등 귀여운 액세서리로 그녀만의 빈티지한 감성을 드러낸 현아.', '', '시어한 소재의 아가일 패턴 블라우스에 레터링 장식 톱과 펑키한 무드의 액세서리를 레이어드해 개성을 더한 리사.', '', '단정해 보이고 싶다면 문별처럼! 클린한 셔츠와 슬랙스, 아가일 패턴의 베스트로 모범생 스타일의 아웃핏을 완성했어요.', '', '베이지와 브라운 컬러의 톤온톤 매치가 돋보이는 아가일 스웨터로 분위기 여신의 면모를 드러낸 엄현경.', '', '올겨울 부츠보다 트렌디한 건 니삭스! 배우 이주우는캐멀 컬러의 미디스커트에 아가일 패턴의 니삭스로 확실하게 포인트를 주었습니다.']]
# --------------------------------------------------
# ...

# %%
elle_lisa['no'] = 0

# %%
elle_lisa.loc[elle_lisa['contents'].str.contains('모델 이사 리사의'), 'no'] = np.NaN

# %%
elle_lisa.loc[elle_lisa['contents'].str.contains('리사 레이하나'), 'no'] = np.NaN

# %%
elle_lisa.loc[elle_lisa['contents'].str.contains('리사 밴더펌프'), 'no'] = np.NaN

# %%
elle_lisa.loc[elle_lisa['contents'].str.contains('리사 캉테르'), 'no'] = np.NaN

# %%
elle_lisa.loc[elle_lisa['contents'].str.contains('투어 가이드 리사와 나눈'), 'no'] = np.NaN

# %%
elle_lisa.loc[elle_lisa['contents'].str.contains('멀리사'), 'no'] = np.NaN

# %%
elle_lisa.loc[elle_lisa['contents'].str.contains('리사 올쓰'), 'no'] = np.NaN

# %%
elle_lisa.loc[elle_lisa['contents'].str.contains('리사와 다니엘은'), 'no'] = np.NaN

# %%
elle_lisa.loc[elle_lisa['contents'].str.contains('리사 쿠드로'), 'no'] = np.NaN

# %%
elle_lisa.loc[elle_lisa['contents'].str.contains('#리사 장윤주'), 'no'] = np.NaN

# %%
elle_lisa.loc[elle_lisa['contents'].str.contains('리사 로고빈'), 'no'] = np.NaN

# %%
elle_lisa.loc[elle_lisa['contents'].str.contains('LISA CORTI'), 'no'] = np.NaN

# %%
elle_lisa.loc[elle_lisa['contents'].str.contains('리사와 함께 레고를 조립하며'), 'no'] = np.NaN

# %%
elle_lisa.loc[elle_lisa['contents'].str.contains('딸 리사 마리의'), 'no'] = np.NaN

# %%
elle_lisa.loc[elle_lisa['contents'].str.contains('예술 감정가 리사 페리'), 'no'] = np.NaN

# %%
elle_lisa.loc[elle_lisa['contents'].str.contains('오른 또 다른 친구는 리사'), 'no'] = np.NaN

# %%
elle_lisa.loc[elle_lisa['contents'].str.contains('안나리사'), 'no'] = np.NaN

# %%
elle_lisa.loc[elle_lisa['contents'].str.contains('리사 마리 페르난데즈'), 'no'] = np.NaN

# %%
elle_lisa.loc[elle_lisa['contents'].str.contains('부사장 리사 니시무라'), 'no'] = np.NaN

# %%
elle_lisa.loc[elle_lisa['contents'].str.contains('<리사>를 냈다'), 'no'] = np.NaN

# %%
elle_lisa.dropna(inplace=True)

# %%
elle_lisa.isnull().sum()
# Out:
# title         0
# link          0
# date          0
# elle_link     0
# contents      0
# category      0
# title_name    0
# check         0
# no            0
# dtype: int64

# %%
elle_lisa.reset_index(drop=True, inplace =True)

# %%
len(elle_lisa)
# Out:
# 46

# %%
elle_lisa[['title', 'contents']]
# Out:
#                                   title  \
# 0   데일리 윈터룩, 이만한 게 없지! '아가일 패턴'을 즐겨입는 법
# 1              새로운 뷰티 아이콘으로 등극한 블랙핑크 리사
# 2                        이번 가을? 체크를 체크!
# 3                        그녀의 가방이 궁금해 #1
# 4                        필카와 사랑에 빠진 스타들
# 5                  리사부터 선미까지 스타들의 블랙 홀릭
# 6     아이스크림 칠링칠링, 블랙핑크와 셀레나 고메즈의 (스압주의)
# 7                  제니, 걸그룹 브랜드 평판 1위 등극
# 8                              돌아온 블랙핑크
# 9                           골지 니트 '잘'입기
# 10                          리사, 프라다 레이디
# 11   같은 옷 다른 느낌! 패션위크를 찾은 K스타 VS 런웨이 모델
# 12                스타 잇템. 머스트 해브 #크로스보디백
# 13      오늘을 위한 아우터, 울 블레이저 _ 요주의 물건 #19
# 14                               꽃보다 리사
# 15                   블랙핑크 리사, 꽃 보다 아름다워
# 16          K-메이크업의 중심에 선 이명선 메이크업 아티스트
# 17           블랙핑크 리사가 <엘르>에만 전한 소확행의 순간
# 18                         리사, 꽃처럼 피어나다
# 19            리사 플러스 로제? 또 다른 스타 더하기 스타
# 20                             수고했어 올해도
# 21                         부츠와 팬츠의 상관관계
# ...

# %% [markdown]
# ### 로제

# %%
# 요리사 삭제
for word in elle_rose['contents']:
    if '로제' in word:
        print(word)
        print('-'*50)
# Out:
# [[], ['', '출산 후 아이와 함께 산책하는 모습을 깜짝 공개한 지지 하디드. 아기띠를 둘렀지만 편안하고 스타일리시한 룩을 포기하지 않았어요. 위아래 한 벌로 맞춰 입은 하늘색 트레이닝 수트 위에 루스한 롱 카디건을 걸치고 비니를 써 멋스럽게 연출했죠. 여기에 울 삭스와 투박한 어그 부츠로 보온성에 신경 쓴 느낌 있는 산책 룩이 인상적입니다.', '', "로제가 ‘꾸안꾸' 데일리 룩으로 고른 슈즈는어그 슬리퍼입니다. 발등을 넓게 덮은 시어링 디테일이 귀여운 인상을 풍기는데요, 그녀는 블랙, 네이비처럼 톤 다운된 룩과 매치하고 슈즈의 컬러와 비슷한 크로스보디 백을 짧게 메 포인트 있는 아웃 핏을 즐겼습니다.", '', '멋진 일몰 풍경을 감상하기 위해 자연으로 떠난 김용지는 추운 날씨를 대비해 든든하게 옷을 챙겨 입었습니다. 도톰한 트레이 닝 팬츠 위에 후디와 경량 패딩, 울 점퍼까지 여러 겹을 레이어드하고 귀를 덮는 트래퍼햇으로 마무리했죠. 여기에 바지와 같 은 컬러의 어그 부츠를 신어 머리부터 발끝까지 완벽하게 무장했어요.', '', '캠핑지에서 신을 슈즈를 찾고 있다면 ‘갬성’ 캠핑을 떠난 솔라의어그 슬리퍼를 눈여겨보세요. 튼튼한 러버솔을 장착해 자갈이 많은 지형에서도 활용 만점! 코지한 트레이닝 룩과도 잘 어울릴 뿐만 아니라 귀여움은 덤!', '', '핫 핑크 컬러의 어그 부츠를 신고 모델 포스를 발산하는 조안 스몰스. 아찔한 킬힐은 아니지만, 강렬한 컬러 덕분에 에지있어 보입니다. 슈즈와비슷한 색깔로 맞춤 한 캐미솔에 보색인 라임 컬러의 오버사이즈 셔츠를 걸쳐 화려한 컬러 매치를 선보였어요.', '', '어그 부츠를 힙하게 소화하고 싶다면 허영지의 룩을 참고해보세요. 흔한 데님 팬츠보다는 트레이닝 팬츠에 매치하는 것이 훨씬 쿨해 보일 수 있어요. 꾸미지 않은 듯 위아래 세트로 트레이닝 룩을 맞춰 입는다면 금상첨화! 볼륨감 있는 쇼트 패딩 점퍼 나 플리스 점퍼처럼 짧은 아우터를 더하면 활동적인 이미지를 드러낼 수 있답니다.']]
# ...

# %%
elle_rose['no'] = 0

# %%
elle_rose.loc[elle_rose['contents'].str.contains('로제 와인'), 'no'] = np.NaN

# %%
elle_rose.loc[elle_rose['contents'].str.contains('로제 파스타'), 'no'] = np.NaN

# %%
elle_rose.loc[elle_rose['contents'].str.contains('로제 임페리얼'), 'no'] = np.NaN

# %%
elle_rose.loc[elle_rose['contents'].str.contains('크루즈 로제'), 'no'] = np.NaN

# %%
elle_rose.loc[elle_rose['contents'].str.contains('와인'), 'no'] = np.NaN

# %%
elle_rose.loc[elle_rose['contents'].str.contains('로제 바딤'), 'no'] = np.NaN

# %%
elle_rose.loc[elle_rose['contents'].str.contains('뵈브 클리코 로제'), 'no'] = np.NaN

# %%
elle_rose.loc[elle_rose['contents'].str.contains('베쥬 로제'), 'no'] = np.NaN

# %%
elle_rose.loc[elle_rose['contents'].str.contains('로제를 얇게 바르고'), 'no'] = np.NaN

# %%
elle_rose.loc[elle_rose['contents'].str.contains('샴페인'), 'no'] = np.NaN

# %%
elle_rose.loc[elle_rose['contents'].str.contains('린 로제'), 'no'] = np.NaN

# %%
elle_rose.loc[elle_rose['contents'].str.contains('로제 페스토'), 'no'] = np.NaN

# %%
elle_rose.loc[elle_rose['contents'].str.contains('슈가 로제'), 'no'] = np.NaN

# %%
elle_rose.loc[elle_rose['contents'].str.contains('로제, 7만2천원'), 'no'] = np.NaN

# %%
elle_rose.loc[elle_rose['contents'].str.contains('로제, 바닐라, 아이리스'), 'no'] = np.NaN

# %%
elle_rose.loc[elle_rose['contents'].str.contains('르네 로제'), 'no'] = np.NaN

# %%
elle_rose.loc[elle_rose['contents'].str.contains('로제 핑크'), 'no'] = np.NaN

# %%
elle_rose.dropna(inplace=True)

# %%
elle_rose.isnull().sum()
# Out:
# title         0
# link          0
# date          0
# elle_link     0
# contents      0
# category      0
# title_name    0
# check         0
# no            0
# dtype: int64

# %%
elle_rose.reset_index(drop=True, inplace =True)

# %%
elle_rose[['title', 'contents']]
# Out:
#                                  title  \
# 0                   유행은 돌아오는 거야! #어그슈즈
# 1                     '베레모'하나면 드레스업 끝!
# 2                로제처럼 귀엽게? 사랑스러운 핑크 헤어
# 3                    여름과 가을 사이, 니트 베스트
# 4                      로제만이 존재한 몰입의 순간
# 5                 리사부터 선미까지 스타들의 블랙 홀릭
# 6    아이스크림 칠링칠링, 블랙핑크와 셀레나 고메즈의 (스압주의)
# 7                 제니, 걸그룹 브랜드 평판 1위 등극
# 8       스타들이 픽한 여름 헤어 스타일링! 상큼 발랄 포니테일
# 9                          로제, 우먼 인 블랙
# 10                블랙핑크가 쓰는 K-pop의 새 역사
# 11                            돌아온 블랙핑크
# 12                           로제에게 경배를!
# 13                        스타들의 #덕분에챌린지
# 14                       스타 패션 in 패션위크
# 15  같은 옷 다른 느낌! 패션위크를 찾은 K스타 VS 런웨이 모델
# 16                      프런트로를 접수한 스타 5
# 17     로제, 수현, 오연서가 겨울 휴가로 선택한 곳 그리고 룩
# 18           리사 플러스 로제? 또 다른 스타 더하기 스타
# 19                         주목! Z세대 스타들
# 20                     양말 아무거나 신지 마세요!
# 21                   쉽게 대체되지 않을 이름, 제니
# 22          '쇼핑카트' 스타 패션으로 만나는 가을 재킷 5
# ...

# %% [markdown]
# ### 지수

# %%
elle_jisu
# Out:
#                                  title  \
# 0       쇼핑 각! 겨울 데일리 룩을 돋보이게 해줄 #크롭트재킷
# 1    떠오르는 사복 패션 강자! 표예진 스타일 탐구 #옷잘입는언니
# 2               독보적인 무드를 자아내는 앤더슨벨 원피스
# 3                      겨울, 이젠 페이크퍼의 계절
# 4            김나영부터 지수까지! 진주 주얼리를 한 스타들
# ..                                 ...
# 176                         똑똑한 수분섭취 법
# 177                         손님 이건 고데예요
# 178                         9월 신제품 품평기
# 179                       미세먼지 흡수율 제로!
# 180                        꽃미남 황자, 남주혁
#
#                                             link        date  \
# 0    http://v.media.daum.net/v/20201207070042388  2020.12.07
# 1    http://v.media.daum.net/v/20201204164057784  2020.12.04
# 2    http://v.media.daum.net/v/20201130195636025  2020.11.30
# 3    http://v.media.daum.net/v/20201130000006671  2020.11.30
# 4    http://v.media.daum.net/v/20201126070033106  2020.11.26
# ..                                           ...         ...
# ...

# %% [markdown]
# 지수

# %%
# 요리사 삭제
for word in elle_jisu['contents']:
    if '지수' in word:
        if '블랙핑크' not in word:
            print(word)
            print('-'*50)
# Out:
# [[], ['', '쇄골 라인에 걸리는 진주 목걸이의 클래식한 매력을 캐치한 제니. 화이트 셔츠와 블랙 컬러의 테일러드 재킷에 진주 목걸이를 매치해 세련되게 연출했습니다. 진주 주얼리에 도전해보고 싶다면 어떤 룩에든 자연스럽게 어울리는 간결한 진주 목걸이부터 시작해보세요.', '', '김나영은 캐주얼한 프린트 티셔츠와 데님 팬츠에 허리 라인까지 내려오는 긴 진주 목걸이를 매치했어요. 이런 스타일은 쇄골 라인에 걸쳐지는 짧은 목걸이보다 더 화려하고 성숙한 느낌을 줄 수 있죠. 목에 두 번 감아 짧게 연출할 수도 있으니 일석이조!', '', '진주 주얼리가 얌전하다는 고정관념은 이제 버리셔도 좋습니다. 볼륨감 있는 진주 주얼리는 섹시하고 대담한 이미지를 줄 수 있거든요. 진주 목걸이를 목에 딱 맞는 초커 스타일로 레이어드하고 귀여운 꽃 모티프의 펜던트가 잘 보이게 아래로 늘어뜨려 화려하게 연출한 전소미의 스타일을 참고하세요.', '', '지수의 언밸런스한 이어링에 주목해보세요. 한쪽 귀엔 작고 심플한 진주 이어링을, 다른 쪽 귀엔 진주를 체인으로 연결한 드롭 이어링을 선택했습니다. 이렇게 각기 다른 스타일의 진주 이어링을 믹스하면 통일감은 유지하면서 센스 넘치는 연출을 할 수 있어요.', '', '다라는 핸드폰을 액세서리처럼 적극 활용하고 있어요. 진주와 체인이 믹스된 크로스 보디 형태의 핸드폰 스트랩을 연결하고 화려한 패턴의 케이스를 장착해 진주의 무궁무진한 활용법을 제시합니다.', '', '예리는 진주 목걸이 대신 헤어 밴드를 선택했어요. 단정하게 정리한 긴 생머리에 촘촘하게 꿴 진주 헤어 밴드를 더해 클래식한 매력을 극대화했죠. 골드 버튼 포인트의 니트 원피스와 군더더기 없는 사각 백으로 우아하게 연출한 오늘의 룩과도 잘 어울리네요.', '* 잔나비, 사이먼도미닉, 이성경, 이제훈, 박정민, 코드 쿤스트가 함께한 뮤직 프로젝트 보기']]
# --------------------------------------------------
# ...

# %%
elle_jisu['no']=0

# %%
elle_jisu.loc[elle_jisu['contents'].str.contains('부탄의 행복 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('메이크업 지수까지'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('차단지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('체질량지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('스트레스 해소 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('자외선 차단지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains(' PA 지수 표시 기준'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains(' 귀여움 지수가 수직 상승'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('pH 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('지수 얘기는 그동안'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('행복 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('노출지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('귀여움 지수'), 'no'] = np.NaN

elle_jisu.loc[elle_jisu['contents'].str.contains('자외선 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('성평등 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('스타일 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('로맨틱 지수'), 'no'] = np.NaN

elle_jisu.loc[elle_jisu['contents'].str.contains('고용지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('건조지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('스타일지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('스타일링 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('스트레스 지수'), 'no'] = np.NaN

elle_jisu.loc[elle_jisu['contents'].str.contains('건조 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('행복지수'), 'no'] = np.NaN

elle_jisu.loc[elle_jisu['contents'].str.contains('유행지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('세제사용지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('화제성지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('차단 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('설렘지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('유행지수'), 'no'] = np.NaN

elle_jisu.loc[elle_jisu['contents'].str.contains('동반성장지수평가'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('신선도 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('애정지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('불쾌지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('pH 지수는'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('유행지수'), 'no'] = np.NaN

elle_jisu.loc[elle_jisu['contents'].str.contains('러블리 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('체지방 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('궁합지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('SPF 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('관능지수'), 'no'] = np.NaN

elle_jisu.loc[elle_jisu['contents'].str.contains('현모양처'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('설렘 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('지수와 출연한 <꽃미남 브로맨스>'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('품질지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('섹시 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('배우 지수'), 'no'] = np.NaN

elle_jisu.loc[elle_jisu['contents'].str.contains('매력지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('GI지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('잘생김 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('호기심 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('질 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('노출 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('지수가 높은 자외선차단제'), 'no'] = np.NaN


elle_jisu.loc[elle_jisu['contents'].str.contains('사랑스러움 지수를 업그레이드'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('화제성 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('케미스트리 지수는'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('FFP3으로 표시하는데'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('예쁨 지수'), 'no'] = np.NaN

elle_jisu.loc[elle_jisu['contents'].str.contains('호감 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('미적 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('매력지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('청량지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('혈당지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('불안 지수'), 'no'] = np.NaN

elle_jisu.loc[elle_jisu['contents'].str.contains('예민 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('예민지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('만족도 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('지수함수적'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('공복 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('체질량 지수'), 'no'] = np.NaN
elle_jisu.loc[elle_jisu['contents'].str.contains('행복지수'), 'no'] = np.NaN

# %%
elle_jisu.dropna(inplace=True)

# %%
elle_jisu.isnull().sum()
# Out:
# title         0
# link          0
# date          0
# elle_link     0
# contents      0
# category      0
# title_name    0
# check         0
# no            0
# dtype: int64

# %%
elle_jisu.reset_index(drop=True, inplace =True)

# %%
len(elle_jisu)
# Out:
# 40

# %%
elle_jisu[['title', 'contents']]
# Out:
#                                   title  \
# 0             김나영부터 지수까지! 진주 주얼리를 한 스타들
# 1              공효진부터 제니까지! 스타들의 #니트 활용법
# 2              스타일 지수 올려주는 비장의 액세서리, 벨트
# 3   환불 원정대 제시부터 블핑 지수까지! 셉럽들의 레오퍼드 패션 7
# 4           파샤 드 까르띠에와 지수, 세훈, 손흥민의 공통점
# 5               가방에 쏙! 간절기 BEST 스카프 활용법
# 6   블핑 지수부터 손나은까지 스타들의 필수템 #화이트셔츠 돌려 입기
# 7                              지금은 청청시대
# 8     아이스크림 칠링칠링, 블랙핑크와 셀레나 고메즈의 (스압주의)
# 9     블랙핑크 지수, 드라마 '설강화' 주연 발탁!_#ELLE뉴스
# 10                            장마철 뷰티 비책
# 11                             여름에도 카디건
# 12                         형형색색 아이 메이크업
# 13                 제니, 걸그룹 브랜드 평판 1위 등극
# 14                디올의 뮤즈 지수, 청량한 여름을 닮은
# 15           스타일링 지수 높여주는 마법의 액세서리 '벨트'
# 16                               지수의 여름
# 17                             돌아온 블랙핑크
# 18                 인간 미스 디올, 지수의 여름 이야기
# 19                   불쾌지수 타파하는 여름 스타일링,
# 20         시크 지수 업! 오픈엔드 라운드 슬리브 블랙자켓코디
# 21             더 사랑스럽게! 머리에 리본을 묶은 스타 5
# ...

# %% [markdown]
# ## 코스모폴리탄

# %%
len(cosmo_jenny)
# Out:
# 97

# %%
cosmo_jenny
# Out:
#                                  title  \
# 0   '안광'이 있는 실물 갑 연예인, 티아라 지연 말고 또 누구?
# 1                   뷔랑 제니가 즐겨하는 액세서리는?
# 2                       아이돌 모자 패션 다 모음
# 3           블핑 과거 미공개 영상을 여기서 볼 수 있다고?
# 4                 블랙핑크 멤버들의 실제 성격을 밝혀라
# ..                                 ...
# 92                    빅스, 그들의 색깔은 뚜렷했다
# 93                     프랑스 파리에서 만난 이민정
# 94                     아티스트의 사심 듬뿍 립스틱
# 95                 박신혜, 이성경의 '예쁨' 비결은?
# 96               파워블로거들이 요즘 꽂힌 스마트 주얼리
#
#                                            link        date  \
# 0   http://v.media.daum.net/v/20201124145429159  2020.11.24
# 1   http://v.media.daum.net/v/20201022093031943  2020.10.22
# 2   http://v.media.daum.net/v/20201022153721335  2020.10.22
# 3   http://v.media.daum.net/v/20201015145934137  2020.10.15
# 4   http://v.media.daum.net/v/20201014184113530  2020.10.14
# ..                                          ...         ...
# 92  http://v.media.daum.net/v/20160922093704456  2016.09.22
# ...

# %%
# 제니퍼 삭제
for word in cosmo_jenny['contents']:
    if '제니' in word:
        if '블랙핑크' not in word:
            print(word)
            print('-'*50)
# Out:
# [['「 이거 입으면 뉴요커? 제니와 태양 입은 잠옷! 」', '「 이거 입으면 뉴요커? 제니와 태양 입은 잠옷! 」', '', '', '', '', '', '한때 MBC 예능 〈나 혼자 산다〉에서 잠옷 덕후로 소문났던 태양이 입던 그 잠옷! JTBC 예능 〈블핑하우스〉에서 제니가 입던 그 잠옷! 일명 ‘태양 잠옷’으로 소문난 슬리피 존스(Sleepy Jones)는 뉴욕의 디자이너 앤디 스페이드가 2013년에 런칭한 브랜드다. 밤마다 잠옷을 꼭 챙겨입는 본인과 친구들을 위해 만든 브랜드라고. 침실뿐만 아니라 작업실, 카페, 거리 등 어디에서 입어도 자연스러운 파자마를 만드는 게 목표인 만큼 스트라이프나 체크 패턴 등 질리지 않는 디자인을 선보인다. 가격대는 200불 후반. 아직 정식적으로 국내에는 들어오지 않아 직구해야하지만, 세일 기간을 잘 노리면 괜찮은 가격에 구매할 수 있다.', '「 밖에서도 입는 정유미와 손담비 잠옷! 」', '「 밖에서도 입는 정유미와 손담비 잠옷! 」', '', '', '', '', '', '', '', '', '', '이번엔 손담비 잠옷이다! MBC 예능 〈나 혼자 산다〉에서 손담비가 입고 나온 블루 체크 잠옷은 스타일리스트 최경원이 만든 아밤(AVAM) 제품. 최근 tvN 예능 〈여름 방학〉에서 정유미도, 큐브TV 예능 〈네버엔딩 네버랜드〉에서 여자아이들 민니도 같은 제품을 입고 나왔다. 컬러는 블루와 브라운 두 가지. 클래식한 패턴인 만큼 셔츠로 입어도 자연스러운 디자인이라 니트나 청바지와 함께 입으면 외출용으로도 연출할 수 있으니 일석이조!', '「 우리 오빠랑 커플 잠옷을 입고 싶다면? 」', '「 우리 오빠랑 커플 잠옷을 입고 싶다면? 」', '', '', '', '방탄소년단도 세븐틴도 입었다! 뷔와 에스쿱스가 V LIVE를 하며 입은 스트라이프 잠옷은 이브니에(EVENIE). 무려 40년 동안 이어온 브랜드로 커플 파자마를 선보인다. BTS와 엑소를 비롯한 아이돌과 배우들이 입고 나와 유명해진 브랜드인 만큼 방송 곳
# ...

# %%
cosmo_jenny['no']=0

# %%
cosmo_jenny.loc[cosmo_jenny['contents'].str.contains('제니하우스'), 'no'] = np.NaN

# %%
cosmo_jenny.loc[cosmo_jenny['contents'].str.contains('제이제니'), 'no'] = np.NaN

# %%
cosmo_jenny.loc[cosmo_jenny['contents'].str.contains('제니 홀저'), 'no'] = np.NaN

# %%
cosmo_jenny.loc[cosmo_jenny['contents'].str.contains('제니 한'), 'no'] = np.NaN

# %%
cosmo_jenny.loc[cosmo_jenny['contents'].str.contains('제니 버드'), 'no'] = np.NaN

# %%
cosmo_jenny.loc[cosmo_jenny['contents'].str.contains('제니 테이츠'), 'no'] = np.NaN

# %%
cosmo_jenny.loc[cosmo_jenny['contents'].str.contains('제니팍'), 'no'] = np.NaN

# %%
cosmo_jenny.loc[cosmo_jenny['contents'].str.contains('엘리슨 제니'), 'no'] = np.NaN
cosmo_jenny.loc[cosmo_jenny['contents'].str.contains('앨리슨 제니'), 'no'] = np.NaN

# %%
cosmo_jenny.loc[cosmo_jenny['contents'].str.contains('제니 월튼'), 'no'] = np.NaN

# %%
cosmo_jenny.loc[cosmo_jenny['contents'].str.contains('blog.naver.com/yjsk0717/220741516561'), 'no'] = np.NaN

# %%
cosmo_jenny.dropna(inplace=True)

# %%
cosmo_jenny.isnull().sum()
# Out:
# title         0
# link          0
# date          0
# cosmo_link    0
# contents      0
# category      0
# title_name    0
# check         0
# no            0
# dtype: int64

# %%
cosmo_jenny.reset_index(drop=True, inplace =True)

# %%
len(cosmo_jenny)
# Out:
# 52

# %%
cosmo_jenny[['title', 'contents']]
# Out:
#                                  title  \
# 0   '안광'이 있는 실물 갑 연예인, 티아라 지연 말고 또 누구?
# 1                   뷔랑 제니가 즐겨하는 액세서리는?
# 2                       아이돌 모자 패션 다 모음
# 3           블핑 과거 미공개 영상을 여기서 볼 수 있다고?
# 4                 블랙핑크 멤버들의 실제 성격을 밝혀라
# 5                            탈모 지옥 탈출법
# 6                   상큼 과다 주의보! 하이틴 스타일
# 7                        아이돌 눈썹 손민수 하기
# 8            스타들이 입는 잠옷, 이 가격이면 나도 살까?
# 9               카디건 센스 있게 입는 셀럽들의 노하우!
# 10                      맥시멀리즘이 찰떡인 아이돌
# 11                 여름에 딱! 뷔스티에 원피스 연출법
# 12                 작가세요? 사진 잘 찍는 아이돌 8
# 13                        그녀들의 가방이 궁금해
# 14                  이토록 예쁜 아이돌들의 '더듬이'
# 15                  틴티드 선글라스 찰떡 메이크업 2
# 16                   90년대 감성이 듬뿍, 미니 백
# 17                무대를 씹어드셨다! 우먼 아티스트 5
# 18                          아이돌 한복 대결!
# 19            제니의 '앞머리 탈색' 내가 하면 슬리피?!
# 20                      아이돌들의 주얼리 스타일링
# 21                아이돌 셀카장인에게 배우는 포즈 10
# 22               재난지원금, 이렇게도 쓸 수 있다고?!
# ...

# %% [markdown]
# ### 로제

# %%
len(cosmo_rose)
# Out:
# 53

# %%
# 제니퍼 삭제
for word in cosmo_rose['contents']:
    if '로제' in word:
        if '블랙핑크' not in word:
            print(word)
            print('-'*50)
# Out:
# [['「 마켓컬리 샐러드판다 판다의 로제 베지누들 5천2백원 」\n면 러버 다이어터를 위한 밀키트. 밀가루나 곤약 면이 아닌 리얼 채소로 만든 면을 사용했는데, 오이와 식감이 비슷한 주키니 호박의 겉 부분을 얇게 저민 뒤 면처럼 길게 채 썰어 담아냈다. 로제, 토마토, 미트소스 등 8가지 맛을 선보인다.', '「 마켓컬리 샐러드판다 판다의 로제 베지누들 5천2백원 」', '「 CJ 쿡킷 부채살 찹스테이크 2만8백원 」\nCJ 제일제당에서 운영 중인 밀키트 브랜드 ‘쿡킷’은 국내외 특급 호텔 경력의 셰프 13인과 함께 개발한 밀키트를 선보인다. 타사보다 가격대가 있는 편이지만 일상적인 메뉴의 재료도 엄격하게 선별하고 외식으로 먹는 특별식도 간편하게 즐길 수 있도록 구성된 점이 특징. 메뉴에 들어가는 재료별로 특성에 맞는 포장재를 적용해 신선함이 남다르다는 것도 쿡킷만의 차별점이다.', '「 CJ 쿡킷 부채살 찹스테이크 2만8백원 」', '「 우주인피자 키트 페퍼로니 앤 파인애플 9천9백원 」\n소꿉장난하듯 만들어 먹는 밀키트 피자! 2개 분량의 얇은 도와 풍미 가득한 소스, 심플한 토핑까지 들어 있어 오븐이나 에어프라이어에 10분 정도만 구워내면 꽤 그럴듯한 피자가 완성된다. 재료를 급속 냉동 후 개별 진공 포장해서 그런지 반죽이 쫄깃하고 마치 화덕에서 구워낸 듯한 피자 맛을 경험할 수 있다.', '「 우주인피자 키트 페퍼로니 앤 파인애플 9천9백원 」', '「 마이셰프 감바스알아히요 1만3천9백원 」\n마이셰프에서는 볼케이노 나베, 육전, 족발덮밥 등 국적 불문, 다양한 개성으로 특화된 요리 메뉴를 고를 수 있다. 새벽 배송이 가능한 쿠팡이나 SSG닷컴 등에 입점해 있어 빠르게 배송 받아볼 수 있는 것도 장점이다.', '「 마이셰프 감바스알아히요 1만3천9백원 」', '「 피코크 시추안하우스 마라 소고기 전골 1만5천8백원 」\n혈중 마라 농도가 훅 떨어졌다면 주목! 이마트 피코크는 사천 요리 맛집인 ‘시추안하우스’와 협업해 마라 특유의 얼얼한 맛을 제대로
# ...

# %%
cosmo_rose['no']=0

# %%
cosmo_rose.loc[cosmo_rose['contents'].str.contains('와인'), 'no'] = np.NaN
cosmo_rose.loc[cosmo_rose['contents'].str.contains('파스타'), 'no'] = np.NaN
cosmo_rose.loc[cosmo_rose['contents'].str.contains('샴페인'), 'no'] = np.NaN
cosmo_rose.loc[cosmo_rose['contents'].str.contains('찜닭'), 'no'] = np.NaN
cosmo_rose.loc[cosmo_rose['contents'].str.contains('로제도르'), 'no'] = np.NaN

cosmo_rose.loc[cosmo_rose['contents'].str.contains('로제 베지누들'), 'no'] = np.NaN
cosmo_rose.loc[cosmo_rose['contents'].str.contains('메이크업 베이스 로제'), 'no'] = np.NaN
cosmo_rose.loc[cosmo_rose['contents'].str.contains('누드 로제'), 'no'] = np.NaN
cosmo_rose.loc[cosmo_rose['contents'].str.contains('피부에는 로제'), 'no'] = np.NaN

cosmo_rose.loc[cosmo_rose['contents'].str.contains('23호는 로제'), 'no'] = np.NaN
cosmo_rose.loc[cosmo_rose['contents'].str.contains('블러셔 드 로제'), 'no'] = np.NaN
cosmo_rose.loc[cosmo_rose['contents'].str.contains(' 로제 바딤'), 'no'] = np.NaN
cosmo_rose.loc[cosmo_rose['contents'].str.contains('라 로제'), 'no'] = np.NaN
cosmo_rose.loc[cosmo_rose['contents'].str.contains('로제 휘기에'), 'no'] = np.NaN
cosmo_rose.loc[cosmo_rose['contents'].str.contains(' 로 로제'), 'no'] = np.NaN

# %%
cosmo_rose.dropna(inplace=True)

# %%
cosmo_rose.isnull().sum()
# Out:
# title         0
# link          0
# date          0
# cosmo_link    0
# contents      0
# category      0
# title_name    0
# check         0
# no            0
# dtype: int64

# %%
cosmo_rose.reset_index(drop=True, inplace =True)

# %%
len(cosmo_rose)
# Out:
# 21

# %%
cosmo_rose[['title', 'contents']]
# Out:
#                          title  \
# 0   블핑 과거 미공개 영상을 여기서 볼 수 있다고?
# 1         블랙핑크 멤버들의 실제 성격을 밝혀라
# 2           외국인이었어? 아이돌 의외의 국적
# 3       카디건 센스 있게 입는 셀럽들의 노하우!
# 4                     강다니엘의 컬러
# 5             아이돌로 본 가을 헤어 트렌드
# 6         무대를 씹어드셨다! 우먼 아티스트 5
# 7                   아이돌 한복 대결!
# 8             사회 초년생 첫 명품 백 추천
# 9              백 투 베이식, 진주 주얼리
# 10            신민아가 보여주는 뷰티 믿보템
# 11        룩에 생기를 불어 넣는 컬러풀 주얼리
# 12                     신민아 플래쉬
# 13            FW20 컬렉션을 찾은 스타들
# 14         생각보다 쉽고 시크하다! 란제리 룩
# 15                반바지 슈트 입어봤어?
# 16        전시 데이트 갈 때는 이렇게 입어봐!
# 17             겨울 속 여름 즐기는 언니들
# 18        잘 때 입는 옷을 파티에서도 입는 법
# 19    블핑부터 트와이스까지 금발 박제 각 여돌 6
# 20                판타스틱 4, 블랙핑크
#
#                                              contents
# 0   [[], ['', '할리우드 감독이 만든 블핑 다큐 〈블랙핑크: 세상을 밝혀라〉',...
# 1   [[], ['', '[블랙핑크: 세상을 밝혀라]는 레이디 가가, 테일러 스위프트 등...
# 2   [['「 블랙핑크 로제 - 뉴질랜드 & 한국 」', '「 블랙핑크 로제 - 뉴질랜드...
# ...

# %% [markdown]
# ### 리사

# %%
len(cosmo_lisa)
# Out:
# 60

# %%
# 제니퍼 삭제
for word in cosmo_lisa['contents']:
    if '리사' in word:
        if '블랙핑크' not in word:
            print(word)
            print('-'*50)
# Out:
# [['', '', '', '', '', '', '', '', '', '한예슬 in 펜디', '', '', '', '', '', '로제 in 생 로랑', '', '', '', '', '', '조이 in 마이클 코어스', '', '', '', '', '', '박민영 in 토즈', '', '', '', '', '', '설현 in 코치', '', '', '', '', '', '송혜교 in 보테가 베네타', '', '', '', '', '', '리사 in 프라다', '', ''], ['', '', '', '', '', '', '', '']]
# --------------------------------------------------
# ...

# %%
cosmo_lisa['no']=0

# %%
cosmo_lisa.loc[cosmo_lisa['contents'].str.contains('에이샤-리사'), 'no'] = np.NaN
cosmo_lisa.loc[cosmo_lisa['contents'].str.contains('알리사'), 'no'] = np.NaN
cosmo_lisa.loc[cosmo_lisa['contents'].str.contains('리사 쿠드로'), 'no'] = np.NaN
cosmo_lisa.loc[cosmo_lisa['contents'].str.contains('리사 레이하나'), 'no'] = np.NaN
cosmo_lisa.loc[cosmo_lisa['contents'].str.contains('리사 올슨'), 'no'] = np.NaN
cosmo_lisa.loc[cosmo_lisa['contents'].str.contains('립스틱 리사'), 'no'] = np.NaN
cosmo_lisa.loc[cosmo_lisa['contents'].str.contains('리사 브레이트먼'), 'no'] = np.NaN
cosmo_lisa.loc[cosmo_lisa['contents'].str.contains('리사 웰링 박사'), 'no'] = np.NaN
cosmo_lisa.loc[cosmo_lisa['contents'].str.contains('리사 에이컨'), 'no'] = np.NaN
cosmo_lisa.loc[cosmo_lisa['contents'].str.contains('리사 퀸'), 'no'] = np.NaN

cosmo_lisa.loc[cosmo_lisa['contents'].str.contains('리사’가 혼자'), 'no'] = np.NaN
cosmo_lisa.loc[cosmo_lisa['contents'].str.contains('엘리사'), 'no'] = np.NaN
cosmo_lisa.loc[cosmo_lisa['contents'].str.contains('리사 프리드먼'), 'no'] = np.NaN
cosmo_lisa.loc[cosmo_lisa['contents'].str.contains('리사 마리 페르난데'), 'no'] = np.NaN
cosmo_lisa.loc[cosmo_lisa['contents'].str.contains('리사마리페르난데즈'), 'no'] = np.NaN
cosmo_lisa.loc[cosmo_lisa['contents'].str.contains('리사 웨이드'), 'no'] = np.NaN
cosmo_lisa.loc[cosmo_lisa['contents'].str.contains('리사 야카스'), 'no'] = np.NaN
cosmo_lisa.loc[cosmo_lisa['contents'].str.contains('매튜’와 ‘리사’'), 'no'] = np.NaN

cosmo_lisa.loc[cosmo_lisa['contents'].str.contains('리사 아이켄'), 'no'] = np.NaN

# %%
cosmo_lisa.dropna(inplace=True)

# %%
cosmo_lisa.isnull().sum()
# Out:
# title         0
# link          0
# date          0
# cosmo_link    0
# contents      0
# category      0
# title_name    0
# check         0
# no            0
# dtype: int64

# %%
cosmo_lisa.reset_index(drop=True, inplace =True)

# %%
len(cosmo_lisa)
# Out:
# 19

# %%
cosmo_lisa[['title', 'contents']]
# Out:
#                          title  \
# 0             아이돌들의 '최애' 주얼리는?
# 1   블핑 과거 미공개 영상을 여기서 볼 수 있다고?
# 2         블랙핑크 멤버들의 실제 성격을 밝혀라
# 3                 가을엔 흑발을 하겠어요
# 4             아이돌로 본 가을 헤어 트렌드
# 5        서예지 뺨치는 셀럽들의 칼단발 스타일링
# 6         무대를 씹어드셨다! 우먼 아티스트 5
# 7     모델이야? 아이돌이야? '갓 바디' 모델돌들
# 8             FW20 컬렉션을 찾은 스타들
# 9      아이돌계 못 말리는 냥 집사 VS 댕 집사
# 10         루이비통&불가리가 여는 파티 클라스
# 11   설리, 태연, 청하까지 아이돌의 컬러풀 헤어!
# 12        발에 팔찌를 찬다고? 바로, 앵클릿!
# 13            비율 퀸 아이돌 best 5!
# 14  2019 S/S 패션위크에서는 무슨 일이? #4
# 15                판타스틱 4, 블랙핑크
# 16              스타가 찜콩한 그 립스틱!
# 17              스타가 찜콩한 그 립스틱!
# 18              스타가 찜콩한 그 립스틱!
#
#                                              contents
# 0   [['「 Layered Pearl 」', '「 Layered Pearl 」', ''...
# 1   [[], ['', '할리우드 감독이 만든 블핑 다큐 〈블랙핑크: 세상을 밝혀라〉',...
# 2   [[], ['', '[블랙핑크: 세상을 밝혀라]는 레이디 가가, 테일러 스위프트 등...
# 3   [['「 블랙핑크 리사 」', '「 블랙핑크 리사 」', '무게감 있는 풀 뱅 헤어...
# ...

# %% [markdown]
# ### 지수

# %%
len(cosmo_jisu)
# Out:
# 206

# %%
# 제니퍼 삭제
for word in cosmo_jisu['contents']:
    if '지수' in word:
        if '블랙핑크' not in word:
            print(word)
            print('-'*50)
# Out:
# [['「 방탄소년단 - 바디프렌드 」', '「 방탄소년단 - 바디프렌드 」', '', '', '', '어떤 광고든 반응이 폭발적인 방탄소년단이지만 허를 찌른 광고주였다. 실버 세대의 럭셔리 건강기기로 꼽히던 안마 의자 광고라니! 4월부터 끊임없이 새 이야기를 공개해 온 이 시리즈는 대개 시크, 다이내믹의 아이콘인 방탄소년단 멤버 중 한 명이 골골대는 걸로 시작한다. 당연하게도 늘 해결책은 안마 의자. 그러면서 은근히 최첨단을 걷는 기능 하나씩을 소개. 지난여름 영상에서 쿨링 기능이라면 10월 5일 버전에선 추간판 탈출증, 퇴행성 협착증 치료에 도움된다는 ‘견인 기능’을 소개한다. 전혀 자연스럽지 않고 과장된 멤버들의 연기도 웃음 버튼!', '「 지수 - 디올 」', '「 지수 - 디올 」', '', '', '', '코로나19 이후, 또 MZ세대 취향에 맞춰 온라인 마케팅에 열을 올리는 글로벌 브랜드들. 지수는 우아한 이미지와 폭넓은 국제적 인지도로 패션 하우스 디올의 이미지를 완벽하게 소화하는 케이팝 아이돌이다. 지난 9월 30일 2021 S/S 컬렉션 홍보를 맡은 유일한 연예인으로서 디올의 공식 인스타그램 계정에 등장해 시종일관 한국어로 말하며 ‘안녕하세요’, ‘감사합니다’, ‘사랑해’ 등을 세계에 전파. 디올 뷰티 앰배서더인 동시에 2020 F/W 시즌부턴 패션 부문 뮤즈로서도 왕성히 활동 중이다.', '「 Nct127 – 네이처 리퍼블릭 」\n아이돌을 알차게 활용하기로 유명한 네이처 리퍼블릭의 이번 선택은 NCT127. 젠더리스 시대인 만큼 수려한 비주얼 꽃미남 9명이 매일같이 아름다움을 과시한다. 지난 6일 올라온 ‘앳홈’은 배경이 집임에도 불구, 킹스맨 느낌 수트 차림에 한껏 메이크업한 멤버들 때문에 마법처럼 저절로 주문을 클릭하게 된다. 슬리핑 마스크와 세럼 세트 포함 3만 원 이상 구입하면 NCT127 고퀄 포토북을 주는, ‘굿즈를 샀더니 화장품이 딸려 왔다’ 식 마케팅으로 날개 돋친 듯 팔렸다는 후문.', '「 Nct127 – 네이처 리퍼블릭
# ...

# %%
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('패션 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('브로맨스 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('애정 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('분노 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('민감지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('핑크 지수 20%'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('UVA 지수'), 'no'] = np.NaN


cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('센스 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('용감 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains(' 시크 지수 '), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('공존지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('박기훈'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('귀요미 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('50 지수의'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('남주혁, 지수,'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('케미 지수'), 'no'] = np.NaN

cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('주가 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('뉴딜 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('근엄지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('불안감 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('코스피지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('레트로 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('혈당 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('스코빌 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('공감지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('시원함 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('주인공 지수'), 'no'] = np.NaN

cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('궁합 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('미모 지수 '), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('그 이상의 지수를 갖춘'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('짜증 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('배고픔 지수'), 'no'] = np.NaN

cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('지수’와 ‘재현'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('포용지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('쿨 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('BMI 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('미모 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('이별 극복 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('매력 지수'), 'no'] = np.NaN

cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('지수 Assistant'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('지능 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('지수 가죽 재킷을 유용하게'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('GI 지수'), 'no'] = np.NaN

cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('지수 저하 '), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('감성 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('일머리 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('깨방정 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('음주가무 지수'), 'no'] = np.NaN

cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('프레시 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('음주가무 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('유머 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('윤지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('미세먼지 지수'), 'no'] = np.NaN

cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('엥겔 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('귀염지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('휘게 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('러브 지수'), 'no'] = np.NaN
cosmo_jisu.loc[cosmo_jisu['contents'].str.contains('호감지수'), 'no'] = np.NaN

# %%
cosmo_jisu.dropna(inplace=True)

# %%
cosmo_jisu.isnull().sum()
# Out:
# title         0
# link          0
# date          0
# cosmo_link    0
# contents      0
# category      0
# title_name    0
# check         0
# no            0
# dtype: int64

# %%
cosmo_jisu.reset_index(drop=True, inplace =True)

# %%
len(cosmo_jisu)
# Out:
# 26

# %%
elle_jenny['member'] = 'Je'
elle_jisu['member'] = 'Ji'
elle_rose['member'] = 'R'
elle_lisa['member'] = 'L'

# %%
cosmo_jenny['member'] = 'Je'
cosmo_jisu['member'] = 'Ji'
cosmo_rose['member'] = 'R'
cosmo_lisa['member'] = 'L'

# %%
elle_jenny['magazine'] = 'E'
elle_jisu['magazine'] = 'E'
elle_rose['magazine'] = 'E'
elle_lisa['magazine'] = 'E'

# %%
cosmo_jenny['magazine'] = 'C'
cosmo_jisu['magazine'] = 'C'
cosmo_rose['magazine'] = 'C'
cosmo_lisa['magazine'] = 'C'

# %%
cosmo_lisa.columns
# Out:
# Index(['title', 'link', 'date', 'cosmo_link', 'contents', 'category',
#        'title_name', 'check', 'no', 'member', 'magazine'],
#       dtype='object')

# %%
elle_jenny = elle_jenny[['title', 'link', 'date', 'elle_link', 'contents', 'category',
       'title_name', 'check', 'member', 'magazine']]

elle_jisu = elle_jisu[['title', 'link', 'date', 'elle_link', 'contents', 'category',
       'title_name', 'check', 'member', 'magazine']]

elle_rose = elle_rose[['title', 'link', 'date', 'elle_link', 'contents', 'category',
       'title_name', 'check', 'member', 'magazine']]

elle_lisa = elle_lisa[['title', 'link', 'date', 'elle_link', 'contents', 'category',
       'title_name', 'check', 'member', 'magazine']]

# %%
cosmo_jenny = cosmo_jenny[['title', 'link', 'date', 'cosmo_link', 'contents', 'category',
       'title_name', 'check', 'member', 'magazine']]

cosmo_jisu = cosmo_jisu[['title', 'link', 'date', 'cosmo_link', 'contents', 'category',
       'title_name', 'check', 'member', 'magazine']]

cosmo_rose = cosmo_rose[['title', 'link', 'date', 'cosmo_link', 'contents', 'category',
       'title_name', 'check', 'member', 'magazine']]

cosmo_lisa = cosmo_lisa[['title', 'link', 'date', 'cosmo_link', 'contents', 'category',
       'title_name', 'check', 'member', 'magazine']]

# %% [markdown]
# ### 문단 - elle

# %%
word_jenny = []
for i in range(len(elle_jenny)):
    cont = []
    if elle_jenny.loc[i, 'title_name'] == 1:
        cont.append(elle_jenny.loc[i, 'contents'])
    else:
        for content in elle_jenny.loc[i, 'contents'].split("', '"):
#             print(content)
#             print('-'*50)
            if ('제니') in content:
                cont.append(content)
    word_jenny.append(cont)

len(word_jenny)
# Out:
# 83

# %%
elle_jenny['word_jenny'] = word_jenny

# %%
word_jisu = []
for i in range(len(elle_jisu)):
    cont = []
    if elle_jisu.loc[i, 'title_name'] == 1:
        cont.append(elle_jisu.loc[i, 'contents'])
    else:
        for content in elle_jisu.loc[i, 'contents'].split("', '"):
#             print(content)
#             print('-'*50)
            if ('지수') in content:
                cont.append(content)
    word_jisu.append(cont)

len(word_jisu)
# Out:
# 40

# %%
elle_jisu['word_jisu'] = word_jisu

# %%
word_rose = []
for i in range(len(elle_rose)):
    cont = []
    if elle_rose.loc[i, 'title_name'] == 1:
        cont.append(elle_rose.loc[i, 'contents'])
    else:
        for content in elle_rose.loc[i, 'contents'].split("', '"):
#             print(content)
#             print('-'*50)
            if ('로제') in content:
                cont.append(content)
    word_rose.append(cont)

len(word_rose)
# Out:
# 31

# %%
elle_rose['word_jisu'] = word_rose

# %%
word_lisa = []
for i in range(len(elle_lisa)):
    cont = []
    if elle_lisa.loc[i, 'title_name'] == 1:
        cont.append(elle_lisa.loc[i, 'contents'])
    else:
        for content in elle_lisa.loc[i, 'contents'].split("', '"):
#             print(content)
#             print('-'*50)
            if ('리사') in content:
                cont.append(content)
    word_lisa.append(cont)

len(word_lisa)
# Out:
# 46

# %%
elle_lisa['word_jisu'] = word_lisa

# %% [markdown]
# ### 문단 - cosmo

# %%
word_jenny = []
for i in range(len(cosmo_jenny)):
    cont = []
    if cosmo_jenny.loc[i, 'title_name'] == 1:
        cont.append(cosmo_jenny.loc[i, 'contents'])
    else:
        for content in cosmo_jenny.loc[i, 'contents'].split("', '"):
#             print(content)
#             print('-'*50)
            if ('제니') in content:
                cont.append(content)
    word_jenny.append(cont)

len(word_jenny)
# Out:
# 52

# %%
cosmo_jenny['word_jenny'] = word_jenny

# %%
word_jisu = []
for i in range(len(cosmo_jisu)):
    cont = []
    if cosmo_jisu.loc[i, 'title_name'] == 1:
        cont.append(cosmo_jisu.loc[i, 'contents'])
    else:
        for content in cosmo_jisu.loc[i, 'contents'].split("', '"):
#             print(content)
#             print('-'*50)
            if ('지수') in content:
                cont.append(content)
    word_jisu.append(cont)

len(word_jisu)
# Out:
# 26

# %%
cosmo_jisu['word_jenny'] = word_jisu

# %%
word_rose = []
for i in range(len(cosmo_rose)):
    cont = []
    if cosmo_rose.loc[i, 'title_name'] == 1:
        cont.append(cosmo_rose.loc[i, 'contents'])
    else:
        for content in cosmo_rose.loc[i, 'contents'].split("', '"):
#             print(content)
#             print('-'*50)
            if ('로제') in content:
                cont.append(content)
    word_rose.append(cont)

len(word_rose)
# Out:
# 21

# %%
cosmo_rose['word_jenny'] = word_rose

# %%
word_lisa = []
for i in range(len(cosmo_lisa)):
    cont = []
    if cosmo_lisa.loc[i, 'title_name'] == 1:
        cont.append(cosmo_lisa.loc[i, 'contents'])
    else:
        for content in cosmo_lisa.loc[i, 'contents'].split("', '"):
#             print(content)
#             print('-'*50)
            if ('리사') in content:
                cont.append(content)
    word_lisa.append(cont)

len(word_lisa)
# Out:
# 19

# %%
cosmo_lisa['word_jenny'] = word_lisa

# %%
elle_jenny.to_csv('./blackpink/elle_Je.csv', sep='|', encoding = 'utf-8', index = False)
elle_jisu.to_csv('./blackpink/elle_Ji.csv', sep='|', encoding = 'utf-8', index = False)
elle_rose.to_csv('./blackpink/elle_R.csv', sep='|', encoding = 'utf-8', index = False)
elle_lisa.to_csv('./blackpink/elle_L.csv', sep='|', encoding = 'utf-8', index = False)

# %%
cosmo_jenny.to_csv('./blackpink/cosmo_Je.csv', sep='|', encoding = 'utf-8', index = False)
cosmo_jisu.to_csv('./blackpink/cosmo_Ji.csv', sep='|', encoding = 'utf-8', index = False)
cosmo_rose.to_csv('./blackpink/cosmo_R.csv', sep='|', encoding = 'utf-8', index = False)
cosmo_lisa.to_csv('./blackpink/cosmo_L.csv', sep='|', encoding = 'utf-8', index = False)
