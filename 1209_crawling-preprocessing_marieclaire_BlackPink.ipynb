# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time

# %%
import pandas as pd
import numpy as np

# %%
marie_jenny = pd.read_csv('./blackpink/marie_jenny.csv', sep='|', encoding = 'utf-8')
marie_jisu = pd.read_csv('./blackpink/marie_jisu.csv', sep='|', encoding = 'utf-8')
marie_rose = pd.read_csv('./blackpink/marie_rose.csv', sep='|', encoding = 'utf-8')
marie_lisa = pd.read_csv('./blackpink/marie_lisa.csv', sep='|', encoding = 'utf-8')

# %%
marie_jenny = marie_jenny[['title', 'link', 'year', 'mon', 'date', 'contents']]
marie_jisu = marie_jisu[['title', 'link', 'year', 'mon', 'date', 'contents']]
marie_rose = marie_rose[['title', 'link', 'year', 'mon', 'date', 'contents']]
marie_lisa = marie_lisa[['title', 'link', 'year', 'mon', 'date', 'contents']]

# %%
marie_bp = [marie_jenny, marie_jisu, marie_lisa, marie_rose]

# %% [markdown]
# # 카테고리 가져오기

# %%
marie_jenny['category'] = marie_jenny['link'].str.split('/').str[3]
marie_jisu['category'] = marie_jisu['link'].str.split('/').str[3]
marie_rose['category'] = marie_rose['link'].str.split('/').str[3]
marie_lisa['category'] = marie_lisa['link'].str.split('/').str[3]

# %% [markdown]
# ## 제니퍼, 제니하우스 삭제

# %%
for word in marie_jenny['contents']:
    if '제니 하우스' in word:
        print(word)
        print('-'*50)
# Out:
# ['시스루 뱅의 인기가 저물고 정수리부터 무겁게 떨어지는 풀 뱅 스타일이 돌아왔다. 앞머리를 자르지 않은 긴 생머리를 고집해온 배우 오연서는 최근 지방시 행사장에 앞머리를 일자로 싹둑 자른 모습으로 나타나 특유의 청순한 매력을 뽐내고, 뷰티 유튜버 소봉은 뱅 헤어에 라인을 길게 뺀 캐츠 아이 메이크업을 매치해 트렌디한 스타일을 선보였다. 뱅 헤어의 매력은 일자로 가지런히 뻗은 듯 연출하는 것. 아이론으로 스타일링을 할 때 동그랗게 말지 말고 일직선으로 떨어지게 펴주는 것이 좋다. 과감하게 앞머리를 자르기가 두렵다면 최근 종영한 드라마 <호텔 델루나> 속 장만월(이지은)의 잔머리 스타일을 참고하길. 긴 생머리에 앞머리 숱을 조금만 자르고, 양옆으로 말아 사랑스러운 레트로 룩을 완성했다.', '', '필리밀리 포켓 꼬리빗. 2pcs, 1천9백원.', ' ', '과감한 컬러를 입힌 헤어스타일도 눈에 띈다. 매번 새로운 헤어 컬러를 선보여 시선을 사로잡는 헤이즈는 긴 생머리에 블루와 그린 컬러를 조합한 투톤 염색으로 걸크러시 매력을 뽐냈다. 여기에 최근 영화 <기생충>으로 화제를 모은 배우 박소담도 밝은 투톤으로 염색해 트렌드에 가세했으며, ‘날라리’로 컴백한 가수 선미는 밝은 금발로 염색해 스타일에 정점을 찍었다. 또 헤어 인플루언서 묘정은 인어공주를 연상시키는 토마토 컬러 헤어로 팔로어들의 눈길을 사로잡기도 했다. 염색과 탈색을 자주 하면 모발 컬러가 쉽게 빠지기 때문에 전용 제품을 사용해 유지하는 것이 중요하다. 제니 하우스 청담힐의 효정 부원장은 염색 모발 전용 오일을 수시로 발라 단백질이 빠진 모발에 영양을 채워주라고 권한다.', '', '로레알파리 엑스트라 오디네리 오일 라이트. 100ml, 1만9천원.', ' ', '레드벨벳의 웬디가 선보여 일명 ‘웬디 컷’이라고 불리며 인기를 끌고 있는 차밍 컷은 앞부분은 가볍게 층을 내고 뒤쪽을 무겁게 떨어뜨리는 것이 포인트. 이 머리는 볼륨이 살아 있어야 특유의 가벼운 느낌이 돋보이기 때문에 샴푸 후 모발 전체를
# ...

# %%
marie_jenny.loc[marie_jenny['contents'].str.contains('제니퍼'), 'contents'] = ''

# %%
marie_jenny.loc[marie_jenny['contents'].str.contains('제니 하우스'), 'contents'] = ''

# %%
# marie_jenny.loc[marie_jenny['contents'] == '', 'contents'] = np.NaN

# %%
# marie_jenny.dropna(inplace = True)

# %%
# marie_jenny.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### 날짜 sorting/ 데뷔이전 삭제

# %%
marie_jenny.sort_values(by='date', ascending = False, inplace = True)
marie_jisu.sort_values(by='date', ascending = False, inplace = True)
marie_rose.sort_values(by='date', ascending = False, inplace = True)
marie_lisa.sort_values(by='date', ascending = False, inplace = True)
# Out:
# C:\Users\wnsgo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
marie_jenny.reset_index(drop=True, inplace=True)
marie_jisu.reset_index(drop=True, inplace=True)
marie_rose.reset_index(drop=True, inplace=True)
marie_lisa.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### title확인

# %%
marie_jenny['title_name'] = 0
marie_jisu['title_name'] = 0
marie_rose['title_name'] = 0
marie_lisa['title_name'] = 0

# %%
marie_jenny.loc[marie_jenny['title'].str.contains('제니'), 'title_name'] = 1
# Out:
# C:\Users\wnsgo\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
marie_jisu.loc[marie_jisu['title'].str.contains('지수'), 'title_name']=1
# Out:
# C:\Users\wnsgo\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
marie_rose[marie_rose['title'].str.contains('로제')]
# Out:
# Empty DataFrame
# Columns: [title, link, year, mon, date, contents, category, title_name]
# Index: []

# %%
marie_lisa[marie_lisa['title'].str.contains('리사')]
# Out:
#                     title                                               link  \
# 69   창작하는 요리사 로이든 – Video  http://www.marieclairekorea.com/video/2018/05/...
# 70           창작하는 요리사 로이든  http://www.marieclairekorea.com/lifestyle/2018...
# 97                  아노말리사  http://www.marieclairekorea.com/film/2017/02/%...
# 104      손으로 지은 옷, 멜리사 부이  http://www.marieclairekorea.com/fashion/2016/0...
#
#      year  mon     date                                           contents  \
# 69   2018  5.0  2018-05                                                 []
# 70   2018  4.0  2018-04  ['', '월요일 아침, ‘어반 팜 테이블(Urban Farm Table)’의 로이...
# 97   2017  2.0  2017-02  ['', '스톱모션 애니메이션인 <아노말리사>는 권태로운 삶에 지친 어느 중년 남자...
# 104  2016  9.0  2016-09  [' ', '아직 멜리사 부이(Mellisa Bui)라는 이름이 생소할 수 있는 독...
#
#       category  title_name
# 69       video           0
# 70   lifestyle           0
# 97        film           0
# 104    fashion           0

# %% [markdown]
# ### 콘텐츠 확인

# %% [markdown]
# 제니

# %%
# 제니퍼 삭제
for word in marie_jenny['contents']:
    if '제니' in word:
        print(word)
        print('-'*50)
# Out:
# ['볼드한 주얼리에 눈길이 가는 계절이다.\n두꺼운 체인, 화려한 보석, 주렁주렁한 진주 목걸이는\n울, 니트, 가죽과 같은 소재를 만났을 때 배는 매력적인 법.\n여름엔 약간 부담스러울 수 있겠지만,\n요즘같은 때엔 또 얘기가 다르다.\n미우미우, 루이 비통, 사카이 등\n2020 가을/겨울 컬렉션 런웨이에서 영감 받은\n주얼리 스타일링을 소개한다.', 'LEATHER + CRYSTAL', '화려한 크리스털 주얼리는\n꼭 칵테일 드레스에만 매치해야 하는 게 아니다.\n되려 드레스에는 촌스러울 수 있다.\n미우미우 컬렉션에서처럼\n재킷 안에 쿨하게 매치하자.\n이왕이면 가죽 재킷으로.', 'S/E/O SEOUL의 가을/겨울 시즌\n크롭 가죽 트렌치코트.\n정말 가슴 밑까지만 내려 오는 짧은 기장으로\n단품으로 입거나, 재킷 위에 레이어드 해도 멋스럽다.\n가격은 26만8천원.', '', '미국 LA를 베이스로 한 주얼리 플랑(Flan)은\n만드는 사람의 취향에 따라\n맛이 천차만별로 달라지는 디저트,\n‘플랑’을 모티프로 전개된다.\n주얼리는 착용하는 주체에 따라\n그 스타일이 다르며,\n그에 따르는 모든 취향을 존중한다는 뜻.\n클래식한 디자인이 눈에 띄는\n에머랄드 목걸이와 귀고리.\n가죽 재킷과 환상의 궁합을 자랑할 게 뻔하다.\n회색 스웨트셔츠나 후드 티셔츠와도 멋스러울 것.\n목걸이는 15만9천원,\n귀고리는 11만9천원이다.', '', 'BIG CHAIN + SCARF', '생 로랑은 록 시크의 대명사답게\n볼드한 체일 목걸이를\n정말 다양한 룩에 스타일링 했다.\n특히 매력적이었던\n체크무늬 스카프와\n골드 체인 네크리스의 조화.\n청바지만 입으면 딱이다.', '생 로랑의 얇은 타이 스카프.\n색이면 색, 패턴이면 패턴\n모두 ‘겨울’을 대표한다.\n목에 한 두번 대충 감아주거나,\n터틀넥을 입은 것처럼\n목 전체를 감싸 연출해도 좋다.\n네타포르테(Net-A-Porter)에서 판매 중으로\n가격은 50만원대.', '', '먼데이 에디션 특유의
# ...

# %%
marie_jenny['check'] = 0
for i in range(len(marie_jenny)):
    if marie_jenny.loc[i, 'title_name'] == 0:
        if '제니' not in marie_jenny.loc[i, 'contents']:
            marie_jenny.loc[i, 'check'] = 2
# Out:
# C:\Users\wnsgo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
marie_jenny.loc[marie_jenny['check'] == 2, 'no'] = np.NaN
# Out:
# C:\Users\wnsgo\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
marie_jenny.loc[marie_jenny['contents'].str.contains('유제니'), 'no']= np.NaN

# %%
marie_jenny.loc[59, 'check'] = 0

# %%
marie_jenny.loc[24, 'link']
# Out:
# 'http://www.marieclairekorea.com/fashion/2020/02/daydream/'

# %%
marie_jenny.dropna(inplace=True)
# Out:
# C:\Users\wnsgo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# 리사

# %%
marie_lisa['check'] = 0
for i in range(len(marie_lisa)):
    if marie_lisa.loc[i, 'title_name'] == 0:
        if '리사' not in marie_lisa.loc[i, 'contents']:
            marie_lisa.loc[i, 'check'] = 2
# Out:
# C:\Users\wnsgo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# 요리사
for word in marie_lisa['contents']:
    if '리사이' in word:
        print(word)
        print('-'*50)
# Out:
# [' ', '', '요즘처럼 아침 저녁으로 쌀쌀한 간절기에\n가볍게 툭 걸치기 좋은 바람 막이를 소개한다.', '안다르 Andar\n모나 리버시블 점퍼, 폰데로 사파인, 11만 9천원.', '바람막이는 투박하다는 편견을 없애줄 컬러풀한 디자인.\n리버시블로, 두 가지 스타일을 연출할 수 있다.', ' ', '', '뉴발란스 New Balance\nUNI 에코 리사이클 오버핏 자켓, 카키, 19만 9천원', '재활용 소재를 활용한 친환경 바람막이.\n허리 스트링이 있어\n실루엣을 조절 할 수 있다.\n여유로운 기장으로 엉덩이를 덮어,\n레깅스와 스타일링해도 부담스럽지 않다.', ' ', ' ', ' ', '', '나이키 Nike \n테크 플리스 윈드러너 풀집 후디, 다크 그레이 헤더, 13만 9천원.', '나이키가 개발한 나이키 테크 플리스는\n사용자의 움직임, 온도에 따라\n체온 조절을 해주는 기능성 소재다.\n가볍고, 따뜻하고, 통기성이 뛰어난 것이 특징.\n위드 브레이커로 활용하기 최적의 원단이다.', ' ', '룰루레몬 Lululemon\n미스트 오버 윈드브레이커,블랙, 16만 9천원.', '요가복의 명품 브랜드로 잘 알려진\n룰루레몬의 바람막이.\n후드에 밴드 처리를 해\n운동할 때에도 후드가\n잘 벗겨지지 않는다.\n썸홀 (Thumb Hole),\n히든 포켓 등 착용자를 위한\n섬세한 배려를 느낄 수 있다.']
# --------------------------------------------------
# ...

# %%
marie_lisa.loc[marie_lisa['contents'].str.contains('리사이'), 'check']=2

# %%
marie_lisa.loc[marie_lisa['check']==2, 'no'] = np.NaN
# Out:
# C:\Users\wnsgo\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
marie_lisa[marie_lisa['check']==2]
# Out:
#                    title                                               link  \
# 0          스포츠 브랜드의 바람막이  http://www.marieclairekorea.com/video/fashion-...
# 3          소셜 벤처, 제가 합니다  http://www.marieclairekorea.com/%ed%96%a5%ec%9...
# 4        시원하고 간편하게 트랙 쇼츠  http://www.marieclairekorea.com/fashion/2020/0...
# 9     브루어리 여행 ④ 광주 여행 스팟  http://www.marieclairekorea.com/lifestyle/2020...
# 10             우산보다 버킷 햇  http://www.marieclairekorea.com/fashion/2020/0...
# ..                   ...                                                ...
# 86        썸은 OK, 연애는 NO!  http://www.marieclairekorea.com/lifestyle/2017...
# 88      Instagram Travel  http://www.marieclairekorea.com/lifestyle/2017...
# 98           뜨끈한 겨울 국수 ②  http://www.marieclairekorea.com/lifestyle/2017...
# 99   Rockin’ Around Kids  http://www.marieclairekorea.com/fashion/2016/1...
# 100             서울 레트로 ②  http://www.marieclairekorea.com/lifestyle/2016...
#
#               year     mon                date  \
# ...

# %%
marie_lisa = marie_lisa[marie_lisa['contents'].str.contains('블랙핑크')]

# %% [markdown]
# 로제

# %%
marie_rose['check'] = 0
for i in range(len(marie_rose)):
    if marie_rose.loc[i, 'title_name'] == 0:
        if '로제' not in marie_rose.loc[i, 'contents']:
            marie_rose.loc[i, 'check'] = 2

# %%
# 로제 파스타, 와인 삭제
for word in marie_rose['contents']:
    if '로제' in word:
        print(word)
        print('-'*50)
# Out:
# ['레오퍼드 패턴이라 하면 ‘센’ 이미지가 강했는데,\n그랬던 ‘레오퍼드’가\n어느새 하나쯤 가지고 있어야 하는 필수템이 되었다.', '때로는 멋스럽게, 때로는 과감하게 연출할 수 있는 게\n바로 레오퍼드 패턴의 매력.', '아직 마냥 어렵게 느껴진다고?\n그렇다면 스커트에 먼저 도전해보자.\n의외로 데일리 룩으로 활용하기 좋으니까.\n셀럽들의 인스타그램에서\n살짝 아이디어를 얻어보았다.', ' ', '레오퍼드 패턴을 어떻게 입어야 할지 모르겠다면\n쉽고 간편하게 티셔츠와 매치해보자.', '캐주얼하면서도 센스 있는 룩을 완성할 수 있다.\n이때, 너무 화려하지 않은 컬러\n그러니까 베이지/브라운 톤의\n클래식한 레오퍼드 프린트를 선택하는 게 좋다.', ' ', ' ', '블랙 톱과 레오퍼드 패턴이 만나면\n그 매력이 배가 된다.', '조이, 페르닐 테이스백, 키아라 비아시처럼\n볼드한 액세서리를 더해주는 것도 잊지 말자.', '올가을엔 김나영처럼\n트렌치코트와 함께 매치해보는 건 어떨까.', '가죽 부츠로 시크함을 더해보자.\n다른 액세서리로 너무 과하게 꾸미지 않아도\n충분히 멋스러우니\n티셔츠나 스웨트셔츠를  입을 것을 추천한다.', ' ', ' ', '과감해지고 싶은 날엔 레오퍼드와 레오퍼드를 섞어보자.\n어딜가나 눈에 띄는 스타일을 연출할 수 있다.', '더 과감하고 싶다면\n애니멀, 체크, 스트라이프 등을 섞어\n프린트 믹스 매치에 도전해볼 것.', '반면 로제처럼 잔잔하고 작은 무늬의 셋업(Set-Up)은\n일상에서도 부담스럽지 않게 착용할 수 있다.', ' ', '', '제이청 J.Chung\nBEEN LEOPARD POINTED SKIRT(BLACK), 24만 9천원', '화려한 레오퍼드 패턴의 부담을 덜어줄 스커트.\n밑단에 레오퍼드 프린트의 자카드 원단을 덧대 포인트를 주었다.', '', ' ', '리얼리제이션 RÉAlisation Par\nTHE NAOMI, $180', '어떤 아이템과도 잘 어울리는\n심플한 디자인의 레오퍼드 스커트.\
# ...

# %%
marie_rose.loc[marie_rose['contents'].str.contains('노이 로제'), 'no']= np.NaN

# %%
marie_rose.dropna(inplace=True)
# Out:
# C:\Users\wnsgo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
marie_rose.reset_index(drop=True, inplace = True)

# %% [markdown]
# 지수

# %%
marie_jisu['check'] = 0
for i in range(len(marie_jisu)):
    if marie_jisu.loc[i, 'title_name'] == 0:
        if '지수' not in marie_jisu.loc[i, 'contents']:
            marie_jisu.loc[i, 'check'] = 2
# Out:
# C:\Users\wnsgo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\wnsgo\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
marie_jisu = marie_jisu[marie_jisu['contents'].str.contains('블랙핑크')]

# %%
marie_jisu.reset_index(drop=True, inplace = True)

# %%
marie_lisa.reset_index(drop=True, inplace=True)

# %%
word_jenny = []
for i in range(len(marie_jenny)):
    cont = []
    if marie_jenny.loc[i, 'title_name'] == 1:
        cont.append(marie_jenny.loc[i, 'contents'])
    else:
        for content in marie_jenny.loc[i, 'contents'].split("', '"):
#             print(content)
#             print('-'*50)
            if ('제니') in content:
                cont.append(content)
    word_jenny.append(cont)

len(word_jenny)
# Out:
# 29

# %%
marie_jenny['word_jenny'] = word_jenny
# Out:
# C:\Users\wnsgo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
word_lisa = []
for i in range(len(marie_lisa)):
    cont = []
    if marie_lisa.loc[i, 'title_name'] == 1:
        cont.append(marie_lisa.loc[i, 'contents'])
    else:
        for content in marie_lisa.loc[i, 'contents'].split("', '"):
#             print(content)
#             print('-'*50)
            if ('리사') in content:
                cont.append(content)
    word_lisa.append(cont)

print(len(word_lisa))
len(marie_lisa)
# Out:
# 6
# 6

# %%
marie_lisa['word_lisa'] = word_lisa
# Out:
# C:\Users\wnsgo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
word_rose = []
for i in range(len(marie_rose)):
    cont = []
    if marie_rose.loc[i, 'title_name'] == 1:
        cont.append(marie_rose.loc[i, 'contents'])
    else:
        for content in marie_rose.loc[i, 'contents'].split("', '"):
#             print(content)
#             print('-'*50)
            if ('로제') in content:
                cont.append(content)
    word_rose.append(cont)

print(len(word_rose))
len(marie_rose)
# Out:
# 4
# 4

# %%
marie_rose['word_rose'] = word_rose
# Out:
# C:\Users\wnsgo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
word_jisu = []
for i in range(len(marie_jisu)):
    cont = []
    if marie_jisu.loc[i, 'title_name'] == 1:
        cont.append(marie_jisu.loc[i, 'contents'])
    else:
        for content in marie_jisu.loc[i, 'contents'].split("', '"):
#             print(content)
#             print('-'*50)
            if ('지수') in content:
                cont.append(content)
    word_jisu.append(cont)

print(len(word_jisu))
len(marie_jisu)
# Out:
# 7
# 7

# %%
marie_jisu['word_jisu'] = word_jisu
# Out:
# C:\Users\wnsgo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
marie_jenny['member'] = 'Je'
marie_jisu['member'] = 'Ji'
marie_rose['member'] = 'R'
marie_lisa['member'] = 'L'
# Out:
# C:\Users\wnsgo\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
marie_jenny['magazine'] = 'M'
marie_jisu['magazine'] = 'M'
marie_rose['magazine'] = 'M'
marie_lisa['magazine'] = 'M'
# Out:
# C:\Users\wnsgo\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
marie_jenny = marie_jenny[['title', 'link', 'date', 'contents', 'category',
       'title_name', 'check', 'word_jenny', 'member', 'magazine']]

# %%
marie_jisu = marie_jisu[['title', 'link',  'date', 'contents', 'category',
       'title_name', 'check', 'word_jisu', 'member', 'magazine']]

# %%
marie_rose = marie_rose[['title', 'link',  'date', 'contents', 'category',
       'title_name', 'check', 'word_rose', 'member', 'magazine']]

# %%
marie_lisa = marie_lisa[['title', 'link',  'date', 'contents', 'category',
       'title_name', 'check', 'word_lisa', 'member', 'magazine']]

# %%
marie_jenny.to_csv('./blackpink/marie_Je.csv', sep='|', encoding = 'utf-8', index = False)
marie_jisu.to_csv('./blackpink/marie_Ji.csv', sep='|', encoding = 'utf-8', index = False)
marie_rose.to_csv('./blackpink/marie_R.csv', sep='|', encoding = 'utf-8', index = False)
marie_lisa.to_csv('./blackpink/marie_L.csv', sep='|', encoding = 'utf-8', index = False)
