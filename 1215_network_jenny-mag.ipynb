# %%
import pandas as pd
import numpy as np
import re
import networkx as nx
import matplotlib.pyplot as plt

# %%
# 한글 폰트 문제 해결
import platform

from matplotlib import font_manager, rc
# plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
mag_je = pd.read_csv('./magazine/final/mag_JECH.csv', encoding = 'utf-8', sep = '|')

# %%
mag_je['ADFN'] = mag_je['ADFN'].str.replace('[', '').str.replace(']', '').str.replace("'", "").str.split(', ')

# %% [markdown]
# ### top50 리스트 생성

# %%
top200 = pd.read_csv('./magazine/final/jennytop200.csv', sep='|', encoding = 'utf-8')

# %%
top200
# Out:
#           word  count
# 0           제니    748
# 1    BLACKPINK    327
# 2          스타일    197
# 3           패션    192
# 4           컬러    187
# ..         ...    ...
# 195         지난     22
# 196       국제공항     22
# 197          뒤     21
# 198          준     21
# 199         사용     21
#
# [200 rows x 2 columns]

# %%
top50 = []
for i in range(50):
    top50.append(top200.loc[i, 'word'])
    
print(len(top50))
print(top50)
# Out:
# 50
# ['제니', 'BLACKPINK', '스타일', '패션', '컬러', 'CHANEL', '룩', '헤어', '스타', '연출', '사진', '블랙', '매치', '포인트', '모습', '일링', '리사', '브랜드', '지수', '완성', '앞머리', '팬츠', '매력', '그녀', '로제', '메이크업', '아이템', '화이트', '입술', '기자', '분위기', '재킷', '걸', '톱', '머리', '패턴', '대', '착용', '생각', '말', '레드', '화보', '선택', '제품', '전', '얼굴', '공개', '통해', '눈', '니트']

# %% [markdown]
# ### top100

# %%
top100 = []
for i in range(100):
    top100.append(top200.loc[i, 'word'])
    
print(len(top100))
print(top100[:91])
# Out:
# 100
# ['제니', 'BLACKPINK', '스타일', '패션', '컬러', 'CHANEL', '룩', '헤어', '스타', '연출', '사진', '블랙', '매치', '포인트', '모습', '일링', '리사', '브랜드', '지수', '완성', '앞머리', '팬츠', '매력', '그녀', '로제', '메이크업', '아이템', '화이트', '입술', '기자', '분위기', '재킷', '걸', '톱', '머리', '패턴', '대', '착용', '생각', '말', '레드', '화보', '선택', '제품', '전', '얼굴', '공개', '통해', '눈', '니트', '가장', '데님', '카디건', '멤버', '핑크', '선글라스', '무드', '무대', '백', '공항', '밴드', '디자인', '느낌', '장식', '라인', '사람', '한편', '컬렉션', '지금', '드레스', '시작', '두', '액세서리', '미니', '그룹', '팬', '트', '소화', '립', '↑', '부분', '활용', '티셔츠', '앨범', '날', '첫', '시크', '티', '호', '참석', '투어']

# %% [markdown]
# ### top50만 남기기

# %%
len(mag_je)
# Out:
# 297

# %%
top50_word = []
for i in range(len(mag_je)):
    w=[]
    for word in mag_je.loc[i, 'ADFN']:
        if word in top50:
            w.append(word)
    top50_word.append(w)

# %%
top100_word = []
for i in range(len(mag_je)):
    w=[]
    for word in mag_je.loc[i, 'ADFN']:
        if word in top100:
            w.append(word)
    top100_word.append(w)

# %% [markdown]
# ### item 남기기

# %%
item = ['백', '드레스', '재킷', '주얼리', '옷', '슈즈', '스커트', '링', '팬츠', '가방', '슈트', '향수', '의상', '데님', '액세서리', '톱',
'셔츠', '모자', '수트', '스니커즈', '니트', '시계', '워치', '핸드백', '벨트', '선글라스', '목걸이', '티셔츠', '쇼츠', '샌들',
 '귀고리', '워치', '코트', '부츠', '케이프']

# %%
item_word = []
for i in range(len(mag_je)):
    w=[]
    for word in mag_je.loc[i, 'ADFN']:
        if word in item:
            w.append(word)
    item_word.append(w)

# %% [markdown]
# ### top100이면서 item이 아닌 것

# %%
top100_not_item_word = []
for i in range(len(mag_je)):
    w=[]
    for word in mag_je.loc[i, 'ADFN']:
        if word in top100:
            if word not in item:
                w.append(word)
    top100_not_item_word.append(w)

# %%
len(top100_not_item_word)
# Out:
# 297

# %%
top100_not_item_word[1]
# Out:
# ['패턴', '패턴', '선택', '제니', '느낌', '패턴', '컬러', '핑크', '장식', '그녀', '더욱', '시크', '블랙']

# %% [markdown]
# ### top50이면서 블랙핑크가 아닌 것

# %%
bp = ['BLACKPINK', '지수', '로제', '리사']

# %%
top50_not_bp_word = []
for i in range(len(mag_je)):
    w=[]
    for word in mag_je.loc[i, 'ADFN']:
        if word in top50:
            if word not in bp:
                w.append(word)
    top50_not_bp_word.append(w)

# %%
len(top50_word)
# Out:
# 297

# %%
top50_word[:5]
# Out:
# [['BLACKPINK',
#   '제니',
#   '메이크업',
#   '룩',
#   '스타',
#   '눈',
#   '앞머리',
#   '메이크업',
#   '눈',
#   '메이크업',
#   '메이크업',
#   '대',
#   '대',
#   '스타',
#   '메이크업',
#   '메이크업',
#   '포인트',
#   '메이크업',
#   '스타일',
#   '블랙',
#   '눈',
#   '앞머리',
#   '메이크업',
#   '눈',
#   '앞머리',
#   '포인트',
#   '메이크업',
#   '전',
#   '메이크업',
#   '눈',
#   '앞머리',
#   '포인트',
#   '생각',
#   'BLACKPINK',
#   '제니',
#   '눈',
#   '앞머리',
#   '포인트',
#   'BLACKPINK',
#   '메이크업',
#   '눈',
#   '앞머리',
#   '포인트',
#   '눈',
#   '얼굴',
#   '포인트',
#   '눈',
#   '앞머리',
#   '눈',
#   '완성',
#   '메이크업',
#   '눈',
#   '앞머리',
#   '룩',
#   '눈',
#   '눈',
#   '앞머리',
#   '레드',
#   '컬러',
#   '포인트',
#   '연출',
#   '눈',
#   '눈',
#   '앞머리',
#   '눈',
#   '컬러',
#   '포인트',
#   '연출',
#   '컬러',
#   '연출',
#   '룩',
#   '완성',
#   '메이크업',
#   '포인트',
#   '메이크업',
#   '눈',
#   '포인트',
#   '매력',
#   'BLACKPINK',
#   '제니',
#   '메이크업',
#   '룩',
#   '눈',
#   '생각',
#   '눈',
#   '앞머리',
#   '포인트',
#   '분위기',
#   '눈',
#   '눈',
#   '메이크업',
#   '생각',
#   '포인트',
#   '얼굴',
#   '포인트',
#   '생각',
#   '메이크업',
#   '포인트',
#   '말',
#   '메이크업',
#   '룩',
#   '메이크업',
#   '톱',
#   '메이크업'],
#  ['패턴', '패턴', '선택', '제니', '패턴', '컬러', '그녀', '블랙'],
#  ['제니', '스타일', '스타일', '매치', '톱', '선택', '매치', '연출'],
#  ['아이템',
#   '제니',
#   '헤어',
#   '스타',
#   '일링',
#   '헤어',
#   '헤어',
#   '분위기',
#   '앞머리',
#   '말',
#   '머리',
#   '말',
#   '제니',
#   '제니',
#   '스타일',
#   '머리',
#   '헤어',
#   '스타일',
#   '헤어',
#   '헤어',
#   '스타일',
#   '헤어',
#   '머리',
#   '얼굴',
#   '머리',
#   '얼굴',
#   '머리',
#   '얼굴',
#   '연출',
#   '헤어',
#   '연출',
#   '헤어',
#   '헤어',
#   '앞머리',
#   '걸',
#   '헤어',
#   '헤어',
#   '스타일',
#   '머리',
#   '헤어',
#   '스타일',
#   '연출',
#   '스타일',
#   '포인트'],
#  ['룩', '제니', '스타', '일링', '재킷', '팬츠', '완성', '룩', '블랙', '헤어', '메이크업', '패션']]

# %% [markdown]
# ### 텍스트 한줄씩 읽어와 dataset에 기록

# %% [markdown]
# ### 어프라이어리(Apriori) 알고리즘을 적용하여 연관규칙 분석 수행

# %%
# 어프라이어리(Apriori)
from apyori import apriori

# %%
top50_word[1]
# Out:
# ['패턴', '패턴', '선택', '제니', '패턴', '컬러', '그녀', '블랙']

# %%
# 지지도(support) : P(A∩B)
result = list(apriori(top50_not_bp_word, min_support = 0.01))
df = pd.DataFrame(result)
df['length'] = df['items'].apply(lambda x:len(x))
df = df[(df['length'] == 2) 
        & (df['support'] >= 0.01)].sort_values(by='support', ascending = False)
df.head(10)

# %% [markdown]
# ### networkx 그래프 정의

# %%
G = nx.Graph()
ar = (df['items']); G.add_edges_from(ar)

# %%
# 페이지 랭크
pr = nx.pagerank(G)
nsize = np.array([v for v in pr.values()])
nsize = 2000 * (nsize - min(nsize)) / (max(nsize) - min(nsize))

# %%
pos = nx.spring_layout(G)

# %%
plt.figure(figsize = (16, 12)) ; plt.axis('off')
nx.draw_networkx(G, font_family = 'Malgun Gothic', font_size = 16,
                pos = pos, node_color = list(pr.values()), node_size = nsize,
                alpha=0.7, edge_color='.5', cmap = plt.cm.YlGn)
plt.show()
plt.savefig('./jenny_in_top100.png', bbox_inches = 'tight')

# %%
# ['첫', '처음', '공개', '작업', '이후', '펜디', '판매', '작품', '드', '예정', '시대']

# %%
top50_word
# Out:
# [['BLACKPINK',
#   '제니',
#   '메이크업',
#   '룩',
#   '스타',
#   '눈',
#   '앞머리',
#   '메이크업',
#   '눈',
#   '메이크업',
#   '메이크업',
#   '대',
#   '대',
#   '스타',
#   '메이크업',
#   '메이크업',
#   '포인트',
#   '메이크업',
#   '스타일',
#   '블랙',
#   '눈',
#   '앞머리',
#   '메이크업',
#   '눈',
#   '앞머리',
#   '포인트',
#   '메이크업',
#   '전',
#   '메이크업',
#   '눈',
#   '앞머리',
#   '포인트',
#   '생각',
#   'BLACKPINK',
#   '제니',
#   '눈',
#   '앞머리',
#   '포인트',
#   'BLACKPINK',
#   '메이크업',
#   '눈',
#   '앞머리',
#   '포인트',
#   '눈',
#   '얼굴',
#   '포인트',
#   '눈',
#   '앞머리',
#   '눈',
#   '완성',
#   '메이크업',
#   '눈',
#   '앞머리',
#   '룩',
#   '눈',
#   '눈',
#   '앞머리',
#   '레드',
#   '컬러',
#   '포인트',
#   '연출',
#   '눈',
#   '눈',
#   '앞머리',
#   '눈',
#   '컬러',
#   '포인트',
#   '연출',
#   '컬러',
#   '연출',
#   '룩',
#   '완성',
#   '메이크업',
#   '포인트',
#   '메이크업',
#   '눈',
#   '포인트',
#   '매력',
#   'BLACKPINK',
#   '제니',
#   '메이크업',
#   '룩',
#   '눈',
#   '생각',
#   '눈',
#   '앞머리',
#   '포인트',
#   '분위기',
#   '눈',
#   '눈',
#   '메이크업',
#   '생각',
#   '포인트',
#   '얼굴',
#   '포인트',
#   '생각',
#   '메이크업',
#   '포인트',
#   '말',
#   '메이크업',
#   '룩',
#   '메이크업',
#   '톱',
#   '메이크업'],
#  ['패턴', '패턴', '선택', '제니', '패턴', '컬러', '그녀', '블랙'],
#  ['제니', '스타일', '스타일', '매치', '톱', '선택', '매치', '연출'],
#  ['아이템',
#   '제니',
#   '헤어',
#   '스타',
#   '일링',
#   '헤어',
#   '헤어',
#   '분위기',
#   '앞머리',
#   '말',
#   '머리',
#   '말',
#   '제니',
#   '제니',
#   '스타일',
#   '머리',
#   '헤어',
#   '스타일',
#   '헤어',
#   '헤어',
#   '스타일',
#   '헤어',
#   '머리',
#   '얼굴',
#   '머리',
#   '얼굴',
#   '머리',
#   '얼굴',
#   '연출',
#   '헤어',
#   '연출',
#   '헤어',
#   '헤어',
#   '앞머리',
#   '걸',
#   '헤어',
#   '헤어',
#   '스타일',
#   '머리',
#   '헤어',
#   '스타일',
#   '연출',
#   '스타일',
#   '포인트'],
#  ['룩', '제니', '스타', '일링', '재킷', '팬츠', '완성', '룩', '블랙', '헤어', '메이크업', '패션'],
#  ['컬러',
#   '선택',
#   '제니',
#   '컬러',
#   '패턴',
#   '니트',
#   '니트',
#   '컬러',
#   '분위기',
#   '패턴',
#   '선택',
#   '룩',
#   '완성',
#   '제니',
#   '컬러'],
#  ['제니', '컬러', '패턴', '제니', '톱', '제니', '팬츠', '톱', '매치', '룩', '완성', '눈'],
#  ['룩', '블랙', '리사', '제니', '룩', '컬러', '아이템', '선택', '룩', '연출', '눈', '매치'],
#  ['팬츠',
#   '제니',
#   '팬츠',
#   '팬츠',
#   '눈',
#   '팬츠',
#   '니트',
#   '톱',
#   '매치',
#   '분위기',
#   '제니',
#   '화이트',
#   '팬츠',
#   '재킷',
#   '매치',
#   '룩',
#   '선택',
#   '포인트'],
#  ['제니', 'CHANEL', 'CHANEL', '제니', 'CHANEL', '블랙', '컬러', '재킷', '매치', '룩'],
#  ['BLACKPINK', '제니', '스타일', '제니', '니트', '패턴', '매치', '분위기', '연출'],
#  ['전', '선택', '연출', '제니', '눈', '분위기', '연출'],
#  ['제니', '매력', '얼굴', '제니', '연출', '제니', '모습', '화보', 'CHANEL'],
#  ['블랙', '제니', '스타일', '연출', '머리', '스타일', '완성'],
#  ['CHANEL',
#   '패션',
#   'BLACKPINK',
#   '제니',
#   '룩',
#   '그녀',
#   '패션',
#   '착용',
#   '제니',
#   '패턴',
#   '연출',
#   '매력',
#   '제니',
#   '아이템',
#   '제니',
#   '제니',
#   '패턴',
#   '룩',
#   '톱',
#   '패턴',
#   '재킷',
#   '착용',
#   '톱',
#   '착용',
#   '제니',
#   '룩',
#   '스타일',
#   '연출',
#   '제니',
#   '팬츠',
#   '연출'],
#  ['매력',
#   '전',
#   '브랜드',
#   'BLACKPINK',
#   '제니',
#   '제니',
#   '전',
#   '제니',
#   '그녀',
#   '제니',
#   '스타',
#   '일링',
#   '제니',
#   '스타',
#   '일링'],
#  ['룩', 'BLACKPINK', '제니', '톱', '연출', '대', '제니', '포인트'],
#  ['CHANEL', 'CHANEL', 'CHANEL', 'BLACKPINK', '제니'],
#  ['분위기', '연출', '제니', '스타', '일링', '재킷', '선택', '헤어'],
#  ['제니',
#   '제니',
#   'BLACKPINK',
#   '공개',
#   '제니',
#   '헤어',
#   '스타일',
#   '앞머리',
#   '연출',
#   '제니',
#   '연출',
#   '컬러',
#   '포인트',
#   '블랙',
#   '헤어',
#   '분위기'],
#  ['제니', '화이트', '컬러', '컬러', '포인트', '제니', '컬러', '메이크업', '제니'],
#  ['BLACKPINK', '제니', '아이템', '제니', '제니', '말', '제니'],
#  ['톱', '제니', '톱', '분위기', '헤어', '룩', '포인트'],
#  ['BLACKPINK', '제니', '레드', '룩'],
#  ['제품', 'BLACKPINK', '제니', '재킷', '분위기'],
#  ['입술',
#   '니트',
#   '팬츠',
#   '룩',
#   '스타일',
#   '룩',
#   'BLACKPINK',
#   '제니',
#   '룩',
#   '톱',
#   '팬츠',
#   '착용',
#   'BLACKPINK',
#   '제니',
#   '대'],
#  ['CHANEL',
#   '제니',
#   '착용',
#   '생각',
#   '브랜드',
#   '브랜드',
#   '제품',
#   '매치',
#   '제품',
#   '제품',
#   '제니',
#   '그녀',
#   '룩'],
#  ['BLACKPINK', '제니', '브랜드', '재킷', '블랙', '컬러', '팬츠', '매치', '룩', '완성'],
#  ['메이크업', '제니', '컬러', '컬러', '메이크업', '완성'],
#  ['블랙', '메이크업', '제니', '블랙'],
#  ['제니', '제니', '얼굴', '패션'],
#  ['CHANEL', '블랙', '제니', 'CHANEL', '룩', '재킷', '화이트', '레드', '제니'],
#  ['블랙', '제니', '전'],
#  ['BLACKPINK', '제니'],
#  ['제니', 'BLACKPINK', '제니', '메이크업', '분위기', '매력', '연출'],
#  ['브랜드', '그녀', '말', '그녀', 'BLACKPINK', '제니'],
#  ['BLACKPINK', '제니', '블랙', '선택', '모습', '스타일'],
#  ['BLACKPINK',
#   'BLACKPINK',
#   '공개',
#   '지수',
#   '제니',
#   '로제',
#   '리사',
#   '모습',
#   'BLACKPINK',
#   '스타',
#   '공개',
#   'BLACKPINK'],
#  ['제니', '공개', '제니', '제니', '말', '제니', '제니', '말', '생각', '생각', '제니', '말', '생각'],
#  ['BLACKPINK', '제니', '제니', '헤어', '룩'],
#  ['레드', 'BLACKPINK', '제니', '얼굴'],
#  ['제니', '제니', '제니', '브랜드', '브랜드', '패턴'],
#  ['제니', '제니', '화이트', '제니', '포인트', '룩', '제니'],
#  ['BLACKPINK',
#   '제니',
#   'BLACKPINK',
#   '제니',
#   '화보',
#   '제니',
#   '스타일',
#   '룩',
#   '룩',
#   '헤어',
#   '공개',
#   'BLACKPINK',
#   '공개',
#   '공개'],
#  ['컬러', '매치', '제니', '컬러'],
#  ['BLACKPINK',
#   '제니',
#   'BLACKPINK',
#   '제니',
#   '화보',
#   '말',
#   '화보',
#   '브랜드',
#   '화보',
#   '스타일',
#   '브랜드',
#   '제품',
#   '제니',
#   '화보'],
#  ['제니', '제니', '제니', '포인트', '제니', '포인트'],
#  ['BLACKPINK',
#   '제니',
#   'BLACKPINK',
#   '제니',
#   '제니',
#   '그녀',
#   '선택',
#   '헤어',
#   '앞머리',
#   '스타일',
#   '재킷',
#   '앞머리',
#   '스타',
#   '일링'],
#  ['제니',
#   '룩',
#   '스타',
#   '일링',
#   '걸',
#   '연출',
#   '메이크업',
#   '얼굴',
#   '메이크업',
#   '연출',
#   '연출',
#   '메이크업',
#   '매력'],
#  ['브랜드', '대', 'BLACKPINK', '제니'],
#  ['포인트',
#   '매력',
#   '패션',
#   '브랜드',
#   '스타일',
#   '제니',
#   'CHANEL',
#   '지수',
#   '리사',
#   '로제',
#   '스타일',
#   '레드',
#   '공개'],
#  ['제니', '로제', '제품'],
#  ['제니',
#   'BLACKPINK',
#   '헤어',
#   '앞머리',
#   '머리',
#   '스타일',
#   '스타일',
#   '앞머리',
#   '앞머리',
#   '헤어',
#   '제니',
#   '스타일',
#   '얼굴',
#   '제니',
#   '사진',
#   '앞머리',
#   '제니',
#   '앞머리',
#   '스타일',
#   '제니',
#   '제니',
#   '얼굴',
#   '제니',
#   '걸',
#   '생각',
#   '앞머리',
#   '스타일',
#   '앞머리',
#   '헤어',
#   '스타일',
#   '완성',
#   '컬러',
#   '스타일',
#   '제니',
#   '앞머리',
#   '스타일',
#   '제니',
#   'BLACKPINK',
#   '공개'],
#  ['BLACKPINK', '제니', 'BLACKPINK', '제니', '패션', 'BLACKPINK', '공개'],
#  ['BLACKPINK', '제니'],
#  ['제니'],
#  ['BLACKPINK', '제니', 'BLACKPINK', '제니', '모습', '제니', '스타일', '얼굴'],
#  ['눈', 'BLACKPINK', '제니', 'CHANEL', '아이템', '매력', '제품', '공개', '제품'],
#  ['BLACKPINK',
#   '제니',
#   'BLACKPINK',
#   '제니',
#   '머리',
#   '매력',
#   '그녀',
#   '헤어',
#   '머리',
#   '머리',
#   '머리',
#   '연출',
#   '레드',
#   '그녀',
#   '매력',
#   '그녀',
#   '머리',
#   '스타일',
#   '그녀',
#   '머리',
#   '머리',
#   '포인트',
#   '걸',
#   '스타일',
#   '연출',
#   '그녀',
#   '스타일',
#   '앞머리',
#   '연출',
#   '머리'],
#  ['BLACKPINK',
#   '제니',
#   'BLACKPINK',
#   '제니',
#   '레드',
#   'BLACKPINK',
#   '제니',
#   '제니',
#   '레드',
#   '패션',
#   '스타일',
#   '제니',
#   '레드',
#   '제니'],
#  ['BLACKPINK', '제니', 'CHANEL'],
#  ['CHANEL', '룩', 'CHANEL', '매치', '블랙', '제니', '아이템'],
#  ['스타', '일링', '제니', '룩'],
#  ['블랙', 'BLACKPINK', '제니', '레드', '브랜드', '포인트', '재킷', '매치'],
#  ['제니', '선택', '앞머리', '눈', '스타일', '포인트'],
#  ['재킷', '분위기', '연출', '제니'],
#  ['메이크업', '제니', '컬러'],
#  ['제니', '헤어', '스타일', '헤어'],
#  ['헤어', '제니', '포인트'],
#  ['제니',
#   '제니',
#   '레드',
#   '연출',
#   '입술',
#   '완성',
#   '블랙',
#   '대',
#   '대',
#   '블랙',
#   '대',
#   '레드',
#   '대',
#   '레드',
#   '입술',
#   '연출',
#   '포인트',
#   '메이크업',
#   '스타',
#   '대',
#   '블랙',
#   '대',
#   '대',
#   '레드',
#   '대',
#   '매치',
#   '메이크업',
#   '스타',
#   '대',
#   '블랙',
#   '대',
#   '대',
#   '대',
#   '대',
#   '브랜드',
#   '스타일'],
#  ['BLACKPINK', '제니', '얼굴', '분위기', '머리', '분위기'],
#  ['BLACKPINK', '제니'],
#  ['제니', 'CHANEL', 'CHANEL'],
#  ['제니', 'BLACKPINK', '제니', 'CHANEL', '재킷', '얼굴', '그녀', '사진', '제니', '제품'],
#  ['CHANEL',
#   '제니',
#   '통해',
#   'CHANEL',
#   '룩',
#   'CHANEL',
#   '걸',
#   '매력',
#   '제니',
#   'CHANEL',
#   '룩'],
#  ['걸',
#   '로제',
#   '말',
#   '제니',
#   '생각',
#   '걸',
#   '제니',
#   '분위기',
#   '걸',
#   '제니',
#   '모습',
#   '로제',
#   '리사',
#   '말',
#   '로제',
#   '제니',
#   '걸',
#   '생각',
#   '제니',
#   '전',
#   '화보',
#   '전',
#   '리사',
#   '전',
#   '로제',
#   '로제',
#   '리사',
#   '모습',
#   '제니',
#   '제니',
#   '제니',
#   '전',
#   '패턴',
#   '리사',
#   '전',
#   '걸',
#   '제니',
#   '로제',
#   '지수',
#   '전',
#   '스타일',
#   '리사',
#   '전',
#   '걸',
#   '모습',
#   '로제',
#   '전',
#   '걸',
#   '걸',
#   '제니',
#   '지수',
#   '걸',
#   '제니',
#   '재킷',
#   '사진',
#   '걸',
#   '제니',
#   '블랙',
#   '모습',
#   '모습',
#   '걸',
#   '걸',
#   'BLACKPINK',
#   '생각',
#   'BLACKPINK',
#   '모습',
#   '제니',
#   'BLACKPINK',
#   '화보',
#   '화보',
#   '생각',
#   '모습',
#   '전',
#   'BLACKPINK',
#   '로제',
#   '걸',
#   '모습',
#   'BLACKPINK',
#   '생각',
#   '지수',
#   '말',
#   '말',
#   '생각',
#   'BLACKPINK',
#   '모습',
#   '모습',
#   '로제',
#   '전',
#   '리사',
#   '전',
#   '사진',
#   '전',
#   '사진',
#   '제니',
#   '전',
#   '지수',
#   '말',
#   '로제',
#   '리사',
#   '제니',
#   '걸',
#   '말',
#   '생각',
#   '걸',
#   '걸',
#   '지수',
#   '걸'],
#  ['제니',
#   'CHANEL',
#   'CHANEL',
#   '제니',
#   'CHANEL',
#   '톱',
#   '스타일',
#   'CHANEL',
#   '제니',
#   '그녀',
#   'CHANEL',
#   'CHANEL',
#   'CHANEL',
#   '컬러',
#   'CHANEL',
#   '생각',
#   '그녀',
#   '선택',
#   '톱',
#   '팬츠',
#   'CHANEL',
#   '스타일',
#   'CHANEL',
#   '분위기',
#   'CHANEL',
#   '분위기',
#   '연출',
#   'CHANEL',
#   '분위기',
#   'CHANEL',
#   '매력',
#   '분위기',
#   '눈',
#   '제니',
#   'BLACKPINK'],
#  ['니트', '톱', '제니'],
#  ['BLACKPINK', '제니', '메이크업', '제니', '메이크업', '눈', '눈', '눈', '연출', '헤어'],
#  ['패턴', '컬러', '블랙', '화이트', '패턴', '룩', '완성', '스타일', '블랙', '제니', '패턴', '선택'],
#  ['제니', '헤어', '헤어', '헤어', '연출', '매력', '스타일', '제니', '헤어', '컬러', '헤어', '컬러'],
#  ['분위기'],
#  ['매력', '제니', '화이트', '블랙', '컬러', '재킷', '매치', '연출', '룩'],
#  ['니트',
#   '니트',
#   '패턴',
#   '매력',
#   '니트',
#   '아이템',
#   '선택',
#   '분위기',
#   '패턴',
#   '팬츠',
#   '매치',
#   '대',
#   '룩',
#   '완성',
#   '패턴',
#   '블랙',
#   '팬츠',
#   '니트',
#   '선택',
#   '니트',
#   '니트',
#   '니트',
#   '분위기',
#   '니트',
#   '컬러',
#   '블랙',
#   '스타일',
#   '컬러',
#   '룩',
#   '제니',
#   '블랙',
#   '연출',
#   '선택',
#   '연출',
#   '패턴',
#   '니트',
#   '패턴',
#   '니트',
#   '포인트',
#   '패턴',
#   '분위기',
#   '스타',
#   '블랙',
#   '패턴',
#   '지수',
#   '패턴',
#   '패턴',
#   '컬러',
#   '패턴',
#   '선택',
#   '스타일',
#   '완성',
#   '니트',
#   '니트',
#   '니트',
#   '스타',
#   '룩',
#   '룩',
#   '대',
#   '얼굴',
#   '스타일',
#   '매치',
#   '분위기',
#   '스타',
#   '일링',
#   '포인트',
#   '니트'],
#  ['제니', '화이트', '패턴', '화이트', '룩', '제니', '연출', '모습', '그녀', '눈'],
#  ['스타일',
#   '스타일',
#   '헤어',
#   '분위기',
#   '연출',
#   '스타일',
#   '스타일',
#   '분위기',
#   '연출',
#   '헤어',
#   '헤어',
#   '패션',
#   '얼굴',
#   '헤어',
#   '스타일',
#   '스타일',
#   '분위기',
#   '연출',
#   '헤어',
#   '헤어',
#   '헤어',
#   '말',
#   '블랙',
#   '룩',
#   '포인트',
#   '머리',
#   '앞머리',
#   '머리',
#   '헤어',
#   '완성',
#   '걸',
#   '룩',
#   '선택',
#   '제니',
#   '스타일',
#   '그녀',
#   '스타일',
#   '머리',
#   '헤어',
#   '헤어',
#   '포인트',
#   '컬러',
#   '헤어',
#   '연출',
#   '스타일',
#   '앞머리',
#   '헤어',
#   '매력',
#   '컬러',
#   '그녀',
#   '컬러',
#   '선택',
#   '포인트',
#   '레드',
#   '헤어',
#   '컬러',
#   '선택',
#   '헤어',
#   '스타일',
#   '헤어',
#   '스타일',
#   '완성'],
#  ['제니',
#   '제니',
#   '컬러',
#   '선택',
#   '제니',
#   '룩',
#   '니트',
#   '블랙',
#   '완성',
#   '룩',
#   '컬러',
#   '선택',
#   '패턴',
#   '룩'],
#  ['제니', '컬러', '재킷', '머리', '매치', '대', '스타일', '패션'],
#  ['헤어',
#   '스타일',
#   '제니',
#   '앞머리',
#   '모습',
#   '얼굴',
#   '앞머리',
#   '앞머리',
#   '앞머리',
#   '얼굴',
#   '앞머리',
#   '전',
#   '앞머리',
#   '모습',
#   '공개',
#   '분위기',
#   '앞머리',
#   '스타일',
#   '앞머리',
#   '앞머리',
#   '앞머리',
#   '완성',
#   '앞머리',
#   '머리',
#   '연출',
#   '메이크업',
#   '헤어',
#   '스타일',
#   '앞머리'],
#  ['CHANEL',
#   '제니',
#   'CHANEL',
#   '제니',
#   '스타',
#   '일링',
#   '브랜드',
#   '제니',
#   'CHANEL',
#   'CHANEL',
#   '제니',
#   '착용',
#   '룩',
#   'CHANEL',
#   '제니',
#   'CHANEL',
#   '룩',
#   '완성',
#   '제니',
#   '룩',
#   'CHANEL',
#   '매치',
#   '스타',
#   '일링',
#   '블랙',
#   '포인트',
#   '니트',
#   '패션',
#   '레드',
#   '컬러',
#   '니트',
#   '블랙',
#   '컬러',
#   '제니',
#   'CHANEL',
#   '룩',
#   '생각',
#   '니트',
#   '톱',
#   'CHANEL',
#   '매치',
#   '룩',
#   'CHANEL',
#   '제니',
#   '제니',
#   '제니',
#   '아이템',
#   'CHANEL',
#   '재킷',
#   '룩',
#   '아이템',
#   '생각',
#   '재킷',
#   '제니',
#   '스타',
#   '일링',
#   '화이트',
#   '매치',
#   '룩',
#   '화이트',
#   '연출',
#   '사진',
#   '룩',
#   '스타일',
#   '블랙',
#   '매치',
#   '제니',
#   '블랙',
#   '제니',
#   '제니',
#   '스타일',
#   '제니',
#   '컬러',
#   '재킷',
#   '룩',
#   '제니',
#   '화보',
#   '톱',
#   '매치',
#   '컬러',
#   '팬츠',
#   '매치',
#   '제니',
#   '스타',
#   '일링',
#   '룩',
#   '컬러',
#   '매치',
#   '룩',
#   '완성',
#   '패션',
#   '브랜드',
#   '제니',
#   '아이템',
#   '패턴',
#   '블랙',
#   '니트',
#   '매치',
#   '룩',
#   '제니',
#   '헤어',
#   '스타',
#   '일링',
#   '헤어',
#   '스타',
#   '일링',
#   '제니',
#   '패션',
#   '완성',
#   '헤어',
#   '스타',
#   '룩',
#   'CHANEL',
#   '니트',
#   '헤어',
#   '매치',
#   '룩',
#   '스타',
#   '일링',
#   '제니',
#   '제니',
#   '룩',
#   '제니',
#   '스타',
#   '일링',
#   '스타',
#   '일링',
#   '제니',
#   '아이템',
#   '니트',
#   'CHANEL',
#   '매치',
#   '매치',
#   '블랙',
#   '화이트',
#   '룩',
#   '제니',
#   '룩'],
#  ['얼굴',
#   '헤어',
#   '스타일',
#   '대',
#   '헤어',
#   '스타일',
#   '앞머리',
#   '머리',
#   '헤어',
#   '스타일',
#   '앞머리',
#   '헤어',
#   '컬러',
#   '메이크업',
#   '분위기',
#   '연출',
#   '앞머리',
#   '헤어',
#   '앞머리',
#   '헤어',
#   '스타일',
#   '앞머리',
#   '제품',
#   '앞머리',
#   '포인트',
#   '분위기',
#   '제니',
#   '앞머리',
#   '헤어',
#   '앞머리',
#   '그녀',
#   '앞머리',
#   '얼굴',
#   '헤어',
#   '얼굴',
#   '앞머리',
#   '헤어',
#   '스타일',
#   '완성',
#   '앞머리',
#   '앞머리',
#   '연출',
#   '헤어',
#   '제품',
#   '앞머리',
#   '스타일',
#   '스타일',
#   '헤어',
#   '앞머리',
#   '앞머리',
#   '말',
#   '헤어',
#   '스타일',
#   '헤어',
#   '얼굴',
#   '앞머리',
#   '앞머리',
#   '그녀',
#   '앞머리',
#   '앞머리',
#   '연출'],
#  ['CHANEL', 'BLACKPINK', '제니', '브랜드', '패턴', '재킷', '스타일'],
#  ['매력', '제니', '스타일', '눈', '패턴', '재킷', '연출', '헤어'],
#  ['연출',
#   '패션',
#   '룩',
#   '아이템',
#   '팬츠',
#   'BLACKPINK',
#   '제니',
#   '착용',
#   '패션',
#   '브랜드',
#   '팬츠',
#   '매치',
#   '화이트',
#   '톱'],
#  ['제니',
#   '제니',
#   '컬러',
#   '니트',
#   '블랙',
#   '룩',
#   'BLACKPINK',
#   '제니',
#   '제니',
#   '선택',
#   '니트',
#   '브랜드',
#   '블랙',
#   '컬러',
#   '매치',
#   '매치'],
#  ['제니', '패턴', '매치', '패턴', '머리', '컬러', '포인트'],
#  ['BLACKPINK', '제니', 'BLACKPINK', '제니'],
#  ['레드',
#   '입술',
#   '연출',
#   '제품',
#   '완성',
#   '컬러',
#   '입술',
#   '입술',
#   '제품',
#   '얼굴',
#   '컬러',
#   '매력',
#   '제품',
#   '제품'],
#  ['모습', '제니', '로제', '리사', '지수'],
#  ['스타',
#   '헤어',
#   '앞머리',
#   '헤어',
#   '스타일',
#   '스타',
#   '착용',
#   '매력',
#   '헤어',
#   '착용',
#   '패턴',
#   '재킷',
#   '헤어',
#   '컬러',
#   '제니',
#   '화이트',
#   '룩',
#   '헤어',
#   '스타일',
#   '컬러',
#   '헤어',
#   '재킷',
#   '헤어',
#   '포인트',
#   '톱',
#   '화이트',
#   '컬러',
#   '헤어',
#   '포인트'],
#  ['패션',
#   '선택',
#   '화이트',
#   '스타',
#   '일링',
#   '선택',
#   '분위기',
#   '선택',
#   '패턴',
#   '컬러',
#   '패션',
#   '패턴',
#   '패턴',
#   '팬츠',
#   '매치',
#   '룩',
#   '완성',
#   '스타일',
#   '패턴',
#   '매력',
#   '제니'],
#  ['컬러',
#   '선택',
#   '컬러',
#   '분위기',
#   '컬러',
#   '레드',
#   '컬러',
#   '분위기',
#   '연출',
#   '얼굴',
#   'BLACKPINK',
#   '제니',
#   '눈',
#   '컬러',
#   '컬러'],
#  ['스타일', '제니', '포인트'],
#  ['매력',
#   '룩',
#   '매력',
#   '컬러',
#   'BLACKPINK',
#   '제니',
#   '레드',
#   '브랜드',
#   '컬러',
#   '패턴',
#   '블랙',
#   '매력',
#   '모습',
#   '컬러',
#   '매치',
#   '모습'],
#  ['제니', '선택', '연출', '분위기', '제니', '스타일'],
#  ['제니',
#   '입술',
#   '얼굴',
#   '생각',
#   '얼굴',
#   '입술',
#   '제니',
#   '입술',
#   '입술',
#   '입술',
#   '얼굴',
#   '입술',
#   '입술',
#   '얼굴',
#   '입술',
#   '입술',
#   '입술',
#   '입술',
#   '입술',
#   '입술',
#   '입술',
#   '생각',
#   '생각',
#   '입술',
#   '입술',
#   '입술',
#   '입술',
#   '입술',
#   '사진',
#   '사진',
#   '입술',
#   '말',
#   '분위기',
#   '얼굴',
#   '입술',
#   '입술',
#   '입술',
#   '입술',
#   '입술',
#   '말',
#   '입술',
#   '입술',
#   '입술',
#   '입술',
#   '입술'],
#  ['메이크업',
#   'BLACKPINK',
#   '제니',
#   '메이크업',
#   '사진',
#   '제니',
#   '모습',
#   '메이크업',
#   '공개',
#   '메이크업',
#   '제니',
#   '모습',
#   '제품',
#   '메이크업',
#   '메이크업',
#   '메이크업',
#   '컬러',
#   '블랙',
#   '메이크업',
#   '컬러',
#   'CHANEL',
#   '블랙'],
#  ['BLACKPINK',
#   'BLACKPINK',
#   '브랜드',
#   'BLACKPINK',
#   '제니',
#   '리사',
#   '지수',
#   '로제',
#   '공개',
#   '모습',
#   'BLACKPINK',
#   'BLACKPINK',
#   'BLACKPINK',
#   'BLACKPINK',
#   '로제',
#   '블랙',
#   'BLACKPINK',
#   '리사',
#   'BLACKPINK',
#   '지수'],
#  ['BLACKPINK', '제니', '모습', '스타일'],
#  ['제니', 'CHANEL', '브랜드'],
#  ['BLACKPINK',
#   '스타일',
#   '헤어',
#   '메이크업',
#   '패션',
#   '제니',
#   '공개',
#   '앞머리',
#   '헤어',
#   '제니',
#   '눈',
#   '메이크업'],
#  ['대',
#   '스타',
#   '스타',
#   '팬츠',
#   '톱',
#   '얼굴',
#   '아이템',
#   '전',
#   '스타일',
#   '그녀',
#   '컬러',
#   '컬러',
#   '스타',
#   '일링',
#   '제니',
#   '제니',
#   '스타일',
#   '제니',
#   '컬러',
#   '대',
#   '매치',
#   '컬러',
#   '룩',
#   '패턴',
#   '걸',
#   '선택',
#   '컬러',
#   '아이템',
#   '매치',
#   '선택',
#   'CHANEL',
#   '포인트',
#   '눈',
#   '얼굴',
#   '대',
#   '스타일'],
#  ['분위기', '패턴', '제니'],
#  ['모습',
#   '헤어',
#   '재킷',
#   '헤어',
#   '컬러',
#   '룩',
#   '완성',
#   '헤어',
#   '선택',
#   '컬러',
#   '헤어',
#   '블랙',
#   '제니',
#   '머리',
#   '화이트',
#   '헤어',
#   '스타일'],
#  ['제니',
#   '스타',
#   '착용',
#   'CHANEL',
#   'CHANEL',
#   '생각',
#   '그녀',
#   '말',
#   'CHANEL',
#   '분위기',
#   'CHANEL',
#   '말'],
#  ['BLACKPINK',
#   '제니',
#   'BLACKPINK',
#   '제니',
#   '룩',
#   '제니',
#   '룩',
#   '팬츠',
#   '재킷',
#   '매치',
#   '제니',
#   '패션',
#   '룩',
#   '완성',
#   '컬러',
#   '아이템',
#   '포인트',
#   '컬러',
#   '룩',
#   '연출',
#   '룩',
#   '룩',
#   '컬러',
#   '매치',
#   '패션',
#   '팬츠',
#   '매치',
#   '대',
#   '룩',
#   '매치',
#   '매치',
#   '연출',
#   '블랙',
#   '룩',
#   '선택',
#   '룩',
#   '재킷',
#   '연출'],
#  ['제니', '브랜드', '제니', '브랜드', 'BLACKPINK', '제니', '브랜드', '패턴', '대'],
#  ['스타',
#   '룩',
#   '스타',
#   '일링',
#   '화이트',
#   '톱',
#   '팬츠',
#   '컬러',
#   '화이트',
#   '톱',
#   '제니',
#   '매치',
#   '스타',
#   '일링',
#   '포인트'],
#  ['스타일', '제니', '룩'],
#  ['BLACKPINK', '제니', 'BLACKPINK', '제니', '제니', '걸', '패턴', '연출', '선택', '연출'],
#  ['얼굴',
#   '메이크업',
#   '입술',
#   '컬러',
#   '입술',
#   '입술',
#   '컬러',
#   '입술',
#   '연출',
#   '스타일',
#   '전',
#   '입술',
#   '대',
#   '컬러',
#   '입술',
#   '입술',
#   '입술',
#   '메이크업',
#   '아이템'],
#  ['걸',
#   'BLACKPINK',
#   '전',
#   '메이크업',
#   'BLACKPINK',
#   '걸',
#   '매력',
#   '컬러',
#   '눈',
#   '블랙',
#   '화이트',
#   '제니',
#   '포인트',
#   '메이크업',
#   '메이크업',
#   '패션',
#   '화보',
#   '리사',
#   '블랙',
#   '그녀',
#   '메이크업'],
#  ['BLACKPINK', '제니'],
#  ['BLACKPINK', '제니', '매력', '룩', '그녀', '대', '스타'],
#  ['제니', '헤어', '스타일', '스타일'],
#  ['스타일',
#   '헤어',
#   '메이크업',
#   '스타일',
#   '사진',
#   '스타',
#   '사진',
#   '사진',
#   '패션',
#   '패션',
#   '사진',
#   '패션',
#   'BLACKPINK',
#   '제니',
#   '제니',
#   '전',
#   '전',
#   '스타일',
#   '전',
#   '패션',
#   '메이크업',
#   '패션',
#   '스타일',
#   '스타일',
#   '패션',
#   '패션',
#   '패션',
#   '사진',
#   '사진',
#   '사진'],
#  ['BLACKPINK',
#   '제니',
#   '제품',
#   '브랜드',
#   '블랙',
#   '화이트',
#   '컬러',
#   '통해',
#   '포인트',
#   '팬츠',
#   '매치',
#   '스타일',
#   '제니'],
#  ['팬츠', '화이트', '아이템', '연출', '제니', '니트', '포인트', '머리', '그녀'],
#  ['스타일', '생각', '그녀', '제니', '룩', '연출', '제니', '아이템', '스타일'],
#  ['제니', '모습', '톱', '톱', '컬러', '팬츠'],
#  ['톱',
#   'CHANEL',
#   '제니',
#   '그녀',
#   '그녀',
#   '그녀',
#   '스타일',
#   '제니',
#   '로제',
#   '리사',
#   '지수',
#   '얼굴',
#   '그녀',
#   '전'],
#  ['말',
#   '그녀',
#   '제니',
#   'CHANEL',
#   '아이템',
#   '재킷',
#   '그녀',
#   '화이트',
#   '팬츠',
#   '화이트',
#   '스타',
#   '일링'],
#  ['CHANEL', '제니', '그녀', '룩', '팬츠', '톱', '컬러', '재킷', '스타일', '재킷', '컬러'],
#  ['그녀', '제니', '사진', '블랙', '컬러'],
#  ['제니',
#   'BLACKPINK',
#   '제니',
#   '스타',
#   '제니',
#   '제니',
#   '제니',
#   '얼굴',
#   'CHANEL',
#   '제니',
#   '생각',
#   '제니',
#   'CHANEL',
#   '걸',
#   'CHANEL',
#   '브랜드',
#   '걸',
#   'CHANEL',
#   '스타',
#   '일링',
#   'CHANEL',
#   '걸',
#   '제니',
#   'BLACKPINK',
#   '화보',
#   '사진',
#   'BLACKPINK',
#   '사진',
#   '걸',
#   '지수',
#   '로제',
#   '리사',
#   '모습',
#   '전',
#   'BLACKPINK',
#   '스타일',
#   '스타일',
#   '스타',
#   '일링',
#   '스타일',
#   '패션',
#   'CHANEL',
#   '브랜드',
#   '모습',
#   '화보',
#   '모습',
#   'CHANEL',
#   '제니',
#   '모습',
#   'BLACKPINK',
#   '스타',
#   '일링',
#   '제니',
#   '패션',
#   '말',
#   '사진',
#   '사진',
#   '전',
#   '공개',
#   '제니',
#   '눈',
#   '공개',
#   '생각',
#   '사진',
#   '생각',
#   'BLACKPINK',
#   '제니',
#   '모습',
#   '스타일',
#   '생각',
#   '모습',
#   '모습',
#   '제니',
#   '걸',
#   '전',
#   '전',
#   '생각',
#   '통해',
#   '걸',
#   '말',
#   '제니',
#   'BLACKPINK',
#   '말',
#   '제니',
#   'CHANEL',
#   '사진',
#   '그녀',
#   '제니',
#   '눈',
#   '제니',
#   '그녀',
#   '제니',
#   '스타일',
#   '생각'],
#  [],
#  ['제니', '제니', '톱', '제니', '룩', '헤어', '스타일', '완성'],
#  ['스타',
#   'BLACKPINK',
#   '제니',
#   '포인트',
#   '분위기',
#   '제니',
#   '매력',
#   '눈',
#   '제니',
#   '패션',
#   'CHANEL',
#   '그녀',
#   'CHANEL',
#   '그녀',
#   '착용',
#   '착용',
#   '포인트',
#   '제니',
#   '제니',
#   '매력',
#   '화보'],
#  ['BLACKPINK',
#   '제니',
#   '패션',
#   '제니',
#   '매력',
#   '제니',
#   '분위기',
#   '화보',
#   '제니',
#   '스타',
#   '일링',
#   '스타일',
#   'BLACKPINK',
#   '걸',
#   '걸',
#   '모습',
#   '제니',
#   '브랜드',
#   'CHANEL',
#   '스타일',
#   '제니',
#   'BLACKPINK',
#   '통해',
#   '스타',
#   '제니',
#   '매력',
#   '화보'],
#  ['대', '제니', '머리', '매치', '패션', '연출', '룩'],
#  ['그녀', '패션', '아이템', '매치', '제니', '선택', '눈'],
#  ['제니', '제니', '스타일', '아이템', '매치', '룩', '제니', '얼굴', '대', '화이트'],
#  ['팬츠', '매치', '스타일', '제니', '제니', '룩'],
#  ['제니', '매치', '제니'],
#  ['그녀',
#   '패션',
#   '대',
#   '톱',
#   '팬츠',
#   '제니',
#   '리사',
#   '룩',
#   '매력',
#   '지수',
#   '패턴',
#   '매치',
#   '룩',
#   '완성'],
#  ['BLACKPINK',
#   '제니',
#   '제니',
#   '패션',
#   '스타',
#   '브랜드',
#   '아이템',
#   '사진',
#   '사진',
#   '아이템',
#   '패션',
#   '제니',
#   '니트',
#   '아이템'],
#  ['제니', '머리', '헤어', '머리', '머리', '스타', '일링', '헤어', '머리', '말', '스타', '일링', '제품'],
#  ['CHANEL', 'BLACKPINK', '제니', '제니', 'CHANEL', 'CHANEL', '선택', '분위기', '완성'],
#  ['눈',
#   '사진',
#   '스타',
#   '패션',
#   '패션',
#   '패션',
#   '생각',
#   '머리',
#   '모습',
#   '눈',
#   '패션',
#   '그녀',
#   '컬러',
#   '컬러',
#   '컬러',
#   '팬츠',
#   '화이트',
#   '그녀',
#   '모습',
#   '패션',
#   '눈',
#   '패션',
#   'BLACKPINK',
#   '제니',
#   '패션',
#   'CHANEL',
#   '제니',
#   '스타일',
#   '재킷',
#   '매치',
#   '스타일',
#   '스타일',
#   '스타일',
#   '스타일',
#   '스타',
#   '패션',
#   '전',
#   '스타일',
#   '말',
#   '패션',
#   '룩',
#   '브랜드',
#   '브랜드',
#   '말',
#   '패션',
#   '브랜드',
#   '말',
#   '패션',
#   '모습',
#   '스타일',
#   '패션',
#   '화보',
#   '아이템',
#   '패션',
#   '룩',
#   '브랜드',
#   '톱',
#   '브랜드',
#   '팬츠',
#   '스타일',
#   '스타일',
#   '선택',
#   '컬러',
#   '니트',
#   '아이템',
#   '선택',
#   '걸',
#   '통해',
#   '선택'],
#  ['BLACKPINK',
#   '리사',
#   '제니',
#   '룩',
#   '화이트',
#   '컬러',
#   '리사',
#   '화이트',
#   '제니',
#   '블랙',
#   '화이트',
#   '선택',
#   '블랙',
#   '룩'],
#  ['CHANEL',
#   'CHANEL',
#   'CHANEL',
#   '전',
#   '컬러',
#   '브랜드',
#   'CHANEL',
#   '아이템',
#   '제니',
#   '완성',
#   'CHANEL'],
#  ['제니', 'CHANEL'],
#  ['BLACKPINK', '제니', '니트', '블랙', '팬츠', '아이템', '스타일'],
#  ['제니', '스타', '일링', '스타'],
#  ['제니', '스타', '블랙', '컬러', '아이템', '스타', '일링', '완성', '제니', '화이트', '컬러'],
#  ['제니',
#   '리사',
#   '제니',
#   '스타',
#   '제니',
#   '패션',
#   '화이트',
#   '연출',
#   '그녀',
#   '연출',
#   '제니',
#   '스타',
#   '일링',
#   '완성'],
#  ['BLACKPINK', '걸', 'BLACKPINK', '제니', '공개', '스타일', 'CHANEL', '룩', '선택'],
#  ['제니',
#   '스타일',
#   '제니',
#   '스타일',
#   '매력',
#   '그녀',
#   '톱',
#   '스타일',
#   '완성',
#   '톱',
#   '패턴',
#   '헤어',
#   '컬러'],
#  ['CHANEL',
#   'CHANEL',
#   '룩',
#   '완성',
#   '톱',
#   '제니',
#   '스타',
#   '일링',
#   '스타',
#   '일링',
#   '레드',
#   '레드',
#   '컬러',
#   '착용',
#   '그녀',
#   '화이트',
#   '컬러',
#   '분위기',
#   '연출',
#   '패션',
#   '브랜드',
#   '착용',
#   '포인트',
#   'CHANEL',
#   '스타',
#   '일링',
#   '블랙',
#   'CHANEL',
#   '제니',
#   '걸',
#   '브랜드',
#   '매력',
#   '톱',
#   '사진',
#   '브랜드',
#   'BLACKPINK',
#   '제니'],
#  ['지수',
#   '제니',
#   '로제',
#   '화이트',
#   '리사',
#   'BLACKPINK',
#   '지수',
#   '제니',
#   '리사',
#   '매력',
#   '로제',
#   '지수',
#   '로제',
#   '리사',
#   'BLACKPINK',
#   '제니',
#   '모습',
#   '지수',
#   '제니',
#   '걸',
#   '로제',
#   '말',
#   '통해',
#   '리사',
#   '로제',
#   '제니',
#   '모습',
#   '로제',
#   '지수',
#   '걸',
#   '제니',
#   '리사',
#   '지수',
#   '리사',
#   '사진',
#   '사진',
#   '리사',
#   '지수',
#   '말',
#   '지수',
#   '완성',
#   '제니',
#   '스타',
#   '일링',
#   '화보',
#   '로제',
#   'BLACKPINK',
#   '제니',
#   '리사',
#   '로제',
#   '지수',
#   '리사',
#   '블랙',
#   '지수',
#   '포인트',
#   '블랙',
#   '톱',
#   '블랙',
#   '스타일',
#   '제니',
#   '패턴',
#   '톱',
#   '블랙',
#   '블랙',
#   '스타일',
#   '로제',
#   '톱',
#   '블랙',
#   '팬츠',
#   '블랙',
#   '스타일'],
#  ['제니',
#   '얼굴',
#   'CHANEL',
#   '제니',
#   '매력',
#   '입술',
#   '제품',
#   '니트',
#   '매력',
#   '입술',
#   '컬러',
#   '컬러',
#   '완성',
#   '제품',
#   '포인트',
#   '입술',
#   '제품',
#   '재킷',
#   '컬러',
#   '매력',
#   '입술',
#   '눈',
#   '제품',
#   '입술',
#   '레드',
#   '컬러',
#   '룩',
#   '얼굴',
#   'CHANEL',
#   '입술',
#   '컬러',
#   '제품',
#   '입술',
#   '입술',
#   '컬러',
#   '완성',
#   '입술',
#   '매력',
#   '제품',
#   '컬러',
#   '룩',
#   '레드',
#   '레드',
#   '입술',
#   '레드',
#   '제품',
#   '매력',
#   '제니',
#   '아이템',
#   '컬러',
#   '컬러',
#   '매력',
#   '연출',
#   '레드',
#   '컬러',
#   '포인트',
#   '컬러',
#   '블랙',
#   '포인트',
#   '컬러',
#   '포인트',
#   '입술',
#   '얼굴',
#   '메이크업',
#   '컬러',
#   '입술',
#   '매력',
#   '컬러',
#   '사진'],
#  ['지수',
#   '톱',
#   '리사',
#   '제니',
#   '톱',
#   '팬츠',
#   '로제',
#   '톱',
#   '제니',
#   '지수',
#   '제니',
#   '톱',
#   '리사',
#   '재킷',
#   '지수',
#   '재킷',
#   '블랙',
#   '톱',
#   '제니',
#   '재킷',
#   '블랙',
#   '톱',
#   '로제',
#   '리사',
#   '화이트',
#   '리사',
#   '화이트',
#   '팬츠',
#   '지수',
#   '재킷',
#   '블랙',
#   '톱',
#   '제니',
#   '재킷',
#   '블랙',
#   '톱',
#   '로제',
#   '블랙',
#   '리사',
#   '블랙',
#   '제니',
#   '로제',
#   '블랙',
#   'BLACKPINK',
#   '걸',
#   '매력',
#   '지수',
#   '제니',
#   '로제',
#   '리사',
#   '얼굴',
#   '그녀',
#   '분위기',
#   '매력',
#   '얼굴',
#   '제니',
#   'BLACKPINK',
#   '전',
#   '말',
#   '스타일',
#   '제니',
#   '생각',
#   '제니',
#   '패션',
#   '스타',
#   '제니',
#   '걸',
#   '제니',
#   'BLACKPINK',
#   '로제',
#   '전',
#   '로제'],
#  ['BLACKPINK',
#   '제니',
#   '패션',
#   '그녀',
#   '스타일',
#   '룩',
#   '제니',
#   '착용',
#   '톱',
#   '제품',
#   '룩',
#   '착용',
#   '제니',
#   '연출',
#   '브랜드',
#   '제품',
#   '스타일',
#   '모습',
#   '제니',
#   '화이트',
#   '레드',
#   '룩',
#   '제니',
#   '스타일',
#   '완성',
#   '헤어',
#   '스타일',
#   'CHANEL',
#   '제니',
#   '브랜드',
#   '재킷',
#   'BLACKPINK',
#   '제니',
#   '매력',
#   '제품',
#   '컬러',
#   '패션',
#   '사진',
#   'CHANEL',
#   'BLACKPINK',
#   'BLACKPINK'],
#  ['컬러', 'BLACKPINK', '제니', '컬러', '선택', '레드'],
#  ['BLACKPINK',
#   '제니',
#   '화보',
#   '제니',
#   '패션',
#   'CHANEL',
#   '화보',
#   'CHANEL',
#   'CHANEL',
#   'CHANEL',
#   '화보',
#   '제니',
#   '모습',
#   '헤어',
#   '메이크업',
#   '스타일',
#   '제니',
#   '모습',
#   '패션',
#   '기자'],
#  [],
#  ['대',
#   '패션',
#   '아이템',
#   '말',
#   '패션',
#   '대',
#   'BLACKPINK',
#   '제니',
#   '로제',
#   '사진',
#   '모습',
#   '대',
#   '스타일',
#   '패션',
#   '아이템',
#   '아이템',
#   '패션',
#   '아이템',
#   '패션',
#   '패션',
#   '사진',
#   '팬츠',
#   '매치',
#   '패션',
#   '연출',
#   '연출',
#   '아이템',
#   '매치',
#   '스타일',
#   '사진',
#   '아이템',
#   '톱',
#   '아이템',
#   '스타일',
#   '스타',
#   '패션',
#   '통해',
#   '패션',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '제니',
#   '패션',
#   'CHANEL',
#   '화보',
#   '그녀',
#   '스타',
#   '제니',
#   'CHANEL',
#   '패션',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '니트',
#   '스타일',
#   '공개',
#   '제니',
#   '브랜드',
#   '브랜드',
#   '니트',
#   '착용',
#   '모습',
#   '제니',
#   '화보',
#   '컬러',
#   '니트',
#   '화이트',
#   '포인트',
#   '스타일',
#   '연출',
#   '제품',
#   '니트',
#   '포인트',
#   '컬러',
#   '매치',
#   '니트',
#   '스타일',
#   '연출',
#   '사진',
#   '제니',
#   '착용',
#   '니트',
#   '사진',
#   '제니',
#   '착용',
#   '니트',
#   '사진',
#   '제니',
#   '착용',
#   '니트',
#   '패션',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '제니',
#   '화보',
#   '팬츠',
#   '스타',
#   '일링',
#   '매치',
#   '룩',
#   '매치',
#   '매력',
#   '룩',
#   '연출',
#   '화보',
#   '제니',
#   '모습',
#   '매력',
#   '제니',
#   'BLACKPINK',
#   '패션',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '패션',
#   'BLACKPINK',
#   '통해',
#   '제니',
#   '화이트',
#   '팬츠',
#   '매치',
#   '재킷',
#   '패션',
#   '포인트',
#   '룩',
#   '제니',
#   '패션',
#   '완성',
#   '재킷',
#   '제품',
#   '재킷',
#   '화이트',
#   '컬러',
#   '제니',
#   '팬츠',
#   '제니',
#   'BLACKPINK',
#   '사진',
#   '제니',
#   '착용',
#   '재킷',
#   '사진',
#   '제니',
#   '착용',
#   '재킷',
#   '사진',
#   '제니',
#   '착용',
#   '재킷',
#   '패션',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '패션',
#   'BLACKPINK',
#   '제니',
#   '화보',
#   '통해',
#   '제니',
#   '화이트',
#   '포인트',
#   '패션',
#   '완성',
#   '말',
#   '제니',
#   'BLACKPINK',
#   '패션',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '패션',
#   '제니',
#   '화보',
#   '통해',
#   '헤어',
#   '제니',
#   '포인트',
#   '연출',
#   '룩',
#   '완성',
#   '포인트',
#   '패션',
#   '제니',
#   'BLACKPINK',
#   '통해',
#   '패션',
#   '기자',
#   '사진',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '모습',
#   'BLACKPINK',
#   '제니',
#   '지수',
#   '리사',
#   '로제',
#   '통해',
#   '헤어',
#   '헤어',
#   '스타일',
#   '제니',
#   '니트',
#   '팬츠',
#   '패션',
#   '연출',
#   '재킷',
#   '매치',
#   '룩',
#   '매력',
#   '제니',
#   'BLACKPINK',
#   '통해',
#   '패션',
#   '기자',
#   '사진',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '패션',
#   'BLACKPINK',
#   '제니',
#   '리사',
#   '지수',
#   '로제',
#   '통해',
#   '제니',
#   '패턴',
#   '매치',
#   '팬츠',
#   '룩',
#   '패션',
#   'BLACKPINK',
#   '패션',
#   '기자',
#   '사진',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '통해',
#   '제니',
#   '패션',
#   '재킷',
#   '패션',
#   '착용',
#   '제니',
#   '착용',
#   '완성',
#   '포인트',
#   '매치',
#   '패션',
#   '제니',
#   'BLACKPINK',
#   '패션',
#   '기자',
#   '사진',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '통해',
#   '제니',
#   '화이트',
#   '블랙',
#   '팬츠',
#   '매치',
#   '연출',
#   '화이트',
#   '매치',
#   '패션',
#   '제니',
#   'BLACKPINK',
#   '패션',
#   '기자',
#   '사진',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '패션',
#   '제니',
#   '통해',
#   '제니',
#   '화이트',
#   '착용',
#   '룩',
#   '블랙',
#   '룩',
#   '블랙',
#   '화이트',
#   '완성',
#   '제니',
#   'BLACKPINK',
#   '패션',
#   '기자',
#   '사진',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '모습',
#   '제니',
#   'CHANEL',
#   '제니',
#   '팬츠',
#   '매치',
#   '룩',
#   '연출',
#   '컬러',
#   '매력',
#   '패션',
#   '제니',
#   'BLACKPINK',
#   '사진',
#   'CHANEL',
#   'CHANEL',
#   '패션',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '레드',
#   '블랙',
#   'CHANEL',
#   '제니',
#   '아이템',
#   '니트',
#   '니트',
#   '레드',
#   '팬츠',
#   '매치',
#   '블랙',
#   '패션',
#   '스타',
#   'BLACKPINK',
#   '패션',
#   '기자',
#   '사진',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '분위기',
#   '사진',
#   '분위기',
#   '제니',
#   '사진',
#   '제니',
#   '블랙',
#   '팬츠',
#   '착용',
#   '사진',
#   '제니',
#   '사진',
#   '제니',
#   '착용',
#   '제품',
#   '컬러',
#   '패턴',
#   '연출',
#   '제니',
#   '팬츠',
#   '룩',
#   '완성',
#   '제니',
#   'BLACKPINK',
#   '사진',
#   '제니',
#   '착용',
#   '사진',
#   '제니',
#   '착용',
#   '사진',
#   '제니',
#   '착용',
#   '패션',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   'BLACKPINK',
#   '통해',
#   '제니',
#   '모습',
#   '화이트',
#   '매치',
#   '화이트',
#   '재킷',
#   '패션',
#   '완성',
#   '포인트',
#   'BLACKPINK',
#   '패션',
#   '기자',
#   '사진',
#   '기자'],
#  ['BLACKPINK', '제니', '리사', '로제', '통해'],
#  ['BLACKPINK',
#   '제니',
#   '제니',
#   '사진',
#   '사진',
#   '제니',
#   '팬츠',
#   '니트',
#   '완성',
#   '제니',
#   '착용',
#   '제품',
#   '착용',
#   '연출',
#   '포인트',
#   '제니',
#   '연출',
#   '매치',
#   '아이템',
#   'BLACKPINK',
#   '사진',
#   '제니',
#   '사진',
#   '제니',
#   '사진',
#   '제니',
#   '착용',
#   '사진',
#   '제니',
#   '착용',
#   '사진',
#   '제니',
#   '착용',
#   '패션',
#   '기자'],
#  ['BLACKPINK',
#   '통해',
#   '로제',
#   '제니',
#   '팬츠',
#   '룩',
#   '연출',
#   '제니',
#   '화이트',
#   '컬러',
#   '팬츠',
#   '매치',
#   '컬러',
#   '룩',
#   '완성',
#   '로제',
#   '컬러',
#   '팬츠',
#   '매치',
#   '블랙',
#   '패션',
#   'BLACKPINK',
#   '패션',
#   '기자',
#   '사진',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   'BLACKPINK',
#   '제니',
#   'BLACKPINK',
#   '통해',
#   '제니',
#   '블랙',
#   '니트',
#   '매치',
#   '걸',
#   '연출',
#   '매치',
#   '패션',
#   '완성',
#   'BLACKPINK',
#   '패션',
#   '기자',
#   '사진',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '패션',
#   '패션',
#   'BLACKPINK',
#   '지수',
#   '제니',
#   '로제',
#   '리사',
#   '통해',
#   '제니',
#   '팬츠',
#   '화이트',
#   '매치',
#   '재킷',
#   '매치',
#   '화이트',
#   '패션',
#   '완성',
#   'BLACKPINK',
#   'BLACKPINK',
#   '패션',
#   '기자',
#   '사진',
#   '기자'],
#  ['BLACKPINK',
#   '지수',
#   '제니',
#   '로제',
#   '리사',
#   '제니',
#   '통해',
#   '패션',
#   '제니',
#   '팬츠',
#   '매치',
#   '스타',
#   '일링',
#   '제니',
#   '착용',
#   '팬츠',
#   '제품',
#   '아이템',
#   '포인트',
#   'BLACKPINK',
#   'BLACKPINK',
#   '사진',
#   '제니',
#   '착용',
#   '팬츠',
#   '사진',
#   '제니',
#   '착용',
#   '팬츠',
#   '사진',
#   '제니',
#   '착용',
#   '팬츠',
#   '패션',
#   '기자',
#   '사진',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '모습',
#   'BLACKPINK',
#   '통해',
#   '제니',
#   '화이트',
#   '팬츠',
#   '패션',
#   'BLACKPINK',
#   'BLACKPINK',
#   '패션',
#   '기자',
#   '사진',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '패션',
#   '제니',
#   '착용',
#   '제니',
#   '착용',
#   '제품',
#   '레드',
#   '컬러',
#   '화이트',
#   '연출',
#   '블랙',
#   '화이트',
#   '룩',
#   '연출',
#   '컬러',
#   '포인트',
#   '아이템',
#   '제니',
#   '공개',
#   '사진',
#   '제니',
#   '착용',
#   '사진',
#   '제니',
#   '착용',
#   '사진',
#   '제니',
#   '착용',
#   '패션',
#   '기자'],
#  ['제니',
#   'BLACKPINK',
#   '완성',
#   'CHANEL',
#   '모습',
#   '제니',
#   '패션',
#   '화보',
#   'CHANEL',
#   'CHANEL',
#   '모습',
#   '연출',
#   '통해',
#   'CHANEL',
#   'CHANEL',
#   '브랜드',
#   '생각',
#   '제니',
#   'BLACKPINK',
#   '완성',
#   '패션',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   'CHANEL',
#   'CHANEL',
#   '눈',
#   'CHANEL',
#   'BLACKPINK',
#   '제니',
#   'CHANEL',
#   '룩',
#   'CHANEL',
#   '패션',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '매력',
#   '제니',
#   '통해',
#   '제니',
#   '화이트',
#   '블랙',
#   '매치',
#   '화이트',
#   '매치',
#   '완성',
#   'BLACKPINK',
#   '패션',
#   '기자',
#   '사진',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '통해',
#   '제니',
#   '패션',
#   '블랙',
#   '팬츠',
#   '연출',
#   '블랙',
#   '재킷',
#   '매치',
#   '걸',
#   '완성',
#   '포인트',
#   '매치',
#   '패션',
#   '연출',
#   '매치',
#   '포인트',
#   '컬러',
#   '제니',
#   'BLACKPINK'],
#  ['BLACKPINK',
#   '제니',
#   '제니',
#   '통해',
#   '제니',
#   '패션',
#   '팬츠',
#   '블랙',
#   '재킷',
#   '매치',
#   '블랙',
#   '블랙',
#   '제니',
#   'BLACKPINK',
#   '패션',
#   '기자',
#   '사진',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '패션',
#   '제니',
#   '통해',
#   '제니',
#   '룩',
#   '화이트',
#   '니트',
#   '블랙',
#   '블랙',
#   '분위기',
#   '제니',
#   'BLACKPINK',
#   '패션',
#   '기자',
#   '사진',
#   '기자'],
#  ['BLACKPINK', '지수', '제니', '로제', '리사', '통해', 'BLACKPINK'],
#  ['BLACKPINK',
#   '제니',
#   '통해',
#   '제니',
#   '패션',
#   '패턴',
#   '팬츠',
#   '매치',
#   '제니',
#   '화이트',
#   '포인트',
#   '완성',
#   '제니',
#   '공개',
#   '패션',
#   '기자',
#   '사진',
#   '기자'],
#  ['BLACKPINK', '제니', '블랙', '화이트', '재킷', '매치', '매력'],
#  ['BLACKPINK',
#   '제니',
#   '매력',
#   '제니',
#   'BLACKPINK',
#   '통해',
#   '제니',
#   '패션',
#   '블랙',
#   '제니',
#   '화이트',
#   '재킷',
#   '블랙',
#   '착용',
#   '분위기',
#   '제니',
#   '공개',
#   '패션',
#   '기자',
#   '사진',
#   '기자'],
#  ['BLACKPINK',
#   '지수',
#   '제니',
#   '로제',
#   '리사',
#   '제니',
#   'BLACKPINK',
#   '통해',
#   '제니',
#   '매치',
#   '패션',
#   'BLACKPINK',
#   'BLACKPINK',
#   '패션',
#   '기자',
#   '사진',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '리사',
#   '걸',
#   '매력',
#   '대',
#   'BLACKPINK',
#   '제니',
#   '리사',
#   '화보',
#   '공개',
#   '룩',
#   '제니',
#   '팬츠',
#   '매치',
#   '포인트',
#   '헤어',
#   '연출',
#   '리사',
#   '레드',
#   '컬러',
#   '팬츠',
#   '화이트',
#   '컬러',
#   '포인트',
#   '착용',
#   '통해',
#   '사진',
#   '패션',
#   '기자'],
#  ['CHANEL',
#   'CHANEL',
#   'BLACKPINK',
#   '제니',
#   '제니',
#   '패션',
#   'CHANEL',
#   '블랙',
#   '재킷',
#   '화이트',
#   '팬츠',
#   '매치',
#   '블랙',
#   '화이트',
#   '패션',
#   '매치',
#   '블랙',
#   '룩',
#   '포인트',
#   '매치',
#   '블랙',
#   '화이트',
#   '룩',
#   '패턴',
#   '팬츠',
#   '톱',
#   'CHANEL',
#   '패턴',
#   'CHANEL',
#   '패션',
#   '기자',
#   '사진',
#   '기자'],
#  ['BLACKPINK',
#   '스타일',
#   '브랜드',
#   'BLACKPINK',
#   '지수',
#   '제니',
#   '리사',
#   '로제',
#   '화보',
#   '공개',
#   '화보',
#   '화이트',
#   '컬러',
#   '화이트',
#   '완성',
#   '아이템',
#   '매력',
#   '스타',
#   '일링',
#   '스타',
#   '일링',
#   '지수',
#   '제니',
#   '로제',
#   '컬러',
#   '패션',
#   '리사',
#   '재킷',
#   'BLACKPINK',
#   '사진',
#   '패션',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   'CHANEL',
#   'CHANEL',
#   '제니',
#   'CHANEL',
#   '레드',
#   '제니',
#   '걸',
#   '제니',
#   '블랙',
#   '블랙',
#   '레드',
#   '재킷',
#   '매치',
#   '패션',
#   '블랙',
#   '착용',
#   'CHANEL',
#   '레드',
#   '매력',
#   '제니',
#   'BLACKPINK',
#   '사진',
#   'CHANEL',
#   '패션',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '제니',
#   'CHANEL',
#   '제니',
#   '팬츠',
#   '착용',
#   '분위기',
#   '패션',
#   '매력',
#   '매치',
#   '스타',
#   '일링',
#   '패션',
#   'CHANEL',
#   '전',
#   '패션',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '통해',
#   '걸',
#   '매력',
#   '제니',
#   '재킷',
#   '블랙',
#   '스타일',
#   '재킷',
#   '블랙',
#   '매치',
#   '매력',
#   '블랙',
#   '스타',
#   '일링',
#   '화이트',
#   '스타',
#   '일링',
#   '포인트',
#   '매치',
#   '패션',
#   '패션',
#   '기자',
#   '기자'],
#  ['BLACKPINK',
#   '모습',
#   'BLACKPINK',
#   '화보',
#   '공개',
#   '공개',
#   '화보',
#   '컬러',
#   '제니',
#   '스타일',
#   '매치',
#   '룩',
#   '로제',
#   '팬츠',
#   '지수',
#   '분위기',
#   '사진',
#   '패션',
#   '기자'],
#  ['CHANEL',
#   'CHANEL',
#   'CHANEL',
#   '모습',
#   'CHANEL',
#   '제품',
#   '아이템',
#   'CHANEL',
#   '제니',
#   '스타',
#   '일링',
#   '사진',
#   'CHANEL',
#   '제니',
#   '사진',
#   'CHANEL',
#   '사진',
#   'CHANEL',
#   '사진',
#   'CHANEL',
#   '사진',
#   'CHANEL',
#   '사진',
#   'CHANEL',
#   '사진',
#   'CHANEL',
#   '사진',
#   'CHANEL',
#   '사진',
#   'CHANEL',
#   '사진',
#   'CHANEL',
#   '사진',
#   'CHANEL',
#   '사진',
#   'CHANEL',
#   '패션',
#   '기자'],
#  ['BLACKPINK',
#   '제니',
#   '브랜드',
#   'CHANEL',
#   '제니',
#   '통해',
#   '제니',
#   '화이트',
#   '팬츠',
#   '매치',
#   '스타',
#   '일링',
#   '완성',
#   '제니',
#   '분위기',
#   '화이트',
#   '착용',
#   '스타일',
#   '지수',
#   '제니',
#   'BLACKPINK',
#   '사진',
#   'CHANEL',
#   '패션',
#   '기자'],
#  ['BLACKPINK',
#   '매력',
#   '스타',
#   '스타일',
#   '브랜드',
#   'BLACKPINK',
#   '화보',
#   '공개',
#   'BLACKPINK',
#   '얼굴',
#   '전',
#   'BLACKPINK',
#   '지수',
#   '제니',
#   '리사',
#   '얼굴',
#   '제니',
#   '통해',
#   '레드',
#   '로제',
#   '매력',
#   'BLACKPINK',
#   '걸',
#   '전',
#   'BLACKPINK',
#   '사진',
#   '패션',
#   '기자'],
#  ['브랜드',
#   'BLACKPINK',
#   '화보',
#   '공개',
#   '공개',
#   '화보',
#   'BLACKPINK',
#   '스타',
#   '일링',
#   '매력',
#   '팬츠',
#   '스타일',
#   '리사',
#   '제니',
#   '매력',
#   '로제',
#   '지수',
#   '연출',
#   'BLACKPINK',
#   '매력',
#   '팬츠',
#   '화보',
#   '스타',
#   '일링',
#   '화보',
#   'BLACKPINK',
#   '매력',
#   '스타일',
#   '포인트',
#   '전',
#   '사진',
#   '패션',
#   '기자'],
#  ['스타',
#   '일링',
#   '룩',
#   '아이템',
#   '스타',
#   '일링',
#   '완성',
#   'BLACKPINK',
#   '지수',
#   '제니',
#   '브랜드',
#   '스타',
#   '일링',
#   '분위기',
#   '니트',
#   '포인트',
#   '아이템',
#   '포인트',
#   '아이템',
#   '화보',
#   'BLACKPINK',
#   '지수',
#   '화이트',
#   '컬러',
#   '니트',
#   '매치',
#   '블랙',
#   '컬러',
#   '컬러',
#   '포인트',
#   '포인트',
#   '컬러',
#   '룩',
#   '완성',
#   '사진',
#   '선택',
#   '화보',
#   'BLACKPINK',
#   '제니',
#   '컬러',
#   '매치',
#   '룩',
#   '연출',
#   '컬러',
#   '포인트',
#   '분위기',
#   '사진',
#   '패션',
#   '기자'],
#  ['BLACKPINK',
#   '공개',
#   'BLACKPINK',
#   '컬러',
#   '통해',
#   'BLACKPINK',
#   '지수',
#   '제니',
#   '로제',
#   '리사',
#   '팬츠',
#   '룩',
#   '매치',
#   '그녀',
#   'BLACKPINK',
#   '통해',
#   '사진',
#   '패션'],
#  ['브랜드',
#   '컬러',
#   '스타',
#   '일링',
#   '사진',
#   '화보',
#   '분위기',
#   '스타',
#   '일링',
#   '연출',
#   '매치',
#   '분위기',
#   '스타',
#   '일링',
#   '화보',
#   '제니',
#   '매치',
#   '컬러',
#   '매치',
#   '매력',
#   '컬러',
#   '포인트',
#   '컬러',
#   '사진',
#   '화보',
#   '스타일',
#   '연출',
#   '눈',
#   '컬러',
#   '컬러',
#   '컬러',
#   '매치',
#   '포인트',
#   '컬러',
#   '컬러',
#   '연출',
#   '컬러',
#   '포인트',
#   '스타',
#   '일링',
#   '연출',
#   '화보',
#   '지수',
#   '패션',
#   '컬러',
#   '재킷',
#   '스타',
#   '일링',
#   '완성',
#   '패션'],
#  ['BLACKPINK',
#   '패션',
#   '화보',
#   '통해',
#   '걸',
#   '매력',
#   'BLACKPINK',
#   '브랜드',
#   '화보',
#   '분위기',
#   '연출',
#   '로제',
#   '제니',
#   '화보',
#   '통해',
#   '룩',
#   '연출',
#   '스타',
#   '일링',
#   '포인트',
#   '선택',
#   '패션',
#   '리사',
#   '지수',
#   '룩',
#   '재킷',
#   '패션',
#   'BLACKPINK',
#   '스타일',
#   'BLACKPINK',
#   '화보',
#   '전',
#   '사진',
#   '패션',
#   '기자'],
#  ['브랜드',
#   '제니',
#   '공개',
#   '패션',
#   '제니',
#   '스타일',
#   '전',
#   '분위기',
#   '제니',
#   '제니',
#   '통해',
#   '제니',
#   '제니',
#   '사진',
#   '패션',
#   '기자'],
#  ['패션',
#   '브랜드',
#   'BLACKPINK',
#   '패션',
#   'BLACKPINK',
#   '브랜드',
#   'BLACKPINK',
#   '지수',
#   '제니',
#   '로제',
#   '리사',
#   '브랜드',
#   'BLACKPINK',
#   '매력',
#   'BLACKPINK',
#   '사진',
#   '패션',
#   '기자'],
#  ['블랙', '제니', '제품', '사진', '블랙', '스타', '선택'],
#  ['컬러', '아이템', '룩', '완성', '제니', '제니', '룩', '제품'],
#  ['제니', '아이템'],
#  ['제니'],
#  ['헤어',
#   '스타',
#   '선택',
#   '헤어',
#   '스타',
#   '헤어',
#   '스타일',
#   '스타',
#   '헤어',
#   '말',
#   '컬러',
#   '컬러',
#   '앞머리',
#   '헤어',
#   '앞머리',
#   '머리',
#   '포인트',
#   '헤어',
#   '스타',
#   '일링',
#   '스타일',
#   '제니',
#   'BLACKPINK',
#   '앞머리',
#   '제니',
#   '스타일',
#   '사진',
#   '헤어',
#   '제니',
#   '선택',
#   '포인트',
#   '컬러',
#   '컬러',
#   '헤어',
#   '헤어',
#   '메이크업',
#   '컬러',
#   '머리',
#   '포인트',
#   '스타',
#   '스타일',
#   '말',
#   '앞머리',
#   '컬러',
#   '헤어',
#   '컬러',
#   '머리',
#   '포인트',
#   '스타일',
#   '완성',
#   '헤어',
#   '말',
#   '스타일',
#   '분위기',
#   '전',
#   '헤어',
#   '헤어',
#   '스타',
#   '일링',
#   '분위기',
#   '헤어',
#   '스타',
#   '일링',
#   '전',
#   '걸',
#   '선택',
#   '스타일',
#   '헤어',
#   '화이트',
#   '분위기',
#   '완성',
#   '헤어',
#   '스타일',
#   '헤어',
#   '전',
#   '헤어',
#   '분위기',
#   '스타일',
#   '말'],
#  ['제니', '착용', '스타', '일링', '제니', '포인트'],
#  ['머리', 'BLACKPINK', '제니', '앞머리', '앞머리', '머리', '머리', '헤어', '스타', '일링'],
#  ['제니', '대', '패션', '패턴', '헤어', '머리', '머리', '머리'],
#  ['제니', '연출', '스타', '일링', '머리'],
#  [],
#  [],
#  [],
#  ['대', '매력', '컬러', '컬러', '매치', 'BLACKPINK', '제니', '리사', '대', '룩', '완성'],
#  ['제니'],
#  ['CHANEL', '제니'],
#  ['스타', '일링', '아이템', '블랙', '제니'],
#  ['브랜드', '스타', '포인트', 'BLACKPINK', '제니', 'CHANEL', '모습'],
#  [],
#  [],
#  ['컬러',
#   '레드',
#   '레드',
#   '매력',
#   '컬러',
#   '컬러',
#   '룩',
#   '연출',
#   '레드',
#   '연출',
#   '레드',
#   '얼굴',
#   '레드',
#   '입술',
#   '컬러'],
#  ['메이크업', '얼굴', '앞머리', '연출', '메이크업', '메이크업', '제니'],
#  ['BLACKPINK', '제니', '스타', '일링'],
#  ['지수',
#   '제니',
#   '제니',
#   'BLACKPINK',
#   '제니',
#   '로제',
#   '로제',
#   '리사',
#   '리사',
#   '지수',
#   '리사',
#   '리사',
#   '지수',
#   '지수',
#   '제니',
#   '지수',
#   '제니',
#   '지수',
#   '제니',
#   '말',
#   '모습',
#   '리사',
#   '말',
#   '모습',
#   '로제',
#   '모습',
#   '모습',
#   '제니',
#   '걸',
#   'BLACKPINK',
#   '제니',
#   '지수',
#   '생각',
#   '걸',
#   'BLACKPINK',
#   '제니',
#   '생각',
#   '생각',
#   '걸',
#   '생각',
#   '지수',
#   '생각',
#   '제니',
#   '제니',
#   '걸',
#   '생각',
#   '지수',
#   '생각',
#   '말',
#   '모습',
#   '생각',
#   '로제',
#   '생각',
#   '제니',
#   '말',
#   '로제',
#   '리사',
#   '말',
#   '모습',
#   '말',
#   'BLACKPINK',
#   '말',
#   '제니',
#   '모습',
#   'BLACKPINK',
#   '말',
#   '걸',
#   '지수',
#   '제니',
#   '말',
#   '모습',
#   '포인트',
#   '생각',
#   'BLACKPINK',
#   '생각',
#   '제니',
#   '말',
#   '공개',
#   '모습',
#   '걸',
#   '말',
#   '제니',
#   'BLACKPINK',
#   'BLACKPINK'],
#  ['제니', '연출'],
#  ['BLACKPINK', '리사', '제니', '레드'],
#  ['전', '제니', '블랙', '그녀', '리사', '지수', '얼굴', '로제', '그녀', '모습'],
#  ['BLACKPINK',
#   '제니',
#   '포인트',
#   '패턴',
#   '선택',
#   '패턴',
#   '패턴',
#   '톱',
#   '패턴',
#   '컬러',
#   '선택',
#   '컬러',
#   '선택',
#   '제니',
#   '컬러',
#   '블랙',
#   '컬러',
#   '룩'],
#  ['BLACKPINK', '제니', '패션', '아이템', 'BLACKPINK', '제니', '팬츠', '브랜드'],
#  ['제니'],
#  ['BLACKPINK',
#   '제니',
#   'BLACKPINK',
#   '제니',
#   '팬츠',
#   '대',
#   '걸',
#   '브랜드',
#   '톱',
#   '연출',
#   '스타',
#   '일링'],
#  ['제니', '스타일', '완성', '그녀', '대', '패션', '스타일', '컬러', '헤어', '패션'],
#  ['제니',
#   '브랜드',
#   '대',
#   '아이템',
#   '브랜드',
#   '브랜드',
#   '헤어',
#   '분위기',
#   'BLACKPINK',
#   '로제',
#   '제니',
#   '룩',
#   '연출',
#   '브랜드',
#   '아이템',
#   '아이템',
#   '컬러',
#   '대',
#   '스타일',
#   '패션',
#   '브랜드',
#   '아이템',
#   '컬러',
#   '톱',
#   '스타일',
#   '아이템',
#   '대',
#   '패션',
#   '매력'],
#  ['BLACKPINK',
#   '제니',
#   '통해',
#   '룩',
#   '공개',
#   '제니',
#   '스타',
#   '일링',
#   '제니',
#   '대',
#   '아이템',
#   '스타',
#   '아이템',
#   '제니',
#   '선택',
#   '레드',
#   '컬러',
#   '재킷',
#   '패션',
#   '대',
#   '스타일',
#   '스타일',
#   '대',
#   '패션',
#   '그녀',
#   '말',
#   '패션',
#   '컬러',
#   '컬러',
#   '컬러',
#   '화이트',
#   '룩',
#   '매치',
#   '스타',
#   '일링',
#   '포인트',
#   '대',
#   '스타일',
#   '연출',
#   '아이템',
#   '블랙',
#   '니트',
#   '재킷',
#   '아이템',
#   '스타일',
#   '패션',
#   '포인트',
#   '패턴',
#   '컬러',
#   '완성',
#   '아이템'],
#  ['제니',
#   '그녀',
#   '제니',
#   '제니',
#   'BLACKPINK',
#   '화보',
#   '제니',
#   '제니',
#   '걸',
#   '사진',
#   '모습',
#   '제니',
#   '통해',
#   '모습',
#   '제니',
#   'BLACKPINK',
#   '화보',
#   'CHANEL',
#   'CHANEL',
#   'CHANEL',
#   '그녀',
#   '제니',
#   'CHANEL',
#   '브랜드',
#   '브랜드',
#   '제니',
#   '그녀',
#   'CHANEL',
#   '제니',
#   '생각',
#   'CHANEL',
#   'CHANEL',
#   '패션',
#   '제니',
#   '전',
#   'CHANEL',
#   '제니',
#   '말',
#   '말',
#   '전',
#   '패션',
#   '브랜드',
#   '제니',
#   '패션',
#   '생각',
#   '패션',
#   '브랜드',
#   '모습',
#   '브랜드',
#   '모습',
#   '사진',
#   '제니',
#   '그녀',
#   '말',
#   '눈',
#   '제니',
#   '제니',
#   '제니',
#   '제니',
#   '제니',
#   '모습',
#   '제니',
#   '말',
#   '제니',
#   '통해',
#   '제니',
#   '제니',
#   '통해',
#   '제니',
#   '제니',
#   '제니',
#   '제니',
#   '생각',
#   '제니',
#   '제니',
#   'BLACKPINK'],
#  ['제니',
#   '스타',
#   'BLACKPINK',
#   '제니',
#   'CHANEL',
#   '제니',
#   '스타일',
#   '머리',
#   '제니',
#   '제니',
#   '제니',
#   '스타일',
#   '생각',
#   '그녀'],
#  ['BLACKPINK', '제니', '리사', '레드', 'BLACKPINK', '지수', '레드'],
#  ['제니',
#   '머리',
#   'BLACKPINK',
#   '제니',
#   '헤어',
#   '스타',
#   '머리',
#   '모습',
#   '스타일',
#   '제니',
#   '스타일',
#   '스타일',
#   '스타',
#   '일링',
#   '제니',
#   '선택'],
#  ['제니',
#   '제니',
#   'CHANEL',
#   '그녀',
#   'CHANEL',
#   '재킷',
#   '니트',
#   '재킷',
#   'CHANEL',
#   '톱',
#   'CHANEL',
#   '팬츠',
#   '톱',
#   'BLACKPINK',
#   '제니',
#   '팬츠',
#   '톱'],
#  ['제니', '눈', '앞머리', '포인트'],
#  ['BLACKPINK', '제니', '스타', '모습'],
#  ['제니', '메이크업', '메이크업'],
#  ['제니', '머리', '머리', '스타일'],
#  ['제니', '패턴', '톱', '연출'],
#  ['제니', '로제', '리사', '지수', '모습', '그녀', '사진'],
#  ['스타',
#   '스타',
#   'CHANEL',
#   'BLACKPINK',
#   '제니',
#   '리사',
#   '지수',
#   '로제',
#   '브랜드',
#   '패션',
#   '스타'],
#  ['제니', '패턴', '연출', 'CHANEL', '룩', '제니', '매치', '모습'],
#  ['분위기',
#   'BLACKPINK',
#   '제니',
#   '제니',
#   '통해',
#   '모습',
#   '모습',
#   '모습',
#   '공개',
#   '모습',
#   '룩',
#   '사진',
#   '제니',
#   '메이크업',
#   '제니',
#   '공개',
#   '제니',
#   '말',
#   '사진',
#   '제니',
#   '그녀',
#   '공개',
#   '제니'],
#  ['제니',
#   '제니',
#   '메이크업',
#   '메이크업',
#   '그녀',
#   '메이크업',
#   '매력',
#   '메이크업',
#   '완성',
#   '블랙',
#   '컬러',
#   '완성',
#   '제니',
#   '제니',
#   '눈',
#   '블랙',
#   '포인트',
#   '메이크업'],
#  ['제니', '제니'],
#  ['제니', '얼굴', '얼굴', '얼굴'],
#  ['제니', '그녀', '사진', '화보', 'CHANEL', '제니', '매력'],
#  ['BLACKPINK',
#   '제니',
#   '화보',
#   '사진',
#   '공개',
#   '제니',
#   '통해',
#   '공개',
#   '사진',
#   '사진',
#   '제니',
#   '사진',
#   '제니',
#   '제니',
#   '머리',
#   '스타일',
#   '제니',
#   '스타일',
#   'BLACKPINK'],
#  ['레드', 'BLACKPINK', '제니', '모습', '제니', '제니', '포인트', '연출'],
#  ['제니', '전'],
#  ['CHANEL', '제니'],
#  ['입술', '연출', '제니'],
#  ['걸', 'BLACKPINK', '지수', '제니'],
#  ['BLACKPINK', '제니'],
#  ['BLACKPINK', '제니'],
#  ['BLACKPINK',
#   '생각',
#   'BLACKPINK',
#   '걸',
#   '리사',
#   '지수',
#   '제니',
#   '제니',
#   '지수',
#   'BLACKPINK',
#   '생각',
#   '지수',
#   '화보',
#   '생각',
#   '생각',
#   '로제',
#   '생각',
#   '로제',
#   '제니',
#   '제니',
#   '사진',
#   '리사',
#   '사진',
#   '제니',
#   '제니',
#   '패션',
#   '패션',
#   '브랜드',
#   '제니',
#   '통해',
#   '패션',
#   '패션',
#   '스타일',
#   'BLACKPINK',
#   '제니',
#   '제니',
#   '패션',
#   '스타일',
#   '전',
#   'CHANEL',
#   '재킷',
#   '제니',
#   '지수',
#   '제니',
#   '로제',
#   '리사',
#   'BLACKPINK',
#   '걸',
#   'BLACKPINK',
#   '생각',
#   '모습',
#   '지수'],
#  ['BLACKPINK', 'BLACKPINK', '사진', 'BLACKPINK', '제니', '사진', '블랙'],
#  ['BLACKPINK', '제니', '분위기'],
#  ['전', 'BLACKPINK', '제니', '컬러'],
#  ['제니',
#   '제니',
#   'CHANEL',
#   '제니',
#   '제니',
#   '제니',
#   'BLACKPINK',
#   'BLACKPINK',
#   'BLACKPINK',
#   'BLACKPINK',
#   '제니',
#   '얼굴',
#   '입술',
#   '생각',
#   '눈',
#   '모습',
#   '제니',
#   '통해',
#   '통해',
#   '모습',
#   '공개',
#   '전',
#   'BLACKPINK',
#   '모습',
#   '모습',
#   '걸',
#   '화보',
#   '모습',
#   '화보',
#   '제니',
#   'CHANEL',
#   '아이템',
#   '룩',
#   '착용',
#   '스타',
#   '일링',
#   '스타일',
#   '포인트',
#   '스타일',
#   '착용',
#   '패션',
#   '스타일',
#   '매치',
#   '스타',
#   '일링',
#   '브랜드',
#   'CHANEL',
#   '통해',
#   '패션',
#   '말',
#   '모습',
#   '아이템',
#   '모습',
#   'BLACKPINK',
#   '모습',
#   '생각',
#   '제니',
#   '생각',
#   '모습'],
#  ['헤어',
#   '스타일',
#   'BLACKPINK',
#   '제니',
#   '앞머리',
#   '스타',
#   '일링',
#   '앞머리',
#   '포인트',
#   '연출',
#   '헤어',
#   '스타',
#   '앞머리',
#   '스타일',
#   'BLACKPINK',
#   '제니',
#   'BLACKPINK',
#   '제니',
#   '앞머리',
#   '스타일',
#   '공개',
#   '공개',
#   '그녀',
#   '헤어',
#   '모습',
#   '사진',
#   '블랙',
#   '컬러',
#   '완성',
#   '스타일',
#   '연출',
#   '앞머리',
#   '컬러',
#   '스타',
#   '일링',
#   '헤어',
#   '스타',
#   '일링',
#   '헤어',
#   '헤어',
#   '선택',
#   '스타일',
#   '그녀',
#   '메이크업',
#   '스타일',
#   '그녀',
#   '앞머리',
#   '컬러',
#   '헤어',
#   '얼굴',
#   '머리',
#   '스타일'],
#  ['헤어',
#   '스타',
#   '일링',
#   '대',
#   '머리',
#   '헤어',
#   '헤어',
#   '스타',
#   '일링',
#   '헤어',
#   '스타일',
#   '연출',
#   '스타',
#   '일링',
#   '대',
#   '아이템',
#   '룩',
#   '매치',
#   '머리',
#   '헤어',
#   '연출',
#   '룩',
#   '포인트',
#   '생각',
#   '스타',
#   '룩',
#   '헤어',
#   '아이템',
#   '헤어',
#   '머리',
#   '분위기',
#   'BLACKPINK',
#   '제니',
#   '블랙',
#   '레드',
#   '눈',
#   '컬러',
#   '패턴',
#   '걸',
#   '룩',
#   '매치',
#   '레드',
#   '헤어',
#   '연출',
#   '대',
#   '헤어',
#   '컬러',
#   '연출',
#   '헤어',
#   '헤어',
#   '스타일',
#   '레드',
#   '스타일',
#   '연출',
#   '모습',
#   '포인트',
#   '룩',
#   '눈',
#   '그녀',
#   '스타',
#   '일링',
#   '모습',
#   '그녀',
#   '스타일',
#   '매치',
#   '머리',
#   '머리',
#   '그녀',
#   '모습',
#   '컬러',
#   '매치',
#   '헤어',
#   '머리',
#   '머리',
#   '포인트',
#   '레드',
#   '레드',
#   '머리',
#   '헤어',
#   '헤어',
#   '분위기',
#   '아이템',
#   '룩',
#   '레드',
#   'BLACKPINK',
#   '제니',
#   '레드',
#   '블랙',
#   '컬러',
#   '머리',
#   '헤어',
#   '대',
#   '아이템',
#   '연출',
#   '헤어',
#   '스타일',
#   '연출',
#   '연출',
#   '매력',
#   '스타',
#   '일링',
#   '머리',
#   '연출',
#   '헤어',
#   '룩',
#   'BLACKPINK',
#   '제니',
#   '연출',
#   '머리',
#   '레드',
#   '포인트'],
#  ['대',
#   '제니',
#   '제니',
#   '그녀',
#   '스타',
#   '일링',
#   '재킷',
#   '제니',
#   '아이템',
#   '완성',
#   '스타',
#   '일링',
#   '헤어',
#   '제니',
#   '완성',
#   '재킷',
#   '브랜드',
#   '제품',
#   '대',
#   '제니',
#   '매치',
#   '헤어',
#   '스타',
#   '일링',
#   '대',
#   '스타일',
#   '연출',
#   '그녀',
#   '컬러',
#   '스타',
#   '일링',
#   '제니',
#   '착용',
#   '제품',
#   '연출',
#   'CHANEL',
#   '제품'],
#  ['패션',
#   '톱',
#   '스타일',
#   '패션',
#   '스타일',
#   '패션',
#   '전',
#   'BLACKPINK',
#   '제니',
#   '패션',
#   '스타일',
#   '제니',
#   '재킷',
#   '선택',
#   '재킷',
#   '스타일',
#   '착용',
#   '스타일',
#   '톱',
#   '스타일',
#   '포인트',
#   '완성',
#   '톱',
#   '착용',
#   '모습',
#   '톱',
#   '매치',
#   '패턴',
#   '패션',
#   '완성',
#   '니트',
#   '팬츠',
#   '룩',
#   '매치',
#   '룩',
#   '완성'],
#  ['대',
#   '톱',
#   '그녀',
#   '대',
#   '스타일',
#   'BLACKPINK',
#   '제니',
#   '제니',
#   '톱',
#   'CHANEL',
#   '대',
#   '브랜드',
#   '대',
#   '매치',
#   '제품',
#   '제품',
#   '말',
#   '제품'],
#  ['레드',
#   '메이크업',
#   '제니',
#   '제니',
#   '얼굴',
#   '스타',
#   '입술',
#   '컬러',
#   '입술',
#   '완성',
#   '제품',
#   '제니',
#   '룩',
#   '룩',
#   '입술',
#   '제품',
#   '블랙',
#   '입술',
#   '컬러',
#   '레드',
#   '컬러',
#   '제품',
#   '연출',
#   '포인트',
#   '입술',
#   '입술',
#   '컬러',
#   '완성',
#   '제품',
#   '연출',
#   '연출',
#   '제품',
#   '제니',
#   '입술',
#   '연출',
#   '전',
#   '레드',
#   '입술',
#   '제품',
#   '제품',
#   '메이크업',
#   '연출',
#   '룩',
#   '연출',
#   '연출',
#   '제품',
#   '제품',
#   '블랙',
#   '블랙',
#   '얼굴',
#   '컬러',
#   '입술',
#   '컬러',
#   '룩',
#   '완성',
#   '제품'],
#  ['얼굴', '제니'],
#  ['얼굴', 'CHANEL', '제니'],
#  ['걸', '제니', '매력', '그녀', '모습', '공개', '공개'],
#  ['지수',
#   '제니',
#   'BLACKPINK',
#   '공개',
#   '분위기',
#   'BLACKPINK',
#   '공개',
#   'BLACKPINK',
#   '전',
#   'BLACKPINK',
#   '지수',
#   '제니',
#   'BLACKPINK'],
#  ['스타',
#   'BLACKPINK',
#   '공개',
#   '통해',
#   'BLACKPINK',
#   '공개',
#   '공개',
#   'BLACKPINK',
#   '로제',
#   '말',
#   '제니',
#   '리사',
#   '지수',
#   '분위기',
#   '전',
#   '스타',
#   '공개'],
#  ['BLACKPINK',
#   '제니',
#   '리사',
#   'BLACKPINK',
#   '매력',
#   '머리',
#   '제니',
#   '모습',
#   '리사',
#   '공개',
#   '제니',
#   '모습',
#   '지수',
#   '사진',
#   'BLACKPINK',
#   '공개',
#   '로제',
#   '제니',
#   '리사',
#   'BLACKPINK'],
#  ['패션',
#   '브랜드',
#   'BLACKPINK',
#   '패션',
#   '브랜드',
#   '패션',
#   '브랜드',
#   '스타',
#   '일링',
#   '로제',
#   '로제',
#   '제품',
#   '스타',
#   '일링',
#   '완성',
#   '톱',
#   '리사',
#   '리사',
#   '착용',
#   '브랜드',
#   '제품',
#   '착용',
#   '브랜드',
#   '분위기',
#   '아이템',
#   '제니',
#   '제니',
#   '톱',
#   '선택',
#   '매치',
#   'BLACKPINK',
#   '아이템',
#   'BLACKPINK',
#   '포인트',
#   '지수',
#   '지수',
#   '착용'],
#  ['BLACKPINK',
#   '로제',
#   '리사',
#   '지수',
#   'BLACKPINK',
#   '로제',
#   '리사',
#   '지수',
#   '공개',
#   '통해',
#   '공개',
#   '로제',
#   '리사',
#   '지수',
#   'BLACKPINK',
#   'BLACKPINK',
#   'BLACKPINK',
#   '제니',
#   '로제',
#   '리사',
#   '지수',
#   '모습',
#   'BLACKPINK'],
#  ['BLACKPINK', 'BLACKPINK', '공개', 'BLACKPINK', '제니', 'BLACKPINK', '로제', '화보']]
