# %%
import pandas as pd
import numpy as np

# %%
ch_top50 = pd.read_csv('ch_top50.csv', sep = '|', encoding='utf-8')
ce_top50 = pd.read_csv('ce_top50.csv', sep = '|', encoding='utf-8')

# %%
ch_top50
# Out:
#          word  count
# 0      CHANEL   5469
# 1         브랜드    921
# 2        KARL    882
# 3           쇼    735
# 4          모델    716
# 5          장식    702
# 6           백    665
# 7          그녀    640
# 8         드레스    634
# 9          파리    531
# 10         여성    508
# 11        스타일    495
# 12        트위드    488
# 13         컬러    482
# 14       디자이너    454
# 15         블랙    441
# 16    COUTURE    440
# 17         재킷    428
# 18        디자인    426
# 19        주얼리    409
# 20         코코    403
# 21        새로운    379
# 22        하우스    370
# 23        아이템    364
# 24         세계    354
# 25        화이트    350
# 26  GABRIELLE    344
# 27         공방    339
# 28          옷    318
# 29        럭셔리    310
# 30        크루즈    306
# 31   VIRGINIE    293
# 32         영감    290
# 33         영화    281
# 34        디렉터    274
# 35        프랑스    268
# 36         매력    261
# 37         슈즈    255
# 38        스커트    254
# 39         골드    253
# 40         가죽    241
# 41         팬츠    240
# ...

# %%
ch50 = []
for word in ch_top50['word']:
    ch50.append(word)

# %%
ce50 = []
for word in ce_top50['word']:
    ce50.append(word)

# %%
ch50 = ch50[:50]
ce50 = ce50[:50]

# %%
sl50 = ['LAURENT',
 '브랜드',
 '디자이너',
 'ANTHONY',
 '쇼',
 'HEDI',
 'DIOR',
 '드레스',
 '소재',
 '스타일',
 '모델',
 '여성',
 '파리',
 '팬츠',
 '장식',
 'GUCCI',
 'DESIGN',
 '재킷',
 '제품',
 '하우스',
 '컬러',
 '옷',
 '가죽',
 '부츠',
 '그룹',
 '디렉터',
 'CELINE',
 '새롭',
 '블랙',
 '아이템',
 '슈트',
 'BALENCIAGA',
 '프랑스',
 '럭셔리',
 'CREATIVE',
 'COUTURE',
 '코트',
 '생각',
 '데님',
 '로고',
 '셔츠',
 '여름',
 '영감',
 '슈즈',
 '봄',
 '좋',
 '선글라스',
 '세계',
 '캠페인',
 '실루엣']

# %%
di50 = ['DIOR',
 '컬렉션',
 '패션',
 '브랜드',
 '드레스',
 '쇼',
 '디자이너',
 '여성',
 '룩',
 '장식',
 '하우스',
 'MARIA',
 '컬러',
 'DESIGN',
 '백',
 '제품',
 '모델',
 '디렉터',
 '스타일',
 '파리',
 '시즌',
 'CHRISTIAN',
 '재킷',
 '소재',
 'LADY',
 'COUTURE',
 '영감',
 '작품',
 '사진',
 'CREATIVE',
 '블랙',
 '팬츠',
 'HOMME',
 '생각',
 '영화',
 '화이트',
 '스커트',
 '다양',
 '새롭',
 '매치',
 '옷',
 '시작',
 '세계',
 '프랑스',
 'JONES',
 '아이템',
 'GUCCI',
 '배우',
 'SAINT',
 'LAURENT']

# %%
sl50
# Out:
# ['LAURENT',
#  '브랜드',
#  '디자이너',
#  'ANTHONY',
#  '쇼',
#  'HEDI',
#  'DIOR',
#  '드레스',
#  '소재',
#  '스타일',
#  '모델',
#  '여성',
#  '파리',
#  '팬츠',
#  '장식',
#  'GUCCI',
#  'DESIGN',
#  '재킷',
#  '제품',
#  '하우스',
#  '컬러',
#  '옷',
#  '가죽',
#  '부츠',
#  '그룹',
#  '디렉터',
#  'CELINE',
#  '새롭',
#  '블랙',
#  '아이템',
#  '슈트',
#  'BALENCIAGA',
#  '프랑스',
#  '럭셔리',
#  'CREATIVE',
#  'COUTURE',
#  '코트',
#  '생각',
#  '데님',
#  '로고',
#  '셔츠',
#  '여름',
#  '영감',
#  '슈즈',
#  '봄',
#  '좋',
#  '선글라스',
#  '세계',
#  '캠페인',
#  '실루엣']

# %%
total = ['CHANEL',
 '브랜드',
 'KARL',
 '쇼',
 '모델',
 '장식',
 '백',
 '그녀',
 '드레스',
 '파리',
 '여성',
 '스타일',
 '트위드',
 '컬러',
 '디자이너',
 '블랙',
 'COUTURE',
 '재킷',
 '디자인',
 '주얼리',
 '코코',
 '새로운',
 '하우스',
 '아이템',
 '세계',
 '화이트',
 'GABRIELLE',
 '공방',
 '옷',
 '럭셔리',
 '크루즈',
 'VIRGINIE',
 '영감',
 '영화',
 '디렉터',
 '프랑스',
 '매력',
 '슈즈',
 '스커트',
 '골드',
 '가죽',
 '팬츠',
 'HAUTE',
 '패션쇼',
 '가방',
 '슈트',
 '런웨이',
 '클래식',
 '여름',
 '워치',
 'CELINE',
 '컬렉션',
 'HEDI',
 '브랜드',
 '패션',
 '룩',
 '시즌',
 '디자이너',
 '백',
 '컬러',
 '스타일',
 '여성',
 '드레스',
 '남성',
 '쇼',
 '디자인',
 '장식',
 '팬츠',
 'PHOEBE',
 '디렉터',
 '재킷',
 '코트',
 '파리',
 '새로운',
 '옷',
 '아이템',
 '그녀',
 '사진',
 '매치',
 '모델',
 '소재',
 '첫',
 '크리에이티브',
 '셔츠',
 '로고',
 '블랙',
 '가죽',
 '스커트',
 '트렌드',
 '런웨이',
 '영국',
 '실루엣',
 '시대',
 '봄',
 '부츠',
 '클래식',
 '다양한',
 '매력',
 '연출',
 '여름',
 'DIOR',
 '컬렉션',
 '패션',
 '브랜드',
 '드레스',
 '쇼',
 '디자이너',
 '여성',
 '룩',
 '장식',
 '하우스',
 'MARIA',
 '컬러',
 'DESIGN',
 '백',
 '제품',
 '모델',
 '디렉터',
 '스타일',
 '파리',
 '시즌',
 'CHRISTIAN',
 '재킷',
 '소재',
 'LADY',
 'COUTURE',
 '영감',
 '작품',
 '사진',
 'CREATIVE',
 '블랙',
 '팬츠',
 'HOMME',
 '생각',
 '영화',
 '화이트',
 '스커트',
 '다양',
 '새롭',
 '매치',
 '옷',
 '시작',
 '세계',
 '프랑스',
 'JONES',
 '아이템',
 'GUCCI',
 '배우',
 'SAINT',
 'LAURENT',
'LAURENT',
 '브랜드',
 '디자이너',
 'ANTHONY',
 '쇼',
 'HEDI',
 'DIOR',
 '드레스',
 '소재',
 '스타일',
 '모델',
 '여성',
 '파리',
 '팬츠',
 '장식',
 'GUCCI',
 'DESIGN',
 '재킷',
 '제품',
 '하우스',
 '컬러',
 '옷',
 '가죽',
 '부츠',
 '그룹',
 '디렉터',
 'CELINE',
 '새롭',
 '블랙',
 '아이템',
 '슈트',
 'BALENCIAGA',
 '프랑스',
 '럭셔리',
 'CREATIVE',
 'COUTURE',
 '코트',
 '생각',
 '데님',
 '로고',
 '셔츠',
 '여름',
 '영감',
 '슈즈',
 '봄',
 '좋',
 '선글라스',
 '세계',
 '캠페인',
 '실루엣']

# %%
len(total)
# Out:
# 200

# %%
dic = {}
for word in total:
    if word in dic:
        dic[word] += 1
    else:
        dic[word] = 1

# %%
common = []
for key in dic:
    if dic[key] == 4:
        common.append(key)

# %%
common
# Out:
# ['브랜드',
#  '쇼',
#  '모델',
#  '장식',
#  '드레스',
#  '파리',
#  '여성',
#  '스타일',
#  '컬러',
#  '디자이너',
#  '블랙',
#  '재킷',
#  '아이템',
#  '옷',
#  '디렉터',
#  '팬츠']

# %%
for word in dic:
    if dic[word] == 4:
        print(word)
# Out:
# 브랜드
# 쇼
# 모델
# 장식
# 드레스
# 파리
# 여성
# 스타일
# 컬러
# 디자이너
# 블랙
# 재킷
# 아이템
# 옷
# 디렉터
# 팬츠

# %%
for word in dic:
    if dic[word] == 3:
        print(word)
# Out:
# 백
# COUTURE
# 하우스
# 세계
# 영감
# 프랑스
# 스커트
# 가죽
# 여름
# 소재
