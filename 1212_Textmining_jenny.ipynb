# %%
import pandas as pd
import numpy as np

# %%
from collections import Counter

# %%
a_je = pd.read_csv('./blackpink/a_Je.csv', sep = '|', encoding = 'utf-8')
b_je = pd.read_csv('./blackpink/Bazaar_Je.csv', sep = '|', encoding = 'utf-8')
c_je = pd.read_csv('./blackpink/cosmo_Je.csv', sep='|', encoding = 'utf-8')
e_je = pd.read_csv('./blackpink/elle_Je.csv', sep='|', encoding = 'utf-8')
fn_je = pd.read_csv('./blackpink/fashionn_Je.csv', sep='|', encoding = 'utf-8')
m_je = pd.read_csv('./blackpink/marie_Je.csv', sep='|', encoding = 'utf-8')
v_je = pd.read_csv('./blackpink/V_Je.csv', sep='|', encoding = 'utf-8')
w_je = pd.read_csv('./blackpink/w_Je.csv', sep='|', encoding = 'utf-8')

# %% [markdown]
# ### word_jenny

# %%
fn_je
# Out:
#     magazine brand category                                            title  \
# 0   fashionn    Je     패션뉴스               블랙핑크 제니, 요정 같은 인간 샤넬! 끝없는 변신 어디까지!
# 1   fashionn    Je     스타패션              로제, 생로랑 홍보대사!블랙핑크 멤버 모두 럭셔리 브랜드 싹쓸이
# 2   fashionn    Je      라이프            다시 뜨는 90년대 배꼽티! 이효리도 제니도 푹 빠진 그시절 패션!
# 3   fashionn    Je     인스타일                   블랙핑크 제니, 도발적인 트위드 드레스룩 '시선 강탈'
# 4   fashionn    Je     인스타일      [그 옷 어디꺼] 블랙핑크 제니, 안경 쓰니 딴사람! 도도한 커리어우먼 大변신
# 5   fashionn    Je     스타패션               블랙핑크 제니, 흰 티에 청바지만 입어도 완벽해 '시선 강탈'
# 6    ashionn    Je     인스타일           [그 옷 어디꺼] 블랙핑크 제니, 청바지에 딱! 트위드 재킷 어디꺼?
# 7   fashionn    Je     스타패션                 블랙핑크 제니, 남자 옷 입었나? 이게 바로 젠더 뉴트럴!
# 8   fashionn    Je     스타패션                 [패션엔 포토] 블랙핑크 제니, 크롭트 셔츠로 멋낸 출국길
# 9   fashionn    Je     인스타일           [패션엔 포토] 블랙핑크 제니, 헤어핀으로 포인트! 상큼발랄한 출국길
# 10  fashionn    Je     스타패션         [패션엔 포토] 블랙핑크 제니, 레이어링 끝판왕! 힙한 나비 패턴 패딩룩
# ...

# %%
word_jenny = []
for i in range(len(fn_je)):
    cont = []
    if fn_je.loc[i, 'title_brand'] == 1:
        cont.append(fn_je.loc[i, 'contents'])
    else:
        for content in fn_je.loc[i, 'contents'].split("', \'"):
#             print(content)
#             print('-'*50)
            if '제니' in content:
                cont.append(content)
    word_jenny.append(cont)

len(word_jenny)
# Out:
# 54

# %%
fn_je['word_jenny'] = word_jenny

# %%
w_je
# Out:
#    brand magazine                  category  \
# 0     Je        W  FASHION, FEATURE, 피플, 화보
# 1     Je        W               BEAUTY, 트렌드
# 2     Je        W      BEAUTY, FASHION, 트렌드
# 3     Je        W               FASHION, 쇼핑
# 4     Je        W              FASHION, 트렌드
# 5     Je        W              FASHION, 트렌드
# 6     Je        W                BEAUTY, 화보
# 7     Je        W                      W TV
# 8     Je        W  FASHION, FEATURE, 피플, 화보
# 9     Je        W                  W TV, 패션
# 10    Je        W               W HOT ISSUE
# 11    Je        W               W HOT ISSUE
# 12    Je        W               W HOT ISSUE
# 13    Je        W               FASHION, 뉴스
# 14    Je        W               W HOT ISSUE
# 15    Je        W               W HOT ISSUE
#
#                                   title        date  \
# 0        Dream A Little Dream (블랙핑크 제니)  2020-10-23
# 1   더듬이 헤어? 블랙핑크 제니, 트와이스 채영도 한 앞머리 탈색!  2020-06-26
# ...

# %%
word_jenny = []
for i in range(len(w_je)):
    cont = []
    if w_je.loc[i, 'title_brand'] == 1:
        cont.append(w_je.loc[i, 'contents'])
    else:
        for content in w_je.loc[i, 'contents'].split("', '"):
#             print(content)
#             print('-'*50)
            if '제니' in content:
                cont.append(content)
    word_jenny.append(cont)

len(word_jenny)
# Out:
# 16

# %%
w_je['word_jenny'] = word_jenny

# %% [markdown]
# ### 컬럼 정렬

# %%
v_je.rename(columns = {'word_jennie':'word_jenny'}, inplace = True)

# %%
a_je = a_je[['magazine', 'brand', 'category', 'title', 'link', 'date', 'contents', 'title_brand', 'word_jenny']]
b_je = b_je[['magazine', 'brand', 'category', 'title', 'link', 'date', 'contents', 'title_brand', 'word_jenny']]
c_je = c_je[['magazine', 'brand', 'category', 'title', 'link', 'date', 'contents', 'title_brand', 'word_jenny']]
e_je = e_je[['magazine', 'brand', 'category', 'title', 'link', 'date', 'contents', 'title_brand', 'word_jenny']]
fn_je = fn_je[['magazine', 'brand', 'category', 'title', 'link', 'date', 'contents', 'title_brand', 'word_jenny']]
m_je = m_je[['magazine', 'brand', 'category', 'title', 'link', 'date', 'contents', 'title_brand', 'word_jenny']]
v_je = v_je[['magazine', 'brand', 'category', 'title', 'link', 'date', 'contents', 'title_brand', 'word_jenny']]
w_je = w_je[['magazine', 'brand', 'category', 'title', 'link', 'date', 'contents', 'title_brand', 'word_jenny']]

# %% [markdown]
# ### 합치기 pd.concat

# %%
mag_je = pd.concat([a_je, b_je, c_je, e_je, fn_je, m_je, v_je, w_je])

# %%
mag_je.reset_index(drop=True, inplace = True)

# %%
len(mag_je)
# Out:
# 297

# %%
mag_je[mag_je['word_jenny'].isnull()]
# Out:
# Empty DataFrame
# Columns: [magazine, brand, category, title, link, date, contents, title_brand, word_jenny]
# Index: []

# %%
mag_je['word_jenny'][164]
# Out:
# ["['', '', ' ', '블랙핑크 제니가 요정 같은 매혹적인 화보를 선보였다.', '제니는 패션 매거진과 함께 한 샤넬 커버 화보에서 샤넬(CHANEL) 화인 주얼리의 코코 크러쉬 주얼리와 새로운 샤넬 크루즈 컬렉션 의상을 소화하며 성숙하면서도 아름다운 여인으로 완벽 변신했다.', '화보 속 제니는 카페에 앉아 백일몽을 꾸는 듯한 모습과 몽환적인 눈빛으로 색다른 헤어와 메이크업 스타일로 팬들을 사로잡았다.', '제니는 “무대에 섰을 때 관객이 들려주는 함성과 그 에너지가 늘 큰 힘이 된다. 지금처럼 사는 모습을 어렸을 때 막연하게 꿈꾸긴 했지만, 그 꿈을 하나씩 이뤄가고 있는 이 현실이 아직도 기적처럼 느껴진다”라고 최근 심정을 밝혔다.', '', '', '', '', '', '', '', '패션엔 김금희 기자\\nfashionn@fashionn.com', '']"]

# %%
mag_je.to_csv('./blackpink/mag_je.csv', sep='|', encoding = 'utf-8', index = False)

# %%
mag_je = pd.read_csv('./blackpink/mag_je.csv', sep='|', encoding = 'utf-8')

# %% [markdown]
# # 전처리

# %% [markdown]
# ## 기호삭제

# %%
mag_je['word_jenny'] = mag_je['word_jenny'].str.replace('[', '').str.replace(']', '').str.replace('\\', '').str.replace('"', '').str.replace("'", "").str.replace('「', '').str.replace('」', '').str.replace('”', '').str.replace('‘', '').str.replace('“', '')

# %%
mag_je['word_jenny'][164]
# Out:
# ', ,  , 블랙핑크 제니가 요정 같은 매혹적인 화보를 선보였다., 제니는 패션 매거진과 함께 한 샤넬 커버 화보에서 샤넬(CHANEL) 화인 주얼리의 코코 크러쉬 주얼리와 새로운 샤넬 크루즈 컬렉션 의상을 소화하며 성숙하면서도 아름다운 여인으로 완벽 변신했다., 화보 속 제니는 카페에 앉아 백일몽을 꾸는 듯한 모습과 몽환적인 눈빛으로 색다른 헤어와 메이크업 스타일로 팬들을 사로잡았다., 제니는 무대에 섰을 때 관객이 들려주는 함성과 그 에너지가 늘 큰 힘이 된다. 지금처럼 사는 모습을 어렸을 때 막연하게 꿈꾸긴 했지만, 그 꿈을 하나씩 이뤄가고 있는 이 현실이 아직도 기적처럼 느껴진다라고 최근 심정을 밝혔다., , , , , , , , 패션엔 김금희 기자nfashionn@fashionn.com, '

# %% [markdown]
# ## 디자이너명 브랜드명 replace

# %% [markdown]
# ### 블랙핑크 BLACKPINK

# %%
for word in mag_je['word_jenny']:
    if '파샤' in word:
        print(word)
        print('-'*50)

# %%
mag_je['word_jenny'] = mag_je['word_jenny'].str.replace('블랙핑크', 'BLACKPINK')

# %% [markdown]
# ### 샤넬

# %%
for word in mag_je['word_jenny']:
    if '로랑' in word:
        print(word)
        print('-'*50)
# Out:
# 샤넬, 구찌, 생 로랑, 발렌시아가 등 수많은 패션 하우스들의 사랑을 받고 있는 BLACKPINK 제니가 개인 인스타그램 계정을 오픈하고 데일리 룩을 업로드 중이다.,  화려한 그녀의 사복 패션은 어떨까?, JENNIE dress 몸매가 드러나는 미니 드레스를 착용한 제니. 단조로운 디자인 보다는 군더더기 없는 실루엣에 트위드 소재나 패턴이 있는 미니 드레스로 사랑스럽게 연출했다., LOVELY girl 포카리 걸이 생각나는 시폰 소재의 여성스러운 드레스나 오프 숄더로 청순한 매력까지 더한 제니.,  긴 생머리와 레이스, 러플 디테일이 더해진 아이템과 크리스털 장식 주얼리까지 더하면 여성스러운 제니 변신 완료!, CHECK lover 제니가 클래식한 체크 패턴 룩을 입는 방법?, 캐주얼한 톱과 디스트로이드 진에 체크 패턴 재킷을 착용해 드레스 업 하거나 튜브 톱 드레스로 클래식하면서도 여성스럽게 착용하는 것., 여기에 제니처럼 길이가 다른 네크리스를 레이어드 하는 센스를 발휘해 볼 것!, ACT cool! 스포티한 룩도 본인만의 스타일로 연출하는 제니!, 슬릿 디테일의 트레이닝 팬츠로 섹시함을 더하거나 짧은 쇼트에 삭스와 스니커즈로 귀엽게 연출해도 좋겠다.
# --------------------------------------------------
# ...

# %%
mag_je['word_jenny'] = mag_je['word_jenny'].str.replace('샤넬', 'CHANEL')

# %% [markdown]
# ### 디올

# %%
mag_je['word_jenny'] = mag_je['word_jenny'].str.replace('디올', 'DIOR')

# %% [markdown]
# ### 셀린느

# %%
mag_je['word_jenny'] = mag_je['word_jenny'].str.replace('셀린느', 'CELINE')

# %%
mag_je['word_jenny'] = mag_je['word_jenny'].str.replace('셀린', 'CELINE')

# %% [markdown]
# ### 생로랑

# %%
# 생로랑
mag_je['word_jenny'] = mag_je['word_jenny'].str.replace('생 로랑', 'SAINTLAURENT')
mag_je['word_jenny'] = mag_je['word_jenny'].str.replace('생로랑', 'SAINTLAURENT')

# %% [markdown]
# ## list(article_list) 생성 후 append

# %%
contents_list = []

# %%
article_list = []
for word in mag_je['word_jenny']:
    article_list.append(word)

# %%
len(article_list)
# Out:
# 297

# %%
article_list[6]
# Out:
# 'jennierubyjanen제니n컬러도, 패턴도 따뜻해 보이는 크롭트 카디건이 이토록 시원해 보이는 이유는 제니의 과감한 애티튜드에 있다. 속옷이 보일 정도로 짧은 톱은 레이어드하는 것이 일반적인데, 제니는 과감하게 이너를 생략하고 데님 팬츠에 톱으로 매치해 캐주얼한 감성과 관능적인 무드가 공존하는 룩을 완성했다. 노출이 과해 보이지 않게 심플한 네크리스로 빈 공간을 채워준 센스도 눈여겨볼 것.'

# %% [markdown]
# ## 트위터 패키지 안에 konlpy 모듈 호출

# %%
from konlpy.tag import Twitter

# %%
twitter = Twitter()
# Out:
# C:\Users\wnsgo\anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %% [markdown]
# ### 각 문장별로 형태소 구분하기

# %%
sentences_tag = []

for sentence in article_list:
    morph = twitter.pos(sentence)
    sentences_tag.append(morph)
    
    

print(len(sentences_tag))
# Out:
# 297

# %%
sentences_tag[0]
# Out:
# [('싹', 'Noun'),
#  ('쓰리의', 'Adjective'),
#  ('린다', 'Noun'),
#  ('G', 'Alpha'),
#  (',', 'Punctuation'),
#  ('BLACKPINK', 'Alpha'),
#  ('제니', 'Noun'),
#  (',', 'Punctuation'),
#  ('청', 'Noun'),
#  ('하', 'Suffix'),
#  ('그', 'Noun'),
#  ('외', 'Noun'),
#  ('등등', 'Noun'),
#  ('많은', 'Adjective'),
#  ('셀럽', 'Noun'),
#  ('들', 'Suffix'),
#  ('이', 'Josa'),
#  ('공통', 'Noun'),
#  ('적', 'Suffix'),
#  ('으로', 'Josa'),
#  ('보여준', 'Verb'),
#  ('하나', 'Noun'),
#  ('의', 'Josa'),
#  ('메이크업', 'Noun'),
#  ('룩', 'Noun'),
#  ('이', 'Josa'),
#  ('있다', 'Adjective'),
#  ('?', 'Punctuation'),
#  ('스타', 'Noun'),
#  ('뷰터뷰', 'Noun'),
#  ('를', 'Josa'),
#  ('진행', 'Noun'),
#  ('하며', 'Verb'),
#  ('셀럽', 'Noun'),
#  ('담당', 'Noun'),
#  ('아티스트', 'Noun'),
#  ('에게', 'Josa'),
#  ('직접', 'Noun'),
#  ('들은', 'Verb'),
#  ('눈', 'Noun'),
#  ('앞머리', 'Noun'),
#  ('하이라이트', 'Noun'),
#  ('’', 'Punctuation'),
#  ('에', 'Josa'),
#  ('대한', 'Noun'),
#  ('모든', 'Noun'),
#  ('것', 'Noun'),
#  ('.', 'Punctuation'),
#  ('무슨', 'Noun'),
# ...

# %%
twitter.tagset
# Out:
# {'Adjective': '형용사',
#  'Adverb': '부사',
#  'Alpha': '알파벳',
#  'Conjunction': '접속사',
#  'Determiner': '관형사',
#  'Eomi': '어미',
#  'Exclamation': '감탄사',
#  'Foreign': '외국어, 한자 및 기타기호',
#  'Hashtag': '트위터 해쉬태그',
#  'Josa': '조사',
#  'KoreanParticle': '(ex: ㅋㅋ)',
#  'Noun': '명사',
#  'Number': '숫자',
#  'PreEomi': '선어말어미',
#  'Punctuation': '구두점',
#  'ScreenName': '트위터 아이디',
#  'Suffix': '접미사',
#  'Unknown': '미등록어',
#  'Verb': '동사'}

# %% [markdown]
# ### stopword 추가

# %%
sw_df = pd.read_csv('stopwords.csv', header=None)

# %%
sw_df.columns = ['stopword']

# %%
stop_words = []
for sw in sw_df['stopword']:
    stop_words.append(sw)

# %%
print(len(stop_words))
print(type(stop_words))
# Out:
# 675
# <class 'list'>

# %%
stop_words[-10:]
# Out:
# ['둘', '셋', '넷', '다섯', '여섯', '일곱', '여덟', '아홉', '령', '영']

# %%
add_0 = ['수', '있는', '더', 'n', '위', '듯', '있어요', '중', '게', 
         '같아요', '요', '거', '속', '건', '드', '같은']
for w in add_0:
    stop_words.append(w)

# %% [markdown]
# ### 1. 명사 혹은 형용사인 품사만 선별해 리스트에 담기

# %%
noun_adj_list= []
for sentence1 in sentences_tag:
    for word, tag in sentence1:
        if tag in ['Noun', 'Adjective', 'Alpha', 'Determiner', 'Foreign']:
            if not word in stop_words:
                noun_adj_list.append(word)

# %%
len(noun_adj_list)
# Out:
# 25131

# %%
noun_adj_list[:20]
# Out:
# ['싹',
#  '쓰리의',
#  '린다',
#  'G',
#  'BLACKPINK',
#  '제니',
#  '청',
#  '외',
#  '많은',
#  '셀럽',
#  '공통',
#  '메이크업',
#  '룩',
#  '스타',
#  '뷰터뷰',
#  '진행',
#  '셀럽',
#  '담당',
#  '아티스트',
#  '직접']

# %%
noun_adj_list[:10]
# Out:
# ['싹', '쓰리의', '린다', 'G', 'BLACKPINK', '제니', '청', '외', '많은', '셀럽']

# %%
ADFN_list= []
for sentence1 in sentences_tag:
    words = []
    for word, tag in sentence1:
        if tag in ['Adjective', 'Determiner','Foreign','Noun', 'Alpha']:
            if word not in stop_words:
                words.append(word)
    ADFN_list.append(words)

# %%
len(ADFN_list)
# Out:
# 297

# %%
ADFN_list[0]
# Out:
# ['싹',
#  '쓰리의',
#  '린다',
#  'G',
#  'BLACKPINK',
#  '제니',
#  '청',
#  '외',
#  '많은',
#  '셀럽',
#  '공통',
#  '메이크업',
#  '룩',
#  '스타',
#  '뷰터뷰',
#  '진행',
#  '셀럽',
#  '담당',
#  '아티스트',
#  '직접',
#  '눈',
#  '앞머리',
#  '하이라이트',
#  '대한',
#  '모든',
#  '효과',
#  '영감',
#  '화제',
#  '싹',
#  '쓰리',
#  '린다',
#  'G',
#  '메이크업',
#  '선두',
#  '요즘',
#  '부쩍',
#  '눈',
#  '시작',
#  '메이크업',
#  '시작',
#  '이효리',
#  '메이크업',
#  '담당',
#  '홍성희',
#  '원장',
#  '답',
#  'Photo',
#  'by',
#  'Diane',
#  'Freed',
#  'Photo',
#  'by',
#  'Brenda',
#  'Chase',
#  'Getty',
#  'image',
#  '대',
#  '후반',
#  '대',
#  '초반',
#  '할리우드',
#  '스타',
#  '유행',
#  '스모키',
#  '메이크업',
#  '영감',
#  '특유',
#  '세기말',
#  '감성',
#  '사이버',
#  '전적',
#  '스모키',
#  '메이크업',
#  '느낌',
#  '아주',
#  '적절한',
#  '포인트',
#  '실제',
#  '당시',
#  '브리트니',
#  '스피어스',
#  '카메론',
#  '디아즈',
#  '크리스티나',
#  '아길레',
#  '많은',
#  '셀럽',
#  '메이크업',
#  '스타일',
#  '위아래',
#  '블랙',
#  '아이라인',
#  '눈',
#  '앞머리',
#  '하이라이트',
#  '뒤',
#  '수록',
#  '점점',
#  '진해',
#  '스모키',
#  '메이크업',
#  '공통',
#  '눈',
# ...

# %%
mag_je['ADFN'] = ADFN_list

# %% [markdown]
# ### 선별된 품사별 빈도수 계산 & 상위 빈도 10위까지 출력

# %%
word = Counter(noun_adj_list)
print(word.most_common(200))
# Out:
# [('제니', 748), ('BLACKPINK', 327), ('스타일', 197), ('패션', 192), ('컬러', 187), ('CHANEL', 167), ('룩', 151), ('헤어', 145), ('스타', 132), ('연출', 126), ('사진', 126), ('블랙', 113), ('매치', 112), ('포인트', 104), ('모습', 97), ('일링', 84), ('리사', 77), ('브랜드', 77), ('지수', 77), ('완성', 76), ('앞머리', 75), ('팬츠', 75), ('매력', 73), ('그녀', 73), ('로제', 73), ('메이크업', 71), ('아이템', 69), ('화이트', 69), ('입술', 68), ('기자', 68), ('분위기', 67), ('재킷', 66), ('걸', 64), ('톱', 61), ('머리', 61), ('패턴', 60), ('대', 59), ('착용', 59), ('생각', 58), ('말', 58), ('레드', 57), ('화보', 56), ('선택', 55), ('제품', 55), ('전', 54), ('얼굴', 54), ('공개', 54), ('통해', 54), ('눈', 53), ('니트', 53), ('가장', 52), ('데님', 50), ('카디건', 50), ('멤버', 50), ('핑크', 48), ('선글라스', 48), ('무드', 48), ('무대', 48), ('백', 47), ('공항', 47), ('밴드', 46), ('디자인', 46), ('느낌', 44), ('장식', 44), ('라인', 44), ('사람', 44), ('한편', 44), ('컬렉션', 43), ('지금', 42), ('드레스', 41), ('시작', 40), ('두', 40), ('액세서리', 40), ('미니', 40), ('그룹', 40), ('팬', 39), ('트', 38), ('소화', 38), ('립', 38), ('↑', 38), ('부분', 3
# ...

# %%
# # 한 글자인 단어는 제외

# for i, v in enumerate(noun_adj_list):
#     if len(v)<2:
#         noun_adj_list.pop(i)

# %%
count = Counter(noun_adj_list)

# %%
word_list = count.most_common(200)
for v in word_list:
    print(v)
# Out:
# ('제니', 748)
# ('BLACKPINK', 327)
# ('스타일', 197)
# ('패션', 192)
# ('컬러', 187)
# ('CHANEL', 167)
# ('룩', 151)
# ('헤어', 145)
# ('스타', 132)
# ('연출', 126)
# ('사진', 126)
# ('블랙', 113)
# ('매치', 112)
# ('포인트', 104)
# ('모습', 97)
# ('일링', 84)
# ('리사', 77)
# ('브랜드', 77)
# ('지수', 77)
# ('완성', 76)
# ('앞머리', 75)
# ('팬츠', 75)
# ('매력', 73)
# ('그녀', 73)
# ('로제', 73)
# ('메이크업', 71)
# ('아이템', 69)
# ('화이트', 69)
# ('입술', 68)
# ('기자', 68)
# ('분위기', 67)
# ('재킷', 66)
# ('걸', 64)
# ('톱', 61)
# ('머리', 61)
# ('패턴', 60)
# ('대', 59)
# ('착용', 59)
# ('생각', 58)
# ('말', 58)
# ('레드', 57)
# ('화보', 56)
# ('선택', 55)
# ('제품', 55)
# ('전', 54)
# ('얼굴', 54)
# ('공개', 54)
# ('통해', 54)
# ('눈', 53)
# ('니트', 53)
# ('가장', 52)
# ('데님', 50)
# ('카디건', 50)
# ('멤버', 50)
# ('핑크', 48)
# ('선글라스', 48)
# ('무드', 48)
# ('무대', 48)
# ('백', 47)
# ('공항', 47)
# ('밴드', 46)
# ('디자인', 46)
# ('느낌', 44)
# ('장식', 44)
# ('라인', 44)
# ('사람', 44)
# ('한편', 44)
# ('컬렉션', 43)
# ('지금', 42)
# ('드레스', 41)
# ('시작', 40)
# ('두', 40)
# ('액세서리', 40)
# ('미니', 40)
# ...

# %% [markdown]
# ## 워드클라우드 만들기

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 패키지 설치 및 폰트 어쩌구

# %%
import matplotlib.font_manager as fm

# 이용 가능한 폰트 중 '고딕'만 선별
for font in fm.fontManager.ttflist:
    if 'Gothic' in font.name:
        print(font.name, font.fname)
# Out:
# Malgun Gothic C:\WINDOWS\Fonts\malgun.ttf
# Yu Gothic C:\WINDOWS\Fonts\YuGothB.ttc
# HYGothic-Extra C:\WINDOWS\Fonts\H2GTRE.TTF
# Franklin Gothic Medium C:\WINDOWS\Fonts\framdit.ttf
# Malgun Gothic C:\Windows\Fonts\malgunbd.ttf
# Yu Gothic C:\Windows\Fonts\YuGothL.ttc
# Century Gothic C:\Windows\Fonts\GOTHIC.TTF
# Yu Gothic C:\Windows\Fonts\YuGothM.ttc
# Yu Gothic C:\WINDOWS\Fonts\YuGothR.ttc
# MS Gothic C:\WINDOWS\Fonts\msgothic.ttc
# HYGothic-Medium C:\WINDOWS\Fonts\H2GTRM.TTF
# Malgun Gothic C:\WINDOWS\Fonts\malgunsl.ttf
# Century Gothic C:\Windows\Fonts\GOTHICI.TTF
# Century Gothic C:\WINDOWS\Fonts\GOTHICBI.TTF
# Century Gothic C:\Windows\Fonts\GOTHICB.TTF
# Franklin Gothic Medium C:\WINDOWS\Fonts\framd.ttf

# %%
font_path = 'C:\WINDOWS\Fonts\malgun.ttf'

# %% [markdown]
# ### wordcloud 그리기

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud(font_path=font_path, background_color="white", width=600, height=400)

# %%
wc.generate_from_frequencies(dict(word_list))

plt.imshow(wc) 
plt.axis('off') 
plt.show()


wc.to_file('jenny_adj_twitter.png')

# %%
mag_JECH = mag_je[['magazine', 'brand', 'title', 'link', 'date', 'word_jenny', 'ADFN']]

# %%
mag_JECH.to_csv('./magazine/final/mag_JECH.csv', sep = '|', encoding = 'utf-8', index = False)

# %%
jennytop200 = pd.DataFrame(word_list)

# %%
jennytop200.columns = ['word', 'count']

# %%
jennytop200
# Out:
#           word  count
# 0           제니    748
# 1    BLACKPINK    327
# 2          스타일    197
# 3           패션    192
# 4           컬러    187
# ..         ...    ...
# 195         지난     22
# 196       국제공항     22
# 197          뒤     21
# 198          준     21
# 199         사용     21
#
# [200 rows x 2 columns]

# %%
jennytop200.to_csv('./magazine/final/jennytop200.csv', sep='|', encoding = 'utf-8', index = False)
