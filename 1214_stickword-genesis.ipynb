# %%
import pandas as pd
import numpy as np

# %%
from collections import Counter

# %%
genesis = pd.read_csv('./genesis_adfn.csv', sep='|', encoding = 'utf-8')

# %%
genesis
# Out:
#      magazine                               title  \
# 0           N     제네시스 GV70 12월 출시...싼타페 실내보다 클까?
# 1           N      제네시스 'GV70' 곧 출시… 8일 온라인 공개 행사
# 2           N          현대차 수출 단가 대당 2만달러 시대 '초읽기'
# 3           N           제네시스 GV70, 오는 8일 디지털 공개행사
# 4           N                   국산차 수출 단가 2만달러 육박
# ...       ...                                 ...
# 1549        N       현대차 제네시스 사업부장에 해외통 이용우 부사장 선임
# 1550        N      3년 만에 실적 반등 현대차 "美 가속페달 더 밟는다"
# 1551        N     현대·기아차 신형 엔진 공개… ‘GV80’ 첫 장착 유력
# 1552        N  "이노션, 제네시스 풀 라인업 확보…마케팅 활발해질 것"-NH
# 1553        N         엔비디아-현대기아차, 차량용 인포테인먼트 ‘맞손’
#
#                                                    link        date  \
# 0     https://news.naver.com/main/read.nhn?mode=LSD&...  2020-12-04
# 1     https://news.naver.com/main/read.nhn?mode=LSD&...  2020-12-03
# 2     https://news.naver.com/main/read.nhn?mode=LSD&...  2020-11-29
# 3     https://news.naver.com/main/read.nhn?mode=LSD&...  2020-12-02
# ...

# %%
genesis['ADFN_2'] = genesis['ADFN']

# %%
type(genesis['ADFN_2'][0])
# Out:
# str

# %%
for word in genesis['word_genesis']:
    if '뉴' in word:
        print(word)
        print('-'*50)
# Out:
# 1∼10월 수출 단가 1만9천386달러SUV·제네시스 등 고가차량 수출 늘어 국산차 평균 수출 단가 1만7천749달러작년比 10.7%↑, 이는 스포츠유틸리티차(SUV)와 제네시스 수출 비중이 늘어나며 믹스 개선(고부가가치 제품 판매 확대) 효과를 봤기 때문으로 보인다., 현대차는 올해 베뉴, 코나, 투싼, 넥쏘, 싼타페, 팰리세이드, GV80 등 7개 차종의 SUV를 수출했다. 특히 팰리세이드의 수출이 두 배로 늘고, GV80이 새로 가세하며 대형 SUV 수출이 늘었다., 제네시스의 수출 비중도 소폭 증가했다., 올해 10월까지 G70, G80, G90, GV80 등 제네시스 차종이 현대차 전체 수출에서 차지하는 비중은 2.2%로 지난해 같은 기간보다 0.1%포인트 늘어났다. 판매 대수 자체는 1만4천891대에 그쳤지만 고급차 브랜드인 만큼 적은 대수로도 평균 수출 가격을 올린 것으로 보인다., 특히 대형 SUV인 GV80은 연말부터 해외 시장에 본격적으로 판매되면서 수출 단가 상승을 끌어올리는 역할을 할 전망이다. 제네시스는 연말부터 미국, 캐나다, 호주, 중동 등에서 GV80을 시판하고 내년 초에는 러시아에서도 판매를 시작할 예정이다.
# --------------------------------------------------
# 스포츠경향 제네시스, 세단보다 가격이 높은 SUV 수출이 늘어나며 대당 수출 가격도 올랐다. 볼륨별로 보면 올해 베뉴, 코나, 투싼, 넥쏘, 싼타페, 팰리세이드, GV80 등 7개 차종이 인기를 얻었고 이후 팰리세이드의 수출량은 두 배로 뛰어 올랐으며 GV80는 대형 SUV 카테고리에서 주목을 받았다., 한편 올해 10월까지 G70, G80, G90, GV80 등 제네시스 브랜드들이 현대차 전체 수출에서 차지하는 비중은 2.2%로 지난해 같은 기간보다 0.1%포인트 늘었다. 제네시스는 연말부터 미국, 캐나다, 호주, 중동 등에 GV80을 시판하고 내년 초엔 러시아에도 본격 판매를 이어 나간다.
# ...

# %%
genesis['ADFN'][0][0]
# Out:
# '['

# %%
for word in genesis['ADFN_2']:
    if "중국" in word:
        print(word)
        print('-'*50)
# Out:
# ['현대차', '생산', '현장', '제네시스', '품질', '점검', '전담', '조직', '신설', '정의선', '현대차', '그룹', '회장', '제네시스', '글로벌', '시장', '공략', '원년', '완벽한', '품질', '확보', '위', '의지', '표현', '풀이', '제네시스', '내년', '유럽', '중국', '글로벌', '시장', '진출', '차세대', '전기차', '출시', '정의선', '현대차', '그룹', '회장', '29일', '업계', '현대차', '지난', '9월', '장재훈', '부사', '제네시스', '사업', '부', '제네시스', '전', '차종', '앞', '신차', '전기차', '품질', '점검', '개선', '전담', '조직', '출범', '현재', '관련', '인력', '배치', '업무', '분장', '충', '진행', '조직', '꾸리', '제네시스', '품질', '전담', '조직', '내년', '1분', '기에', '울산', '공장', '현장', '본격', '가동', '예정', '공장', '생산', '직', '아닌', '구직', '인력', '조직', '배치', '품질', '프로세스', '점검', '이례', '현재', '제네시스', '차량', '생산', '전량', '울산', '공장', '담당', '전담', '조직', '제네시스', '완벽한', '품질', '확보', '최', '목표', '기존', '산차', '포함', '신차', '앞', '출시', '전기차', '품질', '안정화', '작업', '진행', '현대차', '내부', '곳곳', '생산', '기술', '품질', '연구', '부문', '유기', '협업', '제조', '프로세스', '개선', '품질', '이슈', '조기', '대응', '주요', '업무', '국내외', '시장', '출시', '차량', '품질', '문제', '발생', '즉각', '원인', '조사', '개선', '방안', '수립', '실행', '재발', '방지', '대책', '합동', '점검', 
# ...

# %%
# 내수
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'내', '수'", "내수")
# 내외
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'내', '외'", "내외")
# 내외부
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'내', '외부'", "내외부")

# %%
# 내구성
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'내', '구성'", "내구성")

# %%
# 스포티
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'스포', '티'", "스포티")

# %%
# 역동적
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'역', '적'", "역동적")
# 역동성
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'역', '동성'", "역동성")

# %%
# 스마트키
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'스마트', '키'", "스마트키")

# %%
# 존재감
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'존재', '감'", "존재감")
# 볼륨감
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'볼륨', '감'", "볼륨감")
# 공간감
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'공간', '감'", "공간감")
# 통일감
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'통일', '감'", "통일감")
# 주행감
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'주행', '감'", "주행감")
# 무게감
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'무게', '감'", "무게감")

# %%
# 국산차
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'국산', '차'", "국산차")
# 수입차
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'수입', '차'", "수입차")

# %%
# 승차감
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'승', '차감'", "승차감")
# 승차감
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'하차', '감'", "하차감")

# %%
# 차종 
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'차', '종이'", "차종")

# %%
# 호감도
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'호감', '도'", "호감도")
# 관심도
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'관심', '도'", "관심도")
# 의존도
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'의존', '도'", "의존도")

# %%
# 소음저감 
# 의존도
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'소음', '감'", "'소음', '저감'")

# %%
# gv80
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'GV', '80'", "GV80")
# gv70
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'GV', '70'", "GV70")

# %%
# g90
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'G', '90'", "'G90'")
# g80
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'G', '80'", "'G80'")
# g70
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'G', '70'", "'G70'")

# %%
# eg80
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'eG', '80'", "eG80")

# K9
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'K', '9'", "K9")

# 펠리세이드 
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'펠', '리세', '이드'", "펠리세이드")

# %%
# 3세대
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'3', '세대'", "3세대")
# 3D
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'3', 'D'", "3D")
# 3차원
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'3', '차원'", "3차원")
# 3개월
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'3', '개월'", "3개월")

# %%
# 2열
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'2', '열'", "2열")
# 2단
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace("'2', '단'", "2단")

# %%
genesis['ADFN_2'] = genesis['ADFN_2'].str.replace('[', '').str.replace(']', '').str.replace('"', '').str.replace("'", "").str.split(', ')

# %% [markdown]
# ### stopwords

# %%
sw_df = pd.read_csv('stopwords.csv', header=None)

# %%
sw_df.columns = ['stopword']

# %%
stop_words = []
for sw in sw_df['stopword']:
    stop_words.append(sw)

# %%
print(len(stop_words))
print(type(stop_words))
# Out:
# 675
# <class 'list'>

# %%
stop_words[-10:]
# Out:
# ['둘', '셋', '넷', '다섯', '여섯', '일곱', '여덟', '아홉', '령', '영']

# %%
add_0 = ['수', '은', '있는', '통해', '말', '중', '내', '두', '개', '위', '지난', '부분', 
        '2만', '3.0', '인치', '위해', '이후', '가장', '내년', '1만', '같은', '추가', '인',
        '경우', '지난해' '2.5', '후', '기반', '강조', '전', '대한', '설명', '총', '앞',
        '1', '2', '3', '4', '5', '6', '7','3.5',
        '더', '관계자', '대비', '때문', '19', '정도', '있도록', 'm', '3세대', '기간', '15일', '지난달', 'ℓ', '대해', 
        '지난해', 'km', '1월', '줄', '2.5', '점']
for w in add_0:
    stop_words.append(w)

# %%
# '1', '2', '3', '4', '5', '6', '3.5'

# %%
['시장', '적용', '주행', '변경', '가격', '시스템', '신차', '변경', '예정', '그룹',  '시작', '공장']

# %%
# 소음-> 소음저감

# %%
len(stop_words)
# Out:
# 736

# %%
noun_adj_list = []
for i in range(len(genesis)):
    for word in genesis.loc[i, 'ADFN_2']:
        if word not in stop_words:
            noun_adj_list.append(word)

# %%
noun_adj_list
# Out:
# ['이데일리',
#  '오토',
#  'in',
#  '남현수',
#  '기자',
#  '제네시스',
#  '달',
#  '중형',
#  'SUV',
#  'GV70',
#  '출시',
#  '올해',
#  '제네시스',
#  'GV80',
#  '시작',
#  'G80',
#  'G70',
#  '변경',
#  '다양한',
#  '신차',
#  '내수',
#  '시장',
#  '호평',
#  '업계',
#  'GV70',
#  '달',
#  '8~10일',
#  '공식',
#  '출시',
#  'GV70',
#  '100',
#  '여대',
#  '10월',
#  '위장',
#  '막',
#  '도로',
#  '활보',
#  '노이즈',
#  '마케팅',
#  '진행',
#  'GV70',
#  '실물',
#  '디자인',
#  '접',
#  '소비자',
#  '제대로',
#  '프리미엄',
#  'SUV',
#  '반응',
#  'GV70',
#  '제네시스',
#  '디자인',
#  '아이덴티티',
#  '헤드',
#  '램프',
#  '테',
#  '램프',
#  '적용',
#  '전면',
#  '그릴',
#  '오각',
#  '크레스트',
#  '형태',
#  '전면',
#  '꽉',
#  '측면',
#  '최근',
#  '유행',
#  '쿠페',
#  '스타일',
#  '후륜',
#  '구동',
#  '특유',
#  '짧은',
#  '프런트',
#  '오버',
#  '행',
#  '휠',
#  '베이스',
#  '유려',
#  '비율',
#  '자랑',
#  '실내',
#  '역시',
#  '최신',
#  '제네시스',
#  '유사한',
#  '구성',
#  '엔트리',
#  'SUV',
#  '임',
#  '프리미엄',
#  '지향',
#  '제네시스',
#  '신차',
#  '답',
#  '12.3',
#  '계',
#  '플로',
#  '팅',
#  '타입',
#  '14.5',
#  '센터',
#  '디스플레이',
#  '장',
# ...

# %%
word = Counter(noun_adj_list)
print(word.most_common(200))
# Out:
# [('제네시스', 8647), ('GV80', 5941), ('현대차', 3569), ('모델', 3413), ('출시', 3370), ('SUV', 3295), ('차량', 2938), ('판매', 2793), ('브랜드', 2704), ('디자인', 2372), ('G80', 2236), ('시장', 2193), ('자동차', 2024), ('적용', 2023), ('주행', 1898), ('차', 1883), ('기술', 1689), ('엔진', 1458), ('국내', 1450), ('올해', 1253), ('신차', 1194), ('디젤', 1166), ('고객', 1101), ('미국', 1052), ('터보', 1040), ('변경', 996), ('가격', 973), ('시스템', 966), ('고급', 965), ('생산', 956), ('대형', 943), ('가솔린', 933), ('세단', 895), ('첫', 892), ('GV70', 875), ('예정', 874), ('그룹', 871), ('운전자', 845), ('스포츠', 807), ('벤츠', 806), ('소음', 781), ('기아차', 760), ('시작', 748), ('공장', 746), ('달', 727), ('현대', 713), ('라인업', 708), ('신형', 705), ('최초', 685), ('기능', 684), ('라인', 683), ('공개', 680), ('프리미엄', 678), ('실내', 677), ('최고', 671), ('중국', 666), ('업계', 660), ('차종', 657), ('판매량', 653), ('성능', 651), ('G70', 647), ('부품', 636), ('보조', 635), ('계획', 631), ('BMW', 629), ('기존', 614), ('계약', 608), ('최대', 582), ('조작', 565), ('글로벌', 556), ('센터', 551), ('공간', 550), ('럭셔리', 539), (
# ...

# %%
count = Counter(noun_adj_list)

# %%
word_list = count.most_common(200)
for v in word_list:
    print(v)
# Out:
# ('제네시스', 8647)
# ('GV80', 5941)
# ('현대차', 3569)
# ('모델', 3413)
# ('출시', 3370)
# ('SUV', 3295)
# ('차량', 2938)
# ('판매', 2793)
# ('브랜드', 2704)
# ('디자인', 2372)
# ('G80', 2236)
# ('시장', 2193)
# ('자동차', 2024)
# ('적용', 2023)
# ('주행', 1898)
# ('차', 1883)
# ('기술', 1689)
# ('엔진', 1458)
# ('국내', 1450)
# ('올해', 1253)
# ('신차', 1194)
# ('디젤', 1166)
# ('고객', 1101)
# ('미국', 1052)
# ('터보', 1040)
# ('변경', 996)
# ('가격', 973)
# ('시스템', 966)
# ('고급', 965)
# ('생산', 956)
# ('대형', 943)
# ('가솔린', 933)
# ('세단', 895)
# ('첫', 892)
# ('GV70', 875)
# ('예정', 874)
# ('그룹', 871)
# ('운전자', 845)
# ('스포츠', 807)
# ('벤츠', 806)
# ('소음', 781)
# ('기아차', 760)
# ('시작', 748)
# ('공장', 746)
# ('달', 727)
# ('현대', 713)
# ('라인업', 708)
# ('신형', 705)
# ('최초', 685)
# ('기능', 684)
# ('라인', 683)
# ('공개', 680)
# ('프리미엄', 678)
# ('실내', 677)
# ('최고', 671)
# ('중국', 666)
# ('업계', 660)
# ('차종', 657)
# ('판매량', 653)
# ('성능', 651)
# ('G70', 647)
# ('부품', 636)
# ('보조', 635)
# ('계획', 631)
# ('BMW', 629)
# ('기존', 614)
# ('계약', 608)
# ('최대', 582)
# ...

# %%
['']

# %% [markdown]
# ## 워드클라우드 만들기

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.font_manager as fm

# 이용 가능한 폰트 중 '고딕'만 선별
for font in fm.fontManager.ttflist:
    if 'Gothic' in font.name:
        print(font.name, font.fname)
# Out:
# Malgun Gothic C:\WINDOWS\Fonts\malgun.ttf
# Yu Gothic C:\WINDOWS\Fonts\YuGothB.ttc
# HYGothic-Extra C:\WINDOWS\Fonts\H2GTRE.TTF
# Franklin Gothic Medium C:\WINDOWS\Fonts\framdit.ttf
# Malgun Gothic C:\Windows\Fonts\malgunbd.ttf
# Yu Gothic C:\Windows\Fonts\YuGothL.ttc
# Century Gothic C:\Windows\Fonts\GOTHIC.TTF
# Yu Gothic C:\Windows\Fonts\YuGothM.ttc
# Yu Gothic C:\WINDOWS\Fonts\YuGothR.ttc
# MS Gothic C:\WINDOWS\Fonts\msgothic.ttc
# HYGothic-Medium C:\WINDOWS\Fonts\H2GTRM.TTF
# Malgun Gothic C:\WINDOWS\Fonts\malgunsl.ttf
# Century Gothic C:\Windows\Fonts\GOTHICI.TTF
# Century Gothic C:\WINDOWS\Fonts\GOTHICBI.TTF
# Century Gothic C:\Windows\Fonts\GOTHICB.TTF
# Franklin Gothic Medium C:\WINDOWS\Fonts\framd.ttf

# %%
font_path = 'C:\WINDOWS\Fonts\malgun.ttf'

# %% [markdown]
# ### 워드클라우드 그리기

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud(font_path=font_path, background_color="white", width=600, height=400)

# %%
wc.generate_from_frequencies(dict(word_list))

plt.imshow(wc) 
plt.axis('off') 
plt.show()


wc.to_file('genesis.png')

# %%
genesis.to_csv('./magazine/final/genesis_adfn_2.csv', sep='|', encoding = 'utf-8', index = False)
