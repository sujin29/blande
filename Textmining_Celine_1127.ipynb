# %%
import pandas as pd
import numpy as np

# %%
from collections import Counter

# %% [markdown]
# ### load files

# %%
a_ce = pd.read_csv('./magazine/Allure_Celine.csv', sep = '|', encoding = 'utf-8')
b_ce = pd.read_csv('./magazine/Daum_BAZAAR_Celine.csv', sep = '|', encoding = 'utf-8')
c_ce = pd.read_csv('./magazine/cos_ce.csv', sep = '|', encoding = 'utf-8')
e_ce = pd.read_csv('./magazine/elle_ce.csv', sep = '|', encoding = 'utf-8')
fb_ce = pd.read_csv('./magazine/FB_Celine.csv', sep = '|', encoding = 'utf-8')
fn_ce = pd.read_csv('./magazine/fashionn_Ce.csv', sep = '|', encoding = 'utf-8')
m_ce = pd.read_csv('./magazine/marie_ce.csv', sep = '|', encoding = 'utf-8')
w_ce = pd.read_csv('./magazine/w_Ce.csv', sep = '|', encoding = 'utf-8')

# %%
m_ce = pd.read_csv('./magazine/marie_ce.csv', sep = '|', encoding = 'utf-8')

# %%
v_ce = pd.read_csv('./magazine/Vogue_Celine.csv', sep ='|', encoding = 'utf-8')

# %% [markdown]
# ### 데이터 확인 및 필요컬럼만 가져오기

# %%
a_ce = a_ce[['magazine', 'brand', 'category', 'title', 'link', 'date', 'contents', 'title_brand','check', 'why']]

# %%
b_ce = b_ce[['magazine', 'brand', 'category', 'title', 'link', 'date', 'contents', 'title_brand','check', 'why']]

# %%
b_ce.tail(1)
# Out:
#    magazine brand category            title  \
# 32        B    Ce  FASHION  백은 이렇게 들어야 합니다.
#
#                                              link        date  \
# 32  https://www.harpersbazaar.co.kr/article/39060  2018.04.20
#
#                                              contents  title_brand  check why
# 32  [" '백은 이렇게 들어야 합니다.", " '어떤 것을 선택하느냐보다 어떤 방식으로...            0      0   -

# %%
c_ce.head(1)
# Out:
#   magazine brand category                 title  \
# 0        C    Ce  FASHION  이보다 시크할 순 없다! 케이프 코트
#
#                                           link        date  \
# 0  http://v.media.daum.net/v/20201121000132646  2020.11.21
#
#                                  contents  title_brand  check  why
# 0  [[], ['', '', '', '', '', '', '', '']]            0      2  NaN

# %%
e_ce.head(1)
# Out:
#   magazine brand category                                  title  \
# 0        E    Ce  FASHION  내일 뭐 입지? 스타들이 픽한 아우터는 바로 '이것' #옷잘입는언니
#
#                                           link        date  \
# 0  http://v.media.daum.net/v/20201121070041038  2020.11.21
#
#                                             contents  title_brand  check  why
# 0  [['「 #강민경의 헤링본 롱 코트 」', '「 #강민경의 헤링본 롱 코트 」', ...            0      0  NaN

# %%
fb_ce
# Out:
#    magazine brand        category                                title  \
# 0        FB    Ce    Today's News            셀린느, 블랙핑크 리사 글로벌 앰배서더로 발탁
# 1        FB    Ce    Today's News      여성 쇼핑앱 브랜디, 구찌 · 셀린느 봄맞이 천원 이벤트
# 2        FB    Ce    Today's News       갤러리아 명품관, 올해 펜디 ∙ 디올 등 명품남성 확대
# 3        FB    Ce    Today's News              [월드] 셀린느, 남성복 패션쇼 잠정 중단
# 4        FB    Ce    Today's News          [월드] 셀린느, 에디 슬리만 향수 컬렉션 론칭?
# 5        FB    Ce    Today's News        갤러리아 웨스트관, 구찌~셀린 '명품남성' 대폭 강화
# 6        FB    Ce      World Wide               아동복 패션 하우스, ‘마이크로 타깃팅’
# 7        FB    Ce    Today's News     [월드] 에디 슬리먼 ‘셀린느’ 뉴욕 콘셉트 플래그십 첫선
# 8        FB    Ce    Today's News        셀린느, 새 디렉터 '에디 슬리먼' 데뷔 컬렉션 공개
# 9        FB    Ce    Today's News       [월드] 에디 슬리먼, 1월에 '셀린느' 남성복 첫 선
# 10       FB    Ce    Today's News      [월드] 에디슬리먼, 패션계 '도널드 트럼프' 등극(?)
# 11       FB    Ce    Today's News           [월드]에디 슬리먼 표 셀린느 첫선부터 이슈몰이
# ...

# %%
fn_ce['magazine'] = 'FN'
fn_ce.rename(columns = {'content':'contents'}, inplace = True)

# %%
fn_ce = fn_ce[['magazine', 'brand', 'category', 'title', 'link', 'date', 'contents', 'title_brand','check', 'why']]

# %%
fn_ce.head(1)
# Out:
#   magazine brand category                                title  \
# 0       FN    Ce      라이프  굿바이 멜라니아! 지난 4년 찬사와 논란의 퍼스트 레이디룩 33
#
#                                                 link        date  \
# 0  https://www.fashionn.com/board/read_new.php?ta...  2020-11-09
#
#                                             contents  title_brand  check  why
# 0  '↑사진 = 2017년 1월20일 미국 대통령 취임 당시/ 2017년 11월7일 한...            0      0  NaN

# %%
m_ce.head()
# Out:
#   magazine brand   category                               title  \
# 0        M    Ce  celebrity                             Look At
# 1        M    Ce  lifestyle             10월 넷째주, 11월 첫째주 #신작 추천
# 2        M    Ce  lifestyle                         오직, 여자의 이야기
# 3        M    Ce    fashion                     MASCULINE SCENE
# 4        M    Ce     beauty  2020 F/W BEAUTY TREND FORECAST – 2
#
#                                                 link     date  \
# 0  http://www.marieclairekorea.com/celebrity/2020...  2020-11
# 1  http://www.marieclairekorea.com/lifestyle/2020...  2020-11
# 2  http://www.marieclairekorea.com/lifestyle/2020...  2020-11
# 3  http://www.marieclairekorea.com/fashion/2020/1...  2020-10
# 4  http://www.marieclairekorea.com/beauty/2020/10...  2020-10
#
#                                             contents  title_brand  check  why
# 0  ['', ' ', '화보 촬영을 즐기는 편인가? 노출도 약간 있었고, 무용 동작을 ...            0      2  NaN
# ...

# %%
v_ce.head()
# Out:
#   magazine brand     category                            title  \
# 0        V    Ce      Fashion         셀린느 글로벌 앰배서더가 된 블랙핑크 리사!
# 1        V    Ce  ADVERTORIAL  인 더 백 : Burberry’s DK88 메이킹 스토리
# 2        V    Ce       Beauty                       삭발에 빠진 여자들
# 3        V    Ce      Fashion                오뜨 꾸뛰르 쇼에서 만난 스타들
# 4        V    Ce      Fashion               2017 S/S Trends 11
#
#                                                 link        date  \
# 0  http://www.vogue.co.kr/2020/09/23/une-fille-ce...  2020.09.23
# 1  http://www.vogue.co.kr/2017/08/09/%ec%9d%b8-%e...  2017.08.09
# 2  http://www.vogue.co.kr/2017/03/12/%ec%82%ad%eb...  2017.03.12
# 3  http://www.vogue.co.kr/2017/01/25/%ec%98%a4%eb...  2017.01.25
# 4  http://www.vogue.co.kr/2017/01/09/2017-ss-tren...  2017.01.09
#
#                                             contents  title_brand  check  why
# 0  ['UNE FILLE CELINE- LISA', '셀린느(CELINE)와 지속적인 ...            1      0  NaN
# ...

# %%
w_ce.head(1)
# Out:
#   brand    category                    title        date  \
# 0    Ce  WHAT'S NEW  셀린느 글로벌 엠버서더가 된 블랙핑크 리사  2020-09-22
#
#                                                 link  title_brand  check  why  \
# 0  http://www.wkorea.com/2020/09/22/%ec%85%80%eb%...            1      0  NaN
#
#                                              content
# 0  '공식적으로 에디 슬리먼 패밀리가 된 그녀!', '블랙핑크 리사가 2020 가을/겨...

# %%
w_ce['magazine'] = 'W'
w_ce.rename(columns = {'content':'contents'}, inplace = True)

# %%
w_ce = w_ce[['magazine', 'brand', 'category', 'title', 'link', 'date', 'contents', 'title_brand','check', 'why']]

# %% [markdown]
# ## 날짜로 sort 후 2016년 9월 이전 삭제

# %% [markdown]
# ### 확인

# %%
# allure

a_ce.sort_values(by = 'date', ascending = False)
# Out:
#     magazine brand   category  \
# 0          A    Ce    FASHION
# 1          A    Ce    FASHION
# 2          A    Ce    FASHION
# 3          A    Ce  CELEBRITY
# 89         A    Ce     BEAUTY
# 4          A    Ce  CELEBRITY
# 16         A    Ce    FASHION
# 5          A    Ce    FASHION
# 7          A    Ce    FASHION
# 6          A    Ce    FASHION
# 8          A    Ce    FASHION
# 14         A    Ce    FASHION
# 9          A    Ce    FASHION
# 10         A    Ce    FASHION
# 90         A    Ce    FEATURE
# 11         A    Ce    FASHION
# 12         A    Ce     BEAUTY
# 13         A    Ce    FASHION
# 15         A    Ce    FASHION
# 17         A    Ce  CELEBRITY
# 91         A    Ce     BEAUTY
# 18         A    Ce    FEATURE
# 19         A    Ce  CELEBRITY
# 21         A    Ce     BEAUTY
# 22         A    Ce    FASHION
# 20         A    Ce    FASHION
# 23         A    Ce    FASHION
# 24         A    Ce    FASHION
# 26         A    Ce    FASHION
# 25         A    Ce    FASHION
# ...

# %%
# bazaar

b_ce.sort_values(by='date', ascending = False)
# Out:
#    magazine brand     category                      title  \
# 1         B    Ce      FASHION     코로나 시대에 '귀족룩'이 트렌드인 이유
# 2         B    Ce    CELEBRITY           뒷광고 말고, 셀럽들의 앞광고
# 3         B    Ce      FASHION    변덕스러운 날씨에 탁월한 서머 샌들 연출법
# 4         B    Ce      FASHION  연휴에 정주행하면 좋을 에디슬리먼의 #집콕영화
# 5         B    Ce      FASHION       이번 시즌 런웨이에서 뽑은 베스트 룩
# 6         B    Ce      FASHION     스타일링이 어려운 베스트, 이렇게 입어!
# 7         B    Ce    CELEBRITY        영화 시상식에 참석한 배우들의 외침
# 8         B    Ce      FASHION          2020 S/S 컬렉션의 핫스팟
# 9         B    Ce  ART&CULTURE                 사랑과 연대의 기록
# 10        B    Ce      FASHION                  루시아 피카의 집
# 11        B    Ce      FASHION       2019 F/W '이것'만 알면 끝!
# 12        B    Ce    LIFESTYLE                모델 이혜승의 사진집
# 13        B    Ce      FASHION           올 가을, 겨울 트렌드 총집합
# 14        B    Ce      FASHION           2019 F/W 런웨이 리포트
# 15        B    Ce      FASHION           톱 모델 강소영의 사적인 취향
# ...

# %%
# cosmppolitan

c_ce.sort_values(by='date', ascending = False)
# Out:
#     magazine brand category                                 title  \
# 0          C    Ce  FASHION                  이보다 시크할 순 없다! 케이프 코트
# 1          C    Ce  FASHION                      올겨울 하의 트렌드 완벽 정리
# 3          C    Ce  FASHION                        가을 여자라면 역시 체크지
# 2          C    Ce  FASHION                    카디건 이렇게도 입을 수 있어요!
# 4          C    Ce   CELEBS                               모두의 클래식
# 112        C    Ce  FASHION                     오래도록 손이 갈 맨즈 재킷 4
# 113        C    Ce   BEAUTY                    지금 가장 뜨거운 뷰티 아이템 5
# 6          C    Ce  FASHION                           디지털 런웨이의 시대
# 7          C    Ce  FASHION                           니트 베스트의 대유행
# 9          C    Ce   CELEBS                           다시, 임시완의 도약
# 12         C    Ce   CELEBS       몽클레르 컬렉션이 함께한, 톱 모델 엘리스의 커버 데뷔!
# 11         C    Ce  FASHION                          클래식 스니커즈의 귀환
# 13         C    Ce  FASHION              작고 소중해, '명품' 브랜드 미니 지갑 5
# ...

# %%
# elle
e_ce.sort_values(by = 'date', ascending = False)
# Out:
#     magazine brand   category                                     title  \
# 0          E    Ce    FASHION     내일 뭐 입지? 스타들이 픽한 아우터는 바로 '이것' #옷잘입는언니
# 1          E    Ce    FASHION  예쁜 애 옆에 예쁜 애! '손민수' 하고 싶은 무스가드 자매의 트위...
# 2          E    Ce    FASHION                      단 하나의 셀린느_요주의 물건 #49
# 3          E    Ce          0                          데일리한 니트 원피스 스타일링
# 4          E    Ce          0              어디에나 잘 어울리는 트렌디한 블랙 아이템 코디법!
# 5          E    Ce    FASHION    포근한 카디건부터 체크 패턴, 스커트 수트까지, 알아두면 패션 ...
# 6          E    Ce          0                       강렬한 포인트 아이템을 소개합니다.
# 7          E    Ce    FASHION                            그녀의 가방이 궁금해 #1
# 8          E    Ce    FASHION            스타들이 픽한 데일리 백은 바로 '이것' #옷잘입는언니
# 9          E    Ce    FASHION            비밀의 숲 배두나 VS 악의 꽃 문채원 #VS드라마패션
# 10         E    Ce    FASHION          <사이코지만 괜찮아> 서예지 vs. 박규영 #VS드라마패션
# 11         E    Ce     BEAUTY                       패피들의 최애 '여름 향수'는? 1
# ...

# %%
# Fashion Biz
fb_ce.sort_values(by = 'date', ascending = False)
# Out:
#    magazine brand        category                                title  \
# 0        FB    Ce    Today's News            셀린느, 블랙핑크 리사 글로벌 앰배서더로 발탁
# 1        FB    Ce    Today's News      여성 쇼핑앱 브랜디, 구찌 · 셀린느 봄맞이 천원 이벤트
# 2        FB    Ce    Today's News       갤러리아 명품관, 올해 펜디 ∙ 디올 등 명품남성 확대
# 3        FB    Ce    Today's News              [월드] 셀린느, 남성복 패션쇼 잠정 중단
# 4        FB    Ce    Today's News          [월드] 셀린느, 에디 슬리만 향수 컬렉션 론칭?
# 5        FB    Ce    Today's News        갤러리아 웨스트관, 구찌~셀린 '명품남성' 대폭 강화
# 6        FB    Ce      World Wide               아동복 패션 하우스, ‘마이크로 타깃팅’
# 7        FB    Ce    Today's News     [월드] 에디 슬리먼 ‘셀린느’ 뉴욕 콘셉트 플래그십 첫선
# 8        FB    Ce    Today's News        셀린느, 새 디렉터 '에디 슬리먼' 데뷔 컬렉션 공개
# 9        FB    Ce    Today's News       [월드] 에디 슬리먼, 1월에 '셀린느' 남성복 첫 선
# 10       FB    Ce    Today's News      [월드] 에디슬리먼, 패션계 '도널드 트럼프' 등극(?)
# 11       FB    Ce    Today's News           [월드]에디 슬리먼 표 셀린느 첫선부터 이슈몰이
# ...

# %%
# fashion N
fn_ce.sort_values(by='date', ascending = False)
# Out:
#     magazine brand category                                     title  \
# 0         FN    Ce      라이프       굿바이 멜라니아! 지난 4년 찬사와 논란의 퍼스트 레이디룩 33
# 1         FN    Ce       리뷰            [리뷰] 파리지엔 걸, 2021 봄/여름 셀린느 컬렉션
# 2         FN    Ce     패션뉴스    롯데백화점, 프리미엄 멘즈셀렉트샵 ‘스말트(SMALT)’ 1호점 오픈
# 3         FN    Ce     인스타일   블랙핑크 지수, 역시 인간 디올! 청순한 듯 클래식한 뷔스티에 원피스룩
# 4         FN    Ce     인스타일          블랙핑크 리사, 셀린느 디자이너가 포착한 시크한 파리지엔룩
# 5         FN    Ce     스타패션             배두나, 독보적 아우라의 매니시룩 '클래스가 달라!'
# 6         FN    Ce     패션뉴스        스마트 시대, 가방도 스마트하게! 초소형 '핸드폰 가방' 뜬다
# 7         FN    Ce     패션뉴스           코로나 시대 여름 휴가! 가방으로 대신하는 해외 바캉스룩
# 8         FN    Ce     월드패션         루이비통, 가죽 제품 디렉터 멀버리 출신 '조니 코카' 영입
# 9         FN    Ce      라이프         '싱글맘' 안젤리나 졸리의 자녀 사랑! 육남매의 폭풍 성장기
# 10        FN    Ce     월드패션        한국 디자이너 표지영, 영국서 코로나 펀드 유망 디자이너 선정
# 11        FN    Ce     패션뉴스           요즘 데님 뭐입어? '청청패션 vs 트러커 재킷' 연출법
# ...

# %%
# marie_claire
m_ce.sort_values(by='date', ascending = False, inplace = True)

# %%
m_ce.reset_index(drop=True, inplace = True)

# %%
m_ce['check'] = 0

# %%
for i in range(len(m_ce)):
    if not '셀린' in m_ce.loc[i, 'contents']:
        m_ce.loc[i, 'check'] = 2

# %%
m_ce.tail(9)
# Out:
#     magazine brand category                                 title  \
# 196        M    Ce  fashion                            새 시즌 트렌치코트
# 197        M    Ce  fashion                              The Muse
# 198        M    Ce  fashion                           모델들의 쿨한 결혼식
# 199        M    Ce  fashion                          On Shoulders
# 200        M    Ce  fashion  패션 에디터 김누리의 See It, Buy It, Love It!
# 201        M    Ce  fashion                              오버해도 좋아!
# 202        M    Ce  fashion                            뉴 룩, 뉴 캠페인
# 203        M    Ce  fashion  패션 에디터 이지민의 See It, Buy It, Love It!
# 204        M    Ce   beauty               간단하게 변신할 수 있는 4가지 헤어스타일
#
#                                                   link     date  \
# 196  http://www.marieclairekorea.com/fashion/2016/0...  2016-09
# 197  http://www.marieclairekorea.com/fashion/2016/0...  2016-09
# 198  http://www.marieclairekorea.com/fashion/2016/0...  2016-09
# ...

# %%
m_ce = m_ce.loc[:204]

# %%
# Vogue

v_ce.sort_values(by='date', ascending = False)
# Out:
#   magazine brand     category  \
# 0        V    Ce      Fashion
# 1        V    Ce  ADVERTORIAL
# 2        V    Ce       Beauty
# 3        V    Ce      Fashion
# 4        V    Ce      Fashion
# 5        V    Ce      Fashion
# 6        V    Ce      Fashion
# 7        V    Ce      Fashion
# 8        V    Ce       Beauty
#
#                                                title  \
# 0                           셀린느 글로벌 앰배서더가 된 블랙핑크 리사!
# 1                    인 더 백 : Burberry’s DK88 메이킹 스토리
# 2                                         삭발에 빠진 여자들
# 3                                  오뜨 꾸뛰르 쇼에서 만난 스타들
# 4                                 2017 S/S Trends 11
# 5                     2017 S/S 밀란 패션위크 – Day 3, 4, 5
# 6  수지 멘키스가 품평한 2016 F/W 파리 패션위크 – 셀린느: 현대 여성을 위한 ...
# 7      수지 멘키스가 품평한 2016 F/W 뉴욕 패션위크 프로엔자 스쿨러: 통제와 해방
# 8                                  촛불을 켠 듯 환한 피부의 비밀
#
#                                                 link        date  \
# ...

# %%
# W
w_ce.sort_values(by='date', ascending = False)
# Out:
#     magazine brand                        category  \
# 3          W    Ce                    FASHION, 트렌드
# 4          W    Ce                 FASHION, 쇼핑, 화보
# 5          W    Ce                FASHION, 쇼핑, 트렌드
# 6          W    Ce                FASHION, 쇼핑, 트렌드
# 7          W    Ce                FASHION, 트렌드, 화보
# 8          W    Ce                 2021 S/S, PARIS
# 9          W    Ce                     FEATURE, 피플
# 10         W    Ce                     FASHION, 화보
# 11         W    Ce                     FASHION, 화보
# 12         W    Ce                     FASHION, 화보
# 13         W    Ce                     BEAUTY, 트렌드
# 14         W    Ce                    FASHION, 트렌드
# 15         W    Ce                     FASHION, 뉴스
# 17         W    Ce                FASHION, 쇼핑, 트렌드
# 16         W    Ce                     FEATURE, 피플
# 0          W    Ce                      WHAT'S NEW
# 18         W    Ce            FASHION, W맨, 쇼핑, 트렌드
# ...

# %% [markdown]
# ### 함수 적용

# %%
magazines_ce = [a_ce, b_ce, c_ce, e_ce, fb_ce, fn_ce, m_ce, v_ce, w_ce]

# %%
def sort_by_date(df):
    df.sort_values(by='date', ascending = False, inplace = True)
    df.reset_index(drop=True, inplace = True)

# %%
for mag in magazines_ce:
    sort_by_date(mag)

# %% [markdown]
# ## check 2 제외

# %%
len(b_ce[b_ce['check'] != 2])
# Out:
# 33

# %%
len(b_ce[(b_ce['check'] != 2) | (b_ce['title_brand'] == 1)])
# Out:
# 33

# %%
def drop_2(df):
    return df[df['check'] != 2]

# %%
a_ce_d = drop_2(a_ce)
b_ce_d = drop_2(b_ce)
c_ce_d = drop_2(c_ce)
e_ce_d = drop_2(e_ce)
fb_ce_d = drop_2(fb_ce)
fn_ce_d = drop_2(fn_ce)
m_ce_d = drop_2(m_ce)
v_ce_d = drop_2(v_ce)
w_ce_d = drop_2(w_ce)

# %%
a_ce_d.to_csv('./magazine/final/a_ce_d.csv', index = False, sep ='|' , encoding = 'utf-8')
b_ce_d.to_csv('./magazine/final/b_ce_d.csv', index = False, sep ='|' , encoding = 'utf-8')
c_ce_d.to_csv('./magazine/final/c_ce_d.csv', index = False, sep ='|' , encoding = 'utf-8')
e_ce_d.to_csv('./magazine/final/e_ce_d.csv', index = False, sep ='|' , encoding = 'utf-8')
fb_ce_d.to_csv('./magazine/final/fb_ce_d.csv', index = False, sep ='|' , encoding = 'utf-8')
fn_ce_d.to_csv('./magazine/final/fn_ce_d.csv', index = False, sep ='|' , encoding = 'utf-8')
m_ce_d.to_csv('./magazine/final/m_ce_d.csv', index = False, sep ='|' , encoding = 'utf-8')
v_ce_d.to_csv('./magazine/final/v_ce_d.csv', index = False, sep ='|' , encoding = 'utf-8')
w_ce_d.to_csv('./magazine/final/w_ce_d.csv', index = False, sep ='|', encoding = 'utf-8')

# %%
celine_d = pd.concat([a_ce_d, b_ce_d, c_ce_d, e_ce_d, fb_ce_d, fn_ce_d, m_ce_d, v_ce_d, w_ce_d])

# %%
celine_d.to_csv('celine_d.csv', sep='|', encoding = 'utf-8', index = False)

# %%
celine_d.reset_index(drop=True, inplace = True)

# %%
celine_d.loc[860, 'link']
# Out:
# 'http://www.wkorea.com/2017/03/24/%ea%b0%80%eb%b3%8d%ea%b2%8c-%eb%9b%b0%eb%a9%b4%ec%84%9c-%ec%a6%90%ea%b8%b0%eb%8a%94-%ec%bf%a0%ed%8a%80%eb%a5%b4/'

# %%
celine_d.loc[861, 'link']
# Out:
# 'http://www.wkorea.com/2017/03/22/moments-for-women-4%ec%9b%94%ed%98%b8-%ec%bb%a4%eb%b2%84-%ed%95%84%eb%a6%84-ver-3/'

# %% [markdown]
# ## list(article_list) 생성 후 append

# %%
contents_list = []

# %%
magazines_ce_d = [a_ce_d, b_ce_d, c_ce_d, e_ce_d, fb_ce_d, fn_ce_d, m_ce_d, w_ce_d]

# %%
magazine_list = []
article_list = []
for magazine in magazines_ce_d:
    articles = magazine['contents']
    for article in articles:
        article_list.append(article)

# %%
len(article_list)
# Out:
# 758

# %% [markdown]
# ## 트위터 패키지 안에 konlpy 모듈 호출

# %%
from konlpy.tag import Twitter

# %%
twitter = Twitter()
# Out:
# C:\Users\i\Anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %% [markdown]
# ### 각 문장별로 형태소 구분하기

# %%
sentences_tag = []

for sentence in article_list:
    morph = twitter.pos(sentence)
    sentences_tag.append(morph)
    
    

print(len(sentences_tag))
# Out:
# 758

# %%
sentences_tag[0]
# Out:
# [("['", 'Punctuation'),
#  ('겨울', 'Noun'),
#  ('이', 'Josa'),
#  ('오기', 'Noun'),
#  ('전', 'Noun'),
#  ('기억', 'Noun'),
#  ('해야', 'Verb'),
#  ('할', 'Verb'),
#  ('코트', 'Noun'),
#  ('의', 'Josa'),
#  ('면', 'Noun'),
#  ('면', 'Josa'),
#  (".',", 'Punctuation'),
#  ("'", 'Punctuation'),
#  ('90', 'Number'),
#  ('’', 'Punctuation'),
#  ('S', 'Alpha'),
#  ('STANDARD', 'Alpha'),
#  ("',", 'Punctuation'),
#  ("'", 'Punctuation'),
#  ('1990년', 'Number'),
#  ('대의', 'Foreign'),
#  ('모던', 'Noun'),
#  ('한', 'Josa'),
#  ('느낌', 'Noun'),
#  ('은', 'Josa'),
#  ('올', 'Modifier'),
#  ('겨울', 'Noun'),
#  ('의', 'Josa'),
#  ('코트', 'Noun'),
#  ('스타일', 'Noun'),
#  ('에서도', 'Josa'),
#  ('엿볼', 'Verb'),
#  ('수', 'Noun'),
#  ('있다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('유행', 'Noun'),
#  ('을', 'Josa'),
#  ('타지', 'Noun'),
#  ('않는', 'Verb'),
#  ('군더더기', 'Noun'),
#  ('없는', 'Adjective'),
#  ('스탠더드', 'Noun'),
#  ('핏', 'Noun'),
#  ('의', 'Josa'),
#  ('코트', 'Noun'),
#  ('는', 'Josa'),
#  ('그때', 'Noun'),
#  ('의', 'Josa'),
# ...

# %% [markdown]
# ### 1. 명사 혹은 형용사인 품사만 선별해 리스트에 담기

# %%
noun_adj_list= []
for sentence1 in sentences_tag:
    for word, tag in sentence1:
        if tag in ['Noun', 'Adjective']:
            noun_adj_list.append(word)

# %%
len(noun_adj_list)
# Out:
# 258521

# %%
noun_adj_list[:20]
# Out:
# ['겨울',
#  '오기',
#  '전',
#  '기억',
#  '코트',
#  '면',
#  '모던',
#  '느낌',
#  '겨울',
#  '코트',
#  '스타일',
#  '수',
#  '있다',
#  '유행',
#  '타지',
#  '군더더기',
#  '없는',
#  '스탠더드',
#  '핏',
#  '코트']

# %%
noun_adj_list[258510:]
# Out:
# ['캡', '모자', '체인', '장식', '스트리트', '스타일', '만끽', '특이', '사항', '하의', '실종']

# %% [markdown]
# ### 선별된 품사별 빈도수 계산 & 상위 빈도 10위까지 출력

# %%
word = Counter(noun_adj_list)
print(word.most_common(200))
# Out:
# [('것', 2619), ('패션', 1622), ('수', 1611), ('그', 1515), ('브랜드', 1352), ('있는', 1281), ('있다', 1252), ('컬렉션', 1205), ('등', 1193), ('백', 1102), ('이', 1091), ('드레스', 1080), ('스타일', 1026), ('셀린느', 971), ('룩', 965), ('디자이너', 959), ('컬러', 954), ('시즌', 908), ('매치', 775), ('이번', 756), ('팬츠', 749), ('더', 748), ('장식', 744), ('디자인', 732), ('아이템', 727), ('의', 718), ('재킷', 699), ('위', 697), ('때', 694), ('여성', 670), ('말', 653), ('소재', 648), ('가격', 644), ('가장', 642), ('쇼', 612), ('에디', 605), ('코트', 603), ('모델', 590), ('셀린', 573), ('같은', 568), ('옷', 557), ('미정', 531), ('그녀', 526), ('새로운', 519), ('지난', 518), ('파리', 516), ('자신', 510), ('가죽', 507), ('사진', 502), ('남성', 485), ('사람', 464), ('나', 463), ('디렉터', 461), ('스타', 458), ('등장', 458), ('블랙', 456), ('봄', 452), ('스커트', 451), ('부츠', 451), ('연출', 451), ('모두', 445), ('듯', 445), ('셔츠', 444), ('데님', 441), ('화이트', 438), ('에디터', 429), ('를', 429), ('여름', 423), ('생각', 414), ('전', 409), ('트렌드', 404), ('시작', 403), ('디올', 400), ('중', 400), ('위해', 392), ('슈트', 384), (
# ...

# %%
# 한 글자인 단어는 제외

for i, v in enumerate(word_list):
    if len(v)<2:
        word_list.pop(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-28367a654ae1> in <module>()
#       1 # 한 글자인 단어는 제외
#       2
# ----> 3 for i, v in enumerate(word_list):
#       4     if len(v)<2:
#       5         word_list.pop(i)
#
# NameError: name 'word_list' is not defined

# %%
count = Counter(word)

# %%
word_list = count.most_common(200)
for v in word_list:
    print(v)

# %% [markdown]
# ### 2. 명사만 선별해 리스트에 담기

# %%
noun= []
for sentence1 in sentences_tag:
    for word, tag in sentence1:
        if tag in ['Noun']:
            noun.append(word)

# %%
for i, v in enumerate(noun):
    if len(v)<2:
        noun.pop(i)

# %%
counts = Counter(noun)

# %% [markdown]
# ### 3. 명사만 선별해 아티클 별로 리스트에 담기

# %%
noun_article= []
for sentence1 in sentences_tag:
    art_noun = []
    for word, tag in sentence1:
        if tag in ['Noun']:
            art_noun.append(word)
    noun_article.append(art_noun)

print(len(noun_article))

# %%
len(article_list)

# %%
noun_df = pd.DataFrame({
    'article':article_list,
    'noun':noun_article
})

# %%
noun_df.to_csv('noun_celine.csv', sep = '|', index = False, encoding = 'utf-8')

# %% [markdown]
# ### 명사빈도 카운트

# %%
noun_list = counts.most_common(200)
for v in noun_list:
    print(v)

# %% [markdown]
# ## 워드클라우드 만들기

# %% [markdown]
# ### 패키지 설치 및 폰트 어쩌구

# %%
import matplotlib.font_manager as fm

# 이용 가능한 폰트 중 '고딕'만 선별
for font in fm.fontManager.ttflist:
    if 'Gothic' in font.name:
        print(font.name, font.fname)

# %%
font_path = 'C:\WINDOWS\Fonts\malgun.ttf'

# %% [markdown]
# ### wordcloud 그리기

# %%
wc.generate_from_frequencies(dict(word_list))
wc.to_file('wordcloud_celine.png')

# %%
wc.generate_from_frequencies(dict(noun_list))
wc.to_file('wordcloud_noun_celine.png')
