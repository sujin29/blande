# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 페이지 리스트에서 타이틀, 링크 크롤링

# %%
start = time.time()

path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)

title = []
link = []

for page in range(1,75):
    url='http://www.marieclairekorea.com/page/'+str(page)+'/?s=%EC%83%A4%EB%84%AC'
    driver.get(url)
    
    contElements = driver.find_elements_by_css_selector('article')

    for cont in contElements:
        # 타이틀 가져오기
        title.append(cont.find_element_by_tag_name('h2').text)
        

        # 링크 가져오기
        link.append(cont.find_element_by_tag_name('a').get_attribute('href'))
        
        time.sleep(5)
print(title)
print(len(title), len(link))


print(time.time() - start)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-4b2d176fae9f> in <module>
#      21         link.append(cont.find_element_by_tag_name('a').get_attribute('href'))
#      22
# ---> 23         time.sleep(5)
#      24 print(title)
#      25 print(len(title), len(link))
#
# KeyboardInterrupt:

# %%
marie = pd.DataFrame({
    'title':title,
    'link':link
})
marie
# Out:
#                          title  \
# 0                    빛을 품은 트위드
# 1   샤넬 오트 쿠튀르 2020 S/S 베스트 모먼트
# 2                   THEMSELVES
# 3                  진화하는 코코 크러쉬
# 4                     다시 만난 패션
# 5             트렌디한 신상 백 쇼핑 가이드
# 6                  신부들의 머스트 해브
# 7               클래식한 커플 워치 컬렉션
# 8            THROUGH THE CRUSH
# 9                 RING FOR YOU
# 10                   DAY DREAM
# 11               INTO THE BLUE
# 12              On The Weekend
# 13                샤넬과 아카데미 시상식
# 14               레트로 데님이 돌아왔다.
# 15            PYRAMID OF GIFTS
# 16          My Skin But Better
# 17                  Z세대의 뷰티 월드
# 18                   홍조 말고 블러쉬
# 19                     I & YOU
#
#                                                  link
# 0   http://www.marieclairekorea.com/fashion/2020/0...
# 1   http://www.marieclairekorea.com/fashion/2020/0...
# 2   http://www.marieclairekorea.com/fashion/2020/0...
# 3   http://www.marieclairekorea.com/fashion/2020/0...
# ...

# %% [markdown]
# ### 기사 크롤링

# %%
path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="06d0f098aabe71400d09bccd0b6023e7")>

# %%
url = 'http://www.marieclairekorea.com/fashion/2020/11/scenery-of-autumn/'
driver.get(url)

# %% [markdown]
# ### 제목, 부제목

# %%
all_elements = driver.find_element_by_css_selector('#main > div')
print(all_elements)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="06d0f098aabe71400d09bccd0b6023e7", element="d37efc03-1c4f-49e3-8e7b-8ef408fce4d8")>

# %%
#main > div > div.post-cls-204853.avada-page-titlebar-wrapper > div > div > div > div > div
#main > div > div.post-cls-204853.avada-page-titlebar-wrapper > div > div > div > div > div

tit_div = all_elements.find_element_by_class_name('fusion-page-title-captions')
title = tit_div.text

print(title)

subtit_div = all_elements.find_element_by_tag_name('h1')
subtitle = subtit_div.text

print(subtitle)
# Out:
# Scenery Of Autumn
# 이번 시즌 주목할 패션 신제품으로 완성한 가을 정경

# %% [markdown]
# ### 본문

# %%
contents = driver.find_element_by_css_selector('#post-204584 > div.post-content')
contents

imgs = contents.find_elements_by_tag_name('img')

for img in imgs:
    photo = img.get_attribute('src')
    print(photo)
# Out:
# http://img.marieclairekorea.com/2020/10/mck_5f9138155a57f-750x938.png
# http://img.marieclairekorea.com/2020/10/mck_5f9138519bb72-750x938.png
# http://img.marieclairekorea.com/2020/10/mck_5f91388d5213a-750x938.png
# http://img.marieclairekorea.com/2020/10/mck_5f9138c5ea6a3-750x938.png

# %%
contents.text
# Out:
# '러버 소재 라운드 토 BV 퍼들 부츠 79만원 보테가 베네타(Bottega Veneta).\n  송아지 가죽 새들 백 4백15만원 디올(Dior), 아이코닉한 모노그램 패턴 송아지 가죽 아카데미 로퍼 1백53만원 루이 비통(Louis Vuitton).\n  브라운 송아지 가죽 로퍼, 호피 무늬 프레임 선글라스, 인조진주와 스트라스, 레진, 메탈의 조합이 감각적인 네크리스 모두 가격 미정. 샤넬(Chanel).\n  크로커다일 가죽 미니 네오클래식 백 가격 미정, 레오퍼드 패턴 스퀘어 프레임 선글라스 57만5천원 모두 발렌시아가(Balenciaga).\n   '

# %% [markdown]
# ### 태그

# %%
tags_elements = driver.find_elements_by_css_selector('#post-204584 > div.single-box.single-tags > div > a')

tag_list = []

for tag in tags_elements:
    tag_list.append(tag.text)
    
print(tag_list)
# Out:
# ['디올', '루이 비통', '발렌시아가', '보테가 베네타', '샤넬']

# %% [markdown]
# ### 크레딧

# %%
credit = driver.find_element_by_css_selector('#post-204584 > div.post-meta-detail.sidebar-block > ul > li:nth-child(3) > div > span:nth-child(2) > span > a')
credit.text
# Out:
# '2020년 11월호'

# %%
marie
# Out:
#                          title  \
# 0                    빛을 품은 트위드
# 1   샤넬 오트 쿠튀르 2020 S/S 베스트 모먼트
# 2                   THEMSELVES
# 3                  진화하는 코코 크러쉬
# 4                     다시 만난 패션
# 5             트렌디한 신상 백 쇼핑 가이드
# 6                  신부들의 머스트 해브
# 7               클래식한 커플 워치 컬렉션
# 8            THROUGH THE CRUSH
# 9                 RING FOR YOU
# 10                   DAY DREAM
# 11               INTO THE BLUE
# 12              On The Weekend
# 13                샤넬과 아카데미 시상식
# 14               레트로 데님이 돌아왔다.
# 15            PYRAMID OF GIFTS
# 16          My Skin But Better
# 17                  Z세대의 뷰티 월드
# 18                   홍조 말고 블러쉬
# 19                     I & YOU
#
#                                                  link
# 0   http://www.marieclairekorea.com/fashion/2020/0...
# 1   http://www.marieclairekorea.com/fashion/2020/0...
# 2   http://www.marieclairekorea.com/fashion/2020/0...
# 3   http://www.marieclairekorea.com/fashion/2020/0...
# ...

# %% [markdown]
# 타이틀, 서브타이틀

# %%
path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)
driver


#main > div > div.post-cls-204853.avada-page-titlebar-wrapper > div > div > div > div > div
#main > div > div.post-cls-204853.avada-page-titlebar-wrapper > div > div > div > div > div


for link in marie['link']:
    url = link
    driver.get(url)
    
    all_elements = driver.find_element_by_css_selector('#main > div')
    
#     tit_div = all_elements.find_element_by_class_name('fusion-page-title-captions')
#     title = tit_div.text

#     print(title)

#     subtit_div = all_elements.find_element_by_tag_name('h1')
#     subtitle = subtit_div.text

#     print(subtitle)
    
    contents_div = driver.find_element_by_css_selector('div.post-content')
    contents_div
    
    content = contents_div.text
    print(content)
    print('-----'*10)

#     imgs = contents.find_elements_by_tag_name('img')

#     for img in imgs:
#         photo = img.get_attribute('src')
#         print(photo)
# Out:
# 1950년대 초부터 샤넬 컬렉션의 중요한 요소로 자리 잡은 트위드는 브랜드의 시그니처 중 하나다. 트위드라는 이름은 트윌(Twill), 즉 능직으로 짠 천을 뜻한다는 설과 영국과 스코틀랜드 사이를 흐르는 트위드(Tweed) 강변에서 제직한 데서 유래했다는 설이 있다. 가브리엘 샤넬의 눈에 트위드는 필요한 모든 것을 갖춘 원단이었다. 자연스러운 모습과 불규칙한 원단의 모양뿐 아니라 빗질하는 과정 없이 실을 뽑아 부드럽고 폭신하며, 그만큼 옷을 만들었을 때 편안하다는 장점에 매료되었다. 그녀는1920년대부터 이 천으로 여행과 운동을 즐기는 활동적었고, 트위드 소재는 이후 진화를 거듭하며 샤넬 컬렉션인 여성들을 위해 수트를 제작해 패션 역사에 한 획을 그에 무한한 영감을 주는 존재로 자리 잡았다. 이번 시즌, 하이 주얼리 컬렉션 역시 트위드를 영감의 원천으로 삼으며 샤넬만이 가진 독창성을 드러냈다.
# ...

# %%
marie_chanel = pd.read_csv('marie_chanel.csv')
marie_dior = pd.read_csv('marie_dior.csv')
marie_ysl = pd.read_csv('marie_ysl.csv')
marie_celine = pd.read_csv('marie_celine.csv')

# %%
marie_dior['year'] = marie_dior['link'].str.split('/').str[4]

# %%
marie_dior['year']
# Out:
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 686    2015
# 687    2014
# 688    2013
# 689    2013
# 690    2013
# Name: year, Length: 691, dtype: object

# %%
marie_dior
# Out:
#      Unnamed: 0                 title  \
# 0             0     Scenery Of Autumn
# 1             1       <스타트업> 수지 패션 탐구
# 2             2  HAPPY EARLY HOLIDAY!
# 3             3                이준의 고요
# 4             4                보습의 정석
# ..          ...                   ...
# 686         686             화장대를 부탁해!
# 687         687          My Fair Lady
# 688         688               지창욱의 탐색
# 689         689        C’Est Chouette
# 690         690         참 괜찮은 뮤지션 박재범
#
#                                                   link  date mon  year
# 0    http://www.marieclairekorea.com/fashion/2020/1...  2020  11  2020
# 1    http://www.marieclairekorea.com/fashion/2020/1...  2020  11  2020
# 2    http://www.marieclairekorea.com/beauty/2020/11...  2020  11  2020
# 3    http://www.marieclairekorea.com/celebrity/2020...  2020  10  2020
# 4    http://www.marieclairekorea.com/beauty/2020/10...  2020  10  2020
# ..                                                 ...   ...  ..   ...
# ...

# %%
marie_dior['mon'] = marie_dior['link'].str.split('/').str[5]

# %%
marie_dior['mon']
# Out:
# 0      11
# 1      11
# 2      11
# 3      10
# 4      10
#        ..
# 686    01
# 687    02
# 688    12
# 689    09
# 690    05
# Name: mon, Length: 691, dtype: object

# %%
marie_dior['date'] = marie_dior['year'].astype(str)+'-'+marie_dior['mon'].astype(str)
marie_dior.head()
# Out:
#    Unnamed: 0                 title  \
# 0           0     Scenery Of Autumn
# 1           1       <스타트업> 수지 패션 탐구
# 2           2  HAPPY EARLY HOLIDAY!
# 3           3                이준의 고요
# 4           4                보습의 정석
#
#                                                 link     date mon  year
# 0  http://www.marieclairekorea.com/fashion/2020/1...  2020-11  11  2020
# 1  http://www.marieclairekorea.com/fashion/2020/1...  2020-11  11  2020
# 2  http://www.marieclairekorea.com/beauty/2020/11...  2020-11  11  2020
# 3  http://www.marieclairekorea.com/celebrity/2020...  2020-10  10  2020
# 4  http://www.marieclairekorea.com/beauty/2020/10...  2020-10  10  2020

# %%
marie_dior[['title', 'link', 'date']]
# Out:
#                     title                                               link  \
# 0       Scenery Of Autumn  http://www.marieclairekorea.com/fashion/2020/1...
# 1         <스타트업> 수지 패션 탐구  http://www.marieclairekorea.com/fashion/2020/1...
# 2    HAPPY EARLY HOLIDAY!  http://www.marieclairekorea.com/beauty/2020/11...
# 3                  이준의 고요  http://www.marieclairekorea.com/celebrity/2020...
# 4                  보습의 정석  http://www.marieclairekorea.com/beauty/2020/10...
# ..                    ...                                                ...
# 686             화장대를 부탁해!  http://www.marieclairekorea.com/beauty/2015/01...
# 687          My Fair Lady  http://www.marieclairekorea.com/celebrity/2014...
# 688               지창욱의 탐색  http://www.marieclairekorea.com/celebrity/2013...
# 689        C’Est Chouette  http://www.marieclairekorea.com/celebrity/2013...
# 690         참 괜찮은 뮤지션 박재범  http://www.marieclairekorea.com/celebrity/2013...
#
#         date
# 0    2020-11
# 1    2020-11
# ...

# %%
def get_date(df):
    df['year'] = df['link'].str.split('/').str[4]
    df['mon'] = df['link'].str.split('/').str[5]
    df['date'] = df['year'].astype(str)+'-'+df['mon'].astype(str)
    display(df)

# %%
get_date(marie_chanel)
# Out:
#      Unnamed: 0                                title  \
# 0             0                    Scenery Of Autumn
# 1             1             연말 파티 메이크업은 펑크 메이크업이 대세!
# 2             2                 HAPPY EARLY HOLIDAY!
# 3             3                               보습의 정석
# 4             4  2021 S/S FASHION WEEK REVIEW #PARIS
# ..          ...                                  ...
# 732         732                         할머니 옷장을 뒤져라!
# 733         733                  미러 선글라스를 위한 메이크업 키트
# 734         734                          Pretty Girl
# 735         735                            화장대를 부탁해!
# 736         736                        Unknown Woman
#
#                                                   link  year mon     date
# 0    http://www.marieclairekorea.com/fashion/2020/1...  2020  11  2020-11
# 1    http://www.marieclairekorea.com/beauty/2020/11...  2020  11  2020-11
# 2    http://www.marieclairekorea.com/beauty/2020/11...  2020  11  2020-11
# ...

# %%
marie_chanel['year'].unique()
# Out:
# array(['2020', '2019', '2018', '2017', '2016', '2015', '2014'],
#       dtype=object)

# %%
# marie_chanel.loc[(marie_chanel['year'] == 'fashion-video') | (marie_chanel['year'] == 'beauty-video'), 'year'] = marie_chanel.loc[(marie_chanel['year'] == 'fashion-video') | (marie_chanel['year'] == 'beauty-video'), 'link'].str.split('/').str[5]
# marie_chanel.loc[(marie_chanel['year'] == 'fashion-video') | (marie_chanel['year'] == 'beauty-video'), 'mon'] = marie_chanel.loc[(marie_chanel['year'] == 'fashion-video') | (marie_chanel['year'] == 'beauty-video'), 'link'].str.split('/').str[6]

# %%
# marie_chanel.loc[marie_chanel['year'] == 'star', 'year'] = marie_chanel.loc[marie_chanel['year'] == 'star', 'link'].str.split('/').str[5]
# marie_chanel.loc[marie_chanel['year'] == 'star', 'mon'] = marie_chanel.loc[marie_chanel['year'] == 'star', 'link'].str.split('/').str[6]

# %%
marie_chanel.loc[marie_chanel['year'] == '']
# Out:
#     Unnamed: 0                  title  \
# 17          17  샤넬 루쥬 알뤼르 라끄 프라이빗 품평단
#
#                                                  link year  mon  date
# 17  http://www.marieclairekorea.com/%ec%83%a4%eb%8...       NaN  -nan

# %%
marie_chanel.dropna(inplace = True)

# %%
marie_chanel
# Out:
#      Unnamed: 0                                title  \
# 0             0                    Scenery Of Autumn
# 1             1             연말 파티 메이크업은 펑크 메이크업이 대세!
# 2             2                 HAPPY EARLY HOLIDAY!
# 3             3                               보습의 정석
# 4             4  2021 S/S FASHION WEEK REVIEW #PARIS
# ..          ...                                  ...
# 732         732                         할머니 옷장을 뒤져라!
# 733         733                  미러 선글라스를 위한 메이크업 키트
# 734         734                          Pretty Girl
# 735         735                            화장대를 부탁해!
# 736         736                        Unknown Woman
#
#                                                   link  year mon     date
# 0    http://www.marieclairekorea.com/fashion/2020/1...  2020  11  2020-11
# 1    http://www.marieclairekorea.com/beauty/2020/11...  2020  11  2020-11
# 2    http://www.marieclairekorea.com/beauty/2020/11...  2020  11  2020-11
# ...

# %%
get_date(marie_dior)
# Out:
#      Unnamed: 0                 title  \
# 0             0     Scenery Of Autumn
# 1             1       <스타트업> 수지 패션 탐구
# 2             2  HAPPY EARLY HOLIDAY!
# 3             3                이준의 고요
# 4             4                보습의 정석
# ..          ...                   ...
# 686         686             화장대를 부탁해!
# 687         687          My Fair Lady
# 688         688               지창욱의 탐색
# 689         689        C’Est Chouette
# 690         690         참 괜찮은 뮤지션 박재범
#
#                                                   link     date mon  year
# 0    http://www.marieclairekorea.com/fashion/2020/1...  2020-11  11  2020
# 1    http://www.marieclairekorea.com/fashion/2020/1...  2020-11  11  2020
# 2    http://www.marieclairekorea.com/beauty/2020/11...  2020-11  11  2020
# 3    http://www.marieclairekorea.com/celebrity/2020...  2020-10  10  2020
# 4    http://www.marieclairekorea.com/beauty/2020/10...  2020-10  10  2020
# ...

# %%
marie_dior['year'].unique()
# Out:
# array(['2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013'],
#       dtype=object)

# %%
marie_dior.loc[marie_dior['year'] == 'fashion-video', 'year'] = marie_dior.loc[marie_dior['year'] == 'fashion-video', 'link'].str.split('/').str[5]
marie_dior.loc[marie_dior['year'] == 'fashion-video', 'mon'] = marie_dior.loc[marie_dior['year'] == 'fashion-video', 'link'].str.split('/').str[6]

# %%
get_date(marie_ysl)
# Out:
#      Unnamed: 0                   title  \
# 0             0              코트 속 러플 셔츠
# 1             1            가을 아우터 코드 #2
# 2             2        BACK TO THE 90’S
# 3             3      AUTUMN VELVET LIPS
# 4             4      부담스럽지 않아, 볼드한 주얼리.
# ..          ...                     ...
# 186         186          원더걸스 유빈의 걸 크러시
# 187         187  원더걸스 유빈의 걸 크러시 – Video
# 188         188               유빈의 B컷 화보
# 189         189          마이크로 백 마니아의 네일
# 190         190           참 괜찮은 뮤지션 박재범
#
#                                                   link  year mon     date
# 0    http://www.marieclairekorea.com/fashion/2020/1...  2020  11  2020-11
# 1    http://www.marieclairekorea.com/fashion/2020/1...  2020  10  2020-10
# 2    http://www.marieclairekorea.com/beauty/2020/10...  2020  10  2020-10
# 3    http://www.marieclairekorea.com/beauty/2020/10...  2020  10  2020-10
# 4    http://www.marieclairekorea.com/fashion/2020/0...  2020  09  2020-09
# ...

# %%
marie_ysl['year'].unique()
# Out:
# array(['2020', '2019', '2018', '2017', '2016', '2015', '2013'],
#       dtype=object)

# %%
get_date(marie_celine)
# Out:
#      Unnamed: 0                               title  \
# 0             0                     MASCULINE SCENE
# 1             1  2020 F/W BEAUTY TREND FORECAST – 2
# 2             2                              낭만의 시대
# 3             3                              DOUBLE
# 4             4                 2020 F/W 뷰티 트렌드 프리뷰
# ..          ...                                 ...
# 177         177                            요즘 뭐 드니?
# 178         178                       Woman In Gold
# 179         179                        디자이너들의 리얼 룩!
# 180         180                              유정의 여정
# 181         181               가늘고 길게, 새로운 감성의 미니멀 룩
#
#                                                   link  year mon     date
# 0    http://www.marieclairekorea.com/fashion/2020/1...  2020  10  2020-10
# 1    http://www.marieclairekorea.com/beauty/2020/10...  2020  10  2020-10
# 2    http://www.marieclairekorea.com/fashion/2020/0...  2020  09  2020-09
# ...

# %%
marie_celine['year'].unique()
# Out:
# array(['2020', '2019', '2018', '2017', '2016', '2015'], dtype=object)

# %%
def get_dt(df):
    df['date'] = df['year'].astype(str)+'-'+df['mon'].astype(str)

# %%
get_dt(marie_chanel)
get_dt(marie_dior)
get_dt(marie_ysl)
get_dt(marie_celine)

# %% [markdown]
# ### 2016년 9월 이전 삭제

# %%
def drop_year(df):
    df.loc[df['year'].astype(int) < 2016, 'year'] = np.NaN
    df.dropna(inplace = True)
    df.loc[(df['year'].astype(int) == 2016) & (df['mon'].astype(int) <9), 'mon'] = np.NaN
    df.dropna(inplace = True)

# %%
marie_chanel
# Out:
# Empty DataFrame
# Columns: [title, link, date, self, year]
# Index: []

# %%
marie_chanel.dropna(inplace=True)

# %%
drop_mon(marie_chanel)

# %%
marie_chanel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 642 entries, 0 to 642
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  642 non-null    int64
#  1   title       642 non-null    object
#  2   link        642 non-null    object
#  3   year        642 non-null    object
#  4   mon         642 non-null    object
#  5   date        642 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 35.1+ KB

# %%
print(len(marie_chanel))
print('-'*50)
drop_year2(marie_chanel)
print(len(marie_chanel))
# Out:
# 642
# --------------------------------------------------
# 0
# C:\Users\wnsgo\anaconda3\lib\site-packages\pandas\core\indexing.py:844: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\wnsgo\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# C:\Users\wnsgo\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# ...

# %%
print(len(marie_dior))
print('-'*50)
drop_year(marie_dior)
print(len(marie_dior))

# %%
print(len(marie_ysl))
print('-'*50)
drop_year(marie_ysl)
print(len(marie_ysl))
# Out:
# 191
# --------------------------------------------------
# 151

# %%
print(len(marie_celine))
print('-'*50)
drop_year(marie_celine)
print(len(marie_celine))
# Out:
# 182
# --------------------------------------------------
# 177

# %%
marie_chanel = marie_chanel[['title', 'link', 'date']]
marie_dior = marie_dior[['title', 'link', 'date']]
marie_ysl = marie_ysl[['title', 'link', 'date']]
marie_celine = marie_celine[['title', 'link', 'date']]

# %%
marie_dior.loc[marie_dior['date'].str[:4].astype(int)<2016, 'date'] = np.NaN
marie_ysl.loc[marie_ysl['date'].str[:4].astype(int)<2016, 'date'] = np.NaN
marie_celine.loc[marie_celine['date'].str[:4].astype(int)<2016, 'date'] = np.NaN
# Out:
# C:\Users\wnsgo\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
print(len(marie_dior))
marie_dior.dropna(inplace = True)
print(len(marie_dior))
# Out:
# 627
# 589
# C:\Users\wnsgo\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(len(marie_ysl))
marie_ysl.dropna(inplace = True)
print(len(marie_ysl))
# Out:
# 151
# 144
# C:\Users\wnsgo\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(len(marie_celine))
marie_celine.dropna(inplace = True)
print(len(marie_celine))
# Out:
# 177
# 175

# %% [markdown]
# ### 기사제목에 브랜드명 포함된 기사 찾기

# %%
def get_self(df, kw):
    df['self'] = 0
    df.loc[df['title'].str.contains(kw), 'self'] = 1
    display(df[df['title'].str.contains(kw)])

# %%
get_self(marie_chanel, '샤넬')
get_self(marie_dior, '디올')
get_self(marie_ysl, '생로랑')
get_self(marie_celine, '셀린느')
# Out:
# C:\Users\wnsgo\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\wnsgo\anaconda3\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#                                               title  \
# 7                                       샤넬의 영화적 모먼트
# 13                          샤넬 2020 F/W 컬렉션 그리고 김고은
# 44   소피아 코폴라가 촬영한 샤넬 2019/20 파리-깡봉가 31번지 공방 컬렉션 캠페인
# ...

# %%
marie_chanel.to_csv('marie_chanel.csv', sep='|', encoding='utf-8', index = False)
marie_dior.to_csv('marie_dior.csv', sep='|', encoding='utf-8', index = False)
marie_ysl.to_csv('marie_ysl.csv', sep='|', encoding='utf-8', index = False)
marie_celine.to_csv('marie_celine.csv', sep='|', encoding='utf-8', index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-3e4768a42913> in <module>()
# ----> 1 marie_chanel.to_csv('marie_chanel.csv', sep='|', encoding='utf-8', index = False)
#       2 marie_dior.to_csv('marie_dior.csv', sep='|', encoding='utf-8', index = False)
#       3 marie_ysl.to_csv('marie_ysl.csv', sep='|', encoding='utf-8', index = False)
#       4 marie_celine.to_csv('marie_celine.csv', sep='|', encoding='utf-8', index = False)
#
# NameError: name 'marie_chanel' is not defined

# %% [markdown]
# ### 본문 읽어보기

# %%
marie_chanel['fashion'] = 0

# %%
marie_chanel.loc[marie_chanel['link'].str.split('/').str[3] == 'fashion', 'fashion'] = 1

# %%
marie_chanel['check'] = 0

# %%
marie_chanel['why'] = ''

# %%
marie_chanel.head()
# Out:
#                                  title  \
# 0                    Scenery Of Autumn
# 1             연말 파티 메이크업은 펑크 메이크업이 대세!
# 2                 HAPPY EARLY HOLIDAY!
# 3                               보습의 정석
# 4  2021 S/S FASHION WEEK REVIEW #PARIS
#
#                                                 link     date  self  fashion  \
# 0  http://www.marieclairekorea.com/fashion/2020/1...  2020-11     0        1
# 1  http://www.marieclairekorea.com/beauty/2020/11...  2020-11     0        0
# 2  http://www.marieclairekorea.com/beauty/2020/11...  2020-11     0        0
# 3  http://www.marieclairekorea.com/beauty/2020/10...  2020-10     0        0
# 4  http://www.marieclairekorea.com/fashion/2020/1...  2020-10     0        1
#
#    check why
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
marie_chanel.to_csv('marie_chanel.csv', sep='|', encoding='utf-8', index=False)

# %% [markdown]
# ### 본문 크롤링

# %%
marie_dior = pd.read_csv('marie_dior.csv', encoding='utf-8', sep = '|')

marie_celine = pd.read_csv('marie_celine.csv', encoding='utf-8', sep = '|')

# %%
path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)
driver

# content_list = []

for i in range(57, len(marie_celine)):
    url = marie_celine['link'][i]
    driver.get(url)
    
    print(i, driver.current_url)
    
    para = []
    
    contents = driver.find_element_by_css_selector('div.post-content')
    
    p_contents = contents.find_elements_by_css_selector('p')
    
    for content_ in p_contents:
        para.append(content_.text)
        
    content_list.append(para)
    
    time.sleep(20)

    
marie_celine['content'] = content_list
print(len(marie_celine))
print(len(content_list))
# Out:
# 57 http://www.marieclairekorea.com/fashion/2019/02/2019-%ed%82%a4%ec%9b%8c%eb%93%9c/
# 58 http://www.marieclairekorea.com/fashion/2019/01/2019%eb%85%84-%ed%94%84%eb%a6%ac%ed%8f%b4-%ec%bb%ac%eb%a0%89%ec%85%98-%ec%8a%88%ed%8d%bc%ec%8a%a4%ed%83%80/
# 59 http://www.marieclairekorea.com/fashion/2019/01/%eb%82%98%eb%a7%8c-%ec%95%8c%ea%b3%a0-%ec%8b%b6%ec%9d%80-%ec%95%a1%ec%84%b8%ec%84%9c%eb%a6%ac-%eb%b8%8c%eb%9e%9c%eb%93%9c-5/
# 60 http://www.marieclairekorea.com/fashion/2019/01/%ec%83%88%ed%95%b4%ec%97%94-%eb%b9%a8%ea%b0%84%ec%a7%80%ea%b0%91/
# 61 http://www.marieclairekorea.com/fashion/2018/12/2018%eb%85%84%ec%9d%84-%ea%b8%b0%ec%96%b5%ed%95%98%eb%a9%b0/
# 62 http://www.marieclairekorea.com/fashion/2018/12/%eb%94%b0%eb%9c%bb%ed%95%98%ea%b3%a0-%ec%95%84%eb%a6%84%eb%8b%a4%ec%9a%b4-%eb%b0%a9%ed%95%9c%ed%85%9c/
# 63 http://www.marieclairekorea.com/fashion/2018/11/%eb%a1%9c%ea%b3%a0-%ec%a0%95%ec%8b%a0/
# ...

# %%
print(len(marie_celine))
print(len(content_list))
print(content_list)
# Out:
# 175
# 175
# ...

# %%
marie_celine
# Out:
#                                     title  \
# 0                         MASCULINE SCENE
# 1      2020 F/W BEAUTY TREND FORECAST – 2
# 2                                  낭만의 시대
# 3                                  DOUBLE
# 4                     2020 F/W 뷰티 트렌드 프리뷰
# 5                                패셔너블한 향수
# 6                               처음 보는 안소희
# 7                         2020 F/W 패션 트렌드
# 8                              태양을 피하는 방법
# 9                              아쉽거나, 반갑거나
# 10                              정경호가 되기까지
# 11                               영원불멸 클래식
# 12                           CLASH ON YOU
# 13                                 셔츠의 품격
# 14                               그 때 그 시절
# 15                           출구 없는 매력, 수트
# 16                             THEMSELVES
# 17                       PYRAMID OF GIFTS
# 18                               블레이저 사세요
# 19                           ADD HEADWEAR
# 20                          SUIT YOURSELF
# ...

# %%
marie_celine['check'] = 0
marie_celine['why'] = ''

# %%
marie_celine
# Out:
#                                     title  \
# 0                         MASCULINE SCENE
# 1      2020 F/W BEAUTY TREND FORECAST – 2
# 2                                  낭만의 시대
# 3                                  DOUBLE
# 4                     2020 F/W 뷰티 트렌드 프리뷰
# 5                                패셔너블한 향수
# 6                               처음 보는 안소희
# 7                         2020 F/W 패션 트렌드
# 8                              태양을 피하는 방법
# 9                              아쉽거나, 반갑거나
# 10                              정경호가 되기까지
# 11                               영원불멸 클래식
# 12                           CLASH ON YOU
# 13                                 셔츠의 품격
# 14                               그 때 그 시절
# 15                           출구 없는 매력, 수트
# 16                             THEMSELVES
# 17                       PYRAMID OF GIFTS
# 18                               블레이저 사세요
# 19                           ADD HEADWEAR
# 20                          SUIT YOURSELF
# ...

# %% [markdown]
# ### 디올

# %%
path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)
driver

# content_list = []

for i in range(345, len(marie_dior)):
    url = marie_dior['link'][i]
    driver.get(url)
    
    print(i, driver.current_url)
    
    para = []
    
    contents = driver.find_element_by_css_selector('div.post-content')
    
    p_contents = contents.find_elements_by_css_selector('p')
    
    for content in p_contents:
        para.append(content.text)
        
    content_list.append(para)
    
    time.sleep(10)

    

print(len(marie_dior))
print(len(content_list))
# Out:
# 345 http://www.marieclairekorea.com/fashion/2018/07/%ec%b7%a8%ed%96%a5-%eb%94%b0%eb%9d%bc-%eb%b9%88%ed%8b%b0%ec%a7%80-%ec%88%8d/
# 346 http://www.marieclairekorea.com/video/2018/07/sunset-rhapsody-video/
# 347 http://www.marieclairekorea.com/fashion/2018/07/the-new-inspire/
# 348 http://www.marieclairekorea.com/fashion/2018/07/%ec%97%ac%eb%a6%84-%ec%a3%bc%ec%96%bc%eb%a6%ac-%ec%b2%b4%ec%9d%b8%eb%b8%8c%eb%a0%88%ec%9d%b4%ec%8a%ac%eb%a6%bf/
# 349 http://www.marieclairekorea.com/beauty/2018/07/lash-tattoo/
# 350 http://www.marieclairekorea.com/beauty/2018/07/2019-ss-%eb%94%94%ec%98%ac-%eb%a7%a8%ec%9d%98-%ec%96%bc%ea%b5%b4/
# 351 http://www.marieclairekorea.com/fashion/2018/07/the-diorodeo/
# 352 http://www.marieclairekorea.com/fashion/2018/07/sunset-rhapsody/
# 353 http://www.marieclairekorea.com/beauty/2018/07/new-muse-of-dior-%ec%a0%9c%eb%8b%88%ed%8d%bc-%eb%a1%9c%eb%a0%8c%ec%8a%a4/
# 354 http://www.marieclairekorea.com/fashion/2018/07/shine-on-me-long-chain-necklace/
# ...

# %%
print(len(marie_dior))
print(len(content_list))
print(content_list)
# Out:
# 589
# 589
# ...

# %%
marie_dior['content'] = content_list

# %%
marie_dior
# Out:
#                                     title  \
# 0                       Scenery Of Autumn
# 1                         <스타트업> 수지 패션 탐구
# 2                    HAPPY EARLY HOLIDAY!
# 3                                  이준의 고요
# 4                                  보습의 정석
# 5     2021 S/S FASHION WEEK REVIEW #PARIS
# 6                       2020 WONDER KIDDY
# 7                    THINGS WE SAID TODAY
# 8                                  니트의 계절
# 9                   NAIL IN AUTUMN CLOSET
# 10                          Autumn Breeze
# 11                       BACK TO THE 90’S
# 12                       MY SCENT JOURNEY
# 13                               FOR FALL
# 14                     AUTUMN VELVET LIPS
# 15                            영원불변의 클래식 백
# 16                          Unforgettable
# 17                            계속해서 나아갈 용기
# 18                         A PEACEFUL DAY
# 19                              앵두같은 내 입술
# 20                              여전히 첼시 부츠
# ...

# %%
marie_dior['check'] = 0
marie_dior['why'] = ''

# %%
marie_dior
# Out:
#                                     title  \
# 0                       Scenery Of Autumn
# 1                         <스타트업> 수지 패션 탐구
# 2                    HAPPY EARLY HOLIDAY!
# 3                                  이준의 고요
# 4                                  보습의 정석
# 5     2021 S/S FASHION WEEK REVIEW #PARIS
# 6                       2020 WONDER KIDDY
# 7                    THINGS WE SAID TODAY
# 8                                  니트의 계절
# 9                   NAIL IN AUTUMN CLOSET
# 10                          Autumn Breeze
# 11                       BACK TO THE 90’S
# 12                       MY SCENT JOURNEY
# 13                               FOR FALL
# 14                     AUTUMN VELVET LIPS
# 15                            영원불변의 클래식 백
# 16                          Unforgettable
# 17                            계속해서 나아갈 용기
# 18                         A PEACEFUL DAY
# 19                              앵두같은 내 입술
# 20                              여전히 첼시 부츠
# ...

# %%
marie_dior.to_csv('marie_dior.csv', sep='|', encoding='utf-8', index = False)

# %%
marie_dior['content'] = marie_dior['content'].astype(str)

# %%
for i in range(len(marie_dior)):
    if marie_dior['self'][i] == 0:
        if not '디올' in marie_dior['content'][i]:
            marie_dior['check'][i] = 2
# Out:
# C:\Users\i\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
marie_dior
# Out:
#                                     title  \
# 0                       Scenery Of Autumn
# 1                         <스타트업> 수지 패션 탐구
# 2                    HAPPY EARLY HOLIDAY!
# 3                                  이준의 고요
# 4                                  보습의 정석
# 5     2021 S/S FASHION WEEK REVIEW #PARIS
# 6                       2020 WONDER KIDDY
# 7                    THINGS WE SAID TODAY
# 8                                  니트의 계절
# 9                   NAIL IN AUTUMN CLOSET
# 10                          Autumn Breeze
# 11                       BACK TO THE 90’S
# 12                       MY SCENT JOURNEY
# 13                               FOR FALL
# 14                     AUTUMN VELVET LIPS
# 15                            영원불변의 클래식 백
# 16                          Unforgettable
# 17                            계속해서 나아갈 용기
# 18                         A PEACEFUL DAY
# 19                              앵두같은 내 입술
# 20                              여전히 첼시 부츠
# ...

# %%
marie_dior[marie_dior['check'] == 0]
# Out:
#                                     title  \
# 1                         <스타트업> 수지 패션 탐구
# 2                    HAPPY EARLY HOLIDAY!
# 4                                  보습의 정석
# 5     2021 S/S FASHION WEEK REVIEW #PARIS
# 8                                  니트의 계절
# 14                     AUTUMN VELVET LIPS
# 15                            영원불변의 클래식 백
# 19                              앵두같은 내 입술
# 20                              여전히 첼시 부츠
# 21                              가을엔 레드 립.
# 22                            디지털 나라의 런웨이
# 25             습한 여름부터 건조한 겨울까지 사계절 쓰는 립밤
# 26                    2020 F/W 뷰티 트렌드 프리뷰
# 27                               패셔너블한 향수
# 28                              말을 타는 여성들
# 31               디올 뷰티의 뮤즈, 지수와 함께한 뷰티 필름
# 33                          BEAUTY BEHIND
# 35                                지수다운 순간
# 37                       패션 에디터들이 입어본 스커트
# 39          원스 어폰 어 타임, 과거에서 영감 받은 패션 스타일
# 40                          지금 핫!한 콜라보레이션
# ...

# %%
len(marie_dior[marie_dior['check'] == 0])
# Out:
# 370

# %%
marie_celine.to_csv('marie_celine.csv', sep='|', encoding='utf-8', index = False)

# %% [markdown]
# ### 로랑으로 다시 크롤링

# %%
start = time.time()

path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)

title = []
link = []

for page in range(1,41):
    url='http://www.marieclairekorea.com/page/'+str(page)+'/?s=%EB%A1%9C%EB%9E%91'
    driver.get(url)
    
    print(driver.current_url)
    
    contElements = driver.find_elements_by_css_selector('article')

    for cont in contElements:
        # 타이틀 가져오기
        title.append(cont.find_element_by_tag_name('h2').text)
        

        # 링크 가져오기
        link.append(cont.find_element_by_tag_name('a').get_attribute('href'))
        
        time.sleep(5)
print(title)
print(len(title), len(link))


print(time.time() - start)
# Out:
# http://www.marieclairekorea.com/page/1/?s=%EB%A1%9C%EB%9E%91
# http://www.marieclairekorea.com/page/2/?s=%EB%A1%9C%EB%9E%91
# http://www.marieclairekorea.com/page/3/?s=%EB%A1%9C%EB%9E%91
# http://www.marieclairekorea.com/page/4/?s=%EB%A1%9C%EB%9E%91
# http://www.marieclairekorea.com/page/5/?s=%EB%A1%9C%EB%9E%91
# http://www.marieclairekorea.com/page/6/?s=%EB%A1%9C%EB%9E%91
# http://www.marieclairekorea.com/page/7/?s=%EB%A1%9C%EB%9E%91
# http://www.marieclairekorea.com/page/8/?s=%EB%A1%9C%EB%9E%91
# http://www.marieclairekorea.com/page/9/?s=%EB%A1%9C%EB%9E%91
# http://www.marieclairekorea.com/page/10/?s=%EB%A1%9C%EB%9E%91
# http://www.marieclairekorea.com/page/11/?s=%EB%A1%9C%EB%9E%91
# http://www.marieclairekorea.com/page/12/?s=%EB%A1%9C%EB%9E%91
# http://www.marieclairekorea.com/page/13/?s=%EB%A1%9C%EB%9E%91
# http://www.marieclairekorea.com/page/14/?s=%EB%A1%9C%EB%9E%91
# http://www.marieclairekorea.com/page/15/?s=%EB%A1%9C%EB%9E%91
# ...

# %%
marie_ysl = pd.DataFrame({
    'title':title,
    'link':link
})
marie_ysl.head()
# Out:
#                   title                                               link
# 0            코트 속 러플 셔츠  http://www.marieclairekorea.com/fashion/2020/1...
# 1  THINGS WE SAID TODAY  http://www.marieclairekorea.com/celebrity/2020...
# 2    THE SENSUAL THINGS  http://www.marieclairekorea.com/fashion/2020/1...
# 3          가을 아우터 코드 #2  http://www.marieclairekorea.com/fashion/2020/1...
# 4      BACK TO THE 90’S  http://www.marieclairekorea.com/beauty/2020/10...

# %% [markdown]
# ### 본문 가져오기

# %%
path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)
driver

# content_list = []

for i in range(296, len(marie_ysl)):
    url = marie_ysl['link'][i]
    driver.get(url)
    
    print(i, driver.current_url)
    
    para = []
    
    contents = driver.find_element_by_css_selector('div.post-content')
    
    p_contents = contents.find_elements_by_css_selector('p')
    
    for content in p_contents:
        para.append(content.text)
        
    content_list.append(para)
    
    time.sleep(10)

    

print(len(marie_ysl))
print(len(content_list))
# Out:
# 296 http://www.marieclairekorea.com/beauty/2016/07/%eb%a6%bd%ec%8a%a4%ed%8b%b1-%eb%b0%9c%ec%83%89-%ed%9b%84%ea%b8%b0/
# 297 http://www.marieclairekorea.com/fashion/2016/07/new-and-pretty/
# 298 http://www.marieclairekorea.com/fashion/2016/07/%ec%a3%bc%eb%aa%a9%ed%95%a0-%eb%a7%8c%ed%95%9c-%ec%83%88%eb%a1%9c%ec%9a%b4-%ec%8b%a4%eb%a3%a8%ec%97%a3-4/
# 299 http://www.marieclairekorea.com/fashion/2016/07/von-voyage-black-white/
# 300 http://www.marieclairekorea.com/fashion/2016/07/von-voyage-sportism/
# 301 http://www.marieclairekorea.com/fashion/2016/07/von-voyage-tropical/
# 302 http://www.marieclairekorea.com/fashion/2016/07/end-of-summer/
# 303 http://www.marieclairekorea.com/beauty/2016/07/summer-lips-tips-%ed%95%91%ed%81%ac%ec%98%a4%eb%a0%8c%ec%a7%80/
# 304 http://www.marieclairekorea.com/beauty/2016/07/ultra-waterproof/
# 305 http://www.marieclairekorea.com/fashion/2016/07/sun-is-shining-and-so-are-you/
# ...

# %%
print(len(marie_ysl))
print(len(content_list))
# Out:
# 391
# 391

# %%
marie_ysl['content'] = content_list

# %%
marie_ysl
# Out:
#                                    title  \
# 0                             코트 속 러플 셔츠
# 1                   THINGS WE SAID TODAY
# 2                     THE SENSUAL THINGS
# 3                           가을 아우터 코드 #2
# 4                       BACK TO THE 90’S
# 5     2020 F/W BEAUTY TREND FORECAST – 2
# 6                     AUTUMN VELVET LIPS
# 7                     부담스럽지 않아, 볼드한 주얼리.
# 8                                 달콤한 인생
# 9                              여전히 첼시 부츠
# 10       하룻밤 만에 달라지는 피부, Just One Night!
# 11                            묶고 묶고 또 묶고
# 12                     쇼타임! 잊을 수 없는 패션 쇼
# 13         원스 어폰 어 타임, 과거에서 영감 받은 패션 스타일
# 14                         MIRROR MIRROR
# 15                             한여름, 액세서리
# 16                            태양을 피하는 방법
# 17                            7월의 뷰티 신제품
# 18                        6월의 뷰티 신제품 #향수
# 19                     샤넬 공방 이야기 ① – 르사주
# 20                          CLASH ON YOU
# 21                          #성년의날 선물 리스트
# ...

# %%
marie_ysl.to_csv('marie_ysl.csv', sep='|', encoding='utf-8', index = False)
