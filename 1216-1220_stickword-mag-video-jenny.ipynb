# %%
import pandas as pd
import numpy as np

# %%
from collections import Counter

# %%
tot_je = pd.read_csv('./magazine/final/video_je_adfn.csv', sep='|', encoding = 'utf-8')

# %%
tot_je
# Out:
#     magazine    brand                                              title  \
# 0    YOUTUBE  YOUTUBE  BLACKPINK - 'KILL THIS LOVE' JENNIE TEASER VID...
# 1    YOUTUBE  YOUTUBE  BLACKPINK - JENNIE 'Don't Know What To Do' FOC...
# 2    YOUTUBE  YOUTUBE  BLACKPINK - JENNIE 'Forever Young' FOCUSED CAM...
# 3    YOUTUBE  YOUTUBE  BLACKPINK - JENNIE '뚜두뚜두 (DDU-DU DDU-DU)' FOCU...
# 4    YOUTUBE  YOUTUBE  JENNIE - 'SOLO' CHOREOGRAPHY CUT TEASER_korean...
# ..       ...      ...                                                ...
# 346        W       Je                           블랙핑크X세레나 고메즈 영상통화, 협업 티징
# 347        W       Je                            블랙핑크가 아이스크림 셀카를 올린 이유는?
# 348        W       Je                               블랙핑크 컴백! 남다른 패션 스타일링
# 349        W       Je                           블랙핑크 로제, 리사, 지수 솔로곡 공개한다
# 350        W       Je                              K팝 그룹 최초, 11억뷰 퀸 블랙핑크
#
#                                             word_jenny  \
# ...

# %%
tot_je['ADFN_2'] = tot_je['ADFN']

# %%
for word in tot_je['word_jenny']:
    if '움' in word:
        print(word)
        print('-'*50)
# Out:
# ['저 애매한 길이의 생머리와 샤네루 상의랑 하얀색 옷인거 거기에 이노래까지 진짜 이 날의 이 분위기가 너무 청초..??예쁘다  그냥....ㅠㅠ', '제니직캠 화려한게 많은데 이건진짜 애기같음 분냄새 날거같아 귀여움', '다들 이 노래는 로제노래라고 하는데 그냥 내가 제니가 더 좋은가보다 모든 노래가 그냥 다 제니노래같아ㅠㅠ 저 애매한 길이의 생머리가 어케 잘어울리는 것이며 제일 베이직한 의상인데 그냥 젤예쁘다  제니ㅠㅠ 제니 사댱해 지쨔ㅠㅠㅠ샤네루 제니', '제니 마르고 몸매예쁘다 서 키 167은 되는줄 알았는데 163이라고해서 놀랬다ㅠㅠㅠ 진짜 비율도 너무 좋고 마르고 완전 예쁘다  진짜ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ', '하 진짜 이렇게 고급지게 생긴 사람이 또 있을까ㅠㅠ', '컴백 언제해 ㅡㅠㅜ 계속 미뤄지는 거 아니지?', '개예쁘다 ,,,  언니 사랑해요,,,', '너무 예쁘다 완벽해서 다른 세상 사람같아.. 분명 나보다 나이 네다섯살 많은 언니일뿐인데', '불랙핑크 엄청난 팬이지만 이노래는 로재를 위한 노래라고 할수있다 음색 너무 잘어율려', '와 진짜 세상에서 제일 예쁘다  울 제니 사랑해..ㅠ%ㅠ', '미추리 보다가 이거 보니까 너무 적응 안된다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '항상 무대 할때 제니가 눈에 많이 들어옴 ㅠㅠ 너무 뼈처럼 마르지 않고 피부도 이영상에서는 살짝 어둠게 나왔는데 너무하얀거 보다 이런게 개성 있고 좋음ㅠ', '이 개띵곡ㅜㅜㅜㅜㅜ 하 모든게 완벽하다.. 엠알도 너무 잘 뽑았고 분위기며 다 완벽해', '하 너무 예쁘다 진짜ㅠㅠ', '아 난 제니언니 저 중단발이 너무 좋아..ㅠㅠ 긴머리 웨이브도 당연히 오지게 이쁘지만 저 중단발이 수수하고 훨씬 예쁘다 거같아..ㅠㅠ 물론 제니 언니 미모는 절대 수수하지 않지만..', '젤 고급져ㅠㅠㅠㅠ', '차분한 스타일도 잘어울려ㅠㅠ', '하 씨 언제 봐도 너무 좋아 언니  얼른 이 시기 끝나고 좋은 노래로 컴백해죠', '춤추면서 머리때매 젤 귀찮아보인다...', '제니 최
# ...

# %%
tot_je['ADFN'][0][0]
# Out:
# '['

# %%
for word in tot_je['ADFN_2']:
    if "우아" in word:
        print(word)
        print('-'*50)
# Out:
# ['지금', '불어', '배우는', '학생', '말', '하는데', '불어', '발', '존나', '어렵답니다', '제니', '발음', '완벽하다', '사람', '프랑스어', '하니', '고급', '짐', '귀엽다', '사랑스러', '움', '한번', '느껴질수', '있지', 'BLACKPINK', '해외', '진짜', '인기', '많은가보다', '한국어', '댓글', '없넼', '언어', '재능', '데', '제니', '언어능력', '둡', '취미', '우아하게', '하네', '승마', '양궁', '사격', '지금', '불어', '하고', '싶다고', '시대', '공주', '없네', '프랑스어', '하니까', '진짜', '고급', '지다', '제니', 'looks', 'very', 'classy', 'when', 'she', 'speaks', 'French', '불문', '졸업생', '제니', '발음', '좋네욬', '한국인', '악센트', '살짝', '들어있지만', '아주', '미미하게', '들어있고', '전체', '발음', '광장', '좋네요', '악센트', '약하니', '알아듣', '기도', '쉽고', '한국', '연예인', '불어', '발음', '최고', '같네요', '더', '하면', '원어민', '발음', '정말', '비슷해질', '듯', '제니', '어쩜', '하는게', '없냐', '요즘', '리사', 'BLACKPINK', '입덕', '해서', '헤어', '나올수가', '없다', '학', '헐', '제니', '프랑스', '영화', '튀어나온', '줄', '요새', '보고', '있는', '에밀리', '파리', '가다', '그거', '보는줄', '알았음', '고급', '지지', '쥬뗌므', '원래', '귀엽다', '단어', '임', '존나', '예쁘다', '미쳤나', '제니', '불어', '느낌', '바이킹', '탈때', '배', '질', '질', '느낌', '프랑스인', '댓글', '제니', '발음', '좋다고', '하네요', '외국인', '
# ...

# %%
# 걸크러시
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'걸', '크러시", "걸크러시")
# 걸크러쉬
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'걸', '크러쉬'", "걸크러시")
# 걸크
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'걸', '크'", "걸크러시")

# 걸그룹
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'걸', '그룹'", "걸그룹")

# %%
# 글로우
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'글', '로우'", "글로우")

# %%
# 아우터
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'아우', '터'", "아우터")

# %%
# 데일리
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'데', '일리'", "데일리")

# %%
# 볼륨감
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'볼륨', '감'", "볼륨감")
# 존재감
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'존재', '감'", "존재감")
# 통일감
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'통일', '감'", "통일감")

# %%
# 스타일링
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'스타', '일링'", "스타일링")

# %%
# 캐주얼
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'캐', '주얼'", "캐주얼")

# 비쥬얼
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'비쥬', '얼'", "비주얼")

# %%
# FW / SS
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'F', 'W'", "FW")
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'S', 'S'", "SS")

# %%
# 스포티
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'스포', '티'", "스포티")
# 프리티
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'프리', '티'", "프리티")

# %%
# 테일러 / 레이어
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'테일러', '드'", "테일러드")
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'레이어', '드'", "레이어드")

# %%
# 하이틴
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'하이', '틴'", "하이틴")

# %%
# 눈정화 / 눈호강
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'눈', '호강'", "눈호강")
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'눈', '정화'", "눈정화")

# %%
# 미추리
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'미추', '리'", "미추리")

# %%
# 뚜두뚜두 
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'뚜', '두', '뚜', '두'", "뚜두뚜두")
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'뚜', '두', '뚜'", "뚜두뚜두")

# %%
# 진짜
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'진', '짜'", "진짜")

# %%
# 비주얼
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'비주'", "비주얼")
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'visual'", "비주얼")

tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'아름다'", "아름다운")
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'아름답습니다'", "아름다운")
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'아름답고'", "아름다운")
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'아름답게'", "아름다운")
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'아름다워진다'", "아름다운")
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'아름다워'", "아름다운")
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'아름답습니다'", "아름다운")
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'아름답다'", "아름다운")

# %%
# 귀엽다
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'귀엽'", "귀엽다")
# 귀엽다
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'귀여운'", "귀엽다")


tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("elegance", "우아")

# %%
# 좋겠어요
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("좋겠어요", "좋겠다")
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("좋은", "좋아")
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("좋고", "좋아")
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("좋아하는", "좋아")
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("좋은데", "좋아")

# %%
# 우아
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'우아한'", "우아")
# 우아
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'우아하게'", "우아")
# 우아
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'우아함'", "우아")
# 우아
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'우아하다'", "우아")

# %%
# 진짜
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'진', '짜'", "진짜")
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("♡", "")

# 퀸
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'QUINN'", "퀸")
# 퀸
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'QUEEN'", "퀸")

# 최고
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'BEST'", "최고")
# 최고
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'최고다'", "최고")
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'원', '탑'", "원탑")


# 디자인
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'DESIGN'", "디자인")
# 이모지
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'♡'", "")
# 인플루언서
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'INFLUENCER'", "인플루언서")
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'CREATIVE'", "크리에이티브")

# 드
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'데이즈', '드'", "데이즈드")
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'레이어', '드'", "레이어드")

# 새롭
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'새롭'", "새로운")

# %%
# 사랑스러워
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'사랑스러워'", "사랑스럽다")
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'사랑스러운'", "사랑스럽다")

# %%
# 쩐다
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'쩐다'", "최고")
# 대박
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace("'대박'", "최고")

# %%
tot_je
# Out:
#     magazine    brand                                              title  \
# 0    YOUTUBE  YOUTUBE  BLACKPINK - 'KILL THIS LOVE' JENNIE TEASER VID...
# 1    YOUTUBE  YOUTUBE  BLACKPINK - JENNIE 'Don't Know What To Do' FOC...
# 2    YOUTUBE  YOUTUBE  BLACKPINK - JENNIE 'Forever Young' FOCUSED CAM...
# 3    YOUTUBE  YOUTUBE  BLACKPINK - JENNIE '뚜두뚜두 (DDU-DU DDU-DU)' FOCU...
# 4    YOUTUBE  YOUTUBE  JENNIE - 'SOLO' CHOREOGRAPHY CUT TEASER_korean...
# ..       ...      ...                                                ...
# 346        W       Je                           블랙핑크X세레나 고메즈 영상통화, 협업 티징
# 347        W       Je                            블랙핑크가 아이스크림 셀카를 올린 이유는?
# 348        W       Je                               블랙핑크 컴백! 남다른 패션 스타일링
# 349        W       Je                           블랙핑크 로제, 리사, 지수 솔로곡 공개한다
# 350        W       Je                              K팝 그룹 최초, 11억뷰 퀸 블랙핑크
#
#                                             word_jenny  \
# ...

# %% [markdown]
# ### stopword 추가

# %%
sw_df = pd.read_csv('stopwords.csv', header=None)

# %%
sw_df.columns = ['stopword']

# %%
stop_words = []
for sw in sw_df['stopword']:
    stop_words.append(sw)

# %%
print(len(stop_words))
print(type(stop_words))
# Out:
# 675
# <class 'list'>

# %%
stop_words[-10:]
# Out:
# ['둘', '셋', '넷', '다섯', '여섯', '일곱', '여덟', '아홉', '령', '영']

# %%
add_0 = ['진짜', '존나', '보고', '그냥', '카이', '이광수', '광수', '런닝맨', '❤️', '없는', '유재석', '❤', '♥', '♡', '♡','♡',
         '있고', '거', 
         '내', '더', '개', '사람', '영상', '광고', '언니', '말', '뭐', '수', '생각', '아는', 
        '있는', '정말', '같은', '같음', '듯', '♡', '완전', '같아', '정도', '지금', '역시', '뭔가', '입니다', '때문', '아니라',
         '함', '같은데', '해', '하는', '할', '넘', '한', '안', '했다', '보면', '데', '하고', '하면', '게', '해서', '봐도', 
         '한다', '된', '건', '요', '움', '임', '애', '하는거', '해도', '보는', '이제', '했는데', '하는데', '하는게', '같아요', 
         '합니다', '하지', '하게', '되는', 'I', '는', '난', '서', '도', '줄', '위', '분', '알', '은', '두', '번', '뒤',
         '이건', '없다', '있어요', '아니고', '있어', 
        '계속', '원래', '뭘', '못', '후', '이름', '속', '욕', '옆', '하네', '아님', '그런', '된다', '있음',
        '같', '돼', 'you', '제품', '표현', 'n', '봤는데', '건가', '나오는', '가지', '저런', '보이', '고',
        '중', '사진', '댓글', '부분', '진심', '그녀', '보', '날', '겁나', '요즘', '앞', '워', '이유', '솔직히', '하며', '통해',
        '모든', '항상', '전', '기자', '다시', '오늘', '↑', '이자', '대해',
        '링', '한편', '️⃣',
        '람쥐', '아닌가', '도민준', '없네', '이수근', '아이유', 'our', '젠', '였다면', '올해', '미우', 'The', 'my', '이란',
        '그게', '같고', '아니다', '아닌데', '있지',  '만큼', '백예린', '같네', 'we', '있게', '덕분', '있어서', '든', '썸넬',
        '라서', '여서', '라면', '인지', 'a','와중', '하자', '이후', '해야', '예전', '막',
        '없어', '왜케', 'You', 'THE', 'your', 'u', 'AN', '수가',
        'MUCH', 'FORTIFFANYANDCO', 'TIFFANYANDCO', 'ahh', 'her', 'knew', '않고', '보니', '처음',  '가사', '누나', '없음', 'if',
        '아아', '헐','', '시작', '고민', '않는', '했습니다', '손흥민', 
        '했던', '절대', '하세요', '않은', '했을', '있나요', '제대로', '보세요', '런가', '비해', '있다는', 
         '없어서', '그거', '있다면', '보일', 'T', '그거', '걸', '처음', '머리', '헤어', '고민', '뿐',
        '헤어', '패턴', '가족', '달곰', '봄', '존재', '평소', '뿐', '늘', '그대로', '팝', '긴', '성',
        '자막', '장면', '트', '입고', '가진', '직접', '기억', '선', '땐', '돈', '목', 'ELLE', '대표',  
         '달', '널', '유', '비', '식', '풀',
        '오빠', '양', '수도',  '헬륨가스', '평가', '에스', '주는', '호', '바', 
         '로서', '까르띠', '수지', '아빠', '밤', '뷰', '무드', '체크','점점', '받는', '캐', '순', 
         '대신', '발라', '받은', '올', '당시', '단', '진짜', '존나', '보고', '그냥', '카이', '이광수', '광수', '런닝맨', '❤️', '없는', '유재석', '❤', '♥', '있고', '거', 
         '내', '더', '개', '사람', '영상', '광고', '언니', '말', '뭐', '수', '생각',
        '있는', '정말', '같은', '같음', '듯', '♡', '완전', '같아', '정도', '지금', '역시', '뭔가', '입니다', '때문', '아니라',
         '함', '같은데', '해', '하는', '할', '넘', '한', '안', '했다', '보면', '데', '하고', '하면', '게', '해서', '봐도', 
         '한다', '된', '건', '요', '움', '임', '애', '하는거', '해도', '보는', '이제', '했는데', '하는데', '하는게', '같아요', 
         '합니다', '하지', '하게', '되는', 'I', '는', '난', '서', '도', '줄', '위', '분', '알', '은', '두', '번', '뒤',
         '이건', '없다', '있어요', '아니고', '있어',
        '계속', '원래', '뭘', '못', '후', '이름', '속', '욕', '옆', '하네', '아님', '그런', '된다', '있음',
        '같', '돼', 'you', '제품', '표현', 'n', '봤는데', '건가', '나오는', '가지', '저런', '보이', '고',
        '중', '사진', '댓글', '부분', '진심', '그녀', '보', '날', '겁나', '요즘', '앞', '워', '이유', '솔직히', '하며', '통해',
        '모든', '항상', '전', '기자', '다시', '오늘', '걸', '처음', '머리', '헤어', '고민', '뿐', '',
        '잘', '눈', '자체', '제일', '나도', '대', 'YG', '제발', '한번', '가장', '누가', '보러',
         '울', '입고', 'u', '트와이스', '입', '큰', '어쩜', '까', '끝', '사실', '썸넬', '젤', '기여', '미',
         '회수', '순간', '시작', '볼때',
        '패턴', '비', '제목', '막', '있는데', '수가', '헐', '없어', '해주세요', '트', '알았는데', '해야',
         '보이는', '보니', '만', '자꾸', '길이', '됨', '실제', '아주', '척', '땐', '머', 'lo', '유튜브',
        '왜케', '논란', '한편', '아닌데', '호', '얘', '몇번', '첫', '보임', '보면서', '짧은', '얼', 'xa', '남', 
         '감', '웃겨', '니', '될', '보게', '앤', '나오면', '보다가', '않고', '아닌', '위해', '무', '듣고', '싶다', '와중', '없음']
for w in add_0:
    stop_words.append(w)

# %%
add_1 = ['BLACKPINK', '리사', '지수', '로제']
for w in add_1:
    stop_words.append(w)

# %%
len(stop_words)
# Out:
# 1217

# %%
tot_je['ADFN_2'] = tot_je['ADFN_2'].str.replace('[', '').str.replace(']', '').str.replace('"', '').str.replace("'", "").str.split(', ')

# %%
a = []
for i in range(len(tot_je)):
    b = []
    for word in tot_je.loc[i, 'ADFN_2']:
        if not word in stop_words:
            b.append(word)
    a.append(b)

# %%
len(a)
# Out:
# 351

# %%
tot_je['ADFN_2'] = a

# %%
noun_adj_list = []
for i in range(len(tot_je)):
    for word in tot_je.loc[i, 'ADFN_2']:
        if word not in stop_words:
            noun_adj_list.append(word)

# %%
# # 유튜브만
# noun_adj_list = []
# for i in range(len(tot_je)):
#     if tot_je.loc[i, 'magazine'] == 'YOUTUBE':
#         for word in tot_je.loc[i, 'ADFN_2']:
#             if word not in stop_words:
#                 noun_adj_list.append(word)

# %%
# # 잡지만
# noun_adj_list = []
# for i in range(len(tot_je)):
#     if tot_je.loc[i, 'magazine'] != 'YOUTUBE':
#         for word in tot_je.loc[i, 'ADFN_2']:
#             if word not in stop_words:
#                 noun_adj_list.append(word)

# %%
noun_adj_list

# %%
word = Counter(noun_adj_list)
print(word.most_common(200))

# %%
count = Counter(noun_adj_list)

# %%
word_list = count.most_common(500)
for v in word_list:
    print(v)

# %%
top500 = pd.DataFrame(word_list)

# %%
top500.columns = ['word', 'count']

# %%
top500

# %%
top500.to_csv('./tot_jenny_top500.csv', sep='|', encoding = 'utf-8', index = False)

# %% [markdown]
# ## 워드클라우드 만들기

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.font_manager as fm

# 이용 가능한 폰트 중 '고딕'만 선별
for font in fm.fontManager.ttflist:
    if 'Gothic' in font.name:
        print(font.name, font.fname)
# Out:
# Malgun Gothic C:\WINDOWS\Fonts\malgun.ttf
# Yu Gothic C:\WINDOWS\Fonts\YuGothB.ttc
# HYGothic-Extra C:\WINDOWS\Fonts\H2GTRE.TTF
# Franklin Gothic Medium C:\WINDOWS\Fonts\framdit.ttf
# Malgun Gothic C:\Windows\Fonts\malgunbd.ttf
# Yu Gothic C:\Windows\Fonts\YuGothL.ttc
# Century Gothic C:\Windows\Fonts\GOTHIC.TTF
# Yu Gothic C:\Windows\Fonts\YuGothM.ttc
# Yu Gothic C:\WINDOWS\Fonts\YuGothR.ttc
# MS Gothic C:\WINDOWS\Fonts\msgothic.ttc
# HYGothic-Medium C:\WINDOWS\Fonts\H2GTRM.TTF
# Malgun Gothic C:\WINDOWS\Fonts\malgunsl.ttf
# Century Gothic C:\Windows\Fonts\GOTHICI.TTF
# Century Gothic C:\WINDOWS\Fonts\GOTHICBI.TTF
# Century Gothic C:\Windows\Fonts\GOTHICB.TTF
# Franklin Gothic Medium C:\WINDOWS\Fonts\framd.ttf

# %%
font_path = 'C:\WINDOWS\Fonts\malgun.ttf'

# %% [markdown]
# ### 워드클라우드 그리기

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud(font_path=font_path, background_color= '#272727', width=600, height=400, colormap = 'RdPu_r')

# %%
wc.generate_from_frequencies(dict(word_list[:100]))

plt.imshow(wc) 
plt.axis('off') 

# plt.savefig('./final_img/rose_total50.png', bbox_inches = 'tight')
plt.show()


wc.to_file('./final_img/jennie_total100.png')

# %%
tot_je.to_csv('./magazine/final/video_jenny_adfn_2.csv', sep='|', encoding = 'utf-8', index = False)
