# %%
import pandas as pd
import numpy as np

# %%
from collections import Counter

# %%
tot_l = pd.read_csv('./magazine/final/video_lisa_adfn.csv', sep='|', encoding = 'utf-8')

# %%
tot_l
# Out:
#     magazine    brand                                              title  \
# 0    YOUTUBE  YOUTUBE  BLACKPINK - 'How You Like That' LISA Concept T...
# 1    YOUTUBE  YOUTUBE  BLACKPINK - 'KILL THIS LOVE' LISA TEASER VIDEO...
# 2    YOUTUBE  YOUTUBE  BLACKPINK - 'SQUARE UP' LISA MOVING POSTER_kor...
# 3    YOUTUBE  YOUTUBE  BLACKPINK - 'THE ALBUM' LISA Concept Teaser Vi...
# 4    YOUTUBE  YOUTUBE  BLACKPINK - LISA 'Forever Young' FOCUSED CAMER...
# ..       ...      ...                                                ...
# 192        W        L                                         밀라노로 떠난 리사
# 193        W        L                                         리사의 새로운 행보
# 194        W        L                           블랙핑크X세레나 고메즈 영상통화, 협업 티징
# 195        W        L                            블랙핑크가 아이스크림 셀카를 올린 이유는?
# 196        W        L                               블랙핑크 컴백! 남다른 패션 스타일링
#
#                                              word_lisa  \
# ...

# %%
tot_l['ADFN_2'] = tot_l['ADFN']

# %%
for word in tot_l['word_lisa']:
    if '리싸' in word:
        print(word)
        print('-'*50)
# Out:
# ['아니 리사 진지한모습이 존나 개예쁘다 데....? 솔직히 몰랐는데 예쁘다 지 .. 정색하는 저 눈이 존나 도도하면서 예쁘다  웹툰에 나오는 여주갘네..', '솔직히 호랑이쌤은 배쌤같은 분 얘기하는거지 리사는 거의 초등학교 저학년 쌤들급 친절함... 진짜 착하다...', '와 리사 3개국어 미쳤네', '저건 호랑이가 아니지 가르치는 입장에서 정말 정중한거다', '딱히 호랑이 선생님 아닌데...이게 호랑이면 대체.....그냥 편집에서 효과음만 “싸아....” 하고 싸늘한 음악 넣어서 그래보임ㅋㅋ리사의 대사랑 말투만 잘 보면 그냥 잔잔하고 기본적인 선생님이네', '1:09 리사 얼굴 크기 실화냐... 뒤에 있는 사람보다 작음...', '1:22리사는 진지한데 춤이 1도 안 진지해서 너무 귀엽다ㅜㅜㅜ', 'BLACKPINK중에 제니가 좀 흔하지 않으면서 예쁘다 얼굴이라 생각햇는데 리사 저 헤어스타일 뱅앞머리 너무 예쁘다 .... 진지한모습도 예쁘다 .', 'BLACKPINK에서 사실 리사가 제일좋음...나로썬 빅뱅의 태양같은느낌...', '리사 현타 올듯.. 내가 왜 얘들을 가르치고 있어야되지 하면서.. 진심 동네 댄스아카데미보다 못한다', '리사 실물 봤었는데 진짜 카메라 잘 못 받는 거 같음 진짜 리사밖에 안 보이는데', '진짜 리사가 개사기캐 아니냐ㅋㅋㅋ 언어를 몇개를 구사하는거여... 제2외국어 배우기도 빡신데', '진지하게 일하는거 진짜 겁나 멋있다..', '저옷 리사한테 엄청 잘어울리네', '춤춰본사람들은 알텐데,,,, 저건진짜 착하고 자상한거임 ㅋㅋㅋㅋㅋ', '근데 이 영상 뭔가 엄청 중독성있음..ㅋㅋㅋ뜰때마다ㅏ계속 들어오게 됨', '1:22 리사 쿵쿵꾸구궁 하는거 너무 귀엽다 ㅠㅠ', '리사는 정말 인형인가? 얼굴크기가.....', '근데 저 방송이 무슨 상황인지는 모르겠지만 호랑이는 아닌듯 자상해보이는데? 지금 춤추는 애들 다 손동작 하나도 안맞고 서로 맞는게 하나 없는데 이정도면 보살인거지 정말ㅋㅋㅋㅋㅋ저게 A반이라는데 가르치는 입장에서 화가
# ...

# %%
tot_l['ADFN'][0][0]
# Out:
# '['

# %%
for word in tot_l['ADFN_2']:
    if "리" in word:
        print(word)
        print('-'*50)
# Out:
# ['Yorumlada', 'turk', 'cok', 'g', 'ö', 'rdum', 've', 'selamlar', 'ver', 'ı', 'yorum', '한국어', '깜박임', '다시', '봐도', '넘', '멋있당', '리사', 'BLACKPINK', '니', '닺내애', '휸', '도', '잳재넬', '래댇', '댜', '종', '댲', '지', '√®', 'T', 'ü', 'm', 'Turk', 'ı', 'sh', 'bl', 'ı', 'nk', 'lovesickgirl', 'aks', 'ı', 'n', 'yar', 'ışı', 'kazanmal', 'ı', 'y', 'ı', 'zzz', '터키어', '깜박임', '사랑', '말랐네', '갈비뼈', '보인다', '채널', '구독', '해주세요', '등록', '하신', '어머니', '만', '달러', '벌고', '평생', '행복하길', '바랍니다', 'BLACKPINK', 'ILOVE', 'YOU', '리사', '해', '요', '♡♡', '멋있다', '매력', '넘치는', '리사', '넘', '예쁘다', '요', '🤩', '와우', '리사', '완벽한', '브라보', 'Wawww', 'cloths', '리사', '사랑', '하나님', '매우', '달콤하고', '사랑', '합니다', '깜빡', '아니며', '사랑', '합니다', '와우', '리사', '멋있다', '아름다워', '미쳤지', '않고', '내', '사랑', '알', '됩니다', '아닙니다', '내', '인생', '세상', '가장', '좋은', '소녀', '입니다', '사랑', '합니다', '햇살', '굉장하다', '사랑', '해', '내', '사는', '이유', '존재', '대해', '매우', '감사합니다', '솔직히', '그녀', '내', '좋아하는', '유일한', '사람', '입니다', '리자', '사랑', '와칸', '포에버', '여버세']
# --------------------------------------------------
# ...

# %%
# 걸크러시
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'걸', '크러시", "걸크러시")
# 걸크러쉬
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'걸', '크러쉬'", "걸크러시")
# 걸크
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'걸', '크'", "걸크러시")

# 걸그룹
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'걸', '그룹'", "걸그룹")

# %%
# 글로우
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'글', '로우'", "글로우")

# %%
# 아우터
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'아우', '터'", "아우터")

# %%
# 데일리
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'데', '일리'", "데일리")

# %%
# 볼륨감
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'볼륨', '감'", "볼륨감")
# 존재감
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'존재', '감'", "존재감")
# 통일감
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'통일', '감'", "통일감")
# 예능감
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'예능', '감'", "예능감")
# 위화감
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'위화', '감'", "위화감")
# 위화감
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'거부', '감'", "거부감")
# 무게감
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'무게', '감'", "무게감")

# %%
# 스타일링
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'스타', '일링'", "스타일링")

# %%
# 캐주얼
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'캐', '주얼'", "캐주얼")

# 비쥬얼
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'비쥬', '얼'", "비주얼")
# 비주얼
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'비주', '얼'", "비주얼")

# %%
# FW / SS
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'F', 'W'", "FW")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'S', 'S'", "SS")

# %%
# 스포티
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'스포', '티'", "스포티")
# 프리티
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'프리', '티'", "프리티")

# %%
# 테일러 / 레이어
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'테일러', '드'", "테일러드")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'레이어', '드'", "레이어드")

# %%
# 하이틴
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'하이', '틴'", "하이틴")

# %%
# 눈정화 / 눈호강
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'눈', '호강'", "눈호강")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'눈', '정화'", "눈정화")

# %%
# 뚜두뚜두 
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'뚜', '두', '뚜', '두'", "뚜두뚜두")
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'뚜', '두', '뚜'", "뚜두뚜두")

# %%
# 코
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace("'코', '어스'", "코어스")

# %%
tot_l
# Out:
#     magazine    brand                                              title  \
# 0    YOUTUBE  YOUTUBE  BLACKPINK - 'How You Like That' LISA Concept T...
# 1    YOUTUBE  YOUTUBE  BLACKPINK - 'KILL THIS LOVE' LISA TEASER VIDEO...
# 2    YOUTUBE  YOUTUBE  BLACKPINK - 'SQUARE UP' LISA MOVING POSTER_kor...
# 3    YOUTUBE  YOUTUBE  BLACKPINK - 'THE ALBUM' LISA Concept Teaser Vi...
# 4    YOUTUBE  YOUTUBE  BLACKPINK - LISA 'Forever Young' FOCUSED CAMER...
# ..       ...      ...                                                ...
# 192        W        L                                         밀라노로 떠난 리사
# 193        W        L                                         리사의 새로운 행보
# 194        W        L                           블랙핑크X세레나 고메즈 영상통화, 협업 티징
# 195        W        L                            블랙핑크가 아이스크림 셀카를 올린 이유는?
# 196        W        L                               블랙핑크 컴백! 남다른 패션 스타일링
#
#                                              word_lisa  \
# ...

# %% [markdown]
# ### stopword 추가

# %%
sw_df = pd.read_csv('stopwords.csv', header=None)

# %%
sw_df.columns = ['stopword']

# %%
stop_words = []
for sw in sw_df['stopword']:
    stop_words.append(sw)

# %%
print(len(stop_words))
print(type(stop_words))
# Out:
# 675
# <class 'list'>

# %%
stop_words[-10:]
# Out:
# ['둘', '셋', '넷', '다섯', '여섯', '일곱', '여덟', '아홉', '령', '영']

# %%
add_0 = ['해', '하는', '할', '한', '영상', '했다', '뭐', '넘', '수', '정말', '그냥', '보고', '있는',
         '전소민', '공유', '양세찬', '항상', '다시', '통해', '한편', 'a', '공개', '자체', '형', '와중', '↑', '걸',
         '있습니다', 'to', '아닌데', '있는데', '보기', '하다', '곤', '없어', '대한', '싶다', '명', '민','the',
         '보니', '아는', '전', '진짜', '멤버', '잘', '모습', '발음', '제일', '기자', '데뷔', '아는', '택시', 
         '활동', '썸네일', '나도', '가사', '하네요', '길다', '보이는', '까', '없는데', '몰랐는데', '대해', 
         '보인다', '위해', '로서', '이수근', '보여', '있으면', '보다', '같네', '하자', '최수영', 'that', 
         '하며', '세찬', '않고', '됨', '오는',
        '진짜', '존나', '보고', '그냥', '카이', '이광수', '광수', '런닝맨', '❤️', '없는', '유재석', '❤', '♥', '있고', '거', 
         '내', '더', '개', '사람', '영상', '광고', '언니', '말', '뭐', '수', '생각',
        '있는', '정말', '같은', '같음', '듯', '♡', '완전', '같아', '정도', '지금', '역시', '뭔가', '입니다', '때문', '아니라',
         '함', '같은데', '해', '하는', '할', '넘', '한', '안', '했다', '보면', '데', '하고', '하면', '게', '해서', '봐도', 
         '한다', '된', '건', '요', '움', '임', '애', '하는거', '해도', '보는', '이제', '했는데', '하는데', '하는게', '같아요', 
         '합니다', '하지', '하게', '되는', 'I', '는', '난', '서', '도', '줄', '위', '분', '알', '은', '두', '번', '뒤',
         '이건', '없다', '있어요', '아니고', '있어',
        '계속', '원래', '뭘', '못', '후', '이름', '속', '욕', '옆', '하네', '아님', '그런', '된다', '있음',
        '같', '돼', 'you', '제품', '표현', 'n', '봤는데', '건가', '나오는', '가지', '저런', '보이', '고',
        '중', '사진', '댓글', '부분', '진심', '그녀', '보', '날', '겁나', '요즘', '앞', '워', '이유', '솔직히']
for w in add_0:
    stop_words.append(w)

# %%
add_1 = ['BLACKPINK', '제니', '지수', '로제', '젠']
for w in add_1:
    stop_words.append(w)

# %%
len(stop_words)
# Out:
# 895

# %%
tot_l['ADFN_2'] = tot_l['ADFN_2'].str.replace('[', '').str.replace(']', '').str.replace('"', '').str.replace("'", "").str.split(', ')

# %%
noun_adj_list = []
for i in range(len(tot_l)):
    for word in tot_l.loc[i, 'ADFN_2']:
        if word not in stop_words:
            noun_adj_list.append(word)

# %%
# # 유튜브만
# noun_adj_list = []
# for i in range(len(tot_je)):
#     if tot_je.loc[i, 'magazine'] == 'YOUTUBE':
#         for word in tot_je.loc[i, 'ADFN_2']:
#             if word not in stop_words:
#                 noun_adj_list.append(word)

# %%
# # 잡지만
# noun_adj_list = []
# for i in range(len(tot_je)):
#     if tot_je.loc[i, 'magazine'] != 'YOUTUBE':
#         for word in tot_je.loc[i, 'ADFN_2']:
#             if word not in stop_words:
#                 noun_adj_list.append(word)

# %%
noun_adj_list
# Out:
# ['Yorumlada',
#  'turk',
#  'cok',
#  'g',
#  'ö',
#  'rdum',
#  've',
#  'selamlar',
#  'ver',
#  'ı',
#  'yorum',
#  '한국어',
#  '깜박임',
#  '멋있당',
#  '리사',
#  '니',
#  '닺내애',
#  '휸',
#  '잳재넬',
#  '래댇',
#  '댜',
#  '종',
#  '댲',
#  '지',
#  '√®',
#  'T',
#  'ü',
#  'm',
#  'Turk',
#  'ı',
#  'sh',
#  'bl',
#  'ı',
#  'nk',
#  'lovesickgirl',
#  'aks',
#  'ı',
#  'yar',
#  'ışı',
#  'kazanmal',
#  'ı',
#  'y',
#  'ı',
#  'zzz',
#  '터키어',
#  '깜박임',
#  '사랑',
#  '말랐네',
#  '갈비뼈',
#  '채널',
#  '구독',
#  '해주세요',
#  '등록',
#  '하신',
#  '어머니',
#  '만',
#  '달러',
#  '벌고',
#  '평생',
#  '행복하길',
#  '바랍니다',
#  'ILOVE',
#  'YOU',
#  '리사',
#  '♡♡',
#  '멋있다',
#  '매력',
#  '넘치는',
#  '리사',
#  '예쁘다',
#  '🤩',
#  '와우',
#  '리사',
#  '완벽한',
#  '브라보',
#  'Wawww',
#  'cloths',
#  '리사',
#  '사랑',
#  '하나님',
#  '매우',
#  '달콤하고',
#  '사랑',
#  '깜빡',
#  '아니며',
#  '사랑',
#  '와우',
#  '리사',
#  '멋있다',
#  '아름다워',
#  '미쳤지',
#  '사랑',
#  '됩니다',
#  '아닙니다',
#  '인생',
#  '세상',
#  '가장',
#  '좋은',
#  '소녀',
#  '사랑',
#  '햇살',
#  '굉장하다',
#  '사랑',
# ...

# %%
word = Counter(noun_adj_list)
print(word.most_common(200))
# Out:
# [('리사', 3570), ('예쁘다', 676), ('귀엽다', 543), ('춤', 478), ('사랑', 319), ('랩', 275), ('한국', 255), ('영어', 247), ('노래', 223), ('얼굴', 195), ('무대', 192), ('아이돌', 178), ('매력', 172), ('태국', 170), ('한국어', 155), ('중국', 153), ('한국인', 145), ('패션', 139), ('표정', 132), ('비율', 131), ('멋있다', 129), ('실력', 124), ('느낌', 123), ('외국인', 117), ('팬', 107), ('여자', 100), ('블랙', 98), ('머리', 92), ('눈', 91), ('최고', 90), ('연습생', 88), ('호랑이', 86), ('컬러', 84), ('예능', 79), ('인기', 78), ('스타일', 76), ('룩', 75), ('가장', 74), ('프로', 71), ('다리', 71), ('앞머리', 69), ('좋은', 68), ('단발', 67), ('걸그룹', 67), ('태국인', 67), ('컬렉션', 67), ('외국', 66), ('CELINE', 65), ('인형', 64), ('그룹', 64), ('브랜드', 64), ('YG', 62), ('모델', 61), ('좋다', 61), ('대박', 60), ('노력', 60), ('카리스마', 60), ('짱', 60), ('쌤', 59), ('한국말', 58), ('처음', 57), ('간지', 56), ('선생님', 56), ('스타', 55), ('참석', 55), ('우리나라', 53), ('세계', 53), ('컴백', 53), ('봄', 53), ('해외', 52), ('프라다', 52), ('좋아요', 51), ('포인트', 51), ('매치', 51), ('미쳤다', 50), ('연습', 50), ('옷', 49), ('성격', 48), ('목소리', 48), (
# ...

# %%
count = Counter(noun_adj_list)

# %%
word_list = count.most_common(500)
for v in word_list:
    print(v)
# Out:
# ('리사', 3570)
# ('예쁘다', 676)
# ('귀엽다', 543)
# ('춤', 478)
# ('사랑', 319)
# ('랩', 275)
# ('한국', 255)
# ('영어', 247)
# ('노래', 223)
# ('얼굴', 195)
# ('무대', 192)
# ('아이돌', 178)
# ('매력', 172)
# ('태국', 170)
# ('한국어', 155)
# ('중국', 153)
# ('한국인', 145)
# ('패션', 139)
# ('표정', 132)
# ('비율', 131)
# ('멋있다', 129)
# ('실력', 124)
# ('느낌', 123)
# ('외국인', 117)
# ('팬', 107)
# ('여자', 100)
# ('블랙', 98)
# ('머리', 92)
# ('눈', 91)
# ('최고', 90)
# ('연습생', 88)
# ('호랑이', 86)
# ('컬러', 84)
# ('예능', 79)
# ('인기', 78)
# ('스타일', 76)
# ('룩', 75)
# ('가장', 74)
# ('프로', 71)
# ('다리', 71)
# ('앞머리', 69)
# ('좋은', 68)
# ('단발', 67)
# ('걸그룹', 67)
# ('태국인', 67)
# ('컬렉션', 67)
# ('외국', 66)
# ('CELINE', 65)
# ('인형', 64)
# ('그룹', 64)
# ('브랜드', 64)
# ('YG', 62)
# ('모델', 61)
# ('좋다', 61)
# ('대박', 60)
# ('노력', 60)
# ('카리스마', 60)
# ('짱', 60)
# ('쌤', 59)
# ('한국말', 58)
# ('처음', 57)
# ('간지', 56)
# ('선생님', 56)
# ('스타', 55)
# ('참석', 55)
# ('우리나라', 53)
# ('세계', 53)
# ('컴백', 53)
# ('봄', 53)
# ('해외', 52)
# ('프라다', 52)
# ('좋아요', 51)
# ('포인트', 51)
# ...

# %%
top500 = pd.DataFrame(word_list)

# %%
top500.columns = ['word', 'count']

# %%
top500
# Out:
#     word  count
# 0     리사   3570
# 1    예쁘다    676
# 2    귀엽다    543
# 3      춤    478
# 4     사랑    319
# ..   ...    ...
# 495   허리     16
# 496   칭찬     16
# 497   능력     16
# 498   국적     16
# 499   어깨     16
#
# [500 rows x 2 columns]

# %%
top500.to_csv('./tot_lisa_top500.csv', sep='|', encoding = 'utf-8', index = False)

# %% [markdown]
# ## 워드클라우드 만들기

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.font_manager as fm

# 이용 가능한 폰트 중 '고딕'만 선별
for font in fm.fontManager.ttflist:
    if 'Gothic' in font.name:
        print(font.name, font.fname)
# Out:
# Malgun Gothic C:\WINDOWS\Fonts\malgun.ttf
# Yu Gothic C:\WINDOWS\Fonts\YuGothB.ttc
# HYGothic-Extra C:\WINDOWS\Fonts\H2GTRE.TTF
# Franklin Gothic Medium C:\WINDOWS\Fonts\framdit.ttf
# Malgun Gothic C:\Windows\Fonts\malgunbd.ttf
# Yu Gothic C:\Windows\Fonts\YuGothL.ttc
# Century Gothic C:\Windows\Fonts\GOTHIC.TTF
# Yu Gothic C:\Windows\Fonts\YuGothM.ttc
# Yu Gothic C:\WINDOWS\Fonts\YuGothR.ttc
# MS Gothic C:\WINDOWS\Fonts\msgothic.ttc
# HYGothic-Medium C:\WINDOWS\Fonts\H2GTRM.TTF
# Malgun Gothic C:\WINDOWS\Fonts\malgunsl.ttf
# Century Gothic C:\Windows\Fonts\GOTHICI.TTF
# Century Gothic C:\WINDOWS\Fonts\GOTHICBI.TTF
# Century Gothic C:\Windows\Fonts\GOTHICB.TTF
# Franklin Gothic Medium C:\WINDOWS\Fonts\framd.ttf

# %%
font_path = 'C:\WINDOWS\Fonts\malgun.ttf'

# %% [markdown]
# ### 워드클라우드 그리기

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud(font_path=font_path, background_color="white", width=600, height=400)

# %%
wc.generate_from_frequencies(dict(word_list))

plt.imshow(wc) 
plt.axis('off') 
plt.show()


wc.to_file('lisa_total.png')

# %%
tot_l.to_csv('./magazine/final/video_lisa_adfn_2.csv', sep='|', encoding = 'utf-8', index = False)
