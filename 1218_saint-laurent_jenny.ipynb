# %%
import pandas as pd
import numpy as np
import re
import networkx as nx
import matplotlib.pyplot as plt

# %%
from collections import Counter

# %% [markdown]
# ## 생로랑

# %%
mag_s = pd.read_csv('./magazine/final/magazine_s_stickword.csv', sep ='|', encoding = 'utf-8')

# %%
mag_s
# Out:
#      magazine brand                    title  \
# 0           A   YSL         깊게 뿌리내리기 위하여, 수영
# 1           A   YSL                    코트 체크
# 2           A   YSL                데님이여 영원하라
# 3           A   YSL                 안경 하세요?!
# 4           A   YSL  가을의 정석, 트렌치 코트 입는 법 8가지
# ...       ...   ...                      ...
# 1269        W   YSL                   어깨로말해요
# 1270        W   YSL                    W해시태그
# 1271        W   YSL                  따로 또 같이
# 1272        W   YSL                두려움 없는 반란
# 1273        W   YSL                너도 나도 베트멍
#
#                                                    link        date  \
# 0     http://www.allurekorea.com/2020/11/20/%ea%b9%8...  2020-11-20
# 1     http://www.allurekorea.com/2020/11/10/%ec%bd%9...  2020-10-26
# 2     http://www.allurekorea.com/2020/11/06/%eb%8d%b...  2020-10-26
# 3     http://www.allurekorea.com/2020/10/29/%ec%95%8...  2020-10-23
# 4     http://www.allurekorea.com/2020/10/11/%ea%b0%8...  2020-09-27
# ...

# %%
mag_s['word'] = mag_s['word_laurent']

# %%
mag_S = mag_s[['magazine', 'brand', 'title', 'word', 'ADFN', 'ADFN_2']]

# %%
len(mag_S)
# Out:
# 1274

# %% [markdown]
# ### 3

# %%
idx3 = []
for i in range(len(mag_S)):
    if i % 3 == 0 :
        idx3.append(i)

# %%
mag_S3 = mag_S.loc[idx3]

# %%
mag_S3.reset_index(drop = True, inplace = True)

# %%
len(mag_S3)
# Out:
# 425

# %% [markdown]
# ## 제니

# %% [markdown]
# ### 제니 (유튜브 + 매거진)

# %%
tot_je = pd.read_csv('./magazine/final/video_jenny_adfn_2.csv', encoding = 'utf-8', sep = '|')

# %%
tot_je['word'] = tot_je['word_jenny']

# %%
tot_JE = tot_je[['magazine', 'brand', 'title', 'word', 'ADFN', 'ADFN_2']]

# %%
len(tot_JE)
# Out:
# 351

# %% [markdown]
# ### 생로랑 + 제니

# %%
S3JE = pd.concat([mag_S3, tot_JE])

# %%
S3JE.reset_index(drop = True, inplace = True)

# %%
S3JE.to_csv('./magazine/final/S3JE.csv', sep = '|', encoding = 'utf-8', index = False)

# %%
len(S3JE)
# Out:
# 776

# %% [markdown]
# ## stopword 추가

# %%
sw_df = pd.read_csv('stopwords.csv', header=None)

# %%
sw_df.columns = ['stopword']

# %%
stop_words = []
for sw in sw_df['stopword']:
    stop_words.append(sw)

# %%
print(len(stop_words))
print(type(stop_words))
# Out:
# 675
# <class 'list'>

# %%
stop_words[-10:]
# Out:
# ['둘', '셋', '넷', '다섯', '여섯', '일곱', '여덟', '아홉', '령', '영']

# %%
add_0 = ['진짜', '존나', '보고', '그냥', '카이', '이광수', '광수', '런닝맨', '❤️', '없는', '유재석', '❤', '♥', '있고', '거', 
         '내', '더', '개', '사람', '영상', '광고', '언니', '말', '뭐', '수', '생각',
        '있는', '정말', '같은', '같음', '듯', '♡', '완전', '같아', '정도', '지금', '역시', '뭔가', '입니다', '때문', '아니라',
         '함', '같은데', '해', '하는', '할', '넘', '한', '안', '했다', '보면', '데', '하고', '하면', '게', '해서', '봐도', 
         '한다', '된', '건', '요', '움', '임', '애', '하는거', '해도', '보는', '이제', '했는데', '하는데', '하는게', '같아요', 
         '합니다', '하지', '하게', '되는', 'I', '는', '난', '서', '도', '줄', '위', '분', '알', '은', '두', '번', '뒤',
         '이건', '없다', '있어요', '아니고', '있어', 
        '계속', '원래', '뭘', '못', '후', '이름', '속', '욕', '옆', '하네', '아님', '그런', '된다', '있음',
        '같', '돼', 'you', '제품', '표현', 'n', '봤는데', '건가', '나오는', '가지', '저런', '보이', '고',
        '중', '사진', '댓글', '부분', '진심', '그녀', '보', '날', '겁나', '요즘', '앞', '워', '이유', '솔직히', '하며', '통해',
        '모든', '항상', '전', '기자', '다시', '오늘', '↑', '이자', '대해',
        '링', '한편']
for w in add_0:
    stop_words.append(w)

# %%
add_1 = ['BLACKPINK', '리사', '지수', '로제']
for w in add_1:
    stop_words.append(w)

# %%
len(stop_words)
# Out:
# 827

# %%
S3JE['ADFN_2'] = S3JE['ADFN_2'].str.replace('[', '').str.replace(']', '').str.replace('"', '').str.replace("'", "").str.split(', ')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-063459787adf> in <module>
# ----> 1 S3JE['ADFN_2'] = S3JE['ADFN_2'].str.replace('[', '').str.replace(']', '').str.replace('"', '').str.replace("'", "").str.split(', ')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
# ...

# %%
noun_adj_list = []
for i in range(len(S3JE)):
    for word in S3JE.loc[i, 'ADFN_2']:
        if word not in stop_words:
            noun_adj_list.append(word)

# %%
word = Counter(noun_adj_list)
print(word.most_common(200))
# Out:
# [('제니', 9276), ('귀엽다', 2144), ('예쁘다', 1817), ('사랑', 844), ('LAURENT', 799), ('얼굴', 687), ('패션', 492), ('노래', 490), ('무대', 485), ('매력', 447), ('옷', 420), ('잘', 410), ('아이돌', 381), ('스타일', 371), ('젠득', 321), ('팬', 313), ('여자', 309), ('브랜드', 289), ('CHANEL', 289), ('실력', 284), ('느낌', 280), ('영어', 270), ('컬러', 254), ('눈', 242), ('걸', 240), ('앞머리', 239), ('처음', 236), ('컬렉션', 229), ('머리', 227), ('예능', 209), ('랩', 207), ('최고', 201), ('헤어', 198), ('모습', 198), ('춤', 194), ('모델', 190), ('블랙', 187), ('분위기', 186), ('목소리', 182), ('표정', 181), ('멤버', 178), ('고급', 175), ('좋은', 173), ('팬츠', 172), ('공주', 172), ('발음', 172), ('자체', 171), ('연예인', 171), ('쇼', 163), ('세상', 163), ('라이브', 163), ('디자이너', 162), ('치마', 162), ('의상', 157), ('한국', 157), ('룩', 154), ('재킷', 153), ('그룹', 151), ('입덕', 149), ('드레스', 148), ('여성', 147), ('포인트', 146), ('ANTHONY', 142), ('인간', 142), ('제일', 139), ('좋다', 137), ('썸네일', 133), ('스타일링', 131), ('애기', 130), ('HEDI', 129), ('연출', 128), ('레전드', 127), ('레드', 126), ('봄', 126), ('마음', 
# ...

# %%
count = Counter(noun_adj_list)

# %%
word_list = count.most_common(500)
for v in word_list:
    print(v)
# Out:
# ('제니', 9276)
# ('귀엽다', 2144)
# ('예쁘다', 1817)
# ('사랑', 844)
# ('LAURENT', 799)
# ('얼굴', 687)
# ('패션', 492)
# ('노래', 490)
# ('무대', 485)
# ('매력', 447)
# ('옷', 420)
# ('잘', 410)
# ('아이돌', 381)
# ('스타일', 371)
# ('젠득', 321)
# ('팬', 313)
# ('여자', 309)
# ('브랜드', 289)
# ('CHANEL', 289)
# ('실력', 284)
# ('느낌', 280)
# ('영어', 270)
# ('컬러', 254)
# ('눈', 242)
# ('걸', 240)
# ('앞머리', 239)
# ('처음', 236)
# ('컬렉션', 229)
# ('머리', 227)
# ('예능', 209)
# ('랩', 207)
# ('최고', 201)
# ('헤어', 198)
# ('모습', 198)
# ('춤', 194)
# ('모델', 190)
# ('블랙', 187)
# ('분위기', 186)
# ('목소리', 182)
# ('표정', 181)
# ('멤버', 178)
# ('고급', 175)
# ('좋은', 173)
# ('팬츠', 172)
# ('공주', 172)
# ('발음', 172)
# ('자체', 171)
# ('연예인', 171)
# ('쇼', 163)
# ('세상', 163)
# ('라이브', 163)
# ('디자이너', 162)
# ('치마', 162)
# ('의상', 157)
# ('한국', 157)
# ('룩', 154)
# ('재킷', 153)
# ('그룹', 151)
# ('입덕', 149)
# ('드레스', 148)
# ('여성', 147)
# ('포인트', 146)
# ('ANTHONY', 142)
# ('인간', 142)
# ('제일', 139)
# ('좋다', 137)
# ('썸네일', 133)
# ('스타일링', 131)
# ('애기', 130)
# ...

# %%
top500 = pd.DataFrame(word_list)

# %%
top500.columns = ['word', 'count']

# %%
top500.to_csv('./S3JE_top500.csv', sep='|', encoding = 'utf-8', index = False)

# %% [markdown]
# ## 워드클라우드 만들기

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.font_manager as fm

# 이용 가능한 폰트 중 '고딕'만 선별
for font in fm.fontManager.ttflist:
    if 'Gothic' in font.name:
        print(font.name, font.fname)
# Out:
# Malgun Gothic C:\WINDOWS\Fonts\malgun.ttf
# Yu Gothic C:\WINDOWS\Fonts\YuGothB.ttc
# HYGothic-Extra C:\WINDOWS\Fonts\H2GTRE.TTF
# Franklin Gothic Medium C:\WINDOWS\Fonts\framdit.ttf
# Malgun Gothic C:\Windows\Fonts\malgunbd.ttf
# Yu Gothic C:\Windows\Fonts\YuGothL.ttc
# Century Gothic C:\Windows\Fonts\GOTHIC.TTF
# Yu Gothic C:\Windows\Fonts\YuGothM.ttc
# Yu Gothic C:\WINDOWS\Fonts\YuGothR.ttc
# MS Gothic C:\WINDOWS\Fonts\msgothic.ttc
# HYGothic-Medium C:\WINDOWS\Fonts\H2GTRM.TTF
# Malgun Gothic C:\WINDOWS\Fonts\malgunsl.ttf
# Century Gothic C:\Windows\Fonts\GOTHICI.TTF
# Century Gothic C:\WINDOWS\Fonts\GOTHICBI.TTF
# Century Gothic C:\Windows\Fonts\GOTHICB.TTF
# Franklin Gothic Medium C:\WINDOWS\Fonts\framd.ttf

# %%
font_path = 'C:\WINDOWS\Fonts\malgun.ttf'

# %% [markdown]
# ### 워드클라우드 그리기

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud(font_path=font_path, background_color="white", width=600, height=400)

# %%
wc.generate_from_frequencies(dict(word_list))

plt.imshow(wc) 
plt.axis('off') 
plt.show()


wc.to_file('S3JE.png')

# %%
S3JE.to_csv('./magazine/final/S3JE_adfn_2.csv', sep='|', encoding = 'utf-8', index = False)
